# %% [markdown]
# # Calibration Tutorial - Fort Peck, MT - Unirrigated Flux Plot
#
# ## Step 2: Calibrate with PEST++
#
# Now we see if we can improve the model's performance through calibration.
#
# ### PEST++ Resources
#
# PEST++ has excellent documentation covering both theory and practice:
#
# 1. **The PEST Manual 4th Ed.** (Doherty, 2002): https://www.epa.gov/sites/default/files/documents/PESTMAN.PDF
# 2. **GMDSI tutorial notebooks**: https://github.com/gmdsi/GMDSI_notebooks
# 3. **PEST++ User's Manual**: https://github.com/usgs/pestpp/blob/master/documentation/pestpp_users_manual.md
# 4. **PEST Book** (Doherty, 2015): https://pesthomepage.org/pest-book
#
# **Note:** We use SSEBop ETf and SNODAS SWE for calibration - not flux observations. The flux data is reserved for validation only.

# %% [markdown]
# ### PEST++ Installation
#
# Install PEST++ via conda-forge (recommended):
#
# ```bash
# conda install conda-forge::pestpp
# ```
#
# This installs `pestpp-ies` and other PEST++ tools directly into your conda environment. Verify the installation:
#
# ```bash
# pestpp-ies --version
# ```
#
# **Alternative:** For manual installation from source, see the [PEST++ GitHub releases](https://github.com/usgs/pestpp/releases).

# %%
import os
import sys

root = os.path.abspath('../..')
sys.path.append(root)

from swimrs.container import SwimContainer
from swimrs.calibrate.pest_builder import PestBuilder
from swimrs.swim.config import ProjectConfig
from swimrs.calibrate.run_pest import run_pst
# Out:
# /home/dgketchum/miniconda/envs/swim/lib/python3.11/site-packages/pyemu/__init__.py:37: UserWarning: Failed to import legacy module. May impact ability to access older methods.ModuleNotFoundError No module named 'flopy'

# %% [markdown]
# ## 1. Load Configuration
#
# Load the project configuration and prepare paths.

# %%
project = '2_Fort_Peck'
project_ws = os.path.abspath('.')

config_path = os.path.join(project_ws, '2_Fort_Peck.toml')

config = ProjectConfig()
config.read_config(config_path, project_ws)

# %% [markdown]
# ## 2. Generate Observation Files
#
# PEST++ needs observation files (ETf and SWE) to compare against model predictions. We export these from the SwimContainer built in the data preparation step.
#
# The export creates per-field numpy files:
# - `obs_etf_{field_id}.np`: ETf observations with irrigation mask switching
# - `obs_swe_{field_id}.np`: SWE observations from SNODAS

# %%
# Open container for observations export and PEST++ setup
container_path = os.path.join(project_ws, 'data', f'{project}.swim')
container = SwimContainer.open(container_path, mode='r')

# Export observation files for PEST++ calibration
# Note: obs_folder is set to {pest_run_dir}/obs in the TOML config
obs_dir = os.path.join(project_ws, 'data', 'pestrun', 'obs')
os.makedirs(obs_dir, exist_ok=True)

container.export.observations(
    output_dir=obs_dir,
    etf_model='ssebop',
    masks=('irr', 'inv_irr'),
    irr_threshold=0.1,
)
print(f"Observation files written to {obs_dir}")
# Out:
# Observation files written to /home/dgketchum/code/swim-rs/examples/2_Fort_Peck/data/pestrun/obs

# %% [markdown]
# ## 3. Build PEST++ Control Files
#
# The `PestBuilder` class sets up everything needed for PEST++ calibration:
#
# ### Calibration Loop
# 1. Initialize model with initial parameter values
# 2. Run model, write results
# 3. Compare results to observations (ETf, SWE)
# 4. Propose new parameters
# 5. Repeat until convergence
#
# ### Tunable Parameters
# SWIM uses 8 tunable parameters:
# - **Soil water:** `aw` (available water), `rew` (readily evaporable water), `tew` (total evaporable water)
# - **NDVI-Kcb relationship:** `ndvi_alpha`, `ndvi_beta`
# - **Stress threshold:** `mad` (management allowable depletion)
# - **Snow melt:** `swe_alpha`, `swe_beta`

# %%
py_script = os.path.join(project_ws, 'custom_forward_run.py')

# Pass container to PestBuilder for ETf/SWE data access
builder = PestBuilder(config, container=container, use_existing=False, python_script=py_script)

# %% [markdown]
# ### Build the .pst Control File
#
# The `build_pest()` method:
# - Copies project files to a `pest/` directory
# - Creates the `.pst` control file
# - Sets up parameter templates (`.tpl`) and instruction files (`.ins`)
#
# **Note:** ETf observations are sparse (only on satellite capture dates). The PEST builder automatically assigns weight 1.0 to valid observations and weight 0.0 to missing dates, ensuring we only calibrate against actual satellite captures.

# %%
# Build the pest control file
# WARNING: This will erase any existing pest directory!
builder.build_pest(target_etf=config.etf_target_model, members=config.etf_ensemble_members)
# Out:
# 2026-01-14 19:46:36.467630 starting: opening PstFrom.log for logging
# 2026-01-14 19:46:36.467955 starting PstFrom process
# 2026-01-14 19:46:36.467997 starting: setting up dirs
# 2026-01-14 19:46:36.468148 starting: removing existing new_d '/home/dgketchum/code/swim-rs/examples/2_Fort_Peck/data/pestrun/pest'
# 2026-01-14 19:46:36.478886 finished: removing existing new_d '/home/dgketchum/code/swim-rs/examples/2_Fort_Peck/data/pestrun/pest' took: 0:00:00.010738
# 2026-01-14 19:46:36.478953 starting: copying original_d '/home/dgketchum/code/swim-rs/examples/2_Fort_Peck/data/pestrun' to new_d '/home/dgketchum/code/swim-rs/examples/2_Fort_Peck/data/pestrun/pest'
# 2026-01-14 19:46:36.480267 finished: copying original_d '/home/dgketchum/code/swim-rs/examples/2_Fort_Peck/data/pestrun' to new_d '/home/dgketchum/code/swim-rs/examples/2_Fort_Peck/data/pestrun/pest' took: 0:00:00.001314
# 2026-01-14 19:46:36.480490 finished: setting up dirs took: 0:00:00.012493
# 2026-01-14 19:46:36.480631 starting: adding constant type m style parameters for file(s) ['params.csv']
# 2026-01-14 19:46:36.480736 starting: loading list-style /home/dgketchum/code/swim-rs/examples/2_Fort_Peck/data/pestrun/pest/params.csv
# 2026-01-14 19:46:36.480796 starting: reading list-style file: /home/dgketchum/code/swim-rs/examples/2_Fort_Peck/data/pestrun/pest/params.csv
# 2026-01-14 19:46:36.482784 finished: reading list-style file: /home/dgketchum/code/swim-rs/examples/2_Fort_Peck/data/pestrun/pest/params.csv took: 0:00:00.001988
# 2026-01-14 19:46:36.482949 loaded list-style '/home/dgketchum/code/swim-rs/examples/2_Fort_Peck/data/pestrun/pest/params.csv' of shape (9, 3)
# 2026-01-14 19:46:36.485091 finished: loading list-style /home/dgketchum/code/swim-rs/examples/2_Fort_Peck/data/pestrun/pest/params.csv took: 0:00:00.004355
# 2026-01-14 19:46:36.485201 starting: writing list-style template file '/home/dgketchum/code/swim-rs/examples/2_Fort_Peck/data/pestrun/pest/p_aw_US-FPe_0_constant.csv.tpl'
# 2026-01-14 19:46:36.496545 finished: writing list-style template file '/home/dgketchum/code/swim-rs/examples/2_Fort_Peck/data/pestrun/pest/p_aw_US-FPe_0_constant.csv.tpl' took: 0:00:00.011344
# 2026-01-14 19:46:36.500035 finished: adding constant type m style parameters for file(s) ['params.csv'] took: 0:00:00.019404
# 2026-01-14 19:46:36.500339 starting: adding constant type m style parameters for file(s) ['params.csv']
# 2026-01-14 19:46:36.500426 starting: loading list-style /home/dgketchum/code/swim-rs/examples/2_Fort_Peck/data/pestrun/pest/params.csv
# 2026-01-14 19:46:36.500483 starting: reading list-style file: /home/dgketchum/code/swim-rs/examples/2_Fort_Peck/data/pestrun/pest/params.csv
# 2026-01-14 19:46:36.501523 finished: reading list-style file: /home/dgketchum/code/swim-rs/examples/2_Fort_Peck/data/pestrun/pest/params.csv took: 0:00:00.001040
# 2026-01-14 19:46:36.501605 loaded list-style '/home/dgketchum/code/swim-rs/examples/2_Fort_Peck/data/pestrun/pest/params.csv' of shape (9, 3)
# 2026-01-14 19:46:36.502962 finished: loading list-style /home/dgketchum/code/swim-rs/examples/2_Fort_Peck/data/pestrun/pest/params.csv took: 0:00:00.002536
# 2026-01-14 19:46:36.503058 starting: writing list-style template file '/home/dgketchum/code/swim-rs/examples/2_Fort_Peck/data/pestrun/pest/p_ks_alpha_US-FPe_0_constant.csv.tpl'
# 2026-01-14 19:46:36.511208 finished: writing list-style template file '/home/dgketchum/code/swim-rs/examples/2_Fort_Peck/data/pestrun/pest/p_ks_alpha_US-FPe_0_constant.csv.tpl' took: 0:00:00.008150
# 2026-01-14 19:46:36.514254 finished: adding constant type m style parameters for file(s) ['params.csv'] took: 0:00:00.013915
# 2026-01-14 19:46:36.514361 starting: adding constant type m style parameters for file(s) ['params.csv']
# 2026-01-14 19:46:36.514436 starting: loading list-style /home/dgketchum/code/swim-rs/examples/2_Fort_Peck/data/pestrun/pest/params.csv
# 2026-01-14 19:46:36.514488 starting: reading list-style file: /home/dgketchum/code/swim-rs/examples/2_Fort_Peck/data/pestrun/pest/params.csv
# 2026-01-14 19:46:36.515422 finished: reading list-style file: /home/dgketchum/code/swim-rs/examples/2_Fort_Peck/data/pestrun/pest/params.csv took: 0:00:00.000934
# 2026-01-14 19:46:36.515518 loaded list-style '/home/dgketchum/code/swim-rs/examples/2_Fort_Peck/data/pestrun/pest/params.csv' of shape (9, 3)
# 2026-01-14 19:46:36.516772 finished: loading list-style /home/dgketchum/code/swim-rs/examples/2_Fort_Peck/data/pestrun/pest/params.csv took: 0:00:00.002336
# 2026-01-14 19:46:36.516866 starting: writing list-style template file '/home/dgketchum/code/swim-rs/examples/2_Fort_Peck/data/pestrun/pest/p_kr_alpha_US-FPe_0_constant.csv.tpl'
# 2026-01-14 19:46:36.524684 finished: writing list-style template file '/home/dgketchum/code/swim-rs/examples/2_Fort_Peck/data/pestrun/pest/p_kr_alpha_US-FPe_0_constant.csv.tpl' took: 0:00:00.007818
# 2026-01-14 19:46:36.527751 finished: adding constant type m style parameters for file(s) ['params.csv'] took: 0:00:00.013390
# 2026-01-14 19:46:36.527859 starting: adding constant type m style parameters for file(s) ['params.csv']
# 2026-01-14 19:46:36.527935 starting: loading list-style /home/dgketchum/code/swim-rs/examples/2_Fort_Peck/data/pestrun/pest/params.csv
# 2026-01-14 19:46:36.527987 starting: reading list-style file: /home/dgketchum/code/swim-rs/examples/2_Fort_Peck/data/pestrun/pest/params.csv
# 2026-01-14 19:46:36.528955 finished: reading list-style file: /home/dgketchum/code/swim-rs/examples/2_Fort_Peck/data/pestrun/pest/params.csv took: 0:00:00.000968
# 2026-01-14 19:46:36.529038 loaded list-style '/home/dgketchum/code/swim-rs/examples/2_Fort_Peck/data/pestrun/pest/params.csv' of shape (9, 3)
# 2026-01-14 19:46:36.530255 finished: loading list-style /home/dgketchum/code/swim-rs/examples/2_Fort_Peck/data/pestrun/pest/params.csv took: 0:00:00.002320
# 2026-01-14 19:46:36.530341 starting: writing list-style template file '/home/dgketchum/code/swim-rs/examples/2_Fort_Peck/data/pestrun/pest/p_ndvi_k_US-FPe_0_constant.csv.tpl'
# 2026-01-14 19:46:36.538248 finished: writing list-style template file '/home/dgketchum/code/swim-rs/examples/2_Fort_Peck/data/pestrun/pest/p_ndvi_k_US-FPe_0_constant.csv.tpl' took: 0:00:00.007907
# 2026-01-14 19:46:36.541149 finished: adding constant type m style parameters for file(s) ['params.csv'] took: 0:00:00.013290
# 2026-01-14 19:46:36.541254 starting: adding constant type m style parameters for file(s) ['params.csv']
# 2026-01-14 19:46:36.541325 starting: loading list-style /home/dgketchum/code/swim-rs/examples/2_Fort_Peck/data/pestrun/pest/params.csv
# 2026-01-14 19:46:36.541374 starting: reading list-style file: /home/dgketchum/code/swim-rs/examples/2_Fort_Peck/data/pestrun/pest/params.csv
# 2026-01-14 19:46:36.542251 finished: reading list-style file: /home/dgketchum/code/swim-rs/examples/2_Fort_Peck/data/pestrun/pest/params.csv took: 0:00:00.000877
# 2026-01-14 19:46:36.542329 loaded list-style '/home/dgketchum/code/swim-rs/examples/2_Fort_Peck/data/pestrun/pest/params.csv' of shape (9, 3)
# 2026-01-14 19:46:36.543505 finished: loading list-style /home/dgketchum/code/swim-rs/examples/2_Fort_Peck/data/pestrun/pest/params.csv took: 0:00:00.002180
# 2026-01-14 19:46:36.543591 starting: writing list-style template file '/home/dgketchum/code/swim-rs/examples/2_Fort_Peck/data/pestrun/pest/p_ndvi_0_US-FPe_0_constant.csv.tpl'
# 2026-01-14 19:46:36.551163 finished: writing list-style template file '/home/dgketchum/code/swim-rs/examples/2_Fort_Peck/data/pestrun/pest/p_ndvi_0_US-FPe_0_constant.csv.tpl' took: 0:00:00.007572
# 2026-01-14 19:46:36.553974 finished: adding constant type m style parameters for file(s) ['params.csv'] took: 0:00:00.012720
# 2026-01-14 19:46:36.554074 starting: adding constant type m style parameters for file(s) ['params.csv']
# 2026-01-14 19:46:36.554142 starting: loading list-style /home/dgketchum/code/swim-rs/examples/2_Fort_Peck/data/pestrun/pest/params.csv
# 2026-01-14 19:46:36.554188 starting: reading list-style file: /home/dgketchum/code/swim-rs/examples/2_Fort_Peck/data/pestrun/pest/params.csv
# 2026-01-14 19:46:36.555012 finished: reading list-style file: /home/dgketchum/code/swim-rs/examples/2_Fort_Peck/data/pestrun/pest/params.csv took: 0:00:00.000824
# 2026-01-14 19:46:36.555086 loaded list-style '/home/dgketchum/code/swim-rs/examples/2_Fort_Peck/data/pestrun/pest/params.csv' of shape (9, 3)
# 2026-01-14 19:46:36.556258 finished: loading list-style /home/dgketchum/code/swim-rs/examples/2_Fort_Peck/data/pestrun/pest/params.csv took: 0:00:00.002116
# 2026-01-14 19:46:36.556344 starting: writing list-style template file '/home/dgketchum/code/swim-rs/examples/2_Fort_Peck/data/pestrun/pest/p_mad_US-FPe_0_constant.csv.tpl'
# 2026-01-14 19:46:36.564002 finished: writing list-style template file '/home/dgketchum/code/swim-rs/examples/2_Fort_Peck/data/pestrun/pest/p_mad_US-FPe_0_constant.csv.tpl' took: 0:00:00.007658
# 2026-01-14 19:46:36.566821 finished: adding constant type m style parameters for file(s) ['params.csv'] took: 0:00:00.012747
# 2026-01-14 19:46:36.566921 starting: adding constant type m style parameters for file(s) ['params.csv']
# 2026-01-14 19:46:36.566988 starting: loading list-style /home/dgketchum/code/swim-rs/examples/2_Fort_Peck/data/pestrun/pest/params.csv
# 2026-01-14 19:46:36.567035 starting: reading list-style file: /home/dgketchum/code/swim-rs/examples/2_Fort_Peck/data/pestrun/pest/params.csv
# 2026-01-14 19:46:36.569618 finished: reading list-style file: /home/dgketchum/code/swim-rs/examples/2_Fort_Peck/data/pestrun/pest/params.csv took: 0:00:00.002583
# 2026-01-14 19:46:36.569882 loaded list-style '/home/dgketchum/code/swim-rs/examples/2_Fort_Peck/data/pestrun/pest/params.csv' of shape (9, 3)
# 2026-01-14 19:46:36.573890 finished: loading list-style /home/dgketchum/code/swim-rs/examples/2_Fort_Peck/data/pestrun/pest/params.csv took: 0:00:00.006902
# 2026-01-14 19:46:36.574164 starting: writing list-style template file '/home/dgketchum/code/swim-rs/examples/2_Fort_Peck/data/pestrun/pest/p_swe_alpha_US-FPe_0_constant.csv.tpl'
# 2026-01-14 19:46:36.593240 finished: writing list-style template file '/home/dgketchum/code/swim-rs/examples/2_Fort_Peck/data/pestrun/pest/p_swe_alpha_US-FPe_0_constant.csv.tpl' took: 0:00:00.019076
# 2026-01-14 19:46:36.597685 finished: adding constant type m style parameters for file(s) ['params.csv'] took: 0:00:00.030764
# 2026-01-14 19:46:36.597851 starting: adding constant type m style parameters for file(s) ['params.csv']
# 2026-01-14 19:46:36.597969 starting: loading list-style /home/dgketchum/code/swim-rs/examples/2_Fort_Peck/data/pestrun/pest/params.csv
# 2026-01-14 19:46:36.598046 starting: reading list-style file: /home/dgketchum/code/swim-rs/examples/2_Fort_Peck/data/pestrun/pest/params.csv
# 2026-01-14 19:46:36.599503 finished: reading list-style file: /home/dgketchum/code/swim-rs/examples/2_Fort_Peck/data/pestrun/pest/params.csv took: 0:00:00.001457
# 2026-01-14 19:46:36.599622 loaded list-style '/home/dgketchum/code/swim-rs/examples/2_Fort_Peck/data/pestrun/pest/params.csv' of shape (9, 3)
# 2026-01-14 19:46:36.601418 finished: loading list-style /home/dgketchum/code/swim-rs/examples/2_Fort_Peck/data/pestrun/pest/params.csv took: 0:00:00.003449
# 2026-01-14 19:46:36.601533 starting: writing list-style template file '/home/dgketchum/code/swim-rs/examples/2_Fort_Peck/data/pestrun/pest/p_swe_beta_US-FPe_0_constant.csv.tpl'
# 2026-01-14 19:46:36.609420 finished: writing list-style template file '/home/dgketchum/code/swim-rs/examples/2_Fort_Peck/data/pestrun/pest/p_swe_beta_US-FPe_0_constant.csv.tpl' took: 0:00:00.007887
# 2026-01-14 19:46:36.612468 finished: adding constant type m style parameters for file(s) ['params.csv'] took: 0:00:00.014617
# 2026-01-14 19:46:36.699233 starting: adding observations from output file obs/obs_etf_US-FPe.np
# 2026-01-14 19:46:36.699888 starting: adding observations from array output file 'obs/obs_etf_US-FPe.np'
# 2026-01-14 19:46:36.734282 starting: adding observation from instruction file '/home/dgketchum/code/swim-rs/examples/2_Fort_Peck/data/pestrun/pest/etf_US-FPe.ins'
# 2026-01-14 19:46:36.873628 finished: adding observation from instruction file '/home/dgketchum/code/swim-rs/examples/2_Fort_Peck/data/pestrun/pest/etf_US-FPe.ins' took: 0:00:00.139346
# 2026-01-14 19:46:36.874508 finished: adding observations from array output file 'obs/obs_etf_US-FPe.np' took: 0:00:00.174620
# 2026-01-14 19:46:36.874705 finished: adding observations from output file obs/obs_etf_US-FPe.np took: 0:00:00.175472
# 2026-01-14 19:46:37.614161 starting: adding observations from output file obs/obs_swe_US-FPe.np
# 2026-01-14 19:46:37.614382 starting: adding observations from array output file 'obs/obs_swe_US-FPe.np'
# 2026-01-14 19:46:37.641126 starting: adding observation from instruction file '/home/dgketchum/code/swim-rs/examples/2_Fort_Peck/data/pestrun/pest/swe_US-FPe.ins'
# 2026-01-14 19:46:37.751393 finished: adding observation from instruction file '/home/dgketchum/code/swim-rs/examples/2_Fort_Peck/data/pestrun/pest/swe_US-FPe.ins' took: 0:00:00.110267
# 2026-01-14 19:46:37.752248 finished: adding observations from array output file 'obs/obs_swe_US-FPe.np' took: 0:00:00.137866
# 2026-01-14 19:46:37.752436 finished: adding observations from output file obs/obs_swe_US-FPe.np took: 0:00:00.138275
# noptmax:0, npar_adj:8, nnz_obs:2717
# noptmax:0, npar_adj:8, nnz_obs:2717
# Configured PEST++ for 1 targets,

# %%
# Show the files created in the pest directory
pest_files = [f for f in sorted(os.listdir(builder.pest_dir)) 
              if os.path.isfile(os.path.join(builder.pest_dir, f))]
print("Files in pest directory:")
for f in pest_files:
    print(f"  {f}")
# Out:
# Files in pest directory:
#   2_Fort_Peck.idx.csv
#   2_Fort_Peck.pst
#   2_fort_peck.insfile_data.csv
#   2_fort_peck.obs_data.csv
#   2_fort_peck.par_data.csv
#   2_fort_peck.pargp_data.csv
#   2_fort_peck.tplfile_data.csv
#   custom_forward_run.py
#   etf_US-FPe.ins
#   mult2model_info.csv
#   p_aw_US-FPe_0_constant.csv.tpl
#   p_kr_alpha_US-FPe_0_constant.csv.tpl
#   p_ks_alpha_US-FPe_0_constant.csv.tpl
#   p_mad_US-FPe_0_constant.csv.tpl
#   p_ndvi_0_US-FPe_0_constant.csv.tpl
#   p_ndvi_k_US-FPe_0_constant.csv.tpl
#   p_swe_alpha_US-FPe_0_constant.csv.tpl
#   p_swe_beta_US-FPe_0_constant.csv.tpl
#   params.csv
#   spinup.json
#   swe_US-FPe.ins

# %% [markdown]
# ### Examine the .pst File
#
# The PEST++ version 2 control file is concise, delegating details to external files:

# %%
with open(builder.pst_file, 'r') as f:
    print(f.read())
# Out:
# pcf version=2
# * control data keyword
# pestmode                                 estimation
# noptmax                                 0
# svdmode                                 1
# maxsing                          10000000
# eigthresh                           1e-06
# eigwrite                                1
# * parameter groups external
# 2_fort_peck.pargp_data.csv
# * parameter data external
# 2_fort_peck.par_data.csv
# * observation data external
# 2_fort_peck.obs_data.csv
# * model command line
# python custom_forward_run.py
# * model input external
# 2_fort_peck.tplfile_data.csv
# * model output external
# 2_fort_peck.insfile_data.csv

# %% [markdown]
# ## 4. Configure and Test
#
# Now we:
# 1. Build the localizer matrix (links parameters to relevant observations)
# 2. Run spinup to save initial water balance state
# 3. Do a dry run to verify everything works
# 4. Set control parameters for the full calibration

# %%
# Build localizer matrix
# - SWE observations update only swe_alpha and swe_beta
# - ETf observations update all other parameters
builder.build_localizer()

# Run spinup to save water balance state as initial conditions for calibration runs
# This runs the model once and saves the final state to spinup.json
print("Running spinup...")
builder.spinup(overwrite=True)

# Run a minimal model run to verify the setup
print("\nRunning dry run...")
builder.dry_run()

# Configure for 3 optimization iterations with 20 realizations each
# Increase realizations (e.g., 100-200) for production runs
builder.write_control_settings(noptmax=3, reals=20)
# Out:
# noptmax:0, npar_adj:8, nnz_obs:2717
# Running spinup...
# RUNNING SPINUP
# USING PARAMETER DEFAULTS
#
# Running dry run...
# noptmax:3, npar_adj:8, nnz_obs:2717
# writing /home/dgketchum/code/swim-rs/examples/2_Fort_Peck/data/pestrun/pest/2_Fort_Peck.pst with noptmax=3, 20 realizations

# %%
# Show the updated control file with calibration settings
with open(builder.pst_file, 'r') as f:
    print(f.read())
# Out:
# pcf version=2
# * control data keyword
# pestmode                                 estimation
# noptmax                                 3
# svdmode                                 1
# maxsing                          10000000
# eigthresh                           1e-06
# eigwrite                                1
# ies_localizer                  loc.mat
# ies_num_reals                  20
# ies_drop_conflicts             true
# * parameter groups external
# 2_fort_peck.pargp_data.csv
# * parameter data external
# 2_fort_peck.par_data.csv
# * observation data external
# 2_fort_peck.obs_data.csv
# * model command line
# python custom_forward_run.py
# * model input external
# 2_fort_peck.tplfile_data.csv
# * model output external
# 2_fort_peck.insfile_data.csv

# %% [markdown]
# ## 5. Run PEST++ Calibration
#
# Now we launch PEST++ with parallel workers. Adjust `workers` to match your machine's capabilities.
#
# **Important:** This can take a while. Watch for the progress indicator showing completed runs (C), failed (F), and total (T).

# %%
workers = config.workers or 6
_pst = f"{config.project_name}.pst"

print(f"Starting PEST++ with {workers} workers...")
print(f"Control file: {_pst}")

run_pst(builder.pest_dir,
        'pestpp-ies',
        _pst,
        num_workers=workers,
        worker_root=builder.workers_dir,
        master_dir=builder.master_dir,
        cleanup=True,
        verbose=True)
# Out:
# Starting PEST++ with 20 workers...
# Control file: 2_Fort_Peck.pst
# master:pestpp-ies 2_Fort_Peck.pst /h :5005 in /home/dgketchum/code/swim-rs/examples/2_Fort_Peck/data/pestrun/master
#
#
#              pestpp-ies: a GLM iterative ensemble smoother
#
#                    by the PEST++ development team
#
# ...processing command line: ' pestpp-ies 2_Fort_Peck.pst /h :5005'
# ...using panther run manager in master mode using port 5005
#
#
# version: 5.2.25
# binary compiled on Jan 13 2026 at 20:33:04
# using control file: "2_Fort_Peck.pst"
# in directory: "/home/dgketchum/code/swim-rs/examples/2_Fort_Peck/data/pestrun/master"
# on host: "fcfc-mcozoran"
# on a(n) linux operating system
# with release configuration
# started at 01/14/26 19:47:05
#
# processing control file 2_Fort_Peck.pst
#
#
# :~-._                                                 _.-~:
# : :.~^o._        ________---------________        _.o^~.:.:
#  : ::.`?88booo~~~.::::::::...::::::::::::..~~oood88P'.::.:
#  :  ::: `?88P .:::....         ........:::::. ?88P' :::. :
#   :  :::. `? .::.            . ...........:::. P' .:::. :
#    :  :::   ... ..  ...       .. .::::......::.   :::. :
#    `  :' .... ..  .:::::.     . ..:::::::....:::.  `: .'
#     :..    ____:::::::::.  . . ....:::::::::____  ... :
#    :... `:~    ^~-:::::..  .........:::::-~^    ~::.::::
#    `.::. `\   (8)  \b:::..::.:.:::::::d/  (8)   /'.::::'
#     ::::.  ~-._v    |b.::::::::::::::d|    v_.-~..:::::
#     `.:::::... ~~^?888b..:::::::::::d888P^~...::::::::'
#      `.::::::::::....~~~ .:::::::::~~~:::::::::::::::'
#       `..:::::::::::   .   ....::::    ::::::::::::,'
#         `. .:::::::    .      .::::.    ::::::::'.'
#           `._ .:::    .        :::::.    :::::_.'
#              `-. :    .        :::::      :,-'
#                 :.   :___     .:::___   .::
#       ..--~~~~--:+::. ~~^?b..:::dP^~~.::++:--~~~~--..
#         ___....--`+:::.    `~8~'    .:::+'--....___
#       ~~   __..---`_=:: ___gd8bg___ :==_'---..__   ~~
#        -~~~  _.--~~`-.~~~~~~~~~~~~~~~,-' ~~--._ ~~~-
#
#
#                starting PANTHER master...
#
# IP addresses:
#   0.0.0.0:5005 (IPv4)
#
# PANTHER master listening on socket: 0.0.0.0:5005 (IPv4)
#
#   ---  initializing  ---
# ...using glm algorithm
# ...using REDSVD for truncated svd solve
# ...maxsing: 10000000
# ...eigthresh:  1e-06
# ...initializing localizer
# ...using localized solution with 8 sequential upgrade steps
# ...localizing by parameters
# ...using lambda multipliers: 0.1 , 1 , 10 ,
# ...using lambda scaling factors: 0.75 , 1 , 1.1 ,
# ...acceptable phi factor:  1.05
# ...lambda increase factor:  10
# ...lambda decrease factor:  0.75
# ...max run fail:  1
# ...initializing prior parameter covariance matrix
# ...parcov loaded  from parameter bounds, using par_sigma_range 4
# ...initializing observation noise covariance matrix
# worker:pestpp-ies 2_Fort_Peck.pst /h localhost:5005 in /home/dgketchum/code/swim-rs/examples/2_Fort_Peck/data/pestrun/workers/worker_0
# worker:pestpp-ies 2_Fort_Peck.pst /h localhost:5005 in /home/dgketchum/code/swim-rs/examples/2_Fort_Peck/data/pestrun/workers/worker_1
# worker:pestpp-ies 2_Fort_Peck.pst /h localhost:5005 in /home/dgketchum/code/swim-rs/examples/2_Fort_Peck/data/pestrun/workers/worker_2
# worker:pestpp-ies 2_Fort_Peck.pst /h localhost:5005 in /home/dgketchum/code/swim-rs/examples/2_Fort_Peck/data/pestrun/workers/worker_3
# worker:pestpp-ies 2_Fort_Peck.pst /h localhost:5005 in /home/dgketchum/code/swim-rs/examples/2_Fort_Peck/data/pestrun/workers/worker_4
# worker:pestpp-ies 2_Fort_Peck.pst /h localhost:5005 in /home/dgketchum/code/swim-rs/examples/2_Fort_Peck/data/pestrun/workers/worker_5
# worker:pestpp-ies 2_Fort_Peck.pst /h localhost:5005 in /home/dgketchum/code/swim-rs/examples/2_Fort_Peck/data/pestrun/workers/worker_6
# worker:pestpp-ies 2_Fort_Peck.pst /h localhost:5005 in /home/dgketchum/code/swim-rs/examples/2_Fort_Peck/data/pestrun/workers/worker_7
# worker:pestpp-ies 2_Fort_Peck.pst /h localhost:5005 in /home/dgketchum/code/swim-rs/examples/2_Fort_Peck/data/pestrun/workers/worker_8
# worker:pestpp-ies 2_Fort_Peck.pst /h localhost:5005 in /home/dgketchum/code/swim-rs/examples/2_Fort_Peck/data/pestrun/workers/worker_9
# worker:pestpp-ies 2_Fort_Peck.pst /h localhost:5005 in /home/dgketchum/code/swim-rs/examples/2_Fort_Peck/data/pestrun/workers/worker_10
# ...obscov loaded  from observation weights
# worker:pestpp-ies 2_Fort_Peck.pst /h localhost:5005 in /home/dgketchum/code/swim-rs/examples/2_Fort_Peck/data/pestrun/workers/worker_11
# ...drawing parameter realizations:  20
# ...not using prior parameter covariance matrix scaling
# worker:pestpp-ies 2_Fort_Peck.pst /h localhost:5005 in /home/dgketchum/code/swim-rs/examples/2_Fort_Peck/data/pestrun/workers/worker_12
# worker:pestpp-ies 2_Fort_Peck.pst /h localhost:5005 in /home/dgketchum/code/swim-rs/examples/2_Fort_Peck/data/pestrun/workers/worker_13
# worker:pestpp-ies 2_Fort_Peck.pst /h localhost:5005 in /home/dgketchum/code/swim-rs/examples/2_Fort_Peck/data/pestrun/workers/worker_14
# ...drawing observation noise realizations:  20
# worker:pestpp-ies 2_Fort_Peck.pst /h localhost:5005 in /home/dgketchum/code/swim-rs/examples/2_Fort_Peck/data/pestrun/workers/worker_15
# observations not grouped by observations groups, reordering obs ensemble
# worker:pestpp-ies 2_Fort_Peck.pst /h localhost:5005 in /home/dgketchum/code/swim-rs/examples/2_Fort_Peck/data/pestrun/workers/worker_16
# worker:pestpp-ies 2_Fort_Peck.pst /h localhost:5005 in /home/dgketchum/code/swim-rs/examples/2_Fort_Peck/data/pestrun/workers/worker_17
# worker:pestpp-ies 2_Fort_Peck.pst /h localhost:5005 in /home/dgketchum/code/swim-rs/examples/2_Fort_Peck/data/pestrun/workers/worker_18
# worker:pestpp-ies 2_Fort_Peck.pst /h localhost:5005 in /home/dgketchum/code/swim-rs/examples/2_Fort_Peck/data/pestrun/workers/worker_19
# ...setting weights ensemble from control file weights
# ...saved weight ensemble to  2_Fort_Peck.weights.csv
# ...adding 'base' parameter values to ensemble
# ...adding 'base' observation values to ensemble
# ...adding 'base' weight values to weight ensemble
# ...saved initial parameter ensemble to  2_Fort_Peck.0.par.csv
# ...saved obs+noise observation ensemble (obsval + noise realizations) to  2_Fort_Peck.obs+noise.csv
# ...using subset in lambda testing, percentage of realizations used in subset testing:  10
# ...subset how:  RANDOM
# ...centering on ensemble mean vector
# ...running initial ensemble of size 20
#     running model 20 times
#     starting at 01/14/26 19:47:07
#
#     waiting for agents to appear...
#
#
# PANTHER progress
#    avg = average model run time in minutes
#    runs(C = completed | F = failed | T = timed out)
#    agents(R = running | W = waiting | U = unavailable)
# --------------------------------------------------------------------------------
# 01/14 19:47:23 remaining file transfers: 0|T0    ) agents(R1   |W19  |U0   ) 0
#
#    20 runs complete :  0 runs failed
#    0.245 avg run time (min) : 0.277 run mgr time (min)
#    20 agents connected
#
#
# ...saved initial obs ensemble to 2_Fort_Peck.0.obs.csv
# saved par and rei files for realization BASE for iteration 0
# saved par and rei files for realization BASE
#
#   ---  pre-drop initial phi summary  ---
#        phi type           mean            std            min            max
#        measured        461.118        395.272        274.433        1918.24
#          actual        389.053        395.286        240.513        1847.69
#      note: 'measured' phi reported above includes
#            realizations of measurement noise,
#            'actual' phi does not.
#   ---  observation group phi summary ---
#        (computed using 'actual' phi)
#            (sorted by mean phi)
# group                                   count  nconflict      mean       std       min       max   percent       std
# oname:obs/obs_etf_us-fpe.np_otype:arr     788        156       263      23.9       228       329      91.1      25.4
# oname:obs/obs_swe_us-fpe.np_otype:arr    1929          5       127       400     0.851  1.59e+03      8.89      25.4
#
# ...checking for prior-data conflict
#
#   ---  WARNING: 161 non-zero weighted observations are in conflict with the prior simulated ensemble.
#   ---
# ...see 2_Fort_Peck.0.pdc.csv for listing of conflicted observations
#
# ...dropping conflicted observations
# ...number of non-zero weighted observations reduced from 2717 to 2556
#
# ...updating localizer
# dropped 161 from localizer rows because forgive_missing is true
# ...saved adjusted weight ensemble to  2_Fort_Peck.adjusted.weights.csv
# saved par and rei files for realization BASE for iteration 0
# saved par and rei files for realization BASE
#
#   ---  initial phi summary  ---
#        phi type           mean            std            min            max
#        measured        333.816        389.362         141.73         1764.7
#          actual        271.414        392.125        126.634        1710.33
#      note: 'measured' phi reported above includes
#            realizations of measurement noise,
#            'actual' phi does not.
#   ---  observation group phi summary ---
#        (computed using 'actual' phi)
#            (sorted by mean phi)
# group                                   count  nconflict      mean       std       min       max   percent       std
# oname:obs/obs_etf_us-fpe.np_otype:arr     632          0       145      18.8       125       188      89.9      27.4
# oname:obs/obs_swe_us-fpe.np_otype:arr    1924          0       126       398      0.85  1.58e+03      10.1      27.4
#
# ...current lambda: 0.01
#
#    ---  parameter group change summary  ---
# group     count  mean chg  std chg  n at ubnd  % at ubnd  n at lbnd  % at lbnd  n std decr
# swe_beta      1         0        0          4         20          0          0           0
# ndvi_0        1         0        0          4         20          0          0           0
# mad           1         0        0          3         15          0          0           0
# swe_alpha     1         0        0          2         10          0          0           0
# ndvi_k        1         0        0          1          5          0          0           0
# aw            1         0        0          1          5          0          0           0
# ks_alpha      1         0        0          0          0          0          0           0
# kr_alpha      1         0        0          0          0          0          0           0
#
#
#   ---  initialization complete  ---
#
#   ---  starting solve for iteration: 1  ---
# ...current lambda:  0.01
# ...preparing fast-lookup containers for threaded localization solve
# ...starting calcs for glm factor 0.001
# ...finished calcs for: 0.001
# ...starting calcs for glm factor 0.01
# ...finished calcs for: 0.01
# ...starting calcs for glm factor 0.1
# ...finished calcs for: 0.1
#
#   ---  running upgrade ensembles  ---
# ...subset idx:pe real name:  5:5, 6:6, 13:13, 19:BASE,
# ...subset idx:oe real name:  5:5, 6:6, 13:13, 19:BASE,
#     running model 36 times
#     starting at 01/14/26 19:47:26
#     20 agents ready
#
#
# PANTHER progress
#    avg = average model run time in minutes
#    runs(C = completed | F = failed | T = timed out)
#    agents(R = running | W = waiting | U = unavailable)
# --------------------------------------------------------------------------------
# 01/14 19:47:55 remaining file transfers: 0|T0    ) agents(R2   |W17  |U1   ) 0
#
#    36 runs complete :  0 runs failed
#    0.241 avg run time (min) : 0.494 run mgr time (min)
#    20 agents connected
#
#
#
#   ---  evaluating upgrade ensembles  ---
# ...last mean:  333.816
# ...last stdev:  389.362
#
#   ---  phi summary for best lambda, scale fac: 0.001 , 1.1 ,   ---
#        phi type           mean            std            min            max
#        measured        184.386        39.9767        128.403        222.708
#          actual        129.126        1.96358        127.184        131.822
#      note: 'measured' phi reported above includes
#            realizations of measurement noise,
#            'actual' phi does not.
#
#   ---  running remaining realizations for best lambda, scale:0.001 , 1.1 ,   ---
#     running model 16 times
#     starting at 01/14/26 19:47:57
#     20 agents ready
#
#
# PANTHER progress
#    avg = average model run time in minutes
#    runs(C = completed | F = failed | T = timed out)
#    agents(R = running | W = waiting | U = unavailable)
# --------------------------------------------------------------------------------
# 01/14 19:48:11 remaining file transfers: 0|T0    ) agents(R6   |W11  |U3   ) 0
#
#    16 runs complete :  0 runs failed
#    0.233 avg run time (min) : 0.242 run mgr time (min)
#    20 agents connected
#
#
# ...phi summary for entire ensemble using lambda,scale_fac 0.001 , 1.1 ,
#        phi type           mean            std            min            max
#        measured        194.166        22.6508        128.403        233.802
#          actual        132.677        6.21606        118.892         144.43
#      note: 'measured' phi reported above includes
#            realizations of measurement noise,
#            'actual' phi does not.
# ...last best mean phi * acceptable phi factor:  350.507
# ...current best mean phi:  194.166
#
#   ---  updating parameter ensemble  ---
#
#   ---  updating lambda to  0.00075  ---
#
#   ---  EnsembleMethod iteration 1 report  ---
#    number of active realizations:   20
#    number of model runs:            72
#       current obs ensemble saved to 2_Fort_Peck.1.obs.csv
#       current par ensemble saved to 2_Fort_Peck.1.par.csv
# saved par and rei files for realization BASE for iteration 1
# saved par and rei files for realization BASE
#        phi type           mean            std            min            max
#        measured        194.166        22.6508        128.403        233.802
#          actual        132.677        6.21606        118.892         144.43
#      note: 'measured' phi reported above includes
#            realizations of measurement noise,
#            'actual' phi does not.
#   ---  observation group phi summary ---
#        (computed using 'actual' phi)
#            (sorted by mean phi)
# group                                   count  nconflict      mean       std       min       max   percent       std
# oname:obs/obs_etf_us-fpe.np_otype:arr     632        110       131      6.41       117       143      98.8     0.454
# oname:obs/obs_swe_us-fpe.np_otype:arr    1924        688      1.62     0.582     0.855      2.67      1.23     0.454
#
#
#    ---  parameter group change summary  ---
# group     count  mean chg  std chg  n at ubnd  % at ubnd  n at lbnd  % at lbnd  n std decr
# swe_beta      1     2.722    1.047          0          0          0          0           0
# swe_alpha     1     3.615    23.98          0          0          0          0           0
# ndvi_k        1     3.667     29.8          0          0          0          0           0
# ndvi_0        1     3.972    81.51          0          0          0          0           0
# mad           1     21.23    44.19          0          0          0          0           0
# ks_alpha      1     21.76    23.87          0          0          0          0           0
# kr_alpha      1     73.34    75.76          0          0          0          0           0
# aw            1     1.193    33.46          0          0          0          0           0
#
# ...saved parameter change summary to 2_Fort_Peck.1.pcs.csv
#
#   ---  phi-based termination criteria check  ---
# ...phiredstp:  0.01
# ...nphistp:  3
# ...nphinored (also used for consecutive bad lambda cycles):  3
# ...best mean phi sequence: 333.816 , 194.166 ,
# ...best phi yet:  194.166
# ...number of consecutive bad lambda testing cycles:  0
# ...number of iterations satisfying phiredstp criteria:  1
# ...number of iterations since best yet mean phi:  0
#
#   ---  starting solve for iteration: 2  ---
# ...current lambda:  0.00075
# ...preparing fast-lookup containers for threaded localization solve
# ...starting calcs for glm factor 7.5e-05
# ...finished calcs for: 7.5e-05
# ...starting calcs for glm factor 0.00075
# ...finished calcs for: 0.00075
# ...starting calcs for glm factor 0.0075
# ...finished calcs for: 0.0075
#
#   ---  running upgrade ensembles  ---
# ...subset idx:pe real name:  3:BASE, 7:3, 9:7, 11:9,
# ...subset idx:oe real name:  3:BASE, 7:3, 9:7, 11:9,
#     running model 36 times
#     starting at 01/14/26 19:48:13
#     20 agents ready
#
#
# PANTHER progress
#    avg = average model run time in minutes
#    runs(C = completed | F = failed | T = timed out)
#    agents(R = running | W = waiting | U = unavailable)
# --------------------------------------------------------------------------------
# 01/14 19:48:43 remaining file transfers: 0|T0    ) agents(R0   |W19  |U1   ) 0
#
#    36 runs complete :  0 runs failed
#    0.243 avg run time (min) : 0.501 run mgr time (min)
#    20 agents connected
#
#
#
#   ---  evaluating upgrade ensembles  ---
# ...last mean:  194.166
# ...last stdev:  22.6508
#
#   ---  phi summary for best lambda, scale fac: 7.5e-05 , 1.1 ,   ---
#        phi type           mean            std            min            max
#        measured        175.777        33.5037          125.6        194.501
#          actual        127.431        2.82793        125.391        131.486
#      note: 'measured' phi reported above includes
#            realizations of measurement noise,
#            'actual' phi does not.
#
#   ---  running remaining realizations for best lambda, scale:7.5e-05 , 1.1 ,   ---
#     running model 16 times
#     starting at 01/14/26 19:48:44
#     20 agents ready
#
#
# PANTHER progress
#    avg = average model run time in minutes
#    runs(C = completed | F = failed | T = timed out)
#    agents(R = running | W = waiting | U = unavailable)
# --------------------------------------------------------------------------------
# 01/14 19:48:59 remaining file transfers: 0|T0    ) agents(R7   |W13  |U0   ) 0
#
#    16 runs complete :  0 runs failed
#    0.232 avg run time (min) : 0.248 run mgr time (min)
#    20 agents connected
#
#
# ...phi summary for entire ensemble using lambda,scale_fac 7.5e-05 , 1.1 ,
#        phi type           mean            std            min            max
#        measured        190.793        22.3638          125.6        231.815
#          actual        129.767        4.58176        124.271        139.742
#      note: 'measured' phi reported above includes
#            realizations of measurement noise,
#            'actual' phi does not.
# ...last best mean phi * acceptable phi factor:  203.875
# ...current best mean phi:  190.793
#
#   ---  updating parameter ensemble  ---
#
#   ---  updating lambda to  5.625e-05  ---
#
#   ---  EnsembleMethod iteration 2 report  ---
#    number of active realizations:   20
#    number of model runs:            124
#       current obs ensemble saved to 2_Fort_Peck.2.obs.csv
#       current par ensemble saved to 2_Fort_Peck.2.par.csv
# saved par and rei files for realization BASE for iteration 2
# saved par and rei files for realization BASE
#        phi type           mean            std            min            max
#        measured        190.793        22.3638          125.6        231.815
#          actual        129.767        4.58176        124.271        139.742
#      note: 'measured' phi reported above includes
#            realizations of measurement noise,
#            'actual' phi does not.
#   ---  observation group phi summary ---
#        (computed using 'actual' phi)
#            (sorted by mean phi)
# group                                   count  nconflict      mean       std       min       max   percent       std
# oname:obs/obs_etf_us-fpe.np_otype:arr     632        127       128       4.9       123       139      98.9     0.456
# oname:obs/obs_swe_us-fpe.np_otype:arr    1924        676      1.43     0.563     0.838      2.63      1.11     0.456
#
#
#    ---  parameter group change summary  ---
# group     count  mean chg  std chg  n at ubnd  % at ubnd  n at lbnd  % at lbnd  n std decr
# swe_beta      1     13.08    2.609          0          0          0          0           0
# swe_alpha     1     22.88    31.98          0          0          0          0           0
# ndvi_k        1     4.717    51.75          0          0          0          0           0
# ndvi_0        1     9.255    89.98          0          0          0          0           0
# mad           1     27.23    45.31          0          0          0          0           0
# ks_alpha      1     25.09    44.54          0          0          0          0           0
# kr_alpha      1     97.93    87.85          0          0          0          0           0
# aw            1    0.3842    49.01          0          0          0          0           0
#
# ...saved parameter change summary to 2_Fort_Peck.2.pcs.csv
#
#   ---  phi-based termination criteria check  ---
# ...phiredstp:  0.01
# ...nphistp:  3
# ...nphinored (also used for consecutive bad lambda cycles):  3
# ...best mean phi sequence: 333.816 , 194.166 , 190.793 ,
# ...best phi yet:  190.793
# ...number of consecutive bad lambda testing cycles:  0
# ...number of iterations satisfying phiredstp criteria:  1
# ...number of iterations since best yet mean phi:  0
#
#   ---  starting solve for iteration: 3  ---
# ...current lambda:  5.625e-05
# ...preparing fast-lookup containers for threaded localization solve
# ...starting calcs for glm factor 5.625e-06
# ...finished calcs for: 5.625e-06
# ...starting calcs for glm factor 5.625e-05
# ...finished calcs for: 5.625e-05
# ...starting calcs for glm factor 0.0005625
# ...finished calcs for: 0.0005625
#
#   ---  running upgrade ensembles  ---
# ...subset idx:pe real name:  0:BASE, 6:13, 7:0, 9:2,
# ...subset idx:oe real name:  0:BASE, 6:13, 7:0, 9:2,
#     running model 36 times
#     starting at 01/14/26 19:49:01
#     20 agents ready
#
#
# PANTHER progress
#    avg = average model run time in minutes
#    runs(C = completed | F = failed | T = timed out)
#    agents(R = running | W = waiting | U = unavailable)
# --------------------------------------------------------------------------------
# 01/14 19:49:30 remaining file transfers: 0|T0    ) agents(R3   |W17  |U0   ) 0
#
#    36 runs complete :  0 runs failed
#    0.241 avg run time (min) : 0.494 run mgr time (min)
#    20 agents connected
#
#
#
#   ---  evaluating upgrade ensembles  ---
# ...last mean:  190.793
# ...last stdev:  22.3638
#
#   ---  phi summary for best lambda, scale fac: 5.625e-06 , 1.1 ,   ---
#        phi type           mean            std            min            max
#        measured        167.198        28.2752        125.289        186.041
#          actual        125.894          0.763        125.289        126.882
#      note: 'measured' phi reported above includes
#            realizations of measurement noise,
#            'actual' phi does not.
#
#   ---  running remaining realizations for best lambda, scale:5.625e-06 , 1.1 ,   ---
#     running model 16 times
#     starting at 01/14/26 19:49:32
#     20 agents ready
#
#
# PANTHER progress
#    avg = average model run time in minutes
#    runs(C = completed | F = failed | T = timed out)
#    agents(R = running | W = waiting | U = unavailable)
# --------------------------------------------------------------------------------
# 01/14 19:49:47 remaining file transfers: 0|T0    ) agents(R1   |W19  |U0   ) 0
#
#    16 runs complete :  0 runs failed
#    0.234 avg run time (min) : 0.253 run mgr time (min)
#    20 agents connected
#
#
# ...phi summary for entire ensemble using lambda,scale_fac 5.625e-06 , 1.1 ,
#        phi type           mean            std            min            max
#        measured        189.891        22.1999        125.289        228.624
#          actual        128.659        4.74635         123.36        138.245
#      note: 'measured' phi reported above includes
#            realizations of measurement noise,
#            'actual' phi does not.
# ...last best mean phi * acceptable phi factor:  200.332
# ...current best mean phi:  189.891
#
#   ---  updating parameter ensemble  ---
#
#   ---  updating lambda to  4.21875e-06  ---
#
#   ---  EnsembleMethod iteration 3 report  ---
#    number of active realizations:   20
#    number of model runs:            176
#       current obs ensemble saved to 2_Fort_Peck.3.obs.csv
#       current par ensemble saved to 2_Fort_Peck.3.par.csv
# saved par and rei files for realization BASE for iteration 3
# saved par and rei files for realization BASE
#        phi type           mean            std            min            max
#        measured        189.891        22.1999        125.289        228.624
#          actual        128.659        4.74635         123.36        138.245
#      note: 'measured' phi reported above includes
#            realizations of measurement noise,
#            'actual' phi does not.
#   ---  observation group phi summary ---
#        (computed using 'actual' phi)
#            (sorted by mean phi)
# group                                   count  nconflict      mean       std       min       max   percent       std
# oname:obs/obs_etf_us-fpe.np_otype:arr     632        135       127      5.07       122       137        99     0.432
# oname:obs/obs_swe_us-fpe.np_otype:arr    1924        665      1.29      0.52     0.841      2.58      1.01     0.432
#
#
#    ---  parameter group change summary  ---
# group     count  mean chg  std chg  n at ubnd  % at ubnd  n at lbnd  % at lbnd  n std decr
# swe_beta      1     23.12     5.24          0          0          0          0           0
# swe_alpha     1     43.76     40.4          0          0          0          0           0
# ndvi_k        1     2.619     59.4          0          0          0          0           0
# ndvi_0        1     11.02    91.98          0          0          0          0           0
# mad           1     41.12    46.32          0          0          0          0           0
# ks_alpha      1     31.21    52.59          0          0          0          0           0
# kr_alpha      1     104.7    89.96          0          0          0          0           0
# aw            1    0.8614    53.39          0          0          0          0           0
#
# ...saved parameter change summary to 2_Fort_Peck.3.pcs.csv
#
#   ---  phi-based termination criteria check  ---
# ...phiredstp:  0.01
# ...nphistp:  3
# ...nphinored (also used for consecutive bad lambda cycles):  3
# ...best mean phi sequence: 333.816 , 194.166 , 190.793 , 189.891 ,
# ...best phi yet:  189.891
# ...number of consecutive bad lambda testing cycles:  0
# ...number of iterations satisfying phiredstp criteria:  2
# ...number of iterations since best yet mean phi:  0
# ...solution iterations >= noptmax, all done
#
#
# pestpp-ies analysis complete...
# started at 01/14/26 19:47:05
# finished at 01/14/26 19:49:48
# took 2.71667 minutes

# %% [markdown]
# ## Debugging Tips
#
# If calibration fails, try these steps:
#
# ### Never saw the PEST++ panther logo?
# - Ensure `pestpp-ies` is in your PATH
# - Try running with full path: `/path/to/pestpp-ies`
# - On Windows, use `.exe` extension
#
# ### Python error traceback?
# Debug from the bottom up:
# 1. Verify `swimrs/calibrate/run_mp.py` runs standalone
# 2. Test `custom_forward_run.py` from the pest directory
# 3. Try running `pestpp-ies` directly from pest directory
#
# ### Saw panther but got errors?
# Common error: `output file 'pred/pred_swe_US-FPe.np' not found`
# - This usually means SWIM failed before writing predictions
# - Set `cleanup=False` above to preserve worker directories
# - Check `workers/worker_0/panther_worker.rec` for errors
#
# **Most errors (90%) are due to incorrect paths!**

# %% [markdown]
# ## 6. Check Results
#
# After successful calibration, parameter files are saved for each optimization iteration:

# %%
# Parameter files are in master_dir after calibration
import os
import shutil

results_dir = builder.master_dir if os.path.exists(builder.master_dir) else builder.pest_dir

par_files = [f for f in sorted(os.listdir(results_dir)) if '.par.csv' in f]
print(f"Parameter files (in {results_dir}):")
for f in par_files:
    print(f"  {f}")

if par_files:
    final_par = par_files[-1]
    print(f"\nFinal calibrated parameters: {final_par}")
    
    # Copy final parameters to pest/archive/ for consistency with calibration.py script
    archive_dir = os.path.join(builder.pest_dir, 'archive')
    os.makedirs(archive_dir, exist_ok=True)
    src = os.path.join(results_dir, final_par)
    dst = os.path.join(archive_dir, final_par)
    shutil.copy2(src, dst)
    print(f"Archived to: {dst}")

# Close the container
container.close()
print("\nContainer closed.")
# Out:
# Parameter files (in /home/dgketchum/code/swim-rs/examples/2_Fort_Peck/data/pestrun/master):
#   2_Fort_Peck.0.par.csv
#   2_Fort_Peck.1.par.csv
#   2_Fort_Peck.2.par.csv
#   2_Fort_Peck.3.par.csv
#
# Final calibrated parameters: 2_Fort_Peck.3.par.csv
# Archived to: /home/dgketchum/code/swim-rs/examples/2_Fort_Peck/data/pestrun/pest/archive/2_Fort_Peck.3.par.csv
#
# Container closed.

# %% [markdown]
# ## Summary
#
# You've set up and run a PEST++ calibration using:
# - SSEBop ETf observations from Landsat
# - SNODAS SWE observations
# - Iterative Ensemble Smoother (pestpp-ies)
#
# The parameter files (e.g., `2_Fort_Peck.3.par.csv`) contain the calibrated parameter sets. Each row represents a different realization from the ensemble.
#
# **Next step:** In notebook `03_calibrated_model.ipynb`, we'll run the model in forecast mode with calibrated parameters and validate against flux tower observations.
