# %% [markdown]
# # Calibration Tutorial - Fort Peck, MT - Unirrigated Flux Plot
#
# ## Step 2: Calibrate with PEST++
#
# Now we see if we can improve the model's performance through calibration.
#
# ### PEST++ Resources
#
# PEST++ has excellent documentation covering both theory and practice:
#
# 1. **The PEST Manual 4th Ed.** (Doherty, 2002): https://www.epa.gov/sites/default/files/documents/PESTMAN.PDF
# 2. **GMDSI tutorial notebooks**: https://github.com/gmdsi/GMDSI_notebooks
# 3. **PEST++ User's Manual**: https://github.com/usgs/pestpp/blob/master/documentation/pestpp_users_manual.md
# 4. **PEST Book** (Doherty, 2015): https://pesthomepage.org/pest-book
#
# **Note:** We use SSEBop ETf and SNODAS SWE for calibration - not flux observations. The flux data is reserved for validation only.

# %% [markdown]
# ### PEST++ Installation
#
# Install PEST++ via conda-forge (recommended):
#
# ```bash
# conda install conda-forge::pestpp
# ```
#
# This installs `pestpp-ies` and other PEST++ tools directly into your conda environment. Verify the installation:
#
# ```bash
# pestpp-ies --version
# ```
#
# **Alternative:** For manual installation from source, see the [PEST++ GitHub releases](https://github.com/usgs/pestpp/releases).

# %%
import os
import sys

root = os.path.abspath('../..')
sys.path.append(root)

from swimrs.container import SwimContainer
from swimrs.calibrate.pest_builder import PestBuilder
from swimrs.swim.config import ProjectConfig
from swimrs.calibrate.run_pest import run_pst
# Out:
# /home/dgketchum/miniconda/envs/swim/lib/python3.11/site-packages/pyemu/__init__.py:37: UserWarning: Failed to import legacy module. May impact ability to access older methods.ModuleNotFoundError No module named 'flopy'

# %% [markdown]
# ## 1. Load Configuration
#
# Load the project configuration and prepare paths.

# %%
project = '2_Fort_Peck'
project_ws = os.path.abspath('.')

config_path = os.path.join(project_ws, '2_Fort_Peck.toml')

config = ProjectConfig()
config.read_config(config_path, project_ws)

# %% [markdown]
# ## 2. Generate Observation Files
#
# PEST++ needs observation files (ETf and SWE) to compare against model predictions. We export these from the SwimContainer built in the data preparation step.
#
# The export creates per-field numpy files:
# - `obs_etf_{field_id}.np`: ETf observations with irrigation mask switching
# - `obs_swe_{field_id}.np`: SWE observations from SNODAS

# %%
# Open container for observations export and PEST++ setup
container_path = os.path.join(project_ws, 'data', f'{project}.swim')
container = SwimContainer.open(container_path, mode='r')

# Export observation files for PEST++ calibration
container.export.observations(
    output_dir=os.path.join(project_ws, 'obs'),
    etf_model='ssebop',
    masks=('irr', 'inv_irr'),
    irr_threshold=0.1,
)
print("Observation files written to obs/")
# Out:
# Observation files written to obs/

# %% [markdown]
# ## 3. Build PEST++ Control Files
#
# The `PestBuilder` class sets up everything needed for PEST++ calibration:
#
# ### Calibration Loop
# 1. Initialize model with initial parameter values
# 2. Run model, write results
# 3. Compare results to observations (ETf, SWE)
# 4. Propose new parameters
# 5. Repeat until convergence
#
# ### Tunable Parameters
# SWIM uses 8 tunable parameters:
# - **Soil water:** `aw` (available water), `rew` (readily evaporable water), `tew` (total evaporable water)
# - **NDVI-Kcb relationship:** `ndvi_alpha`, `ndvi_beta`
# - **Stress threshold:** `mad` (management allowable depletion)
# - **Snow melt:** `swe_alpha`, `swe_beta`

# %%
py_script = os.path.join(project_ws, 'custom_forward_run.py')

# Pass container to PestBuilder for ETf/SWE data access
builder = PestBuilder(config, container=container, use_existing=False, python_script=py_script)

# %% [markdown]
# ### Build the .pst Control File
#
# The `build_pest()` method:
# - Copies project files to a `pest/` directory
# - Creates the `.pst` control file
# - Sets up parameter templates (`.tpl`) and instruction files (`.ins`)
#
# **Note:** ETf observations are sparse (only on satellite capture dates). The PEST builder automatically assigns weight 1.0 to valid observations and weight 0.0 to missing dates, ensuring we only calibrate against actual satellite captures.

# %%
# Build the pest control file
# WARNING: This will erase any existing pest directory!
builder.build_pest(target_etf=config.etf_target_model, members=config.etf_ensemble_members)
# Out:
# 2026-01-14 18:23:16.288471 starting: opening PstFrom.log for logging
# 2026-01-14 18:23:16.288998 starting PstFrom process
# 2026-01-14 18:23:16.289055 starting: setting up dirs
# 2026-01-14 18:23:16.289180 starting: removing existing new_d '/home/dgketchum/code/swim-rs/examples/2_Fort_Peck/pest'
# 2026-01-14 18:23:17.080696 finished: removing existing new_d '/home/dgketchum/code/swim-rs/examples/2_Fort_Peck/pest' took: 0:00:00.791516
# 2026-01-14 18:23:17.080822 starting: copying original_d '/home/dgketchum/code/swim-rs/examples/2_Fort_Peck' to new_d '/home/dgketchum/code/swim-rs/examples/2_Fort_Peck/pest'
# 2026-01-14 18:23:18.864032 finished: copying original_d '/home/dgketchum/code/swim-rs/examples/2_Fort_Peck' to new_d '/home/dgketchum/code/swim-rs/examples/2_Fort_Peck/pest' took: 0:00:01.783210
# 2026-01-14 18:23:18.864707 finished: setting up dirs took: 0:00:02.575652
# 2026-01-14 18:23:18.864857 starting: adding constant type m style parameters for file(s) ['params.csv']
# 2026-01-14 18:23:18.864966 starting: loading list-style /home/dgketchum/code/swim-rs/examples/2_Fort_Peck/pest/params.csv
# 2026-01-14 18:23:18.865024 starting: reading list-style file: /home/dgketchum/code/swim-rs/examples/2_Fort_Peck/pest/params.csv
# 2026-01-14 18:23:18.866951 finished: reading list-style file: /home/dgketchum/code/swim-rs/examples/2_Fort_Peck/pest/params.csv took: 0:00:00.001927
# 2026-01-14 18:23:18.867113 loaded list-style '/home/dgketchum/code/swim-rs/examples/2_Fort_Peck/pest/params.csv' of shape (9, 3)
# 2026-01-14 18:23:18.869009 finished: loading list-style /home/dgketchum/code/swim-rs/examples/2_Fort_Peck/pest/params.csv took: 0:00:00.004043
# 2026-01-14 18:23:18.869118 starting: writing list-style template file '/home/dgketchum/code/swim-rs/examples/2_Fort_Peck/pest/p_aw_US-FPe_0_constant.csv.tpl'
# 2026-01-14 18:23:18.881043 finished: writing list-style template file '/home/dgketchum/code/swim-rs/examples/2_Fort_Peck/pest/p_aw_US-FPe_0_constant.csv.tpl' took: 0:00:00.011925
# 2026-01-14 18:23:18.885105 finished: adding constant type m style parameters for file(s) ['params.csv'] took: 0:00:00.020248
# 2026-01-14 18:23:18.885236 starting: adding constant type m style parameters for file(s) ['params.csv']
# 2026-01-14 18:23:18.885330 starting: loading list-style /home/dgketchum/code/swim-rs/examples/2_Fort_Peck/pest/params.csv
# 2026-01-14 18:23:18.885392 starting: reading list-style file: /home/dgketchum/code/swim-rs/examples/2_Fort_Peck/pest/params.csv
# 2026-01-14 18:23:18.886546 finished: reading list-style file: /home/dgketchum/code/swim-rs/examples/2_Fort_Peck/pest/params.csv took: 0:00:00.001154
# 2026-01-14 18:23:18.886639 loaded list-style '/home/dgketchum/code/swim-rs/examples/2_Fort_Peck/pest/params.csv' of shape (9, 3)
# 2026-01-14 18:23:18.888110 finished: loading list-style /home/dgketchum/code/swim-rs/examples/2_Fort_Peck/pest/params.csv took: 0:00:00.002780
# 2026-01-14 18:23:18.888215 starting: writing list-style template file '/home/dgketchum/code/swim-rs/examples/2_Fort_Peck/pest/p_ks_alpha_US-FPe_0_constant.csv.tpl'
# 2026-01-14 18:23:18.897718 finished: writing list-style template file '/home/dgketchum/code/swim-rs/examples/2_Fort_Peck/pest/p_ks_alpha_US-FPe_0_constant.csv.tpl' took: 0:00:00.009503
# 2026-01-14 18:23:18.901377 finished: adding constant type m style parameters for file(s) ['params.csv'] took: 0:00:00.016141
# 2026-01-14 18:23:18.901517 starting: adding constant type m style parameters for file(s) ['params.csv']
# 2026-01-14 18:23:18.901603 starting: loading list-style /home/dgketchum/code/swim-rs/examples/2_Fort_Peck/pest/params.csv
# 2026-01-14 18:23:18.901673 starting: reading list-style file: /home/dgketchum/code/swim-rs/examples/2_Fort_Peck/pest/params.csv
# 2026-01-14 18:23:18.902725 finished: reading list-style file: /home/dgketchum/code/swim-rs/examples/2_Fort_Peck/pest/params.csv took: 0:00:00.001052
# 2026-01-14 18:23:18.902824 loaded list-style '/home/dgketchum/code/swim-rs/examples/2_Fort_Peck/pest/params.csv' of shape (9, 3)
# 2026-01-14 18:23:18.904236 finished: loading list-style /home/dgketchum/code/swim-rs/examples/2_Fort_Peck/pest/params.csv took: 0:00:00.002633
# 2026-01-14 18:23:18.904350 starting: writing list-style template file '/home/dgketchum/code/swim-rs/examples/2_Fort_Peck/pest/p_kr_alpha_US-FPe_0_constant.csv.tpl'
# 2026-01-14 18:23:18.913468 finished: writing list-style template file '/home/dgketchum/code/swim-rs/examples/2_Fort_Peck/pest/p_kr_alpha_US-FPe_0_constant.csv.tpl' took: 0:00:00.009118
# 2026-01-14 18:23:18.916881 finished: adding constant type m style parameters for file(s) ['params.csv'] took: 0:00:00.015364
# 2026-01-14 18:23:18.916998 starting: adding constant type m style parameters for file(s) ['params.csv']
# 2026-01-14 18:23:18.917082 starting: loading list-style /home/dgketchum/code/swim-rs/examples/2_Fort_Peck/pest/params.csv
# 2026-01-14 18:23:18.917141 starting: reading list-style file: /home/dgketchum/code/swim-rs/examples/2_Fort_Peck/pest/params.csv
# 2026-01-14 18:23:18.918187 finished: reading list-style file: /home/dgketchum/code/swim-rs/examples/2_Fort_Peck/pest/params.csv took: 0:00:00.001046
# 2026-01-14 18:23:18.918279 loaded list-style '/home/dgketchum/code/swim-rs/examples/2_Fort_Peck/pest/params.csv' of shape (9, 3)
# 2026-01-14 18:23:18.919680 finished: loading list-style /home/dgketchum/code/swim-rs/examples/2_Fort_Peck/pest/params.csv took: 0:00:00.002598
# 2026-01-14 18:23:18.919782 starting: writing list-style template file '/home/dgketchum/code/swim-rs/examples/2_Fort_Peck/pest/p_ndvi_k_US-FPe_0_constant.csv.tpl'
# 2026-01-14 18:23:18.929096 finished: writing list-style template file '/home/dgketchum/code/swim-rs/examples/2_Fort_Peck/pest/p_ndvi_k_US-FPe_0_constant.csv.tpl' took: 0:00:00.009314
# 2026-01-14 18:23:18.932658 finished: adding constant type m style parameters for file(s) ['params.csv'] took: 0:00:00.015660
# 2026-01-14 18:23:18.932807 starting: adding constant type m style parameters for file(s) ['params.csv']
# 2026-01-14 18:23:18.932896 starting: loading list-style /home/dgketchum/code/swim-rs/examples/2_Fort_Peck/pest/params.csv
# 2026-01-14 18:23:18.932958 starting: reading list-style file: /home/dgketchum/code/swim-rs/examples/2_Fort_Peck/pest/params.csv
# 2026-01-14 18:23:18.934075 finished: reading list-style file: /home/dgketchum/code/swim-rs/examples/2_Fort_Peck/pest/params.csv took: 0:00:00.001117
# 2026-01-14 18:23:18.934164 loaded list-style '/home/dgketchum/code/swim-rs/examples/2_Fort_Peck/pest/params.csv' of shape (9, 3)
# 2026-01-14 18:23:18.935458 finished: loading list-style /home/dgketchum/code/swim-rs/examples/2_Fort_Peck/pest/params.csv took: 0:00:00.002562
# 2026-01-14 18:23:18.935544 starting: writing list-style template file '/home/dgketchum/code/swim-rs/examples/2_Fort_Peck/pest/p_ndvi_0_US-FPe_0_constant.csv.tpl'
# 2026-01-14 18:23:18.944325 finished: writing list-style template file '/home/dgketchum/code/swim-rs/examples/2_Fort_Peck/pest/p_ndvi_0_US-FPe_0_constant.csv.tpl' took: 0:00:00.008781
# 2026-01-14 18:23:18.947622 finished: adding constant type m style parameters for file(s) ['params.csv'] took: 0:00:00.014815
# 2026-01-14 18:23:18.947734 starting: adding constant type m style parameters for file(s) ['params.csv']
# 2026-01-14 18:23:18.947811 starting: loading list-style /home/dgketchum/code/swim-rs/examples/2_Fort_Peck/pest/params.csv
# 2026-01-14 18:23:18.947877 starting: reading list-style file: /home/dgketchum/code/swim-rs/examples/2_Fort_Peck/pest/params.csv
# 2026-01-14 18:23:18.948840 finished: reading list-style file: /home/dgketchum/code/swim-rs/examples/2_Fort_Peck/pest/params.csv took: 0:00:00.000963
# 2026-01-14 18:23:18.948928 loaded list-style '/home/dgketchum/code/swim-rs/examples/2_Fort_Peck/pest/params.csv' of shape (9, 3)
# 2026-01-14 18:23:18.950255 finished: loading list-style /home/dgketchum/code/swim-rs/examples/2_Fort_Peck/pest/params.csv took: 0:00:00.002444
# 2026-01-14 18:23:18.950345 starting: writing list-style template file '/home/dgketchum/code/swim-rs/examples/2_Fort_Peck/pest/p_mad_US-FPe_0_constant.csv.tpl'
# 2026-01-14 18:23:18.962233 finished: writing list-style template file '/home/dgketchum/code/swim-rs/examples/2_Fort_Peck/pest/p_mad_US-FPe_0_constant.csv.tpl' took: 0:00:00.011888
# 2026-01-14 18:23:18.965643 finished: adding constant type m style parameters for file(s) ['params.csv'] took: 0:00:00.017909
# 2026-01-14 18:23:18.965775 starting: adding constant type m style parameters for file(s) ['params.csv']
# 2026-01-14 18:23:18.965863 starting: loading list-style /home/dgketchum/code/swim-rs/examples/2_Fort_Peck/pest/params.csv
# 2026-01-14 18:23:18.965918 starting: reading list-style file: /home/dgketchum/code/swim-rs/examples/2_Fort_Peck/pest/params.csv
# 2026-01-14 18:23:18.967131 finished: reading list-style file: /home/dgketchum/code/swim-rs/examples/2_Fort_Peck/pest/params.csv took: 0:00:00.001213
# 2026-01-14 18:23:18.967222 loaded list-style '/home/dgketchum/code/swim-rs/examples/2_Fort_Peck/pest/params.csv' of shape (9, 3)
# 2026-01-14 18:23:18.968614 finished: loading list-style /home/dgketchum/code/swim-rs/examples/2_Fort_Peck/pest/params.csv took: 0:00:00.002751
# 2026-01-14 18:23:18.968705 starting: writing list-style template file '/home/dgketchum/code/swim-rs/examples/2_Fort_Peck/pest/p_swe_alpha_US-FPe_0_constant.csv.tpl'
# 2026-01-14 18:23:18.977786 finished: writing list-style template file '/home/dgketchum/code/swim-rs/examples/2_Fort_Peck/pest/p_swe_alpha_US-FPe_0_constant.csv.tpl' took: 0:00:00.009081
# 2026-01-14 18:23:18.981370 finished: adding constant type m style parameters for file(s) ['params.csv'] took: 0:00:00.015595
# 2026-01-14 18:23:18.981486 starting: adding constant type m style parameters for file(s) ['params.csv']
# 2026-01-14 18:23:18.981594 starting: loading list-style /home/dgketchum/code/swim-rs/examples/2_Fort_Peck/pest/params.csv
# 2026-01-14 18:23:18.981659 starting: reading list-style file: /home/dgketchum/code/swim-rs/examples/2_Fort_Peck/pest/params.csv
# 2026-01-14 18:23:18.982866 finished: reading list-style file: /home/dgketchum/code/swim-rs/examples/2_Fort_Peck/pest/params.csv took: 0:00:00.001207
# 2026-01-14 18:23:18.982955 loaded list-style '/home/dgketchum/code/swim-rs/examples/2_Fort_Peck/pest/params.csv' of shape (9, 3)
# 2026-01-14 18:23:18.984260 finished: loading list-style /home/dgketchum/code/swim-rs/examples/2_Fort_Peck/pest/params.csv took: 0:00:00.002666
# 2026-01-14 18:23:18.984350 starting: writing list-style template file '/home/dgketchum/code/swim-rs/examples/2_Fort_Peck/pest/p_swe_beta_US-FPe_0_constant.csv.tpl'
# 2026-01-14 18:23:18.993269 finished: writing list-style template file '/home/dgketchum/code/swim-rs/examples/2_Fort_Peck/pest/p_swe_beta_US-FPe_0_constant.csv.tpl' took: 0:00:00.008919
# 2026-01-14 18:23:18.996574 finished: adding constant type m style parameters for file(s) ['params.csv'] took: 0:00:00.015088
# 2026-01-14 18:23:19.077451 starting: adding observations from output file obs/obs_etf_US-FPe.np
# 2026-01-14 18:23:19.078116 starting: adding observations from array output file 'obs/obs_etf_US-FPe.np'
# 2026-01-14 18:23:19.109984 starting: adding observation from instruction file '/home/dgketchum/code/swim-rs/examples/2_Fort_Peck/pest/etf_US-FPe.ins'
# 2026-01-14 18:23:19.230388 finished: adding observation from instruction file '/home/dgketchum/code/swim-rs/examples/2_Fort_Peck/pest/etf_US-FPe.ins' took: 0:00:00.120404
# 2026-01-14 18:23:19.231342 finished: adding observations from array output file 'obs/obs_etf_US-FPe.np' took: 0:00:00.153226
# 2026-01-14 18:23:19.231547 finished: adding observations from output file obs/obs_etf_US-FPe.np took: 0:00:00.154096
# 2026-01-14 18:23:19.941203 starting: adding observations from output file obs/obs_swe_US-FPe.np
# 2026-01-14 18:23:19.941765 starting: adding observations from array output file 'obs/obs_swe_US-FPe.np'
# 2026-01-14 18:23:19.974355 starting: adding observation from instruction file '/home/dgketchum/code/swim-rs/examples/2_Fort_Peck/pest/swe_US-FPe.ins'
# 2026-01-14 18:23:20.103100 finished: adding observation from instruction file '/home/dgketchum/code/swim-rs/examples/2_Fort_Peck/pest/swe_US-FPe.ins' took: 0:00:00.128745
# 2026-01-14 18:23:20.104099 finished: adding observations from array output file 'obs/obs_swe_US-FPe.np' took: 0:00:00.162334
# 2026-01-14 18:23:20.104300 finished: adding observations from output file obs/obs_swe_US-FPe.np took: 0:00:00.163097
# noptmax:0, npar_adj:8, nnz_obs:2717
# noptmax:0, npar_adj:8, nnz_obs:2717
# Configured PEST++ for 1 targets,

# %%
# Show the files created in the pest directory
pest_files = [f for f in sorted(os.listdir(builder.pest_dir)) 
              if os.path.isfile(os.path.join(builder.pest_dir, f))]
print("Files in pest directory:")
for f in pest_files:
    print(f"  {f}")
# Out:
# Files in pest directory:
#   01_uncalibrated_model.ipynb
#   02_calibration.ipynb
#   03_calibrated_model.ipynb
#   2_Fort_Peck.idx.csv
#   2_Fort_Peck.pst
#   2_Fort_Peck.toml
#   2_fort_peck.insfile_data.csv
#   2_fort_peck.obs_data.csv
#   2_fort_peck.par_data.csv
#   2_fort_peck.pargp_data.csv
#   2_fort_peck.tplfile_data.csv
#   PstFrom.log
#   README.md
#   combined_output_US-FPe_calibrated.csv
#   combined_output_US-FPe_uncalibrated.csv
#   comparison_scatter_calibrated.png
#   comparison_scatter_uncalibrated.png
#   custom_forward_run.py
#   debug_uncalibrated.py
#   et_calibrated.png
#   et_uncalibrated.png
#   etf_US-FPe.ins
#   mult2model_info.csv
#   p_aw_US-FPe_0_constant.csv.tpl
#   p_kr_alpha_US-FPe_0_constant.csv.tpl
#   p_ks_alpha_US-FPe_0_constant.csv.tpl
#   p_mad_US-FPe_0_constant.csv.tpl
#   p_ndvi_0_US-FPe_0_constant.csv.tpl
#   p_ndvi_k_US-FPe_0_constant.csv.tpl
#   p_swe_alpha_US-FPe_0_constant.csv.tpl
#   p_swe_beta_US-FPe_0_constant.csv.tpl
#   params.csv
#   swe_US-FPe.ins

# %% [markdown]
# ### Examine the .pst File
#
# The PEST++ version 2 control file is concise, delegating details to external files:

# %%
with open(builder.pst_file, 'r') as f:
    print(f.read())
# Out:
# pcf version=2
# * control data keyword
# pestmode                                 estimation
# noptmax                                 0
# svdmode                                 1
# maxsing                          10000000
# eigthresh                           1e-06
# eigwrite                                1
# * parameter groups external
# 2_fort_peck.pargp_data.csv
# * parameter data external
# 2_fort_peck.par_data.csv
# * observation data external
# 2_fort_peck.obs_data.csv
# * model command line
# python custom_forward_run.py
# * model input external
# 2_fort_peck.tplfile_data.csv
# * model output external
# 2_fort_peck.insfile_data.csv

# %% [markdown]
# ## 4. Configure and Test
#
# Now we:
# 1. Build the localizer matrix (links parameters to relevant observations)
# 2. Run spinup to save initial water balance state
# 3. Do a dry run to verify everything works
# 4. Set control parameters for the full calibration

# %%
# Build localizer matrix
# - SWE observations update only swe_alpha and swe_beta
# - ETf observations update all other parameters
builder.build_localizer()

# Run spinup to save water balance state as initial conditions for calibration runs
# This runs the model once and saves the final state to spinup.json
print("Running spinup...")
builder.spinup(overwrite=True)

# Run a minimal model run to verify the setup
print("\nRunning dry run...")
builder.dry_run()

# Configure for 3 optimization iterations with 20 realizations each
# Increase realizations (e.g., 100-200) for production runs
builder.write_control_settings(noptmax=3, reals=20)
# Out:
# noptmax:0, npar_adj:8, nnz_obs:2717
# Running spinup...
# RUNNING SPINUP
# USING PARAMETER DEFAULTS
#
# Running dry run...
# noptmax:3, npar_adj:8, nnz_obs:2717
# writing /home/dgketchum/code/swim-rs/examples/2_Fort_Peck/pest/2_Fort_Peck.pst with noptmax=3, 20 realizations

# %%
# Show the updated control file with calibration settings
with open(builder.pst_file, 'r') as f:
    print(f.read())
# Out:
# pcf version=2
# * control data keyword
# pestmode                                 estimation
# noptmax                                 3
# svdmode                                 1
# maxsing                          10000000
# eigthresh                           1e-06
# eigwrite                                1
# ies_localizer                  loc.mat
# ies_num_reals                  20
# ies_drop_conflicts             true
# * parameter groups external
# 2_fort_peck.pargp_data.csv
# * parameter data external
# 2_fort_peck.par_data.csv
# * observation data external
# 2_fort_peck.obs_data.csv
# * model command line
# python custom_forward_run.py
# * model input external
# 2_fort_peck.tplfile_data.csv
# * model output external
# 2_fort_peck.insfile_data.csv

# %% [markdown]
# ## 5. Run PEST++ Calibration
#
# Now we launch PEST++ with parallel workers. Adjust `workers` to match your machine's capabilities.
#
# **Important:** This can take a while. Watch for the progress indicator showing completed runs (C), failed (F), and total (T).

# %%
workers = config.workers or 6
_pst = f"{config.project_name}.pst"

print(f"Starting PEST++ with {workers} workers...")
print(f"Control file: {_pst}")

run_pst(builder.pest_dir,
        'pestpp-ies',
        _pst,
        num_workers=workers,
        worker_root=builder.workers_dir,
        master_dir=builder.master_dir,
        cleanup=True,
        verbose=True)
# Out:
# Starting PEST++ with 20 workers...
# Control file: 2_Fort_Peck.pst
# master:pestpp-ies 2_Fort_Peck.pst /h :5005 in /home/dgketchum/code/swim-rs/examples/2_Fort_Peck/master
#
#
#              pestpp-ies: a GLM iterative ensemble smoother
#
#                    by the PEST++ development team
#
# ...processing command line: ' pestpp-ies 2_Fort_Peck.pst /h :5005'
# ...using panther run manager in master mode using port 5005
#
#
# version: 5.2.25
# binary compiled on Jan 13 2026 at 20:33:04
# using control file: "2_Fort_Peck.pst"
# in directory: "/home/dgketchum/code/swim-rs/examples/2_Fort_Peck/master"
# on host: "fcfc-mcozoran"
# on a(n) linux operating system
# with release configuration
# started at 01/14/26 18:23:51
#
# processing control file 2_Fort_Peck.pst
#
#
# :~-._                                                 _.-~:
# : :.~^o._        ________---------________        _.o^~.:.:
#  : ::.`?88booo~~~.::::::::...::::::::::::..~~oood88P'.::.:
#  :  ::: `?88P .:::....         ........:::::. ?88P' :::. :
#   :  :::. `? .::.            . ...........:::. P' .:::. :
#    :  :::   ... ..  ...       .. .::::......::.   :::. :
#    `  :' .... ..  .:::::.     . ..:::::::....:::.  `: .'
#     :..    ____:::::::::.  . . ....:::::::::____  ... :
#    :... `:~    ^~-:::::..  .........:::::-~^    ~::.::::
#    `.::. `\   (8)  \b:::..::.:.:::::::d/  (8)   /'.::::'
#     ::::.  ~-._v    |b.::::::::::::::d|    v_.-~..:::::
#     `.:::::... ~~^?888b..:::::::::::d888P^~...::::::::'
#      `.::::::::::....~~~ .:::::::::~~~:::::::::::::::'
#       `..:::::::::::   .   ....::::    ::::::::::::,'
#         `. .:::::::    .      .::::.    ::::::::'.'
#           `._ .:::    .        :::::.    :::::_.'
#              `-. :    .        :::::      :,-'
#                 :.   :___     .:::___   .::
#       ..--~~~~--:+::. ~~^?b..:::dP^~~.::++:--~~~~--..
#         ___....--`+:::.    `~8~'    .:::+'--....___
#       ~~   __..---`_=:: ___gd8bg___ :==_'---..__   ~~
#        -~~~  _.--~~`-.~~~~~~~~~~~~~~~,-' ~~--._ ~~~-
#
#
#                starting PANTHER master...
#
# IP addresses:
#   0.0.0.0:5005 (IPv4)
#
# PANTHER master listening on socket: 0.0.0.0:5005 (IPv4)
#
#   ---  initializing  ---
# ...using glm algorithm
# ...using REDSVD for truncated svd solve
# ...maxsing: 10000000
# ...eigthresh:  1e-06
# ...initializing localizer
# ...using localized solution with 8 sequential upgrade steps
# ...localizing by parameters
# ...using lambda multipliers: 0.1 , 1 , 10 ,
# ...using lambda scaling factors: 0.75 , 1 , 1.1 ,
# ...acceptable phi factor:  1.05
# ...lambda increase factor:  10
# ...lambda decrease factor:  0.75
# ...max run fail:  1
# ...initializing prior parameter covariance matrix
# ...parcov loaded  from parameter bounds, using par_sigma_range 4
# ...initializing observation noise covariance matrix
# ...obscov loaded  from observation weights
# ...drawing parameter realizations:  20
# ...not using prior parameter covariance matrix scaling
# ...drawing observation noise realizations:  20
# observations not grouped by observations groups, reordering obs ensemble
# ...setting weights ensemble from control file weights
# ...saved weight ensemble to  2_Fort_Peck.weights.csv
# ...adding 'base' parameter values to ensemble
# ...adding 'base' observation values to ensemble
# ...adding 'base' weight values to weight ensemble
# ...saved initial parameter ensemble to  2_Fort_Peck.0.par.csv
# ...saved obs+noise observation ensemble (obsval + noise realizations) to  2_Fort_Peck.obs+noise.csv
# ...using subset in lambda testing, percentage of realizations used in subset testing:  10
# ...subset how:  RANDOM
# ...centering on ensemble mean vector
# ...running initial ensemble of size 20
#     running model 20 times
#     starting at 01/14/26 18:23:53
#
#     waiting for agents to appear...
#
#
# PANTHER progress
#    avg = average model run time in minutes
#    runs(C = completed | F = failed | T = timed out)
#    agents(R = running | W = waiting | U = unavailable)
# --------------------------------------------------------------------------------
# worker:pestpp-ies 2_Fort_Peck.pst /h localhost:5005 in /home/dgketchum/code/swim-rs/examples/2_Fort_Peck/workers/worker_0
# worker:pestpp-ies 2_Fort_Peck.pst /h localhost:5005 in /home/dgketchum/code/swim-rs/examples/2_Fort_Peck/workers/worker_1
# worker:pestpp-ies 2_Fort_Peck.pst /h localhost:5005 in /home/dgketchum/code/swim-rs/examples/2_Fort_Peck/workers/worker_2
# worker:pestpp-ies 2_Fort_Peck.pst /h localhost:5005 in /home/dgketchum/code/swim-rs/examples/2_Fort_Peck/workers/worker_3
# worker:pestpp-ies 2_Fort_Peck.pst /h localhost:5005 in /home/dgketchum/code/swim-rs/examples/2_Fort_Peck/workers/worker_4
# worker:pestpp-ies 2_Fort_Peck.pst /h localhost:5005 in /home/dgketchum/code/swim-rs/examples/2_Fort_Peck/workers/worker_5
# worker:pestpp-ies 2_Fort_Peck.pst /h localhost:5005 in /home/dgketchum/code/swim-rs/examples/2_Fort_Peck/workers/worker_6
# worker:pestpp-ies 2_Fort_Peck.pst /h localhost:5005 in /home/dgketchum/code/swim-rs/examples/2_Fort_Peck/workers/worker_7
# worker:pestpp-ies 2_Fort_Peck.pst /h localhost:5005 in /home/dgketchum/code/swim-rs/examples/2_Fort_Peck/workers/worker_8
# worker:pestpp-ies 2_Fort_Peck.pst /h localhost:5005 in /home/dgketchum/code/swim-rs/examples/2_Fort_Peck/workers/worker_9
# worker:pestpp-ies 2_Fort_Peck.pst /h localhost:5005 in /home/dgketchum/code/swim-rs/examples/2_Fort_Peck/workers/worker_10
# worker:pestpp-ies 2_Fort_Peck.pst /h localhost:5005 in /home/dgketchum/code/swim-rs/examples/2_Fort_Peck/workers/worker_11
# worker:pestpp-ies 2_Fort_Peck.pst /h localhost:5005 in /home/dgketchum/code/swim-rs/examples/2_Fort_Peck/workers/worker_12
# worker:pestpp-ies 2_Fort_Peck.pst /h localhost:5005 in /home/dgketchum/code/swim-rs/examples/2_Fort_Peck/workers/worker_13
# worker:pestpp-ies 2_Fort_Peck.pst /h localhost:5005 in /home/dgketchum/code/swim-rs/examples/2_Fort_Peck/workers/worker_14
# worker:pestpp-ies 2_Fort_Peck.pst /h localhost:5005 in /home/dgketchum/code/swim-rs/examples/2_Fort_Peck/workers/worker_15
# worker:pestpp-ies 2_Fort_Peck.pst /h localhost:5005 in /home/dgketchum/code/swim-rs/examples/2_Fort_Peck/workers/worker_16
# worker:pestpp-ies 2_Fort_Peck.pst /h localhost:5005 in /home/dgketchum/code/swim-rs/examples/2_Fort_Peck/workers/worker_17
# worker:pestpp-ies 2_Fort_Peck.pst /h localhost:5005 in /home/dgketchum/code/swim-rs/examples/2_Fort_Peck/workers/worker_18
# worker:pestpp-ies 2_Fort_Peck.pst /h localhost:5005 in /home/dgketchum/code/swim-rs/examples/2_Fort_Peck/workers/worker_19
# 01/14 18:24:36 remaining file transfers: 0|T0    ) agents(R2   |W18  |U0   ) 0
#
#    20 runs complete :  0 runs failed
#    0.263 avg run time (min) : 0.715 run mgr time (min)
#    20 agents connected
#
#
# ...saved initial obs ensemble to 2_Fort_Peck.0.obs.csv
# saved par and rei files for realization BASE for iteration 0
# saved par and rei files for realization BASE
#
#   ---  pre-drop initial phi summary  ---
#        phi type           mean            std            min            max
#        measured        544.715         629.06        270.666        2421.73
#          actual        472.585        630.312        236.998        2354.21
#      note: 'measured' phi reported above includes
#            realizations of measurement noise,
#            'actual' phi does not.
#   ---  observation group phi summary ---
#        (computed using 'actual' phi)
#            (sorted by mean phi)
# group                                   count  nconflict      mean       std       min       max   percent       std
# oname:obs/obs_etf_us-fpe.np_otype:arr     788        149       264      35.8       226       367      90.5      27.4
# oname:obs/obs_swe_us-fpe.np_otype:arr    1929          5       209       638     0.846  2.13e+03      9.47      27.4
#
# ...checking for prior-data conflict
#
#   ---  WARNING: 154 non-zero weighted observations are in conflict with the prior simulated ensemble.
#   ---
# ...see 2_Fort_Peck.0.pdc.csv for listing of conflicted observations
#
# ...dropping conflicted observations
# ...number of non-zero weighted observations reduced from 2717 to 2563
#
# ...updating localizer
# dropped 154 from localizer rows because forgive_missing is true
# ...saved adjusted weight ensemble to  2_Fort_Peck.adjusted.weights.csv
# saved par and rei files for realization BASE for iteration 0
# saved par and rei files for realization BASE
#
#   ---  initial phi summary  ---
#        phi type           mean            std            min            max
#        measured         421.98        624.929        150.525        2296.65
#          actual        358.551        630.052        129.594        2252.91
#      note: 'measured' phi reported above includes
#            realizations of measurement noise,
#            'actual' phi does not.
#   ---  observation group phi summary ---
#        (computed using 'actual' phi)
#            (sorted by mean phi)
# group                                   count  nconflict      mean       std       min       max   percent       std
# oname:obs/obs_swe_us-fpe.np_otype:arr    1924          0       208       635     0.845  2.12e+03      10.3      28.6
# oname:obs/obs_etf_us-fpe.np_otype:arr     639          0       151      25.9       129       226      89.7      28.6
#
# ...current lambda: 0.01
#
#    ---  parameter group change summary  ---
# group     count  mean chg  std chg  n at ubnd  % at ubnd  n at lbnd  % at lbnd  n std decr
# kr_alpha      1         0        0          7         35          0          0           0
# swe_beta      1         0        0          4         20          0          0           0
# mad           1         0        0          3         15          0          0           0
# swe_alpha     1         0        0          1          5          1          5           0
# ndvi_k        1         0        0          2         10          0          0           0
# ndvi_0        1         0        0          1          5          0          0           0
# ks_alpha      1         0        0          1          5          0          0           0
# aw            1         0        0          1          5          0          0           0
#
#
#   ---  initialization complete  ---
#
#   ---  starting solve for iteration: 1  ---
# ...current lambda:  0.01
# ...preparing fast-lookup containers for threaded localization solve
# ...starting calcs for glm factor 0.001
# ...finished calcs for: 0.001
# ...starting calcs for glm factor 0.01
# ...finished calcs for: 0.01
# ...starting calcs for glm factor 0.1
# ...finished calcs for: 0.1
#
#   ---  running upgrade ensembles  ---
# ...subset idx:pe real name:  5:5, 6:6, 13:13, 19:BASE,
# ...subset idx:oe real name:  5:5, 6:6, 13:13, 19:BASE,
#     running model 36 times
#     starting at 01/14/26 18:24:38
#     20 agents ready
#
#
# PANTHER progress
#    avg = average model run time in minutes
#    runs(C = completed | F = failed | T = timed out)
#    agents(R = running | W = waiting | U = unavailable)
# --------------------------------------------------------------------------------
# 01/14 18:25:11 remaining file transfers: 0|T0    ) agents(R2   |W18  |U0   ) 0
#
#    36 runs complete :  0 runs failed
#    0.266 avg run time (min) : 0.543 run mgr time (min)
#    20 agents connected
#
#
#
#   ---  evaluating upgrade ensembles  ---
# ...last mean:  421.98
# ...last stdev:  624.929
#
#   ---  phi summary for best lambda, scale fac: 0.1 , 1.1 ,   ---
#        phi type           mean            std            min            max
#        measured         189.03        43.4696        129.512        233.857
#          actual        134.176        7.31253        126.687        142.342
#      note: 'measured' phi reported above includes
#            realizations of measurement noise,
#            'actual' phi does not.
#
#   ---  running remaining realizations for best lambda, scale:0.1 , 1.1 ,   ---
#     running model 16 times
#     starting at 01/14/26 18:25:12
#     20 agents ready
#
#
# PANTHER progress
#    avg = average model run time in minutes
#    runs(C = completed | F = failed | T = timed out)
#    agents(R = running | W = waiting | U = unavailable)
# --------------------------------------------------------------------------------
# 01/14 18:25:29 remaining file transfers: 0|T0    ) agents(R2   |W18  |U0   ) 0
#
#    16 runs complete :  0 runs failed
#    0.26 avg run time (min) : 0.28 run mgr time (min)
#    20 agents connected
#
#
# ...phi summary for entire ensemble using lambda,scale_fac 0.1 , 1.1 ,
#        phi type           mean            std            min            max
#        measured        200.465         24.415        129.512         242.24
#          actual         136.91        8.33789        122.311        150.509
#      note: 'measured' phi reported above includes
#            realizations of measurement noise,
#            'actual' phi does not.
# ...last best mean phi * acceptable phi factor:  443.079
# ...current best mean phi:  200.465
#
#   ---  updating parameter ensemble  ---
#
#   ---  updating lambda to  0.075  ---
#
#   ---  EnsembleMethod iteration 1 report  ---
#    number of active realizations:   20
#    number of model runs:            72
#       current obs ensemble saved to 2_Fort_Peck.1.obs.csv
#       current par ensemble saved to 2_Fort_Peck.1.par.csv
# saved par and rei files for realization BASE for iteration 1
# saved par and rei files for realization BASE
#        phi type           mean            std            min            max
#        measured        200.465         24.415        129.512         242.24
#          actual         136.91        8.33789        122.311        150.509
#      note: 'measured' phi reported above includes
#            realizations of measurement noise,
#            'actual' phi does not.
#   ---  observation group phi summary ---
#        (computed using 'actual' phi)
#            (sorted by mean phi)
# group                                   count  nconflict      mean       std       min       max   percent       std
# oname:obs/obs_etf_us-fpe.np_otype:arr     639         77       135      8.63       120       150        99     0.463
# oname:obs/obs_swe_us-fpe.np_otype:arr    1924        561      1.41     0.575      0.85      2.68      1.05     0.463
#
#
#    ---  parameter group change summary  ---
# group     count  mean chg  std chg  n at ubnd  % at ubnd  n at lbnd  % at lbnd  n std decr
# ndvi_k        1     5.889    33.28          2         10          0          0           0
# swe_beta      1     1.454    2.187          0          0          0          0           0
# swe_alpha     1      12.7    22.76          0          0          0          0           0
# ndvi_0        1     17.16     76.2          0          0          0          0           0
# mad           1     9.819    54.81          0          0          0          0           0
# ks_alpha      1     18.17    33.33          0          0          0          0           0
# kr_alpha      1     38.94    71.63          0          0          0          0           0
# aw            1     2.828    50.67          0          0          0          0           0
#
# ...saved parameter change summary to 2_Fort_Peck.1.pcs.csv
#
#   ---  phi-based termination criteria check  ---
# ...phiredstp:  0.01
# ...nphistp:  3
# ...nphinored (also used for consecutive bad lambda cycles):  3
# ...best mean phi sequence: 421.98 , 200.465 ,
# ...best phi yet:  200.465
# ...number of consecutive bad lambda testing cycles:  0
# ...number of iterations satisfying phiredstp criteria:  1
# ...number of iterations since best yet mean phi:  0
#
#   ---  starting solve for iteration: 2  ---
# ...current lambda:  0.075
# ...preparing fast-lookup containers for threaded localization solve
# ...starting calcs for glm factor 0.0075
# ...finished calcs for: 0.0075
# ...starting calcs for glm factor 0.075
# ...finished calcs for: 0.075
# ...starting calcs for glm factor 0.75
# ...finished calcs for: 0.75
#
#   ---  running upgrade ensembles  ---
# ...subset idx:pe real name:  3:BASE, 7:3, 9:7, 11:9,
# ...subset idx:oe real name:  3:BASE, 7:3, 9:7, 11:9,
#     running model 36 times
#     starting at 01/14/26 18:25:31
#     20 agents ready
#
#
# PANTHER progress
#    avg = average model run time in minutes
#    runs(C = completed | F = failed | T = timed out)
#    agents(R = running | W = waiting | U = unavailable)
# --------------------------------------------------------------------------------
# 01/14 18:26:04 remaining file transfers: 0|T0    ) agents(R1   |W19  |U0   ) 0
#
#    36 runs complete :  0 runs failed
#    0.269 avg run time (min) : 0.552 run mgr time (min)
#    20 agents connected
#
#
#
#   ---  evaluating upgrade ensembles  ---
# ...last mean:  200.465
# ...last stdev:  24.415
#
#   ---  phi summary for best lambda, scale fac: 0.0075 , 1.1 ,   ---
#        phi type           mean            std            min            max
#        measured        180.087        33.7604        130.062        204.094
#          actual        128.143        2.19085        126.066        130.062
#      note: 'measured' phi reported above includes
#            realizations of measurement noise,
#            'actual' phi does not.
#
#   ---  running remaining realizations for best lambda, scale:0.0075 , 1.1 ,   ---
#     running model 16 times
#     starting at 01/14/26 18:26:06
#     20 agents ready
#
#
# PANTHER progress
#    avg = average model run time in minutes
#    runs(C = completed | F = failed | T = timed out)
#    agents(R = running | W = waiting | U = unavailable)
# --------------------------------------------------------------------------------
# 01/14 18:26:22 remaining file transfers: 0|T0    ) agents(R4   |W16  |U0   ) 0
#
#    16 runs complete :  0 runs failed
#    0.263 avg run time (min) : 0.278 run mgr time (min)
#    20 agents connected
#
#
# ...phi summary for entire ensemble using lambda,scale_fac 0.0075 , 1.1 ,
#        phi type           mean            std            min            max
#        measured        194.576        22.5198        130.062        233.906
#          actual         131.92        5.24775        126.066        144.447
#      note: 'measured' phi reported above includes
#            realizations of measurement noise,
#            'actual' phi does not.
# ...last best mean phi * acceptable phi factor:  210.488
# ...current best mean phi:  194.576
#
#   ---  updating parameter ensemble  ---
#
#   ---  updating lambda to  0.005625  ---
#
#   ---  EnsembleMethod iteration 2 report  ---
#    number of active realizations:   20
#    number of model runs:            124
#       current obs ensemble saved to 2_Fort_Peck.2.obs.csv
#       current par ensemble saved to 2_Fort_Peck.2.par.csv
# saved par and rei files for realization BASE for iteration 2
# saved par and rei files for realization BASE
#        phi type           mean            std            min            max
#        measured        194.576        22.5198        130.062        233.906
#          actual         131.92        5.24775        126.066        144.447
#      note: 'measured' phi reported above includes
#            realizations of measurement noise,
#            'actual' phi does not.
#   ---  observation group phi summary ---
#        (computed using 'actual' phi)
#            (sorted by mean phi)
# group                                   count  nconflict      mean       std       min       max   percent       std
# oname:obs/obs_etf_us-fpe.np_otype:arr     639        103       131      5.56       124       144        99      0.43
# oname:obs/obs_swe_us-fpe.np_otype:arr    1924        556      1.26     0.528     0.854      2.63     0.967      0.43
#
#
#    ---  parameter group change summary  ---
# group     count  mean chg  std chg  n at ubnd  % at ubnd  n at lbnd  % at lbnd  n std decr
# ndvi_k        1     8.702    52.42          1          5          0          0           0
# swe_beta      1     11.03    5.465          0          0          0          0           0
# swe_alpha     1     24.49    33.72          0          0          0          0           0
# ndvi_0        1     27.67    91.18          0          0          0          0           0
# mad           1     3.429       64          0          0          0          0           0
# ks_alpha      1     28.96    51.47          0          0          0          0           0
# kr_alpha      1     45.35    85.68          0          0          0          0           0
# aw            1     2.978    64.15          0          0          0          0           0
#
# ...saved parameter change summary to 2_Fort_Peck.2.pcs.csv
#
#   ---  phi-based termination criteria check  ---
# ...phiredstp:  0.01
# ...nphistp:  3
# ...nphinored (also used for consecutive bad lambda cycles):  3
# ...best mean phi sequence: 421.98 , 200.465 , 194.576 ,
# ...best phi yet:  194.576
# ...number of consecutive bad lambda testing cycles:  0
# ...number of iterations satisfying phiredstp criteria:  1
# ...number of iterations since best yet mean phi:  0
#
#   ---  starting solve for iteration: 3  ---
# ...current lambda:  0.005625
# ...preparing fast-lookup containers for threaded localization solve
# ...starting calcs for glm factor 0.0005625
# ...finished calcs for: 0.0005625
# ...starting calcs for glm factor 0.005625
# ...finished calcs for: 0.005625
# ...starting calcs for glm factor 0.05625
# ...finished calcs for: 0.05625
#
#   ---  running upgrade ensembles  ---
# ...subset idx:pe real name:  0:BASE, 6:13, 7:0, 9:2,
# ...subset idx:oe real name:  0:BASE, 6:13, 7:0, 9:2,
#     running model 36 times
#     starting at 01/14/26 18:26:24
#     20 agents ready
#
#
# PANTHER progress
#    avg = average model run time in minutes
#    runs(C = completed | F = failed | T = timed out)
#    agents(R = running | W = waiting | U = unavailable)
# --------------------------------------------------------------------------------
# 01/14 18:26:59 remaining file transfers: 0|T0    ) agents(R1   |W19  |U0   ) 0
#
#    36 runs complete :  0 runs failed
#    0.275 avg run time (min) : 0.57 run mgr time (min)
#    20 agents connected
#
#
#
#   ---  evaluating upgrade ensembles  ---
# ...last mean:  194.576
# ...last stdev:  22.5198
#
#   ---  phi summary for best lambda, scale fac: 0.05625 , 0.75 ,   ---
#        phi type           mean            std            min            max
#        measured        170.895        26.4098        131.875        188.284
#          actual        130.863        1.53991        128.744        132.118
#      note: 'measured' phi reported above includes
#            realizations of measurement noise,
#            'actual' phi does not.
#
#   ---  running remaining realizations for best lambda, scale:0.05625 , 0.75 ,   ---
#     running model 16 times
#     starting at 01/14/26 18:27:00
#     20 agents ready
#
#
# PANTHER progress
#    avg = average model run time in minutes
#    runs(C = completed | F = failed | T = timed out)
#    agents(R = running | W = waiting | U = unavailable)
# --------------------------------------------------------------------------------
# 01/14 18:27:18 remaining file transfers: 0|T0    ) agents(R1   |W19  |U0   ) 0
#
#    16 runs complete :  0 runs failed
#    0.271 avg run time (min) : 0.293 run mgr time (min)
#    20 agents connected
#
#
# ...phi summary for entire ensemble using lambda,scale_fac 0.05625 , 0.75 ,
#        phi type           mean            std            min            max
#        measured        194.624        22.2885        131.875        236.793
#          actual        131.995         5.3569        125.487        142.688
#      note: 'measured' phi reported above includes
#            realizations of measurement noise,
#            'actual' phi does not.
# ...last best mean phi * acceptable phi factor:  204.305
# ...current best mean phi:  194.624
#
#   ---  updating parameter ensemble  ---
#
#   ---  updating lambda to  0.0421875  ---
#
#   ---  EnsembleMethod iteration 3 report  ---
#    number of active realizations:   20
#    number of model runs:            176
#       current obs ensemble saved to 2_Fort_Peck.3.obs.csv
#       current par ensemble saved to 2_Fort_Peck.3.par.csv
# saved par and rei files for realization BASE for iteration 3
# saved par and rei files for realization BASE
#        phi type           mean            std            min            max
#        measured        194.624        22.2885        131.875        236.793
#          actual        131.995         5.3569        125.487        142.688
#      note: 'measured' phi reported above includes
#            realizations of measurement noise,
#            'actual' phi does not.
#   ---  observation group phi summary ---
#        (computed using 'actual' phi)
#            (sorted by mean phi)
# group                                   count  nconflict      mean       std       min       max   percent       std
# oname:obs/obs_etf_us-fpe.np_otype:arr     639        108       131      5.67       124       142      99.1     0.414
# oname:obs/obs_swe_us-fpe.np_otype:arr    1924        642      1.19     0.503     0.856      2.59     0.915     0.414
#
#
#    ---  parameter group change summary  ---
# group     count  mean chg  std chg  n at ubnd  % at ubnd  n at lbnd  % at lbnd  n std decr
# swe_beta      1     15.15    7.597          0          0          0          0           0
# swe_alpha     1     40.62    40.07          0          0          0          0           0
# ndvi_k        1     7.908    58.82          0          0          0          0           0
# ndvi_0        1     28.09    92.35          0          0          0          0           0
# mad           1     8.768    65.58          0          0          0          0           0
# ks_alpha      1     30.59    55.16          0          0          0          0           0
# kr_alpha      1      47.1    88.12          0          0          0          0           0
# aw            1     3.259    66.93          0          0          0          0           0
#
# ...saved parameter change summary to 2_Fort_Peck.3.pcs.csv
#
#   ---  phi-based termination criteria check  ---
# ...phiredstp:  0.01
# ...nphistp:  3
# ...nphinored (also used for consecutive bad lambda cycles):  3
# ...best mean phi sequence: 421.98 , 200.465 , 194.576 , 194.624 ,
# ...best phi yet:  194.576
# ...number of consecutive bad lambda testing cycles:  0
# ...number of iterations satisfying phiredstp criteria:  2
# ...number of iterations since best yet mean phi:  1
# ...solution iterations >= noptmax, all done
#
#
# pestpp-ies analysis complete...
# started at 01/14/26 18:23:51
# finished at 01/14/26 18:27:20
# took 3.46667 minutes

# %% [markdown]
# ## Debugging Tips
#
# If calibration fails, try these steps:
#
# ### Never saw the PEST++ panther logo?
# - Ensure `pestpp-ies` is in your PATH
# - Try running with full path: `/path/to/pestpp-ies`
# - On Windows, use `.exe` extension
#
# ### Python error traceback?
# Debug from the bottom up:
# 1. Verify `swimrs/calibrate/run_mp.py` runs standalone
# 2. Test `custom_forward_run.py` from the pest directory
# 3. Try running `pestpp-ies` directly from pest directory
#
# ### Saw panther but got errors?
# Common error: `output file 'pred/pred_swe_US-FPe.np' not found`
# - This usually means SWIM failed before writing predictions
# - Set `cleanup=False` above to preserve worker directories
# - Check `workers/worker_0/panther_worker.rec` for errors
#
# **Most errors (90%) are due to incorrect paths!**

# %% [markdown]
# ## 6. Check Results
#
# After successful calibration, parameter files are saved for each optimization iteration:

# %%
# Parameter files are in master_dir after calibration
import os
import shutil

results_dir = builder.master_dir if os.path.exists(builder.master_dir) else builder.pest_dir

par_files = [f for f in sorted(os.listdir(results_dir)) if '.par.csv' in f]
print(f"Parameter files (in {results_dir}):")
for f in par_files:
    print(f"  {f}")

if par_files:
    final_par = par_files[-1]
    print(f"\nFinal calibrated parameters: {final_par}")
    
    # Copy final parameters to pest/archive/ for consistency with calibration.py script
    archive_dir = os.path.join(builder.pest_dir, 'archive')
    os.makedirs(archive_dir, exist_ok=True)
    src = os.path.join(results_dir, final_par)
    dst = os.path.join(archive_dir, final_par)
    shutil.copy2(src, dst)
    print(f"Archived to: {dst}")

# Close the container
container.close()
print("\nContainer closed.")
# Out:
# Parameter files (in /home/dgketchum/code/swim-rs/examples/2_Fort_Peck/master):
#   2_Fort_Peck.0.par.csv
#   2_Fort_Peck.1.par.csv
#   2_Fort_Peck.2.par.csv
#   2_Fort_Peck.3.par.csv
#
# Final calibrated parameters: 2_Fort_Peck.3.par.csv
# Archived to: /home/dgketchum/code/swim-rs/examples/2_Fort_Peck/pest/archive/2_Fort_Peck.3.par.csv
#
# Container closed.

# %% [markdown]
# ## Summary
#
# You've set up and run a PEST++ calibration using:
# - SSEBop ETf observations from Landsat
# - SNODAS SWE observations
# - Iterative Ensemble Smoother (pestpp-ies)
#
# The parameter files (e.g., `2_Fort_Peck.3.par.csv`) contain the calibrated parameter sets. Each row represents a different realization from the ensemble.
#
# **Next step:** In notebook `03_calibrated_model.ipynb`, we'll run the model in forecast mode with calibrated parameters and validate against flux tower observations.
