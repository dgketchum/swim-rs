# %% [markdown]
# # Calibration Tutorial - Fort Peck, MT - Unirrigated Flux Plot
#
# ## Step 2: Calibrate with PEST++
#
# Now we see if we can improve the model's performance through calibration.
#
# ### PEST++ Resources
#
# PEST++ has excellent documentation covering both theory and practice:
#
# 1. **The PEST Manual 4th Ed.** (Doherty, 2002): https://www.epa.gov/sites/default/files/documents/PESTMAN.PDF
# 2. **GMDSI tutorial notebooks**: https://github.com/gmdsi/GMDSI_notebooks
# 3. **PEST++ User's Manual**: https://github.com/usgs/pestpp/blob/master/documentation/pestpp_users_manual.md
# 4. **PEST Book** (Doherty, 2015): https://pesthomepage.org/pest-book
#
# **Note:** We use PT-JPL ETf and SNODAS SWE for calibration - not flux observations. The flux data is reserved for validation only.

# %% [markdown]
# ### PEST++ Installation
#
# Install PEST++ via conda-forge (recommended):
#
# ```bash
# conda install conda-forge::pestpp
# ```
#
# This installs `pestpp-ies` and other PEST++ tools directly into your conda environment. Verify the installation:
#
# ```bash
# pestpp-ies --version
# ```
#
# **Alternative:** For manual installation from source, see the [PEST++ GitHub releases](https://github.com/usgs/pestpp/releases).

# %%
import os
import sys

root = os.path.abspath('../..')
sys.path.append(root)

from swimrs.container import SwimContainer
from swimrs.calibrate.pest_builder import PestBuilder
from swimrs.swim.config import ProjectConfig
from swimrs.calibrate.run_pest import run_pst
# Out:
# /home/dgketchum/miniconda/envs/swim/lib/python3.11/site-packages/pyemu/__init__.py:37: UserWarning: Failed to import legacy module. May impact ability to access older methods.ModuleNotFoundError No module named 'flopy'

# %% [markdown]
# ## 1. Load Configuration
#
# Load the project configuration and prepare paths.

# %%
project = '2_Fort_Peck'
project_ws = os.path.abspath('.')

config_path = os.path.join(project_ws, '2_Fort_Peck.toml')

config = ProjectConfig()
config.read_config(config_path, project_ws)

# %% [markdown]
# ## 2. Generate Observation Files
#
# PEST++ needs observation files (ETf and SWE) to compare against model predictions. We export these from the SwimContainer built in the data preparation step.
#
# The export creates per-field numpy files:
# - `obs_etf_{field_id}.np`: ETf observations (PT-JPL) with irrigation mask switching
# - `obs_swe_{field_id}.np`: SWE observations from SNODAS

# %%
# Open container for observations export and PEST++ setup
container_path = os.path.join(project_ws, 'data', f'{project}.swim')
container = SwimContainer.open(container_path, mode='r')

# Export observation files for PEST++ calibration
# Note: obs_folder is set to {pest_run_dir}/obs in the TOML config
obs_dir = os.path.join(project_ws, 'data', 'pestrun', 'obs')
os.makedirs(obs_dir, exist_ok=True)

container.export.observations(
    output_dir=obs_dir,
    etf_model='ptjpl',
    masks=('irr', 'inv_irr'),
    irr_threshold=0.1,
)
print(f"Observation files written to {obs_dir}")
# Out:
# Observation files written to /home/dgketchum/code/swim-rs/examples/2_Fort_Peck/data/pestrun/obs

# %% [markdown]
# ## 3. Build PEST++ Control Files
#
# The `PestBuilder` class sets up everything needed for PEST++ calibration:
#
# ### Calibration Loop
# 1. Initialize model with initial parameter values
# 2. Run model, write results
# 3. Compare results to observations (ETf, SWE)
# 4. Propose new parameters
# 5. Repeat until convergence
#
# ### Tunable Parameters
# SWIM uses 8 tunable parameters:
# - **Soil water:** `aw` (available water), `rew` (readily evaporable water), `tew` (total evaporable water)
# - **NDVI-Kcb relationship:** `ndvi_alpha`, `ndvi_beta`
# - **Stress threshold:** `mad` (management allowable depletion)
# - **Snow melt:** `swe_alpha`, `swe_beta`

# %%
# PestBuilder auto-generates custom_forward_run.py using the process package
# with portable swim_input.h5 file for fully self-contained workers
builder = PestBuilder(config, container=container, use_existing=False)
# Out:
# Using default Python script at: /home/dgketchum/code/swim-rs/src/swimrs/calibrate/custom_forward_run.py

# %% [markdown]
# ### Build the .pst Control File
#
# The `build_pest()` method:
# - Copies project files to a `pest/` directory
# - Creates the `.pst` control file
# - Sets up parameter templates (`.tpl`) and instruction files (`.ins`)
#
# **Note:** ETf observations are sparse (only on satellite capture dates). The PEST builder automatically assigns weight 1.0 to valid observations and weight 0.0 to missing dates, ensuring we only calibrate against actual satellite captures.

# %%
# Build the pest control file
# WARNING: This will erase any existing pest directory!
builder.build_pest(target_etf=config.etf_target_model, members=config.etf_ensemble_members)
# Out:
# 2026-01-18 22:48:46.776546 starting: opening PstFrom.log for logging
# 2026-01-18 22:48:46.777126 starting PstFrom process
# 2026-01-18 22:48:46.777219 starting: setting up dirs
# 2026-01-18 22:48:46.777393 starting: removing existing new_d '/home/dgketchum/code/swim-rs/examples/2_Fort_Peck/data/pestrun/pest'
# 2026-01-18 22:48:46.778708 finished: removing existing new_d '/home/dgketchum/code/swim-rs/examples/2_Fort_Peck/data/pestrun/pest' took: 0:00:00.001315
# 2026-01-18 22:48:46.778856 starting: copying original_d '/home/dgketchum/code/swim-rs/examples/2_Fort_Peck/data/pestrun/_template' to new_d '/home/dgketchum/code/swim-rs/examples/2_Fort_Peck/data/pestrun/pest'
# 2026-01-18 22:48:46.781321 finished: copying original_d '/home/dgketchum/code/swim-rs/examples/2_Fort_Peck/data/pestrun/_template' to new_d '/home/dgketchum/code/swim-rs/examples/2_Fort_Peck/data/pestrun/pest' took: 0:00:00.002465
# 2026-01-18 22:48:46.781793 finished: setting up dirs took: 0:00:00.004574
# 2026-01-18 22:48:46.782108 starting: adding constant type m style parameters for file(s) ['params.csv']
# 2026-01-18 22:48:46.782367 starting: loading list-style /home/dgketchum/code/swim-rs/examples/2_Fort_Peck/data/pestrun/pest/params.csv
# 2026-01-18 22:48:46.782526 starting: reading list-style file: /home/dgketchum/code/swim-rs/examples/2_Fort_Peck/data/pestrun/pest/params.csv
# 2026-01-18 22:48:46.786572 finished: reading list-style file: /home/dgketchum/code/swim-rs/examples/2_Fort_Peck/data/pestrun/pest/params.csv took: 0:00:00.004046
# 2026-01-18 22:48:46.786922 loaded list-style '/home/dgketchum/code/swim-rs/examples/2_Fort_Peck/data/pestrun/pest/params.csv' of shape (9, 3)
# 2026-01-18 22:48:46.790507 finished: loading list-style /home/dgketchum/code/swim-rs/examples/2_Fort_Peck/data/pestrun/pest/params.csv took: 0:00:00.008140
# 2026-01-18 22:48:46.790722 starting: writing list-style template file '/home/dgketchum/code/swim-rs/examples/2_Fort_Peck/data/pestrun/pest/p_aw_US-FPe_0_constant.csv.tpl'
# 2026-01-18 22:48:46.808533 finished: writing list-style template file '/home/dgketchum/code/swim-rs/examples/2_Fort_Peck/data/pestrun/pest/p_aw_US-FPe_0_constant.csv.tpl' took: 0:00:00.017811
# 2026-01-18 22:48:46.812346 finished: adding constant type m style parameters for file(s) ['params.csv'] took: 0:00:00.030238
# 2026-01-18 22:48:46.812487 starting: adding constant type m style parameters for file(s) ['params.csv']
# 2026-01-18 22:48:46.812573 starting: loading list-style /home/dgketchum/code/swim-rs/examples/2_Fort_Peck/data/pestrun/pest/params.csv
# 2026-01-18 22:48:46.812633 starting: reading list-style file: /home/dgketchum/code/swim-rs/examples/2_Fort_Peck/data/pestrun/pest/params.csv
# 2026-01-18 22:48:46.813760 finished: reading list-style file: /home/dgketchum/code/swim-rs/examples/2_Fort_Peck/data/pestrun/pest/params.csv took: 0:00:00.001127
# 2026-01-18 22:48:46.813860 loaded list-style '/home/dgketchum/code/swim-rs/examples/2_Fort_Peck/data/pestrun/pest/params.csv' of shape (9, 3)
# 2026-01-18 22:48:46.815346 finished: loading list-style /home/dgketchum/code/swim-rs/examples/2_Fort_Peck/data/pestrun/pest/params.csv took: 0:00:00.002773
# 2026-01-18 22:48:46.815458 starting: writing list-style template file '/home/dgketchum/code/swim-rs/examples/2_Fort_Peck/data/pestrun/pest/p_ks_alpha_US-FPe_0_constant.csv.tpl'
# 2026-01-18 22:48:46.825431 finished: writing list-style template file '/home/dgketchum/code/swim-rs/examples/2_Fort_Peck/data/pestrun/pest/p_ks_alpha_US-FPe_0_constant.csv.tpl' took: 0:00:00.009973
# 2026-01-18 22:48:46.828795 finished: adding constant type m style parameters for file(s) ['params.csv'] took: 0:00:00.016308
# 2026-01-18 22:48:46.828918 starting: adding constant type m style parameters for file(s) ['params.csv']
# 2026-01-18 22:48:46.828996 starting: loading list-style /home/dgketchum/code/swim-rs/examples/2_Fort_Peck/data/pestrun/pest/params.csv
# 2026-01-18 22:48:46.829053 starting: reading list-style file: /home/dgketchum/code/swim-rs/examples/2_Fort_Peck/data/pestrun/pest/params.csv
# 2026-01-18 22:48:46.830089 finished: reading list-style file: /home/dgketchum/code/swim-rs/examples/2_Fort_Peck/data/pestrun/pest/params.csv took: 0:00:00.001036
# 2026-01-18 22:48:46.830197 loaded list-style '/home/dgketchum/code/swim-rs/examples/2_Fort_Peck/data/pestrun/pest/params.csv' of shape (9, 3)
# 2026-01-18 22:48:46.831598 finished: loading list-style /home/dgketchum/code/swim-rs/examples/2_Fort_Peck/data/pestrun/pest/params.csv took: 0:00:00.002602
# 2026-01-18 22:48:46.831705 starting: writing list-style template file '/home/dgketchum/code/swim-rs/examples/2_Fort_Peck/data/pestrun/pest/p_kr_alpha_US-FPe_0_constant.csv.tpl'
# 2026-01-18 22:48:46.839808 finished: writing list-style template file '/home/dgketchum/code/swim-rs/examples/2_Fort_Peck/data/pestrun/pest/p_kr_alpha_US-FPe_0_constant.csv.tpl' took: 0:00:00.008103
# 2026-01-18 22:48:46.842872 finished: adding constant type m style parameters for file(s) ['params.csv'] took: 0:00:00.013954
# 2026-01-18 22:48:46.842983 starting: adding constant type m style parameters for file(s) ['params.csv']
# 2026-01-18 22:48:46.843057 starting: loading list-style /home/dgketchum/code/swim-rs/examples/2_Fort_Peck/data/pestrun/pest/params.csv
# 2026-01-18 22:48:46.843111 starting: reading list-style file: /home/dgketchum/code/swim-rs/examples/2_Fort_Peck/data/pestrun/pest/params.csv
# 2026-01-18 22:48:46.844021 finished: reading list-style file: /home/dgketchum/code/swim-rs/examples/2_Fort_Peck/data/pestrun/pest/params.csv took: 0:00:00.000910
# 2026-01-18 22:48:46.844110 loaded list-style '/home/dgketchum/code/swim-rs/examples/2_Fort_Peck/data/pestrun/pest/params.csv' of shape (9, 3)
# 2026-01-18 22:48:46.845375 finished: loading list-style /home/dgketchum/code/swim-rs/examples/2_Fort_Peck/data/pestrun/pest/params.csv took: 0:00:00.002318
# 2026-01-18 22:48:46.845951 starting: writing list-style template file '/home/dgketchum/code/swim-rs/examples/2_Fort_Peck/data/pestrun/pest/p_ndvi_k_US-FPe_0_constant.csv.tpl'
# 2026-01-18 22:48:46.854961 finished: writing list-style template file '/home/dgketchum/code/swim-rs/examples/2_Fort_Peck/data/pestrun/pest/p_ndvi_k_US-FPe_0_constant.csv.tpl' took: 0:00:00.009010
# 2026-01-18 22:48:46.858178 finished: adding constant type m style parameters for file(s) ['params.csv'] took: 0:00:00.015195
# 2026-01-18 22:48:46.858287 starting: adding constant type m style parameters for file(s) ['params.csv']
# 2026-01-18 22:48:46.858359 starting: loading list-style /home/dgketchum/code/swim-rs/examples/2_Fort_Peck/data/pestrun/pest/params.csv
# 2026-01-18 22:48:46.858408 starting: reading list-style file: /home/dgketchum/code/swim-rs/examples/2_Fort_Peck/data/pestrun/pest/params.csv
# 2026-01-18 22:48:46.859285 finished: reading list-style file: /home/dgketchum/code/swim-rs/examples/2_Fort_Peck/data/pestrun/pest/params.csv took: 0:00:00.000877
# 2026-01-18 22:48:46.859370 loaded list-style '/home/dgketchum/code/swim-rs/examples/2_Fort_Peck/data/pestrun/pest/params.csv' of shape (9, 3)
# 2026-01-18 22:48:46.860637 finished: loading list-style /home/dgketchum/code/swim-rs/examples/2_Fort_Peck/data/pestrun/pest/params.csv took: 0:00:00.002278
# 2026-01-18 22:48:46.860735 starting: writing list-style template file '/home/dgketchum/code/swim-rs/examples/2_Fort_Peck/data/pestrun/pest/p_ndvi_0_US-FPe_0_constant.csv.tpl'
# 2026-01-18 22:48:46.868911 finished: writing list-style template file '/home/dgketchum/code/swim-rs/examples/2_Fort_Peck/data/pestrun/pest/p_ndvi_0_US-FPe_0_constant.csv.tpl' took: 0:00:00.008176
# 2026-01-18 22:48:46.872063 finished: adding constant type m style parameters for file(s) ['params.csv'] took: 0:00:00.013776
# 2026-01-18 22:48:46.872175 starting: adding constant type m style parameters for file(s) ['params.csv']
# 2026-01-18 22:48:46.872250 starting: loading list-style /home/dgketchum/code/swim-rs/examples/2_Fort_Peck/data/pestrun/pest/params.csv
# 2026-01-18 22:48:46.872303 starting: reading list-style file: /home/dgketchum/code/swim-rs/examples/2_Fort_Peck/data/pestrun/pest/params.csv
# 2026-01-18 22:48:46.873207 finished: reading list-style file: /home/dgketchum/code/swim-rs/examples/2_Fort_Peck/data/pestrun/pest/params.csv took: 0:00:00.000904
# 2026-01-18 22:48:46.873297 loaded list-style '/home/dgketchum/code/swim-rs/examples/2_Fort_Peck/data/pestrun/pest/params.csv' of shape (9, 3)
# 2026-01-18 22:48:46.874597 finished: loading list-style /home/dgketchum/code/swim-rs/examples/2_Fort_Peck/data/pestrun/pest/params.csv took: 0:00:00.002347
# 2026-01-18 22:48:46.874720 starting: writing list-style template file '/home/dgketchum/code/swim-rs/examples/2_Fort_Peck/data/pestrun/pest/p_mad_US-FPe_0_constant.csv.tpl'
# 2026-01-18 22:48:46.889326 finished: writing list-style template file '/home/dgketchum/code/swim-rs/examples/2_Fort_Peck/data/pestrun/pest/p_mad_US-FPe_0_constant.csv.tpl' took: 0:00:00.014606
# 2026-01-18 22:48:46.897952 finished: adding constant type m style parameters for file(s) ['params.csv'] took: 0:00:00.025777
# 2026-01-18 22:48:46.898257 starting: adding constant type m style parameters for file(s) ['params.csv']
# 2026-01-18 22:48:46.898456 starting: loading list-style /home/dgketchum/code/swim-rs/examples/2_Fort_Peck/data/pestrun/pest/params.csv
# 2026-01-18 22:48:46.898554 starting: reading list-style file: /home/dgketchum/code/swim-rs/examples/2_Fort_Peck/data/pestrun/pest/params.csv
# 2026-01-18 22:48:46.900371 finished: reading list-style file: /home/dgketchum/code/swim-rs/examples/2_Fort_Peck/data/pestrun/pest/params.csv took: 0:00:00.001817
# 2026-01-18 22:48:46.900524 loaded list-style '/home/dgketchum/code/swim-rs/examples/2_Fort_Peck/data/pestrun/pest/params.csv' of shape (9, 3)
# 2026-01-18 22:48:46.902867 finished: loading list-style /home/dgketchum/code/swim-rs/examples/2_Fort_Peck/data/pestrun/pest/params.csv took: 0:00:00.004411
# 2026-01-18 22:48:46.903029 starting: writing list-style template file '/home/dgketchum/code/swim-rs/examples/2_Fort_Peck/data/pestrun/pest/p_swe_alpha_US-FPe_0_constant.csv.tpl'
# 2026-01-18 22:48:46.914613 finished: writing list-style template file '/home/dgketchum/code/swim-rs/examples/2_Fort_Peck/data/pestrun/pest/p_swe_alpha_US-FPe_0_constant.csv.tpl' took: 0:00:00.011584
# 2026-01-18 22:48:46.918234 finished: adding constant type m style parameters for file(s) ['params.csv'] took: 0:00:00.019977
# 2026-01-18 22:48:46.918341 starting: adding constant type m style parameters for file(s) ['params.csv']
# 2026-01-18 22:48:46.918415 starting: loading list-style /home/dgketchum/code/swim-rs/examples/2_Fort_Peck/data/pestrun/pest/params.csv
# 2026-01-18 22:48:46.918463 starting: reading list-style file: /home/dgketchum/code/swim-rs/examples/2_Fort_Peck/data/pestrun/pest/params.csv
# 2026-01-18 22:48:46.919396 finished: reading list-style file: /home/dgketchum/code/swim-rs/examples/2_Fort_Peck/data/pestrun/pest/params.csv took: 0:00:00.000933
# 2026-01-18 22:48:46.919474 loaded list-style '/home/dgketchum/code/swim-rs/examples/2_Fort_Peck/data/pestrun/pest/params.csv' of shape (9, 3)
# 2026-01-18 22:48:46.920638 finished: loading list-style /home/dgketchum/code/swim-rs/examples/2_Fort_Peck/data/pestrun/pest/params.csv took: 0:00:00.002223
# 2026-01-18 22:48:46.920730 starting: writing list-style template file '/home/dgketchum/code/swim-rs/examples/2_Fort_Peck/data/pestrun/pest/p_swe_beta_US-FPe_0_constant.csv.tpl'
# 2026-01-18 22:48:46.928575 finished: writing list-style template file '/home/dgketchum/code/swim-rs/examples/2_Fort_Peck/data/pestrun/pest/p_swe_beta_US-FPe_0_constant.csv.tpl' took: 0:00:00.007845
# 2026-01-18 22:48:46.931546 finished: adding constant type m style parameters for file(s) ['params.csv'] took: 0:00:00.013205
# 2026-01-18 22:48:47.025622 starting: adding observations from output file obs/obs_etf_US-FPe.np
# 2026-01-18 22:48:47.026270 starting: adding observations from array output file 'obs/obs_etf_US-FPe.np'
# 2026-01-18 22:48:47.061007 starting: adding observation from instruction file '/home/dgketchum/code/swim-rs/examples/2_Fort_Peck/data/pestrun/pest/etf_US-FPe.ins'
# 2026-01-18 22:48:47.175470 finished: adding observation from instruction file '/home/dgketchum/code/swim-rs/examples/2_Fort_Peck/data/pestrun/pest/etf_US-FPe.ins' took: 0:00:00.114463
# 2026-01-18 22:48:47.176270 finished: adding observations from array output file 'obs/obs_etf_US-FPe.np' took: 0:00:00.150000
# 2026-01-18 22:48:47.176466 finished: adding observations from output file obs/obs_etf_US-FPe.np took: 0:00:00.150844
# 2026-01-18 22:48:47.883847 starting: adding observations from output file obs/obs_swe_US-FPe.np
# 2026-01-18 22:48:47.884442 starting: adding observations from array output file 'obs/obs_swe_US-FPe.np'
# 2026-01-18 22:48:47.916250 starting: adding observation from instruction file '/home/dgketchum/code/swim-rs/examples/2_Fort_Peck/data/pestrun/pest/swe_US-FPe.ins'
# 2026-01-18 22:48:48.023802 finished: adding observation from instruction file '/home/dgketchum/code/swim-rs/examples/2_Fort_Peck/data/pestrun/pest/swe_US-FPe.ins' took: 0:00:00.107552
# 2026-01-18 22:48:48.024704 finished: adding observations from array output file 'obs/obs_swe_US-FPe.np' took: 0:00:00.140262
# 2026-01-18 22:48:48.024894 finished: adding observations from output file obs/obs_swe_US-FPe.np took: 0:00:00.141047
# noptmax:0, npar_adj:8, nnz_obs:2868
# Building portable swim_input.h5 with spinup state...
# Created swim_input.h5 at /home/dgketchum/code/swim-rs/examples/2_Fort_Peck/data/pestrun/pest/swim_input.h5
# noptmax:0, npar_adj:8, nnz_obs:2868
# Configured PEST++ for 1 targets,

# %%
# Show the files created in the pest directory
pest_files = [f for f in sorted(os.listdir(builder.pest_dir)) 
              if os.path.isfile(os.path.join(builder.pest_dir, f))]
print("Files in pest directory:")
for f in pest_files:
    print(f"  {f}")
# Out:
# Files in pest directory:
#   2_Fort_Peck.idx.csv
#   2_Fort_Peck.pst
#   2_fort_peck.insfile_data.csv
#   2_fort_peck.obs_data.csv
#   2_fort_peck.par_data.csv
#   2_fort_peck.pargp_data.csv
#   2_fort_peck.tplfile_data.csv
#   custom_forward_run.py
#   etf_US-FPe.ins
#   mult2model_info.csv
#   p_aw_US-FPe_0_constant.csv.tpl
#   p_kr_alpha_US-FPe_0_constant.csv.tpl
#   p_ks_alpha_US-FPe_0_constant.csv.tpl
#   p_mad_US-FPe_0_constant.csv.tpl
#   p_ndvi_0_US-FPe_0_constant.csv.tpl
#   p_ndvi_k_US-FPe_0_constant.csv.tpl
#   p_swe_alpha_US-FPe_0_constant.csv.tpl
#   p_swe_beta_US-FPe_0_constant.csv.tpl
#   params.csv
#   swe_US-FPe.ins
#   swim_input.h5

# %% [markdown]
# ### Examine the .pst File
#
# The PEST++ version 2 control file is concise, delegating details to external files:

# %%
with open(builder.pst_file, 'r') as f:
    print(f.read())
# Out:
# pcf version=2
# * control data keyword
# pestmode                                 estimation
# noptmax                                 0
# svdmode                                 1
# maxsing                          10000000
# eigthresh                           1e-06
# eigwrite                                1
# * parameter groups external
# 2_fort_peck.pargp_data.csv
# * parameter data external
# 2_fort_peck.par_data.csv
# * observation data external
# 2_fort_peck.obs_data.csv
# * model command line
# python custom_forward_run.py
# * model input external
# 2_fort_peck.tplfile_data.csv
# * model output external
# 2_fort_peck.insfile_data.csv

# %% [markdown]
# ## 4. Configure and Test
#
# Now we:
# 1. Build the localizer matrix (links parameters to relevant observations)
# 2. Run spinup to save initial water balance state
# 3. Do a dry run to verify everything works
# 4. Set control parameters for the full calibration

# %%
# Build localizer matrix
# - SWE observations update only swe_alpha and swe_beta
# - ETf observations update all other parameters
builder.build_localizer()

# Run spinup to save water balance state as initial conditions for calibration runs
# This runs the model once and saves the final state to spinup.json
print("Running spinup...")
builder.spinup(overwrite=True)

# Run a minimal model run to verify the setup
print("\nRunning dry run...")
builder.dry_run()

# Configure for 3 optimization iterations with 20 realizations each
# Increase realizations (e.g., 100-200) for production runs
builder.write_control_settings(noptmax=3, reals=20)
# Out:
# noptmax:0, npar_adj:8, nnz_obs:2868
# Running spinup...
# RUNNING SPINUP
# Spinup saved to /home/dgketchum/code/swim-rs/examples/2_Fort_Peck/data/pestrun/spinup.json
#
# Running dry run...
# noptmax:3, npar_adj:8, nnz_obs:2868
# writing /home/dgketchum/code/swim-rs/examples/2_Fort_Peck/data/pestrun/pest/2_Fort_Peck.pst with noptmax=3, 20 realizations

# %%
# Show the updated control file with calibration settings
with open(builder.pst_file, 'r') as f:
    print(f.read())
# Out:
# pcf version=2
# * control data keyword
# pestmode                                 estimation
# noptmax                                 3
# svdmode                                 1
# maxsing                          10000000
# eigthresh                           1e-06
# eigwrite                                1
# ies_localizer                  loc.mat
# ies_num_reals                  20
# ies_drop_conflicts             true
# * parameter groups external
# 2_fort_peck.pargp_data.csv
# * parameter data external
# 2_fort_peck.par_data.csv
# * observation data external
# 2_fort_peck.obs_data.csv
# * model command line
# python custom_forward_run.py
# * model input external
# 2_fort_peck.tplfile_data.csv
# * model output external
# 2_fort_peck.insfile_data.csv

# %% [markdown]
# ## 5. Run PEST++ Calibration
#
# Now we launch PEST++ with parallel workers. Adjust `workers` to match your machine's capabilities.
#
# **Important:** This can take a while. Watch for the progress indicator showing completed runs (C), failed (F), and total (T).

# %%
workers = config.workers or 6
_pst = f"{config.project_name}.pst"

print(f"Starting PEST++ with {workers} workers...")
print(f"Control file: {_pst}")

run_pst(builder.pest_dir,
        'pestpp-ies',
        _pst,
        num_workers=workers,
        worker_root=builder.workers_dir,
        master_dir=builder.master_dir,
        cleanup=True,
        verbose=True)
# Out:
# Starting PEST++ with 6 workers...
# Control file: 2_Fort_Peck.pst
# master:pestpp-ies 2_Fort_Peck.pst /h :5005 in /home/dgketchum/code/swim-rs/examples/2_Fort_Peck/data/pestrun/master
#
#
#              pestpp-ies: a GLM iterative ensemble smoother
#
#                    by the PEST++ development team
#
# ...processing command line: ' pestpp-ies 2_Fort_Peck.pst /h :5005'
# ...using panther run manager in master mode using port 5005
#
#
# version: 5.2.25
# binary compiled on Jan 13 2026 at 20:33:04
# using control file: "2_Fort_Peck.pst"
# in directory: "/home/dgketchum/code/swim-rs/examples/2_Fort_Peck/data/pestrun/master"
# on host: "fcfc-mcozoran"
# on a(n) linux operating system
# with release configuration
# started at 01/18/26 22:48:55
#
# processing control file 2_Fort_Peck.pst
#
#
# :~-._                                                 _.-~:
# : :.~^o._        ________---------________        _.o^~.:.:
#  : ::.`?88booo~~~.::::::::...::::::::::::..~~oood88P'.::.:
#  :  ::: `?88P .:::....         ........:::::. ?88P' :::. :
#   :  :::. `? .::.            . ...........:::. P' .:::. :
#    :  :::   ... ..  ...       .. .::::......::.   :::. :
#    `  :' .... ..  .:::::.     . ..:::::::....:::.  `: .'
#     :..    ____:::::::::.  . . ....:::::::::____  ... :
#    :... `:~    ^~-:::::..  .........:::::-~^    ~::.::::
#    `.::. `\   (8)  \b:::..::.:.:::::::d/  (8)   /'.::::'
#     ::::.  ~-._v    |b.::::::::::::::d|    v_.-~..:::::
#     `.:::::... ~~^?888b..:::::::::::d888P^~...::::::::'
#      `.::::::::::....~~~ .:::::::::~~~:::::::::::::::'
#       `..:::::::::::   .   ....::::    ::::::::::::,'
#         `. .:::::::    .      .::::.    ::::::::'.'
#           `._ .:::    .        :::::.    :::::_.'
#              `-. :    .        :::::      :,-'
#                 :.   :___     .:::___   .::
#       ..--~~~~--:+::. ~~^?b..:::dP^~~.::++:--~~~~--..
#         ___....--`+:::.    `~8~'    .:::+'--....___
#       ~~   __..---`_=:: ___gd8bg___ :==_'---..__   ~~
#        -~~~  _.--~~`-.~~~~~~~~~~~~~~~,-' ~~--._ ~~~-
#
#
#                starting PANTHER master...
#
# IP addresses:
#   0.0.0.0:5005 (IPv4)
#
# PANTHER master listening on socket: 0.0.0.0:5005 (IPv4)
#
#   ---  initializing  ---
# ...using glm algorithm
# ...using REDSVD for truncated svd solve
# ...maxsing: 10000000
# ...eigthresh:  1e-06
# ...initializing localizer
# ...using localized solution with 8 sequential upgrade steps
# ...localizing by parameters
# ...using lambda multipliers: 0.1 , 1 , 10 ,
# ...using lambda scaling factors: 0.75 , 1 , 1.1 ,
# ...acceptable phi factor:  1.05
# ...lambda increase factor:  10
# ...lambda decrease factor:  0.75
# ...max run fail:  1
# ...initializing prior parameter covariance matrix
# ...parcov loaded  from parameter bounds, using par_sigma_range 4
# ...initializing observation noise covariance matrix
# worker:pestpp-ies 2_Fort_Peck.pst /h localhost:5005 in /home/dgketchum/code/swim-rs/examples/2_Fort_Peck/data/pestrun/workers/worker_0
# worker:pestpp-ies 2_Fort_Peck.pst /h localhost:5005 in /home/dgketchum/code/swim-rs/examples/2_Fort_Peck/data/pestrun/workers/worker_1
# worker:pestpp-ies 2_Fort_Peck.pst /h localhost:5005 in /home/dgketchum/code/swim-rs/examples/2_Fort_Peck/data/pestrun/workers/worker_2
# worker:pestpp-ies 2_Fort_Peck.pst /h localhost:5005 in /home/dgketchum/code/swim-rs/examples/2_Fort_Peck/data/pestrun/workers/worker_3
# worker:pestpp-ies 2_Fort_Peck.pst /h localhost:5005 in /home/dgketchum/code/swim-rs/examples/2_Fort_Peck/data/pestrun/workers/worker_4
# worker:pestpp-ies 2_Fort_Peck.pst /h localhost:5005 in /home/dgketchum/code/swim-rs/examples/2_Fort_Peck/data/pestrun/workers/worker_5
# ...obscov loaded  from observation weights
# ...drawing parameter realizations:  20
# ...not using prior parameter covariance matrix scaling
# ...drawing observation noise realizations:  20
# observations not grouped by observations groups, reordering obs ensemble
# ...setting weights ensemble from control file weights
# ...saved weight ensemble to  2_Fort_Peck.weights.csv
# ...adding 'base' parameter values to ensemble
# ...adding 'base' observation values to ensemble
# ...adding 'base' weight values to weight ensemble
# ...saved initial parameter ensemble to  2_Fort_Peck.0.par.csv
# ...saved obs+noise observation ensemble (obsval + noise realizations) to  2_Fort_Peck.obs+noise.csv
# ...using subset in lambda testing, percentage of realizations used in subset testing:  10
# ...subset how:  RANDOM
# ...centering on ensemble mean vector
# ...running initial ensemble of size 20
#     running model 20 times
#     starting at 01/18/26 22:48:57
#
#     waiting for agents to appear...
#
#
# PANTHER progress
#    avg = average model run time in minutes
#    runs(C = completed | F = failed | T = timed out)
#    agents(R = running | W = waiting | U = unavailable)
# --------------------------------------------------------------------------------
# 01/18 22:49:10 remaining file transfers: 0|T0    ) agents(R2   |W4   |U0   ) 0
#
#    20 runs complete :  0 runs failed
#    0.051 avg run time (min) : 0.212 run mgr time (min)
#    6 agents connected
#
#
# ...saved initial obs ensemble to 2_Fort_Peck.0.obs.csv
# saved par and rei files for realization BASE for iteration 0
# saved par and rei files for realization BASE
#
#   ---  pre-drop initial phi summary  ---
#        phi type           mean            std            min            max
#        measured        937.968        445.817        547.271        2479.92
#          actual        724.013        423.875        464.988        2211.32
#      note: 'measured' phi reported above includes
#            realizations of measurement noise,
#            'actual' phi does not.
#   ---  observation group phi summary ---
#        (computed using 'actual' phi)
#            (sorted by mean phi)
# group                                   count  nconflict      mean       std       min       max   percent       std
# oname:obs/obs_etf_us-fpe.np_otype:arr     939         54       601       116       463       789      93.4      19.6
# oname:obs/obs_swe_us-fpe.np_otype:arr    1929          7       123       387     0.851  1.54e+03      6.63      19.6
#
# ...checking for prior-data conflict
#
#   ---  WARNING: 61 non-zero weighted observations are in conflict with the prior simulated ensemble.
#   ---
# ...see 2_Fort_Peck.0.pdc.csv for listing of conflicted observations
#
# ...dropping conflicted observations
# ...number of non-zero weighted observations reduced from 2868 to 2807
#
# ...updating localizer
# dropped 61 from localizer rows because forgive_missing is true
# ...saved adjusted weight ensemble to  2_Fort_Peck.adjusted.weights.csv
# saved par and rei files for realization BASE for iteration 0
# saved par and rei files for realization BASE
#
#   ---  initial phi summary  ---
#        phi type           mean            std            min            max
#        measured        758.317        438.447        402.496        2282.49
#          actual        580.761        419.089        336.348        2053.68
#      note: 'measured' phi reported above includes
#            realizations of measurement noise,
#            'actual' phi does not.
#   ---  observation group phi summary ---
#        (computed using 'actual' phi)
#            (sorted by mean phi)
# group                                   count  nconflict      mean       std       min       max   percent       std
# oname:obs/obs_etf_us-fpe.np_otype:arr     885          0       459       107       335       632      92.8      21.1
# oname:obs/obs_swe_us-fpe.np_otype:arr    1922          0       122       386      0.85  1.53e+03      7.24      21.1
#
# ...current lambda: 0.1
#
#    ---  parameter group change summary  ---
# group     count  mean chg  std chg  n at ubnd  % at ubnd  n at lbnd  % at lbnd  n std decr
# swe_beta      1         0        0          4         20          0          0           0
# ndvi_0        1         0        0          4         20          0          0           0
# mad           1         0        0          3         15          0          0           0
# swe_alpha     1         0        0          2         10          0          0           0
# ndvi_k        1         0        0          1          5          0          0           0
# aw            1         0        0          1          5          0          0           0
# ks_alpha      1         0        0          0          0          0          0           0
# kr_alpha      1         0        0          0          0          0          0           0
#
#
#   ---  initialization complete  ---
#
#   ---  starting solve for iteration: 1  ---
# ...current lambda:  0.1
# ...preparing fast-lookup containers for threaded localization solve
# ...starting calcs for glm factor 0.01
# ...finished calcs for: 0.01
# ...starting calcs for glm factor 0.1
# ...finished calcs for: 0.1
# ...starting calcs for glm factor 1
# ...finished calcs for: 1
#
#   ---  running upgrade ensembles  ---
# ...subset idx:pe real name:  2:2, 8:8, 16:16, 19:BASE,
# ...subset idx:oe real name:  2:2, 8:8, 16:16, 19:BASE,
#     running model 36 times
#     starting at 01/18/26 22:49:12
#     6 agents ready
#
#
# PANTHER progress
#    avg = average model run time in minutes
#    runs(C = completed | F = failed | T = timed out)
#    agents(R = running | W = waiting | U = unavailable)
# --------------------------------------------------------------------------------
# 01/18 22:49:31 remaining file transfers: 0|T0    ) agents(R0   |W4   |U2   ) 0
#
#    36 runs complete :  0 runs failed
#    0.0519 avg run time (min) : 0.317 run mgr time (min)
#    6 agents connected
#
#
#
#   ---  evaluating upgrade ensembles  ---
# ...last mean:  758.317
# ...last stdev:  438.447
#
#   ---  phi summary for best lambda, scale fac: 0.01 , 1 ,   ---
#        phi type           mean            std            min            max
#        measured        505.906        105.265        348.437        566.179
#          actual        342.968        17.2025        319.719        360.782
#      note: 'measured' phi reported above includes
#            realizations of measurement noise,
#            'actual' phi does not.
#
#   ---  running remaining realizations for best lambda, scale:0.01 , 1 ,   ---
#     running model 16 times
#     starting at 01/18/26 22:49:32
#     6 agents ready
#
#
# PANTHER progress
#    avg = average model run time in minutes
#    runs(C = completed | F = failed | T = timed out)
#    agents(R = running | W = waiting | U = unavailable)
# --------------------------------------------------------------------------------
# 01/18 22:49:42 remaining file transfers: 0|T0    ) agents(R4   |W2   |U0   ) 0
#
#    16 runs complete :  0 runs failed
#    0.0516 avg run time (min) : 0.157 run mgr time (min)
#    6 agents connected
#
#
# ...phi summary for entire ensemble using lambda,scale_fac 0.01 , 1 ,
#        phi type           mean            std            min            max
#        measured        522.495        48.9607        348.437        566.179
#          actual        344.638        13.1905        316.078        360.782
#      note: 'measured' phi reported above includes
#            realizations of measurement noise,
#            'actual' phi does not.
# ...last best mean phi * acceptable phi factor:  796.233
# ...current best mean phi:  522.495
#
#   ---  updating parameter ensemble  ---
#
#   ---  updating lambda to  0.0075  ---
#
#   ---  EnsembleMethod iteration 1 report  ---
#    number of active realizations:   20
#    number of model runs:            72
#       current obs ensemble saved to 2_Fort_Peck.1.obs.csv
#       current par ensemble saved to 2_Fort_Peck.1.par.csv
# saved par and rei files for realization BASE for iteration 1
# saved par and rei files for realization BASE
#        phi type           mean            std            min            max
#        measured        522.495        48.9607        348.437        566.179
#          actual        344.638        13.1905        316.078        360.782
#      note: 'measured' phi reported above includes
#            realizations of measurement noise,
#            'actual' phi does not.
#   ---  observation group phi summary ---
#        (computed using 'actual' phi)
#            (sorted by mean phi)
# group                                   count  nconflict      mean       std       min       max   percent       std
# oname:obs/obs_etf_us-fpe.np_otype:arr     885         84       343      12.8       315       359      99.5     0.155
# oname:obs/obs_swe_us-fpe.np_otype:arr    1922        696      1.62      0.57     0.857      2.66     0.465     0.155
#
#
#    ---  parameter group change summary  ---
# group     count  mean chg  std chg  n at ubnd  % at ubnd  n at lbnd  % at lbnd  n std decr
# swe_beta      1     2.433   0.9707          0          0          0          0           0
# swe_alpha     1      3.35    23.69          0          0          0          0           0
# ndvi_k        1     5.442    34.13          0          0          0          0           0
# ndvi_0        1     54.47    83.65          0          0          0          0           0
# mad           1     60.36    48.94          0          0          0          0           0
# ks_alpha      1     43.84    29.47          0          0          0          0           0
# kr_alpha      1     53.12    81.14          0          0          0          0           0
# aw            1     3.334    30.15          0          0          0          0           0
#
# ...saved parameter change summary to 2_Fort_Peck.1.pcs.csv
#
#   ---  phi-based termination criteria check  ---
# ...phiredstp:  0.01
# ...nphistp:  3
# ...nphinored (also used for consecutive bad lambda cycles):  3
# ...best mean phi sequence: 758.317 , 522.495 ,
# ...best phi yet:  522.495
# ...number of consecutive bad lambda testing cycles:  0
# ...number of iterations satisfying phiredstp criteria:  1
# ...number of iterations since best yet mean phi:  0
#
#   ---  starting solve for iteration: 2  ---
# ...current lambda:  0.0075
# ...preparing fast-lookup containers for threaded localization solve
# ...starting calcs for glm factor 0.00075
# ...finished calcs for: 0.00075
# ...starting calcs for glm factor 0.0075
# ...finished calcs for: 0.0075
# ...starting calcs for glm factor 0.075
# ...finished calcs for: 0.075
#
#   ---  running upgrade ensembles  ---
# ...subset idx:pe real name:  3:BASE, 6:3, 13:11, 19:18,
# ...subset idx:oe real name:  3:BASE, 6:3, 13:11, 19:18,
#     running model 36 times
#     starting at 01/18/26 22:49:43
#     6 agents ready
#
#
# PANTHER progress
#    avg = average model run time in minutes
#    runs(C = completed | F = failed | T = timed out)
#    agents(R = running | W = waiting | U = unavailable)
# --------------------------------------------------------------------------------
# 01/18 22:50:03 remaining file transfers: 0|T0    ) agents(R5   |W0   |U1   ) 0
#
#    36 runs complete :  0 runs failed
#    0.0527 avg run time (min) : 0.32 run mgr time (min)
#    6 agents connected
#
#
#
#   ---  evaluating upgrade ensembles  ---
# ...last mean:  522.495
# ...last stdev:  48.9607
#
#   ---  phi summary for best lambda, scale fac: 0.00075 , 1.1 ,   ---
#        phi type           mean            std            min            max
#        measured        479.055        102.817        330.934        557.153
#          actual        340.137        6.79859        330.934         346.42
#      note: 'measured' phi reported above includes
#            realizations of measurement noise,
#            'actual' phi does not.
#
#   ---  running remaining realizations for best lambda, scale:0.00075 , 1.1 ,   ---
#     running model 16 times
#     starting at 01/18/26 22:50:04
#     6 agents ready
#
#
# PANTHER progress
#    avg = average model run time in minutes
#    runs(C = completed | F = failed | T = timed out)
#    agents(R = running | W = waiting | U = unavailable)
# --------------------------------------------------------------------------------
# 01/18 22:50:13 remaining file transfers: 0|T0    ) agents(R4   |W2   |U0   ) 0
#
#    16 runs complete :  0 runs failed
#    0.0521 avg run time (min) : 0.157 run mgr time (min)
#    6 agents connected
#
#
# ...phi summary for entire ensemble using lambda,scale_fac 0.00075 , 1.1 ,
#        phi type           mean            std            min            max
#        measured        513.977        52.7923        330.934        571.229
#          actual        335.835        16.3514        306.192        374.578
#      note: 'measured' phi reported above includes
#            realizations of measurement noise,
#            'actual' phi does not.
# ...last best mean phi * acceptable phi factor:  548.62
# ...current best mean phi:  513.977
#
#   ---  updating parameter ensemble  ---
#
#   ---  not updating lambda (standard deviation reduction criteria not met)  ---
#
#   ---  EnsembleMethod iteration 2 report  ---
#    number of active realizations:   20
#    number of model runs:            124
#       current obs ensemble saved to 2_Fort_Peck.2.obs.csv
#       current par ensemble saved to 2_Fort_Peck.2.par.csv
# saved par and rei files for realization BASE for iteration 2
# saved par and rei files for realization BASE
#        phi type           mean            std            min            max
#        measured        513.977        52.7923        330.934        571.229
#          actual        335.835        16.3514        306.192        374.578
#      note: 'measured' phi reported above includes
#            realizations of measurement noise,
#            'actual' phi does not.
#   ---  observation group phi summary ---
#        (computed using 'actual' phi)
#            (sorted by mean phi)
# group                                   count  nconflict      mean       std       min       max   percent       std
# oname:obs/obs_etf_us-fpe.np_otype:arr     885         89       334      16.1       305       374      99.6     0.154
# oname:obs/obs_swe_us-fpe.np_otype:arr    1922        686      1.42     0.554     0.838      2.62     0.419     0.154
#
#
#    ---  parameter group change summary  ---
# group     count  mean chg  std chg  n at ubnd  % at ubnd  n at lbnd  % at lbnd  n std decr
# swe_beta      1     12.54     2.42          0          0          0          0           0
# swe_alpha     1     22.66    31.32          0          0          0          0           0
# ndvi_k        1     12.48    59.99          0          0          0          0           0
# ndvi_0        1     62.09    87.47          0          0          0          0           0
# mad           1     56.09     56.9          0          0          0          0           0
# ks_alpha      1     1.622    47.42          0          0          0          0           0
# kr_alpha      1     83.35    87.39          0          0          0          0           0
# aw            1     4.603    59.89          0          0          0          0           0
#
# ...saved parameter change summary to 2_Fort_Peck.2.pcs.csv
#
#   ---  phi-based termination criteria check  ---
# ...phiredstp:  0.01
# ...nphistp:  3
# ...nphinored (also used for consecutive bad lambda cycles):  3
# ...best mean phi sequence: 758.317 , 522.495 , 513.977 ,
# ...best phi yet:  513.977
# ...number of consecutive bad lambda testing cycles:  0
# ...number of iterations satisfying phiredstp criteria:  1
# ...number of iterations since best yet mean phi:  0
#
#   ---  starting solve for iteration: 3  ---
# ...current lambda:  0.0075
# ...preparing fast-lookup containers for threaded localization solve
# ...starting calcs for glm factor 0.00075
# ...finished calcs for: 0.00075
# ...starting calcs for glm factor 0.0075
# ...finished calcs for: 0.0075
# ...starting calcs for glm factor 0.075
# ...finished calcs for: 0.075
#
#   ---  running upgrade ensembles  ---
# ...subset idx:pe real name:  0:BASE, 4:2, 12:7, 16:13,
# ...subset idx:oe real name:  0:BASE, 4:2, 12:7, 16:13,
#     running model 36 times
#     starting at 01/18/26 22:50:15
#     6 agents ready
#
#
# PANTHER progress
#    avg = average model run time in minutes
#    runs(C = completed | F = failed | T = timed out)
#    agents(R = running | W = waiting | U = unavailable)
# --------------------------------------------------------------------------------
# 01/18 22:50:34 remaining file transfers: 0|T0    ) agents(R6   |W0   |U0   ) 0
#
#    36 runs complete :  0 runs failed
#    0.0529 avg run time (min) : 0.321 run mgr time (min)
#    6 agents connected
#
#
#
#   ---  evaluating upgrade ensembles  ---
# ...last mean:  513.977
# ...last stdev:  52.7923
#
#   ---  phi summary for best lambda, scale fac: 0.00075 , 1.1 ,   ---
#        phi type           mean            std            min            max
#        measured        481.062        111.199        314.625        544.453
#          actual        322.571        10.2495        314.625        337.485
#      note: 'measured' phi reported above includes
#            realizations of measurement noise,
#            'actual' phi does not.
#
#   ---  running remaining realizations for best lambda, scale:0.00075 , 1.1 ,   ---
#     running model 16 times
#     starting at 01/18/26 22:50:35
#     6 agents ready
#
#
# PANTHER progress
#    avg = average model run time in minutes
#    runs(C = completed | F = failed | T = timed out)
#    agents(R = running | W = waiting | U = unavailable)
# --------------------------------------------------------------------------------
# 01/18 22:50:45 remaining file transfers: 0|T0    ) agents(R4   |W2   |U0   ) 0
#
#    16 runs complete :  0 runs failed
#    0.0521 avg run time (min) : 0.159 run mgr time (min)
#    6 agents connected
#
#
# ...phi summary for entire ensemble using lambda,scale_fac 0.00075 , 1.1 ,
#        phi type           mean            std            min            max
#        measured        509.079         57.222        314.625        584.352
#          actual        330.993        19.1315        303.269        385.754
#      note: 'measured' phi reported above includes
#            realizations of measurement noise,
#            'actual' phi does not.
# ...last best mean phi * acceptable phi factor:  539.676
# ...current best mean phi:  509.079
#
#   ---  updating parameter ensemble  ---
#
#   ---  not updating lambda (standard deviation reduction criteria not met)  ---
#
#   ---  EnsembleMethod iteration 3 report  ---
#    number of active realizations:   20
#    number of model runs:            176
#       current obs ensemble saved to 2_Fort_Peck.3.obs.csv
#       current par ensemble saved to 2_Fort_Peck.3.par.csv
# saved par and rei files for realization BASE for iteration 3
# saved par and rei files for realization BASE
#        phi type           mean            std            min            max
#        measured        509.079         57.222        314.625        584.352
#          actual        330.993        19.1315        303.269        385.754
#      note: 'measured' phi reported above includes
#            realizations of measurement noise,
#            'actual' phi does not.
#   ---  observation group phi summary ---
#        (computed using 'actual' phi)
#            (sorted by mean phi)
# group                                   count  nconflict      mean       std       min       max   percent       std
# oname:obs/obs_etf_us-fpe.np_otype:arr     885         87       330      18.9       302       385      99.6     0.146
# oname:obs/obs_swe_us-fpe.np_otype:arr    1922        675      1.27     0.519      0.84      2.57     0.382     0.146
#
#
#    ---  parameter group change summary  ---
# group     count  mean chg  std chg  n at ubnd  % at ubnd  n at lbnd  % at lbnd  n std decr
# swe_beta      1     22.66    4.877          0          0          0          0           0
# swe_alpha     1     43.54    39.38          0          0          0          0           0
# ndvi_k        1     16.58    63.48          0          0          0          0           0
# ndvi_0        1     66.08    87.53          0          0          0          0           0
# mad           1     46.13    60.28          0          0          0          0           0
# ks_alpha      1     22.96    52.69          0          0          0          0           0
# kr_alpha      1     91.12    90.56          0          0          0          0           0
# aw            1     4.304    66.61          0          0          0          0           0
#
# ...saved parameter change summary to 2_Fort_Peck.3.pcs.csv
#
#   ---  phi-based termination criteria check  ---
# ...phiredstp:  0.01
# ...nphistp:  3
# ...nphinored (also used for consecutive bad lambda cycles):  3
# ...best mean phi sequence: 758.317 , 522.495 , 513.977 , 509.079 ,
# ...best phi yet:  509.079
# ...number of consecutive bad lambda testing cycles:  0
# ...number of iterations satisfying phiredstp criteria:  2
# ...number of iterations since best yet mean phi:  0
# ...solution iterations >= noptmax, all done
#
#
# pestpp-ies analysis complete...
# started at 01/18/26 22:48:55
# finished at 01/18/26 22:50:47
# took 1.85 minutes

# %% [markdown]
# ## Debugging Tips
#
# If calibration fails, try these steps:
#
# ### Never saw the PEST++ panther logo?
# - Ensure `pestpp-ies` is in your PATH
# - Try running with full path: `/path/to/pestpp-ies`
# - On Windows, use `.exe` extension
#
# ### Python error traceback?
# Debug from the bottom up:
# 1. Verify `swimrs/calibrate/run_mp.py` runs standalone
# 2. Test `custom_forward_run.py` from the pest directory
# 3. Try running `pestpp-ies` directly from pest directory
#
# ### Saw panther but got errors?
# Common error: `output file 'pred/pred_swe_US-FPe.np' not found`
# - This usually means SWIM failed before writing predictions
# - Set `cleanup=False` above to preserve worker directories
# - Check `workers/worker_0/panther_worker.rec` for errors
#
# **Most errors (90%) are due to incorrect paths!**

# %% [markdown]
# ## 6. Check Results
#
# After successful calibration, parameter files are saved for each optimization iteration:

# %%
# Parameter files are in master_dir after calibration
import os
import shutil

results_dir = builder.master_dir if os.path.exists(builder.master_dir) else builder.pest_dir

par_files = [f for f in sorted(os.listdir(results_dir)) if '.par.csv' in f]
print(f"Parameter files (in {results_dir}):")
for f in par_files:
    print(f"  {f}")

if par_files:
    final_par = par_files[-1]
    print(f"\nFinal calibrated parameters: {final_par}")
    
    # Copy final parameters to pest/archive/ for consistency with calibration.py script
    archive_dir = os.path.join(builder.pest_dir, 'archive')
    os.makedirs(archive_dir, exist_ok=True)
    src = os.path.join(results_dir, final_par)
    dst = os.path.join(archive_dir, final_par)
    shutil.copy2(src, dst)
    print(f"Archived to: {dst}")

# Close the container
container.close()
print("\nContainer closed.")
# Out:
# Parameter files (in /home/dgketchum/code/swim-rs/examples/2_Fort_Peck/data/pestrun/master):
#   2_Fort_Peck.0.par.csv
#   2_Fort_Peck.1.par.csv
#   2_Fort_Peck.2.par.csv
#   2_Fort_Peck.3.par.csv
#
# Final calibrated parameters: 2_Fort_Peck.3.par.csv
# Archived to: /home/dgketchum/code/swim-rs/examples/2_Fort_Peck/data/pestrun/pest/archive/2_Fort_Peck.3.par.csv
#
# Container closed.

# %% [markdown]
# ## Summary
#
# You've set up and run a PEST++ calibration using:
# - PT-JPL ETf observations from Landsat (via OpenET)
# - SNODAS SWE observations
# - Iterative Ensemble Smoother (pestpp-ies)
#
# The parameter files (e.g., `2_Fort_Peck.3.par.csv`) contain the calibrated parameter sets. Each row represents a different realization from the ensemble.
#
# **Next step:** In notebook `03_calibrated_model.ipynb`, we'll run the model in forecast mode with calibrated parameters and validate against flux tower observations.
