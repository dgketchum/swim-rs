# %% [markdown]
# # Calibration Tutorial - Fort Peck, MT - Unirrigated Flux Plot
#
# ## Step 2: Calibrate with PEST++
#
# Now we see if we can improve the model's performance through calibration.
#
# ### PEST++ Resources
#
# PEST++ has excellent documentation covering both theory and practice:
#
# 1. **The PEST Manual 4th Ed.** (Doherty, 2002): https://www.epa.gov/sites/default/files/documents/PESTMAN.PDF
# 2. **GMDSI tutorial notebooks**: https://github.com/gmdsi/GMDSI_notebooks
# 3. **PEST++ User's Manual**: https://github.com/usgs/pestpp/blob/master/documentation/pestpp_users_manual.md
# 4. **PEST Book** (Doherty, 2015): https://pesthomepage.org/pest-book
#
# **Note:** We use PT-JPL ETf and SNODAS SWE for calibration - not flux observations. The flux data is reserved for validation only.

# %% [markdown]
# ### PEST++ Installation
#
# Install PEST++ via conda-forge (recommended):
#
# ```bash
# conda install conda-forge::pestpp
# ```
#
# This installs `pestpp-ies` and other PEST++ tools directly into your conda environment. Verify the installation:
#
# ```bash
# pestpp-ies --version
# ```
#
# **Alternative:** For manual installation from source, see the [PEST++ GitHub releases](https://github.com/usgs/pestpp/releases).

# %%
import os
import sys

root = os.path.abspath('../..')
sys.path.append(root)

from swimrs.container import SwimContainer
from swimrs.calibrate.pest_builder import PestBuilder
from swimrs.swim.config import ProjectConfig
from swimrs.calibrate.run_pest import run_pst
# Out:
# /home/dgketchum/miniconda/envs/swim/lib/python3.11/site-packages/pyemu/__init__.py:37: UserWarning: Failed to import legacy module. May impact ability to access older methods.ModuleNotFoundError No module named 'flopy'

# %% [markdown]
# ## 1. Load Configuration
#
# Load the project configuration and prepare paths.

# %%
project = '2_Fort_Peck'
project_ws = os.path.abspath('.')

config_path = os.path.join(project_ws, '2_Fort_Peck.toml')

config = ProjectConfig()
config.read_config(config_path, project_ws)

# %% [markdown]
# ## 2. Generate Observation Files
#
# PEST++ needs observation files (ETf and SWE) to compare against model predictions. We export these from the SwimContainer built in the data preparation step.
#
# The export creates per-field numpy files:
# - `obs_etf_{field_id}.np`: ETf observations (PT-JPL) with irrigation mask switching
# - `obs_swe_{field_id}.np`: SWE observations from SNODAS

# %%
# Open container for observations export and PEST++ setup
container_path = os.path.join(project_ws, 'data', f'{project}.swim')
container = SwimContainer.open(container_path, mode='r')

# Export observation files for PEST++ calibration
# Note: obs_folder is set to {pest_run_dir}/obs in the TOML config
obs_dir = os.path.join(project_ws, 'data', 'pestrun', 'obs')
os.makedirs(obs_dir, exist_ok=True)

container.export.observations(
    output_dir=obs_dir,
    etf_model='ptjpl',
    masks=('irr', 'inv_irr'),
    irr_threshold=0.1,
)
print(f"Observation files written to {obs_dir}")
# Out:
# Observation files written to /home/dgketchum/code/swim-rs/examples/2_Fort_Peck/data/pestrun/obs

# %% [markdown]
# ## 3. Build PEST++ Control Files
#
# The `PestBuilder` class sets up everything needed for PEST++ calibration:
#
# ### Calibration Loop
# 1. Initialize model with initial parameter values
# 2. Run model, write results
# 3. Compare results to observations (ETf, SWE)
# 4. Propose new parameters
# 5. Repeat until convergence
#
# ### Tunable Parameters
# SWIM uses 8 tunable parameters:
# - **Soil water:** `aw` (available water), `rew` (readily evaporable water), `tew` (total evaporable water)
# - **NDVI-Kcb relationship:** `ndvi_alpha`, `ndvi_beta`
# - **Stress threshold:** `mad` (management allowable depletion)
# - **Snow melt:** `swe_alpha`, `swe_beta`

# %%
# PestBuilder auto-generates custom_forward_run.py using the process package
# with portable swim_input.h5 file for fully self-contained workers
builder = PestBuilder(config, container=container, use_existing=False)
# Out:
# Using default Python script at: /home/dgketchum/code/swim-rs/src/swimrs/calibrate/custom_forward_run.py

# %% [markdown]
# ### Build the .pst Control File
#
# The `build_pest()` method:
# - Copies project files to a `pest/` directory
# - Creates the `.pst` control file
# - Sets up parameter templates (`.tpl`) and instruction files (`.ins`)
#
# **Note:** ETf observations are sparse (only on satellite capture dates). The PEST builder automatically assigns weight 1.0 to valid observations and weight 0.0 to missing dates, ensuring we only calibrate against actual satellite captures.

# %%
# Build the pest control file
# WARNING: This will erase any existing pest directory!
builder.build_pest(target_etf=config.etf_target_model, members=config.etf_ensemble_members)
# Out:
# 2026-01-22 11:39:59.571491 starting: opening PstFrom.log for logging
# 2026-01-22 11:39:59.571855 starting PstFrom process
# 2026-01-22 11:39:59.571941 starting: setting up dirs
# 2026-01-22 11:39:59.572057 starting: removing existing new_d '/home/dgketchum/code/swim-rs/examples/2_Fort_Peck/data/pestrun/pest'
# 2026-01-22 11:39:59.577630 finished: removing existing new_d '/home/dgketchum/code/swim-rs/examples/2_Fort_Peck/data/pestrun/pest' took: 0:00:00.005573
# 2026-01-22 11:39:59.577723 starting: copying original_d '/home/dgketchum/code/swim-rs/examples/2_Fort_Peck/data/pestrun/_template' to new_d '/home/dgketchum/code/swim-rs/examples/2_Fort_Peck/data/pestrun/pest'
# 2026-01-22 11:39:59.579134 finished: copying original_d '/home/dgketchum/code/swim-rs/examples/2_Fort_Peck/data/pestrun/_template' to new_d '/home/dgketchum/code/swim-rs/examples/2_Fort_Peck/data/pestrun/pest' took: 0:00:00.001411
# 2026-01-22 11:39:59.579403 finished: setting up dirs took: 0:00:00.007462
# 2026-01-22 11:39:59.579603 starting: adding constant type m style parameters for file(s) ['params.csv']
# 2026-01-22 11:39:59.579770 starting: loading list-style /home/dgketchum/code/swim-rs/examples/2_Fort_Peck/data/pestrun/pest/params.csv
# 2026-01-22 11:39:59.579872 starting: reading list-style file: /home/dgketchum/code/swim-rs/examples/2_Fort_Peck/data/pestrun/pest/params.csv
# 2026-01-22 11:39:59.582205 finished: reading list-style file: /home/dgketchum/code/swim-rs/examples/2_Fort_Peck/data/pestrun/pest/params.csv took: 0:00:00.002333
# 2026-01-22 11:39:59.582393 loaded list-style '/home/dgketchum/code/swim-rs/examples/2_Fort_Peck/data/pestrun/pest/params.csv' of shape (9, 3)
# 2026-01-22 11:39:59.584813 finished: loading list-style /home/dgketchum/code/swim-rs/examples/2_Fort_Peck/data/pestrun/pest/params.csv took: 0:00:00.005043
# 2026-01-22 11:39:59.584930 starting: writing list-style template file '/home/dgketchum/code/swim-rs/examples/2_Fort_Peck/data/pestrun/pest/p_aw_US-FPe_0_constant.csv.tpl'
# 2026-01-22 11:39:59.596990 finished: writing list-style template file '/home/dgketchum/code/swim-rs/examples/2_Fort_Peck/data/pestrun/pest/p_aw_US-FPe_0_constant.csv.tpl' took: 0:00:00.012060
# 2026-01-22 11:39:59.600421 finished: adding constant type m style parameters for file(s) ['params.csv'] took: 0:00:00.020818
# 2026-01-22 11:39:59.600542 starting: adding constant type m style parameters for file(s) ['params.csv']
# 2026-01-22 11:39:59.600624 starting: loading list-style /home/dgketchum/code/swim-rs/examples/2_Fort_Peck/data/pestrun/pest/params.csv
# 2026-01-22 11:39:59.600686 starting: reading list-style file: /home/dgketchum/code/swim-rs/examples/2_Fort_Peck/data/pestrun/pest/params.csv
# 2026-01-22 11:39:59.601692 finished: reading list-style file: /home/dgketchum/code/swim-rs/examples/2_Fort_Peck/data/pestrun/pest/params.csv took: 0:00:00.001006
# 2026-01-22 11:39:59.601774 loaded list-style '/home/dgketchum/code/swim-rs/examples/2_Fort_Peck/data/pestrun/pest/params.csv' of shape (9, 3)
# 2026-01-22 11:39:59.603076 finished: loading list-style /home/dgketchum/code/swim-rs/examples/2_Fort_Peck/data/pestrun/pest/params.csv took: 0:00:00.002452
# 2026-01-22 11:39:59.603173 starting: writing list-style template file '/home/dgketchum/code/swim-rs/examples/2_Fort_Peck/data/pestrun/pest/p_ks_alpha_US-FPe_0_constant.csv.tpl'
# 2026-01-22 11:39:59.611924 finished: writing list-style template file '/home/dgketchum/code/swim-rs/examples/2_Fort_Peck/data/pestrun/pest/p_ks_alpha_US-FPe_0_constant.csv.tpl' took: 0:00:00.008751
# 2026-01-22 11:39:59.614969 finished: adding constant type m style parameters for file(s) ['params.csv'] took: 0:00:00.014427
# 2026-01-22 11:39:59.615076 starting: adding constant type m style parameters for file(s) ['params.csv']
# 2026-01-22 11:39:59.615152 starting: loading list-style /home/dgketchum/code/swim-rs/examples/2_Fort_Peck/data/pestrun/pest/params.csv
# 2026-01-22 11:39:59.615205 starting: reading list-style file: /home/dgketchum/code/swim-rs/examples/2_Fort_Peck/data/pestrun/pest/params.csv
# 2026-01-22 11:39:59.616098 finished: reading list-style file: /home/dgketchum/code/swim-rs/examples/2_Fort_Peck/data/pestrun/pest/params.csv took: 0:00:00.000893
# 2026-01-22 11:39:59.616193 loaded list-style '/home/dgketchum/code/swim-rs/examples/2_Fort_Peck/data/pestrun/pest/params.csv' of shape (9, 3)
# 2026-01-22 11:39:59.617455 finished: loading list-style /home/dgketchum/code/swim-rs/examples/2_Fort_Peck/data/pestrun/pest/params.csv took: 0:00:00.002303
# 2026-01-22 11:39:59.617552 starting: writing list-style template file '/home/dgketchum/code/swim-rs/examples/2_Fort_Peck/data/pestrun/pest/p_kr_alpha_US-FPe_0_constant.csv.tpl'
# 2026-01-22 11:39:59.625304 finished: writing list-style template file '/home/dgketchum/code/swim-rs/examples/2_Fort_Peck/data/pestrun/pest/p_kr_alpha_US-FPe_0_constant.csv.tpl' took: 0:00:00.007752
# 2026-01-22 11:39:59.628170 finished: adding constant type m style parameters for file(s) ['params.csv'] took: 0:00:00.013094
# 2026-01-22 11:39:59.628276 starting: adding constant type m style parameters for file(s) ['params.csv']
# 2026-01-22 11:39:59.628351 starting: loading list-style /home/dgketchum/code/swim-rs/examples/2_Fort_Peck/data/pestrun/pest/params.csv
# 2026-01-22 11:39:59.628403 starting: reading list-style file: /home/dgketchum/code/swim-rs/examples/2_Fort_Peck/data/pestrun/pest/params.csv
# 2026-01-22 11:39:59.629280 finished: reading list-style file: /home/dgketchum/code/swim-rs/examples/2_Fort_Peck/data/pestrun/pest/params.csv took: 0:00:00.000877
# 2026-01-22 11:39:59.629363 loaded list-style '/home/dgketchum/code/swim-rs/examples/2_Fort_Peck/data/pestrun/pest/params.csv' of shape (9, 3)
# 2026-01-22 11:39:59.630848 finished: loading list-style /home/dgketchum/code/swim-rs/examples/2_Fort_Peck/data/pestrun/pest/params.csv took: 0:00:00.002497
# 2026-01-22 11:39:59.630956 starting: writing list-style template file '/home/dgketchum/code/swim-rs/examples/2_Fort_Peck/data/pestrun/pest/p_ndvi_k_US-FPe_0_constant.csv.tpl'
# 2026-01-22 11:39:59.638792 finished: writing list-style template file '/home/dgketchum/code/swim-rs/examples/2_Fort_Peck/data/pestrun/pest/p_ndvi_k_US-FPe_0_constant.csv.tpl' took: 0:00:00.007836
# 2026-01-22 11:39:59.641663 finished: adding constant type m style parameters for file(s) ['params.csv'] took: 0:00:00.013387
# 2026-01-22 11:39:59.641776 starting: adding constant type m style parameters for file(s) ['params.csv']
# 2026-01-22 11:39:59.641849 starting: loading list-style /home/dgketchum/code/swim-rs/examples/2_Fort_Peck/data/pestrun/pest/params.csv
# 2026-01-22 11:39:59.641899 starting: reading list-style file: /home/dgketchum/code/swim-rs/examples/2_Fort_Peck/data/pestrun/pest/params.csv
# 2026-01-22 11:39:59.642751 finished: reading list-style file: /home/dgketchum/code/swim-rs/examples/2_Fort_Peck/data/pestrun/pest/params.csv took: 0:00:00.000852
# 2026-01-22 11:39:59.642831 loaded list-style '/home/dgketchum/code/swim-rs/examples/2_Fort_Peck/data/pestrun/pest/params.csv' of shape (9, 3)
# 2026-01-22 11:39:59.644016 finished: loading list-style /home/dgketchum/code/swim-rs/examples/2_Fort_Peck/data/pestrun/pest/params.csv took: 0:00:00.002167
# 2026-01-22 11:39:59.644101 starting: writing list-style template file '/home/dgketchum/code/swim-rs/examples/2_Fort_Peck/data/pestrun/pest/p_ndvi_0_US-FPe_0_constant.csv.tpl'
# 2026-01-22 11:39:59.652791 finished: writing list-style template file '/home/dgketchum/code/swim-rs/examples/2_Fort_Peck/data/pestrun/pest/p_ndvi_0_US-FPe_0_constant.csv.tpl' took: 0:00:00.008690
# 2026-01-22 11:39:59.655948 finished: adding constant type m style parameters for file(s) ['params.csv'] took: 0:00:00.014172
# 2026-01-22 11:39:59.656056 starting: adding constant type m style parameters for file(s) ['params.csv']
# 2026-01-22 11:39:59.656130 starting: loading list-style /home/dgketchum/code/swim-rs/examples/2_Fort_Peck/data/pestrun/pest/params.csv
# 2026-01-22 11:39:59.656180 starting: reading list-style file: /home/dgketchum/code/swim-rs/examples/2_Fort_Peck/data/pestrun/pest/params.csv
# 2026-01-22 11:39:59.657076 finished: reading list-style file: /home/dgketchum/code/swim-rs/examples/2_Fort_Peck/data/pestrun/pest/params.csv took: 0:00:00.000896
# 2026-01-22 11:39:59.657165 loaded list-style '/home/dgketchum/code/swim-rs/examples/2_Fort_Peck/data/pestrun/pest/params.csv' of shape (9, 3)
# 2026-01-22 11:39:59.658340 finished: loading list-style /home/dgketchum/code/swim-rs/examples/2_Fort_Peck/data/pestrun/pest/params.csv took: 0:00:00.002210
# 2026-01-22 11:39:59.658426 starting: writing list-style template file '/home/dgketchum/code/swim-rs/examples/2_Fort_Peck/data/pestrun/pest/p_mad_US-FPe_0_constant.csv.tpl'
# 2026-01-22 11:39:59.666030 finished: writing list-style template file '/home/dgketchum/code/swim-rs/examples/2_Fort_Peck/data/pestrun/pest/p_mad_US-FPe_0_constant.csv.tpl' took: 0:00:00.007604
# 2026-01-22 11:39:59.668860 finished: adding constant type m style parameters for file(s) ['params.csv'] took: 0:00:00.012804
# 2026-01-22 11:39:59.668966 starting: adding constant type m style parameters for file(s) ['params.csv']
# 2026-01-22 11:39:59.669038 starting: loading list-style /home/dgketchum/code/swim-rs/examples/2_Fort_Peck/data/pestrun/pest/params.csv
# 2026-01-22 11:39:59.669087 starting: reading list-style file: /home/dgketchum/code/swim-rs/examples/2_Fort_Peck/data/pestrun/pest/params.csv
# 2026-01-22 11:39:59.669942 finished: reading list-style file: /home/dgketchum/code/swim-rs/examples/2_Fort_Peck/data/pestrun/pest/params.csv took: 0:00:00.000855
# 2026-01-22 11:39:59.670021 loaded list-style '/home/dgketchum/code/swim-rs/examples/2_Fort_Peck/data/pestrun/pest/params.csv' of shape (9, 3)
# 2026-01-22 11:39:59.671197 finished: loading list-style /home/dgketchum/code/swim-rs/examples/2_Fort_Peck/data/pestrun/pest/params.csv took: 0:00:00.002159
# 2026-01-22 11:39:59.671282 starting: writing list-style template file '/home/dgketchum/code/swim-rs/examples/2_Fort_Peck/data/pestrun/pest/p_swe_alpha_US-FPe_0_constant.csv.tpl'
# 2026-01-22 11:39:59.678757 finished: writing list-style template file '/home/dgketchum/code/swim-rs/examples/2_Fort_Peck/data/pestrun/pest/p_swe_alpha_US-FPe_0_constant.csv.tpl' took: 0:00:00.007475
# 2026-01-22 11:39:59.681650 finished: adding constant type m style parameters for file(s) ['params.csv'] took: 0:00:00.012684
# 2026-01-22 11:39:59.681766 starting: adding constant type m style parameters for file(s) ['params.csv']
# 2026-01-22 11:39:59.681842 starting: loading list-style /home/dgketchum/code/swim-rs/examples/2_Fort_Peck/data/pestrun/pest/params.csv
# 2026-01-22 11:39:59.681894 starting: reading list-style file: /home/dgketchum/code/swim-rs/examples/2_Fort_Peck/data/pestrun/pest/params.csv
# 2026-01-22 11:39:59.682815 finished: reading list-style file: /home/dgketchum/code/swim-rs/examples/2_Fort_Peck/data/pestrun/pest/params.csv took: 0:00:00.000921
# 2026-01-22 11:39:59.682898 loaded list-style '/home/dgketchum/code/swim-rs/examples/2_Fort_Peck/data/pestrun/pest/params.csv' of shape (9, 3)
# 2026-01-22 11:39:59.684066 finished: loading list-style /home/dgketchum/code/swim-rs/examples/2_Fort_Peck/data/pestrun/pest/params.csv took: 0:00:00.002224
# 2026-01-22 11:39:59.684150 starting: writing list-style template file '/home/dgketchum/code/swim-rs/examples/2_Fort_Peck/data/pestrun/pest/p_swe_beta_US-FPe_0_constant.csv.tpl'
# 2026-01-22 11:39:59.691950 finished: writing list-style template file '/home/dgketchum/code/swim-rs/examples/2_Fort_Peck/data/pestrun/pest/p_swe_beta_US-FPe_0_constant.csv.tpl' took: 0:00:00.007800
# 2026-01-22 11:39:59.694898 finished: adding constant type m style parameters for file(s) ['params.csv'] took: 0:00:00.013132
# 2026-01-22 11:39:59.775581 starting: adding observations from output file obs/obs_etf_US-FPe.np
# 2026-01-22 11:39:59.776099 starting: adding observations from array output file 'obs/obs_etf_US-FPe.np'
# 2026-01-22 11:39:59.806647 starting: adding observation from instruction file '/home/dgketchum/code/swim-rs/examples/2_Fort_Peck/data/pestrun/pest/etf_US-FPe.ins'
# 2026-01-22 11:39:59.930845 finished: adding observation from instruction file '/home/dgketchum/code/swim-rs/examples/2_Fort_Peck/data/pestrun/pest/etf_US-FPe.ins' took: 0:00:00.124198
# 2026-01-22 11:39:59.931735 finished: adding observations from array output file 'obs/obs_etf_US-FPe.np' took: 0:00:00.155636
# 2026-01-22 11:39:59.932328 finished: adding observations from output file obs/obs_etf_US-FPe.np took: 0:00:00.156747
# 2026-01-22 11:40:00.580963 starting: adding observations from output file obs/obs_swe_US-FPe.np
# 2026-01-22 11:40:00.581138 starting: adding observations from array output file 'obs/obs_swe_US-FPe.np'
# 2026-01-22 11:40:00.602256 starting: adding observation from instruction file '/home/dgketchum/code/swim-rs/examples/2_Fort_Peck/data/pestrun/pest/swe_US-FPe.ins'
# 2026-01-22 11:40:00.709429 finished: adding observation from instruction file '/home/dgketchum/code/swim-rs/examples/2_Fort_Peck/data/pestrun/pest/swe_US-FPe.ins' took: 0:00:00.107173
# 2026-01-22 11:40:00.710393 finished: adding observations from array output file 'obs/obs_swe_US-FPe.np' took: 0:00:00.129255
# 2026-01-22 11:40:00.710586 finished: adding observations from output file obs/obs_swe_US-FPe.np took: 0:00:00.129623
# noptmax:0, npar_adj:8, nnz_obs:2868
# Building portable swim_input.h5 with spinup state...
# Created swim_input.h5 at /home/dgketchum/code/swim-rs/examples/2_Fort_Peck/data/pestrun/pest/swim_input.h5
# noptmax:0, npar_adj:8, nnz_obs:2868
# Configured PEST++ for 1 targets,

# %%
# Show the files created in the pest directory
pest_files = [f for f in sorted(os.listdir(builder.pest_dir)) 
              if os.path.isfile(os.path.join(builder.pest_dir, f))]
print("Files in pest directory:")
for f in pest_files:
    print(f"  {f}")
# Out:
# Files in pest directory:
#   2_Fort_Peck.idx.csv
#   2_Fort_Peck.pst
#   2_fort_peck.insfile_data.csv
#   2_fort_peck.obs_data.csv
#   2_fort_peck.par_data.csv
#   2_fort_peck.pargp_data.csv
#   2_fort_peck.tplfile_data.csv
#   custom_forward_run.py
#   etf_US-FPe.ins
#   mult2model_info.csv
#   p_aw_US-FPe_0_constant.csv.tpl
#   p_kr_alpha_US-FPe_0_constant.csv.tpl
#   p_ks_alpha_US-FPe_0_constant.csv.tpl
#   p_mad_US-FPe_0_constant.csv.tpl
#   p_ndvi_0_US-FPe_0_constant.csv.tpl
#   p_ndvi_k_US-FPe_0_constant.csv.tpl
#   p_swe_alpha_US-FPe_0_constant.csv.tpl
#   p_swe_beta_US-FPe_0_constant.csv.tpl
#   params.csv
#   swe_US-FPe.ins
#   swim_input.h5

# %% [markdown]
# ### Examine the .pst File
#
# The PEST++ version 2 control file is concise, delegating details to external files:

# %%
with open(builder.pst_file, 'r') as f:
    print(f.read())
# Out:
# pcf version=2
# * control data keyword
# pestmode                                 estimation
# noptmax                                 0
# svdmode                                 1
# maxsing                          10000000
# eigthresh                           1e-06
# eigwrite                                1
# * parameter groups external
# 2_fort_peck.pargp_data.csv
# * parameter data external
# 2_fort_peck.par_data.csv
# * observation data external
# 2_fort_peck.obs_data.csv
# * model command line
# python custom_forward_run.py
# * model input external
# 2_fort_peck.tplfile_data.csv
# * model output external
# 2_fort_peck.insfile_data.csv

# %% [markdown]
# ## 4. Configure and Test
#
# Now we:
# 1. Build the localizer matrix (links parameters to relevant observations)
# 2. Run spinup to save initial water balance state
# 3. Do a dry run to verify everything works
# 4. Set control parameters for the full calibration

# %%
# Build localizer matrix
# - SWE observations update only swe_alpha and swe_beta
# - ETf observations update all other parameters
builder.build_localizer()

# Run spinup to save water balance state as initial conditions for calibration runs
# This runs the model once and saves the final state to spinup.json
print("Running spinup...")
builder.spinup(overwrite=True)

# Run a minimal model run to verify the setup
print("\nRunning dry run...")
builder.dry_run()

# Configure for 3 optimization iterations with 20 realizations each
# Increase realizations (e.g., 100-200) for production runs
builder.write_control_settings(noptmax=3, reals=20)
# Out:
# noptmax:0, npar_adj:8, nnz_obs:2868
# Running spinup...
# RUNNING SPINUP
# Spinup saved to /home/dgketchum/code/swim-rs/examples/2_Fort_Peck/data/pestrun/spinup.json
#
# Running dry run...
# noptmax:3, npar_adj:8, nnz_obs:2868
# writing /home/dgketchum/code/swim-rs/examples/2_Fort_Peck/data/pestrun/pest/2_Fort_Peck.pst with noptmax=3, 20 realizations

# %%
# Show the updated control file with calibration settings
with open(builder.pst_file, 'r') as f:
    print(f.read())
# Out:
# pcf version=2
# * control data keyword
# pestmode                                 estimation
# noptmax                                 3
# svdmode                                 1
# maxsing                          10000000
# eigthresh                           1e-06
# eigwrite                                1
# ies_localizer                  loc.mat
# ies_num_reals                  20
# ies_drop_conflicts             true
# * parameter groups external
# 2_fort_peck.pargp_data.csv
# * parameter data external
# 2_fort_peck.par_data.csv
# * observation data external
# 2_fort_peck.obs_data.csv
# * model command line
# python custom_forward_run.py
# * model input external
# 2_fort_peck.tplfile_data.csv
# * model output external
# 2_fort_peck.insfile_data.csv

# %% [markdown]
# ## 5. Run PEST++ Calibration
#
# Now we launch PEST++ with parallel workers. Adjust `workers` to match your machine's capabilities.
#
# **Important:** This can take a while. Watch for the progress indicator showing completed runs (C), failed (F), and total (T).

# %%
workers = config.workers or 6
_pst = f"{config.project_name}.pst"

print(f"Starting PEST++ with {workers} workers...")
print(f"Control file: {_pst}")

run_pst(builder.pest_dir,
        'pestpp-ies',
        _pst,
        num_workers=workers,
        worker_root=builder.workers_dir,
        master_dir=builder.master_dir,
        cleanup=True,
        verbose=True)
# Out:
# Starting PEST++ with 20 workers...
# Control file: 2_Fort_Peck.pst
# rmtree: /home/dgketchum/code/swim-rs/examples/2_Fort_Peck/data/pestrun/workers/worker_3
# rmtree: /home/dgketchum/code/swim-rs/examples/2_Fort_Peck/data/pestrun/workers/worker_2
# rmtree: /home/dgketchum/code/swim-rs/examples/2_Fort_Peck/data/pestrun/workers/worker_0
# rmtree: /home/dgketchum/code/swim-rs/examples/2_Fort_Peck/data/pestrun/workers/worker_4
# rmtree: /home/dgketchum/code/swim-rs/examples/2_Fort_Peck/data/pestrun/workers/worker_1
# rmtree: /home/dgketchum/code/swim-rs/examples/2_Fort_Peck/data/pestrun/workers/worker_5
# master:pestpp-ies 2_Fort_Peck.pst /h :5005 in /home/dgketchum/code/swim-rs/examples/2_Fort_Peck/data/pestrun/master
#
#
#              pestpp-ies: a GLM iterative ensemble smoother
#
#                    by the PEST++ development team
#
# ...processing command line: ' pestpp-ies 2_Fort_Peck.pst /h :5005'
# ...using panther run manager in master mode using port 5005
#
#
# version: 5.2.25
# binary compiled on Jan 13 2026 at 20:33:04
# using control file: "2_Fort_Peck.pst"
# in directory: "/home/dgketchum/code/swim-rs/examples/2_Fort_Peck/data/pestrun/master"
# on host: "fcfc-mcozoran"
# on a(n) linux operating system
# with release configuration
# started at 01/22/26 11:40:08
#
# processing control file 2_Fort_Peck.pst
#
#
# :~-._                                                 _.-~:
# : :.~^o._        ________---------________        _.o^~.:.:
#  : ::.`?88booo~~~.::::::::...::::::::::::..~~oood88P'.::.:
#  :  ::: `?88P .:::....         ........:::::. ?88P' :::. :
#   :  :::. `? .::.            . ...........:::. P' .:::. :
#    :  :::   ... ..  ...       .. .::::......::.   :::. :
#    `  :' .... ..  .:::::.     . ..:::::::....:::.  `: .'
#     :..    ____:::::::::.  . . ....:::::::::____  ... :
#    :... `:~    ^~-:::::..  .........:::::-~^    ~::.::::
#    `.::. `\   (8)  \b:::..::.:.:::::::d/  (8)   /'.::::'
#     ::::.  ~-._v    |b.::::::::::::::d|    v_.-~..:::::
#     `.:::::... ~~^?888b..:::::::::::d888P^~...::::::::'
#      `.::::::::::....~~~ .:::::::::~~~:::::::::::::::'
#       `..:::::::::::   .   ....::::    ::::::::::::,'
#         `. .:::::::    .      .::::.    ::::::::'.'
#           `._ .:::    .        :::::.    :::::_.'
#              `-. :    .        :::::      :,-'
#                 :.   :___     .:::___   .::
#       ..--~~~~--:+::. ~~^?b..:::dP^~~.::++:--~~~~--..
#         ___....--`+:::.    `~8~'    .:::+'--....___
#       ~~   __..---`_=:: ___gd8bg___ :==_'---..__   ~~
#        -~~~  _.--~~`-.~~~~~~~~~~~~~~~,-' ~~--._ ~~~-
#
#
#                starting PANTHER master...
#
# IP addresses:
#   0.0.0.0:5005 (IPv4)
#
# PANTHER master listening on socket: 0.0.0.0:5005 (IPv4)
#
#   ---  initializing  ---
# ...using glm algorithm
# ...using REDSVD for truncated svd solve
# ...maxsing: 10000000
# ...eigthresh:  1e-06
# ...initializing localizer
# ...using localized solution with 8 sequential upgrade steps
# ...localizing by parameters
# ...using lambda multipliers: 0.1 , 1 , 10 ,
# ...using lambda scaling factors: 0.75 , 1 , 1.1 ,
# ...acceptable phi factor:  1.05
# ...lambda increase factor:  10
# ...lambda decrease factor:  0.75
# ...max run fail:  1
# ...initializing prior parameter covariance matrix
# ...parcov loaded  from parameter bounds, using par_sigma_range 4
# ...initializing observation noise covariance matrix
# worker:pestpp-ies 2_Fort_Peck.pst /h localhost:5005 in /home/dgketchum/code/swim-rs/examples/2_Fort_Peck/data/pestrun/workers/worker_0
# worker:pestpp-ies 2_Fort_Peck.pst /h localhost:5005 in /home/dgketchum/code/swim-rs/examples/2_Fort_Peck/data/pestrun/workers/worker_1
# worker:pestpp-ies 2_Fort_Peck.pst /h localhost:5005 in /home/dgketchum/code/swim-rs/examples/2_Fort_Peck/data/pestrun/workers/worker_2
# worker:pestpp-ies 2_Fort_Peck.pst /h localhost:5005 in /home/dgketchum/code/swim-rs/examples/2_Fort_Peck/data/pestrun/workers/worker_3
# worker:pestpp-ies 2_Fort_Peck.pst /h localhost:5005 in /home/dgketchum/code/swim-rs/examples/2_Fort_Peck/data/pestrun/workers/worker_4
# worker:pestpp-ies 2_Fort_Peck.pst /h localhost:5005 in /home/dgketchum/code/swim-rs/examples/2_Fort_Peck/data/pestrun/workers/worker_5
# worker:pestpp-ies 2_Fort_Peck.pst /h localhost:5005 in /home/dgketchum/code/swim-rs/examples/2_Fort_Peck/data/pestrun/workers/worker_6
# worker:pestpp-ies 2_Fort_Peck.pst /h localhost:5005 in /home/dgketchum/code/swim-rs/examples/2_Fort_Peck/data/pestrun/workers/worker_7
# worker:pestpp-ies 2_Fort_Peck.pst /h localhost:5005 in /home/dgketchum/code/swim-rs/examples/2_Fort_Peck/data/pestrun/workers/worker_8
# worker:pestpp-ies 2_Fort_Peck.pst /h localhost:5005 in /home/dgketchum/code/swim-rs/examples/2_Fort_Peck/data/pestrun/workers/worker_9
# ...obscov loaded  from observation weights
# worker:pestpp-ies 2_Fort_Peck.pst /h localhost:5005 in /home/dgketchum/code/swim-rs/examples/2_Fort_Peck/data/pestrun/workers/worker_10
# ...drawing parameter realizations:  20
# ...not using prior parameter covariance matrix scaling
# worker:pestpp-ies 2_Fort_Peck.pst /h localhost:5005 in /home/dgketchum/code/swim-rs/examples/2_Fort_Peck/data/pestrun/workers/worker_11
# worker:pestpp-ies 2_Fort_Peck.pst /h localhost:5005 in /home/dgketchum/code/swim-rs/examples/2_Fort_Peck/data/pestrun/workers/worker_12
# worker:pestpp-ies 2_Fort_Peck.pst /h localhost:5005 in /home/dgketchum/code/swim-rs/examples/2_Fort_Peck/data/pestrun/workers/worker_13
# ...drawing observation noise realizations:  20
# worker:pestpp-ies 2_Fort_Peck.pst /h localhost:5005 in /home/dgketchum/code/swim-rs/examples/2_Fort_Peck/data/pestrun/workers/worker_14
# worker:pestpp-ies 2_Fort_Peck.pst /h localhost:5005 in /home/dgketchum/code/swim-rs/examples/2_Fort_Peck/data/pestrun/workers/worker_15
# observations not grouped by observations groups, reordering obs ensemble
# worker:pestpp-ies 2_Fort_Peck.pst /h localhost:5005 in /home/dgketchum/code/swim-rs/examples/2_Fort_Peck/data/pestrun/workers/worker_16
# worker:pestpp-ies 2_Fort_Peck.pst /h localhost:5005 in /home/dgketchum/code/swim-rs/examples/2_Fort_Peck/data/pestrun/workers/worker_17
# worker:pestpp-ies 2_Fort_Peck.pst /h localhost:5005 in /home/dgketchum/code/swim-rs/examples/2_Fort_Peck/data/pestrun/workers/worker_18
# worker:pestpp-ies 2_Fort_Peck.pst /h localhost:5005 in /home/dgketchum/code/swim-rs/examples/2_Fort_Peck/data/pestrun/workers/worker_19
# ...setting weights ensemble from control file weights
# ...saved weight ensemble to  2_Fort_Peck.weights.csv
# ...adding 'base' parameter values to ensemble
# ...adding 'base' observation values to ensemble
# ...adding 'base' weight values to weight ensemble
# ...saved initial parameter ensemble to  2_Fort_Peck.0.par.csv
# ...saved obs+noise observation ensemble (obsval + noise realizations) to  2_Fort_Peck.obs+noise.csv
# ...using subset in lambda testing, percentage of realizations used in subset testing:  10
# ...subset how:  RANDOM
# ...centering on ensemble mean vector
# ...running initial ensemble of size 20
#     running model 20 times
#     starting at 01/22/26 11:40:09
#
#     waiting for agents to appear...
#
#
# PANTHER progress
#    avg = average model run time in minutes
#    runs(C = completed | F = failed | T = timed out)
#    agents(R = running | W = waiting | U = unavailable)
# --------------------------------------------------------------------------------
# 01/22 11:40:14 remaining file transfers: 0|T0    ) agents(R20  |W0   |U0   ) 0
#
#    20 runs complete :  0 runs failed
#    0.07 avg run time (min) : 0.0822 run mgr time (min)
#    20 agents connected
#
#
# ...saved initial obs ensemble to 2_Fort_Peck.0.obs.csv
# saved par and rei files for realization BASE for iteration 0
# saved par and rei files for realization BASE
#
#   ---  pre-drop initial phi summary  ---
#        phi type           mean            std            min            max
#        measured        947.903        442.726        557.328         2499.5
#          actual         732.72        422.626         462.11        2232.34
#      note: 'measured' phi reported above includes
#            realizations of measurement noise,
#            'actual' phi does not.
#   ---  observation group phi summary ---
#        (computed using 'actual' phi)
#            (sorted by mean phi)
# group                                   count  nconflict      mean       std       min       max   percent       std
# oname:obs/obs_etf_us-fpe.np_otype:arr     939         66       610       110       461       789      93.4      19.5
# oname:obs/obs_swe_us-fpe.np_otype:arr    1929          7       123       387     0.851  1.54e+03      6.61      19.5
#
# ...checking for prior-data conflict
#
#   ---  WARNING: 73 non-zero weighted observations are in conflict with the prior simulated ensemble.
#   ---
# ...see 2_Fort_Peck.0.pdc.csv for listing of conflicted observations
#
# ...dropping conflicted observations
# ...number of non-zero weighted observations reduced from 2868 to 2795
#
# ...updating localizer
# dropped 73 from localizer rows because forgive_missing is true
# ...saved adjusted weight ensemble to  2_Fort_Peck.adjusted.weights.csv
# saved par and rei files for realization BASE for iteration 0
# saved par and rei files for realization BASE
#
#   ---  initial phi summary  ---
#        phi type           mean            std            min            max
#        measured        749.365        434.679         397.12        2276.33
#          actual        573.283         418.37        326.798        2057.26
#      note: 'measured' phi reported above includes
#            realizations of measurement noise,
#            'actual' phi does not.
#   ---  observation group phi summary ---
#        (computed using 'actual' phi)
#            (sorted by mean phi)
# group                                   count  nconflict      mean       std       min       max   percent       std
# oname:obs/obs_etf_us-fpe.np_otype:arr     873          0       451       100       325       616      92.7      21.2
# oname:obs/obs_swe_us-fpe.np_otype:arr    1922          0       122       386      0.85  1.53e+03      7.28      21.2
#
# ...current lambda: 0.1
#
#    ---  parameter group change summary  ---
# group     count  mean chg  std chg  n at ubnd  % at ubnd  n at lbnd  % at lbnd  n std decr
# swe_beta      1         0        0          4         20          0          0           0
# ndvi_0        1         0        0          4         20          0          0           0
# mad           1         0        0          3         15          0          0           0
# swe_alpha     1         0        0          2         10          0          0           0
# ndvi_k        1         0        0          1          5          0          0           0
# aw            1         0        0          1          5          0          0           0
# ks_alpha      1         0        0          0          0          0          0           0
# kr_alpha      1         0        0          0          0          0          0           0
#
#
#   ---  initialization complete  ---
#
#   ---  starting solve for iteration: 1  ---
# ...current lambda:  0.1
# ...preparing fast-lookup containers for threaded localization solve
# ...starting calcs for glm factor 0.01
# ...finished calcs for: 0.01
# ...starting calcs for glm factor 0.1
# ...finished calcs for: 0.1
# ...starting calcs for glm factor 1
# ...finished calcs for: 1
#
#   ---  running upgrade ensembles  ---
# ...subset idx:pe real name:  2:2, 8:8, 16:16, 19:BASE,
# ...subset idx:oe real name:  2:2, 8:8, 16:16, 19:BASE,
#     running model 36 times
#     starting at 01/22/26 11:40:17
#     20 agents ready
#
#
# PANTHER progress
#    avg = average model run time in minutes
#    runs(C = completed | F = failed | T = timed out)
#    agents(R = running | W = waiting | U = unavailable)
# --------------------------------------------------------------------------------
# 01/22 11:40:25 remaining file transfers: 0|T0    ) agents(R4   |W16  |U0   ) 0
#
#    36 runs complete :  0 runs failed
#    0.0657 avg run time (min) : 0.138 run mgr time (min)
#    20 agents connected
#
#
#
#   ---  evaluating upgrade ensembles  ---
# ...last mean:  749.365
# ...last stdev:  434.679
#
#   ---  phi summary for best lambda, scale fac: 0.01 , 1.1 ,   ---
#        phi type           mean            std            min            max
#        measured        496.732        97.7931        350.082        547.462
#          actual        337.959        20.9765        313.366        359.854
#      note: 'measured' phi reported above includes
#            realizations of measurement noise,
#            'actual' phi does not.
#
#   ---  running remaining realizations for best lambda, scale:0.01 , 1.1 ,   ---
#     running model 16 times
#     starting at 01/22/26 11:40:26
#     20 agents ready
#
#
# PANTHER progress
#    avg = average model run time in minutes
#    runs(C = completed | F = failed | T = timed out)
#    agents(R = running | W = waiting | U = unavailable)
# --------------------------------------------------------------------------------
# 01/22 11:40:30 remaining file transfers: 0|T0    ) agents(R16  |W4   |U0   ) 0
#
#    16 runs complete :  0 runs failed
#    0.0583 avg run time (min) : 0.0615 run mgr time (min)
#    20 agents connected
#
#
# ...phi summary for entire ensemble using lambda,scale_fac 0.01 , 1.1 ,
#        phi type           mean            std            min            max
#        measured        516.285        45.9755        350.082        556.296
#          actual        341.694        16.6575        302.504        362.273
#      note: 'measured' phi reported above includes
#            realizations of measurement noise,
#            'actual' phi does not.
# ...last best mean phi * acceptable phi factor:  786.833
# ...current best mean phi:  516.285
#
#   ---  updating parameter ensemble  ---
#
#   ---  updating lambda to  0.0075  ---
#
#   ---  EnsembleMethod iteration 1 report  ---
#    number of active realizations:   20
#    number of model runs:            72
#       current obs ensemble saved to 2_Fort_Peck.1.obs.csv
#       current par ensemble saved to 2_Fort_Peck.1.par.csv
# saved par and rei files for realization BASE for iteration 1
# saved par and rei files for realization BASE
#        phi type           mean            std            min            max
#        measured        516.285        45.9755        350.082        556.296
#          actual        341.694        16.6575        302.504        362.273
#      note: 'measured' phi reported above includes
#            realizations of measurement noise,
#            'actual' phi does not.
#   ---  observation group phi summary ---
#        (computed using 'actual' phi)
#            (sorted by mean phi)
# group                                   count  nconflict      mean       std       min       max   percent       std
# oname:obs/obs_etf_us-fpe.np_otype:arr     873        107       340      16.3       302       361      99.5     0.156
# oname:obs/obs_swe_us-fpe.np_otype:arr    1922        696      1.62     0.578     0.855      2.66      0.47     0.156
#
#
#    ---  parameter group change summary  ---
# group     count  mean chg  std chg  n at ubnd  % at ubnd  n at lbnd  % at lbnd  n std decr
# aw            1     6.797    42.02          1          5          0          0           0
# swe_beta      1     2.677    1.032          0          0          0          0           0
# swe_alpha     1     3.685    23.93          0          0          0          0           0
# ndvi_k        1     6.331    45.03          0          0          0          0           0
# ndvi_0        1     42.15    79.52          0          0          0          0           0
# mad           1     66.48    56.32          0          0          0          0           0
# ks_alpha      1     38.66    39.99          0          0          0          0           0
# kr_alpha      1      19.8    81.48          0          0          0          0           0
#
# ...saved parameter change summary to 2_Fort_Peck.1.pcs.csv
#
#   ---  phi-based termination criteria check  ---
# ...phiredstp:  0.01
# ...nphistp:  3
# ...nphinored (also used for consecutive bad lambda cycles):  3
# ...best mean phi sequence: 749.365 , 516.285 ,
# ...best phi yet:  516.285
# ...number of consecutive bad lambda testing cycles:  0
# ...number of iterations satisfying phiredstp criteria:  1
# ...number of iterations since best yet mean phi:  0
#
#   ---  starting solve for iteration: 2  ---
# ...current lambda:  0.0075
# ...preparing fast-lookup containers for threaded localization solve
# ...starting calcs for glm factor 0.00075
# ...finished calcs for: 0.00075
# ...starting calcs for glm factor 0.0075
# ...finished calcs for: 0.0075
# ...starting calcs for glm factor 0.075
# ...finished calcs for: 0.075
#
#   ---  running upgrade ensembles  ---
# ...subset idx:pe real name:  3:BASE, 6:3, 13:11, 19:18,
# ...subset idx:oe real name:  3:BASE, 6:3, 13:11, 19:18,
#     running model 36 times
#     starting at 01/22/26 11:40:32
#     20 agents ready
#
#
# PANTHER progress
#    avg = average model run time in minutes
#    runs(C = completed | F = failed | T = timed out)
#    agents(R = running | W = waiting | U = unavailable)
# --------------------------------------------------------------------------------
# 01/22 11:40:40 remaining file transfers: 0|T0    ) agents(R16  |W4   |U0   ) 0
#
#    36 runs complete :  0 runs failed
#    0.0641 avg run time (min) : 0.133 run mgr time (min)
#    20 agents connected
#
#
#
#   ---  evaluating upgrade ensembles  ---
# ...last mean:  516.285
# ...last stdev:  45.9755
#
#   ---  phi summary for best lambda, scale fac: 0.00075 , 1.1 ,   ---
#        phi type           mean            std            min            max
#        measured        470.408        102.503        320.632        537.412
#          actual        331.072        7.20382        320.632         336.66
#      note: 'measured' phi reported above includes
#            realizations of measurement noise,
#            'actual' phi does not.
#
#   ---  running remaining realizations for best lambda, scale:0.00075 , 1.1 ,   ---
#     running model 16 times
#     starting at 01/22/26 11:40:41
#     20 agents ready
#
#
# PANTHER progress
#    avg = average model run time in minutes
#    runs(C = completed | F = failed | T = timed out)
#    agents(R = running | W = waiting | U = unavailable)
# --------------------------------------------------------------------------------
# 01/22 11:40:45 remaining file transfers: 0|T0    ) agents(R16  |W4   |U0   ) 0
#
#    16 runs complete :  0 runs failed
#    0.0615 avg run time (min) : 0.0649 run mgr time (min)
#    20 agents connected
#
#
# ...phi summary for entire ensemble using lambda,scale_fac 0.00075 , 1.1 ,
#        phi type           mean            std            min            max
#        measured         501.87        51.6884        320.632        565.554
#          actual        327.066        18.7944        297.952        376.608
#      note: 'measured' phi reported above includes
#            realizations of measurement noise,
#            'actual' phi does not.
# ...last best mean phi * acceptable phi factor:  542.1
# ...current best mean phi:  501.87
#
#   ---  updating parameter ensemble  ---
#
#   ---  not updating lambda (standard deviation reduction criteria not met)  ---
#
#   ---  EnsembleMethod iteration 2 report  ---
#    number of active realizations:   20
#    number of model runs:            124
#       current obs ensemble saved to 2_Fort_Peck.2.obs.csv
#       current par ensemble saved to 2_Fort_Peck.2.par.csv
# saved par and rei files for realization BASE for iteration 2
# saved par and rei files for realization BASE
#        phi type           mean            std            min            max
#        measured         501.87        51.6884        320.632        565.554
#          actual        327.066        18.7944        297.952        376.608
#      note: 'measured' phi reported above includes
#            realizations of measurement noise,
#            'actual' phi does not.
#   ---  observation group phi summary ---
#        (computed using 'actual' phi)
#            (sorted by mean phi)
# group                                   count  nconflict      mean       std       min       max   percent       std
# oname:obs/obs_etf_us-fpe.np_otype:arr     873        105       326      18.6       297       376      99.6     0.159
# oname:obs/obs_swe_us-fpe.np_otype:arr    1922        686      1.42     0.559     0.838      2.61     0.433     0.159
#
#
#    ---  parameter group change summary  ---
# group     count  mean chg  std chg  n at ubnd  % at ubnd  n at lbnd  % at lbnd  n std decr
# aw            1     11.34    65.57          3         15          0          0           0
# swe_beta      1     13.02     2.57          0          0          0          0           0
# swe_alpha     1     22.68    31.87          0          0          0          0           0
# ndvi_k        1     13.33    66.59          0          0          0          0           0
# ndvi_0        1     47.91    86.35          0          0          0          0           0
# mad           1     97.98    63.29          0          0          0          0           0
# ks_alpha      1     22.61    58.16          0          0          0          0           0
# kr_alpha      1     46.42    85.61          0          0          0          0           0
#
# ...saved parameter change summary to 2_Fort_Peck.2.pcs.csv
#
#   ---  phi-based termination criteria check  ---
# ...phiredstp:  0.01
# ...nphistp:  3
# ...nphinored (also used for consecutive bad lambda cycles):  3
# ...best mean phi sequence: 749.365 , 516.285 , 501.87 ,
# ...best phi yet:  501.87
# ...number of consecutive bad lambda testing cycles:  0
# ...number of iterations satisfying phiredstp criteria:  1
# ...number of iterations since best yet mean phi:  0
#
#   ---  starting solve for iteration: 3  ---
# ...current lambda:  0.0075
# ...preparing fast-lookup containers for threaded localization solve
# ...starting calcs for glm factor 0.00075
# ...finished calcs for: 0.00075
# ...starting calcs for glm factor 0.0075
# ...finished calcs for: 0.0075
# ...starting calcs for glm factor 0.075
# ...finished calcs for: 0.075
#
#   ---  running upgrade ensembles  ---
# ...subset idx:pe real name:  0:BASE, 4:2, 12:7, 16:13,
# ...subset idx:oe real name:  0:BASE, 4:2, 12:7, 16:13,
#     running model 36 times
#     starting at 01/22/26 11:40:47
#     20 agents ready
#
#
# PANTHER progress
#    avg = average model run time in minutes
#    runs(C = completed | F = failed | T = timed out)
#    agents(R = running | W = waiting | U = unavailable)
# --------------------------------------------------------------------------------
# 01/22 11:40:55 remaining file transfers: 0|T0    ) agents(R16  |W4   |U0   ) 0
#
#    36 runs complete :  0 runs failed
#    0.0631 avg run time (min) : 0.13 run mgr time (min)
#    20 agents connected
#
#
#
#   ---  evaluating upgrade ensembles  ---
# ...last mean:  501.87
# ...last stdev:  51.6884
#
#   ---  phi summary for best lambda, scale fac: 0.00075 , 1.1 ,   ---
#        phi type           mean            std            min            max
#        measured        466.714        109.562        302.474        526.592
#          actual         311.74        12.5989        302.474        330.137
#      note: 'measured' phi reported above includes
#            realizations of measurement noise,
#            'actual' phi does not.
#
#   ---  running remaining realizations for best lambda, scale:0.00075 , 1.1 ,   ---
#     running model 16 times
#     starting at 01/22/26 11:40:56
#     20 agents ready
#
#
# PANTHER progress
#    avg = average model run time in minutes
#    runs(C = completed | F = failed | T = timed out)
#    agents(R = running | W = waiting | U = unavailable)
# --------------------------------------------------------------------------------
# 01/22 11:41:00 remaining file transfers: 0|T0    ) agents(R16  |W4   |U0   ) 0
#
#    16 runs complete :  0 runs failed
#    0.0582 avg run time (min) : 0.0613 run mgr time (min)
#    20 agents connected
#
#
# ...phi summary for entire ensemble using lambda,scale_fac 0.00075 , 1.1 ,
#        phi type           mean            std            min            max
#        measured        496.806        56.5578        302.474        576.481
#          actual        321.775        20.9967        293.921        384.599
#      note: 'measured' phi reported above includes
#            realizations of measurement noise,
#            'actual' phi does not.
# ...last best mean phi * acceptable phi factor:  526.963
# ...current best mean phi:  496.806
#
#   ---  updating parameter ensemble  ---
#
#   ---  not updating lambda (standard deviation reduction criteria not met)  ---
#
#   ---  EnsembleMethod iteration 3 report  ---
#    number of active realizations:   20
#    number of model runs:            176
#       current obs ensemble saved to 2_Fort_Peck.3.obs.csv
#       current par ensemble saved to 2_Fort_Peck.3.par.csv
# saved par and rei files for realization BASE for iteration 3
# saved par and rei files for realization BASE
#        phi type           mean            std            min            max
#        measured        496.806        56.5578        302.474        576.481
#          actual        321.775        20.9967        293.921        384.599
#      note: 'measured' phi reported above includes
#            realizations of measurement noise,
#            'actual' phi does not.
#   ---  observation group phi summary ---
#        (computed using 'actual' phi)
#            (sorted by mean phi)
# group                                   count  nconflict      mean       std       min       max   percent       std
# oname:obs/obs_etf_us-fpe.np_otype:arr     873         97       320      20.8       293       384      99.6     0.151
# oname:obs/obs_swe_us-fpe.np_otype:arr    1922        675      1.29     0.516      0.84      2.57     0.398     0.151
#
#
#    ---  parameter group change summary  ---
# group     count  mean chg  std chg  n at ubnd  % at ubnd  n at lbnd  % at lbnd  n std decr
# aw            1     12.05    68.56          4         20          0          0           0
# swe_beta      1     23.03    5.146          0          0          0          0           0
# swe_alpha     1     43.53    40.23          0          0          0          0           0
# ndvi_k        1     17.18    68.98          0          0          0          0           0
# ndvi_0        1     53.53    87.04          0          0          0          0           0
# mad           1     99.08    64.34          0          0          0          0           0
# ks_alpha      1     4.699    62.78          0          0          0          0           0
# kr_alpha      1     64.28    87.11          0          0          0          0           0
#
# ...saved parameter change summary to 2_Fort_Peck.3.pcs.csv
#
#   ---  phi-based termination criteria check  ---
# ...phiredstp:  0.01
# ...nphistp:  3
# ...nphinored (also used for consecutive bad lambda cycles):  3
# ...best mean phi sequence: 749.365 , 516.285 , 501.87 , 496.806 ,
# ...best phi yet:  496.806
# ...number of consecutive bad lambda testing cycles:  0
# ...number of iterations satisfying phiredstp criteria:  1
# ...number of iterations since best yet mean phi:  0
# ...solution iterations >= noptmax, all done
#
#
# pestpp-ies analysis complete...
# started at 01/22/26 11:40:08
# finished at 01/22/26 11:41:01
# took 0.883333 minutes

# %% [markdown]
# ## Debugging Tips
#
# If calibration fails, try these steps:
#
# ### Never saw the PEST++ panther logo?
# - Ensure `pestpp-ies` is in your PATH
# - Try running with full path: `/path/to/pestpp-ies`
# - On Windows, use `.exe` extension
#
# ### Python error traceback?
# Debug from the bottom up:
# 1. Verify `swimrs/calibrate/run_mp.py` runs standalone
# 2. Test `custom_forward_run.py` from the pest directory
# 3. Try running `pestpp-ies` directly from pest directory
#
# ### Saw panther but got errors?
# Common error: `output file 'pred/pred_swe_US-FPe.np' not found`
# - This usually means SWIM failed before writing predictions
# - Set `cleanup=False` above to preserve worker directories
# - Check `workers/worker_0/panther_worker.rec` for errors
#
# **Most errors (90%) are due to incorrect paths!**

# %% [markdown]
# ## 6. Check Results
#
# After successful calibration, parameter files are saved for each optimization iteration:

# %%
# Parameter files are in master_dir after calibration
import os
import shutil

results_dir = builder.master_dir if os.path.exists(builder.master_dir) else builder.pest_dir

par_files = [f for f in sorted(os.listdir(results_dir)) if '.par.csv' in f]
print(f"Parameter files (in {results_dir}):")
for f in par_files:
    print(f"  {f}")

if par_files:
    final_par = par_files[-1]
    print(f"\nFinal calibrated parameters: {final_par}")
    
    # Copy final parameters to pest/archive/ for consistency with calibration.py script
    archive_dir = os.path.join(builder.pest_dir, 'archive')
    os.makedirs(archive_dir, exist_ok=True)
    src = os.path.join(results_dir, final_par)
    dst = os.path.join(archive_dir, final_par)
    shutil.copy2(src, dst)
    print(f"Archived to: {dst}")

# Close the container
container.close()
print("\nContainer closed.")
# Out:
# Parameter files (in /home/dgketchum/code/swim-rs/examples/2_Fort_Peck/data/pestrun/master):
#   2_Fort_Peck.0.par.csv
#   2_Fort_Peck.1.par.csv
#   2_Fort_Peck.2.par.csv
#   2_Fort_Peck.3.par.csv
#
# Final calibrated parameters: 2_Fort_Peck.3.par.csv
# Archived to: /home/dgketchum/code/swim-rs/examples/2_Fort_Peck/data/pestrun/pest/archive/2_Fort_Peck.3.par.csv
#
# Container closed.

# %% [markdown]
# ## Summary
#
# You've set up and run a PEST++ calibration using:
# - PT-JPL ETf observations from Landsat (via OpenET)
# - SNODAS SWE observations
# - Iterative Ensemble Smoother (pestpp-ies)
#
# The parameter files (e.g., `2_Fort_Peck.3.par.csv`) contain the calibrated parameter sets. Each row represents a different realization from the ensemble.
#
# **Next step:** In notebook `03_calibrated_model.ipynb`, we'll run the model in forecast mode with calibrated parameters and validate against flux tower observations.
