# %% [markdown]
# # Calibration Tutorial - Fort Peck, MT - Unirrigated Flux Plot
#
# ## Step 2: Calibrate with PEST++
#
# Now we see if we can improve the model's performance through calibration.
#
# ### PEST++ Resources
#
# PEST++ has excellent documentation covering both theory and practice:
#
# 1. **The PEST Manual 4th Ed.** (Doherty, 2002): https://www.epa.gov/sites/default/files/documents/PESTMAN.PDF
# 2. **GMDSI tutorial notebooks**: https://github.com/gmdsi/GMDSI_notebooks
# 3. **PEST++ User's Manual**: https://github.com/usgs/pestpp/blob/master/documentation/pestpp_users_manual.md
# 4. **PEST Book** (Doherty, 2015): https://pesthomepage.org/pest-book
#
# **Note:** We use PT-JPL ETf and SNODAS SWE for calibration - not flux observations. The flux data is reserved for validation only.

# %% [markdown]
# ### PEST++ Installation
#
# Install PEST++ via conda-forge (recommended):
#
# ```bash
# conda install conda-forge::pestpp
# ```
#
# This installs `pestpp-ies` and other PEST++ tools directly into your conda environment. Verify the installation:
#
# ```bash
# pestpp-ies --version
# ```
#
# **Alternative:** For manual installation from source, see the [PEST++ GitHub releases](https://github.com/usgs/pestpp/releases).

# %%
import os
import sys

root = os.path.abspath('../..')
sys.path.append(root)

from swimrs.container import SwimContainer
from swimrs.calibrate.pest_builder import PestBuilder
from swimrs.swim.config import ProjectConfig
from swimrs.calibrate.run_pest import run_pst
# Out:
# /home/dgketchum/miniconda/envs/swim/lib/python3.11/site-packages/pyemu/__init__.py:37: UserWarning: Failed to import legacy module. May impact ability to access older methods.ModuleNotFoundError No module named 'flopy'

# %% [markdown]
# ## 1. Load Configuration
#
# Load the project configuration and prepare paths.

# %%
project = '2_Fort_Peck'
project_ws = os.path.abspath('.')

config_path = os.path.join(project_ws, '2_Fort_Peck.toml')

config = ProjectConfig()
config.read_config(config_path, project_ws)

# %% [markdown]
# ## 2. Generate Observation Files
#
# PEST++ needs observation files (ETf and SWE) to compare against model predictions. We export these from the SwimContainer built in the data preparation step.
#
# The export creates per-field numpy files:
# - `obs_etf_{field_id}.np`: ETf observations (PT-JPL) with irrigation mask switching
# - `obs_swe_{field_id}.np`: SWE observations from SNODAS

# %%
# Open container for observations export and PEST++ setup
container_path = os.path.join(project_ws, 'data', f'{project}.swim')
container = SwimContainer.open(container_path, mode='r')

# Export observation files for PEST++ calibration
# Note: obs_folder is set to {pest_run_dir}/obs in the TOML config
obs_dir = os.path.join(project_ws, 'data', 'pestrun', 'obs')
os.makedirs(obs_dir, exist_ok=True)

container.export.observations(
    output_dir=obs_dir,
    etf_model='ptjpl',
    masks=('irr', 'inv_irr'),
    irr_threshold=0.1,
)
print(f"Observation files written to {obs_dir}")
# Out:
# Observation files written to /home/dgketchum/code/swim-rs/examples/2_Fort_Peck/data/pestrun/obs

# %% [markdown]
# ## 3. Build PEST++ Control Files
#
# The `PestBuilder` class sets up everything needed for PEST++ calibration:
#
# ### Calibration Loop
# 1. Initialize model with initial parameter values
# 2. Run model, write results
# 3. Compare results to observations (ETf, SWE)
# 4. Propose new parameters
# 5. Repeat until convergence
#
# ### Tunable Parameters
# SWIM uses 8 tunable parameters:
# - **Soil water:** `aw` (available water), `rew` (readily evaporable water), `tew` (total evaporable water)
# - **NDVI-Kcb relationship:** `ndvi_alpha`, `ndvi_beta`
# - **Stress threshold:** `mad` (management allowable depletion)
# - **Snow melt:** `swe_alpha`, `swe_beta`

# %%
py_script = os.path.join(project_ws, 'custom_forward_run.py')

# Pass container to PestBuilder for ETf/SWE data access
builder = PestBuilder(config, container=container, use_existing=False, python_script=py_script)

# %% [markdown]
# ### Build the .pst Control File
#
# The `build_pest()` method:
# - Copies project files to a `pest/` directory
# - Creates the `.pst` control file
# - Sets up parameter templates (`.tpl`) and instruction files (`.ins`)
#
# **Note:** ETf observations are sparse (only on satellite capture dates). The PEST builder automatically assigns weight 1.0 to valid observations and weight 0.0 to missing dates, ensuring we only calibrate against actual satellite captures.

# %%
# Build the pest control file
# WARNING: This will erase any existing pest directory!
builder.build_pest(target_etf=config.etf_target_model, members=config.etf_ensemble_members)
# Out:
# 2026-01-15 11:19:51.153534 starting: opening PstFrom.log for logging
# 2026-01-15 11:19:51.153828 starting PstFrom process
# 2026-01-15 11:19:51.154010 starting: setting up dirs
# 2026-01-15 11:19:51.154322 starting: removing existing new_d '/home/dgketchum/code/swim-rs/examples/2_Fort_Peck/data/pestrun/pest'
# 2026-01-15 11:19:51.208702 finished: removing existing new_d '/home/dgketchum/code/swim-rs/examples/2_Fort_Peck/data/pestrun/pest' took: 0:00:00.054380
# 2026-01-15 11:19:51.208764 starting: copying original_d '/home/dgketchum/code/swim-rs/examples/2_Fort_Peck/data/pestrun' to new_d '/home/dgketchum/code/swim-rs/examples/2_Fort_Peck/data/pestrun/pest'
# 2026-01-15 11:19:54.711347 finished: copying original_d '/home/dgketchum/code/swim-rs/examples/2_Fort_Peck/data/pestrun' to new_d '/home/dgketchum/code/swim-rs/examples/2_Fort_Peck/data/pestrun/pest' took: 0:00:03.502583
# 2026-01-15 11:19:54.713239 finished: setting up dirs took: 0:00:03.559229
# 2026-01-15 11:19:54.713533 starting: adding constant type m style parameters for file(s) ['params.csv']
# 2026-01-15 11:19:54.713679 starting: loading list-style /home/dgketchum/code/swim-rs/examples/2_Fort_Peck/data/pestrun/pest/params.csv
# 2026-01-15 11:19:54.713755 starting: reading list-style file: /home/dgketchum/code/swim-rs/examples/2_Fort_Peck/data/pestrun/pest/params.csv
# 2026-01-15 11:19:54.717724 finished: reading list-style file: /home/dgketchum/code/swim-rs/examples/2_Fort_Peck/data/pestrun/pest/params.csv took: 0:00:00.003969
# 2026-01-15 11:19:54.717964 loaded list-style '/home/dgketchum/code/swim-rs/examples/2_Fort_Peck/data/pestrun/pest/params.csv' of shape (9, 3)
# 2026-01-15 11:19:54.720250 finished: loading list-style /home/dgketchum/code/swim-rs/examples/2_Fort_Peck/data/pestrun/pest/params.csv took: 0:00:00.006571
# 2026-01-15 11:19:54.720360 starting: writing list-style template file '/home/dgketchum/code/swim-rs/examples/2_Fort_Peck/data/pestrun/pest/p_aw_US-FPe_0_constant.csv.tpl'
# 2026-01-15 11:19:54.731895 finished: writing list-style template file '/home/dgketchum/code/swim-rs/examples/2_Fort_Peck/data/pestrun/pest/p_aw_US-FPe_0_constant.csv.tpl' took: 0:00:00.011535
# 2026-01-15 11:19:54.735647 finished: adding constant type m style parameters for file(s) ['params.csv'] took: 0:00:00.022114
# 2026-01-15 11:19:54.735768 starting: adding constant type m style parameters for file(s) ['params.csv']
# 2026-01-15 11:19:54.735845 starting: loading list-style /home/dgketchum/code/swim-rs/examples/2_Fort_Peck/data/pestrun/pest/params.csv
# 2026-01-15 11:19:54.735897 starting: reading list-style file: /home/dgketchum/code/swim-rs/examples/2_Fort_Peck/data/pestrun/pest/params.csv
# 2026-01-15 11:19:54.736952 finished: reading list-style file: /home/dgketchum/code/swim-rs/examples/2_Fort_Peck/data/pestrun/pest/params.csv took: 0:00:00.001055
# 2026-01-15 11:19:54.737034 loaded list-style '/home/dgketchum/code/swim-rs/examples/2_Fort_Peck/data/pestrun/pest/params.csv' of shape (9, 3)
# 2026-01-15 11:19:54.738333 finished: loading list-style /home/dgketchum/code/swim-rs/examples/2_Fort_Peck/data/pestrun/pest/params.csv took: 0:00:00.002488
# 2026-01-15 11:19:54.738436 starting: writing list-style template file '/home/dgketchum/code/swim-rs/examples/2_Fort_Peck/data/pestrun/pest/p_ks_alpha_US-FPe_0_constant.csv.tpl'
# 2026-01-15 11:19:54.746287 finished: writing list-style template file '/home/dgketchum/code/swim-rs/examples/2_Fort_Peck/data/pestrun/pest/p_ks_alpha_US-FPe_0_constant.csv.tpl' took: 0:00:00.007851
# 2026-01-15 11:19:54.749372 finished: adding constant type m style parameters for file(s) ['params.csv'] took: 0:00:00.013604
# 2026-01-15 11:19:54.749483 starting: adding constant type m style parameters for file(s) ['params.csv']
# 2026-01-15 11:19:54.749558 starting: loading list-style /home/dgketchum/code/swim-rs/examples/2_Fort_Peck/data/pestrun/pest/params.csv
# 2026-01-15 11:19:54.749611 starting: reading list-style file: /home/dgketchum/code/swim-rs/examples/2_Fort_Peck/data/pestrun/pest/params.csv
# 2026-01-15 11:19:54.750585 finished: reading list-style file: /home/dgketchum/code/swim-rs/examples/2_Fort_Peck/data/pestrun/pest/params.csv took: 0:00:00.000974
# 2026-01-15 11:19:54.750685 loaded list-style '/home/dgketchum/code/swim-rs/examples/2_Fort_Peck/data/pestrun/pest/params.csv' of shape (9, 3)
# 2026-01-15 11:19:54.751890 finished: loading list-style /home/dgketchum/code/swim-rs/examples/2_Fort_Peck/data/pestrun/pest/params.csv took: 0:00:00.002332
# 2026-01-15 11:19:54.751986 starting: writing list-style template file '/home/dgketchum/code/swim-rs/examples/2_Fort_Peck/data/pestrun/pest/p_kr_alpha_US-FPe_0_constant.csv.tpl'
# 2026-01-15 11:19:54.759826 finished: writing list-style template file '/home/dgketchum/code/swim-rs/examples/2_Fort_Peck/data/pestrun/pest/p_kr_alpha_US-FPe_0_constant.csv.tpl' took: 0:00:00.007840
# 2026-01-15 11:19:54.762548 finished: adding constant type m style parameters for file(s) ['params.csv'] took: 0:00:00.013065
# 2026-01-15 11:19:54.762652 starting: adding constant type m style parameters for file(s) ['params.csv']
# 2026-01-15 11:19:54.762734 starting: loading list-style /home/dgketchum/code/swim-rs/examples/2_Fort_Peck/data/pestrun/pest/params.csv
# 2026-01-15 11:19:54.762785 starting: reading list-style file: /home/dgketchum/code/swim-rs/examples/2_Fort_Peck/data/pestrun/pest/params.csv
# 2026-01-15 11:19:54.763729 finished: reading list-style file: /home/dgketchum/code/swim-rs/examples/2_Fort_Peck/data/pestrun/pest/params.csv took: 0:00:00.000944
# 2026-01-15 11:19:54.763823 loaded list-style '/home/dgketchum/code/swim-rs/examples/2_Fort_Peck/data/pestrun/pest/params.csv' of shape (9, 3)
# 2026-01-15 11:19:54.764991 finished: loading list-style /home/dgketchum/code/swim-rs/examples/2_Fort_Peck/data/pestrun/pest/params.csv took: 0:00:00.002257
# 2026-01-15 11:19:54.765077 starting: writing list-style template file '/home/dgketchum/code/swim-rs/examples/2_Fort_Peck/data/pestrun/pest/p_ndvi_k_US-FPe_0_constant.csv.tpl'
# 2026-01-15 11:19:54.772690 finished: writing list-style template file '/home/dgketchum/code/swim-rs/examples/2_Fort_Peck/data/pestrun/pest/p_ndvi_k_US-FPe_0_constant.csv.tpl' took: 0:00:00.007613
# 2026-01-15 11:19:54.775451 finished: adding constant type m style parameters for file(s) ['params.csv'] took: 0:00:00.012799
# 2026-01-15 11:19:54.775553 starting: adding constant type m style parameters for file(s) ['params.csv']
# 2026-01-15 11:19:54.775622 starting: loading list-style /home/dgketchum/code/swim-rs/examples/2_Fort_Peck/data/pestrun/pest/params.csv
# 2026-01-15 11:19:54.775679 starting: reading list-style file: /home/dgketchum/code/swim-rs/examples/2_Fort_Peck/data/pestrun/pest/params.csv
# 2026-01-15 11:19:54.776527 finished: reading list-style file: /home/dgketchum/code/swim-rs/examples/2_Fort_Peck/data/pestrun/pest/params.csv took: 0:00:00.000848
# 2026-01-15 11:19:54.776603 loaded list-style '/home/dgketchum/code/swim-rs/examples/2_Fort_Peck/data/pestrun/pest/params.csv' of shape (9, 3)
# 2026-01-15 11:19:54.777807 finished: loading list-style /home/dgketchum/code/swim-rs/examples/2_Fort_Peck/data/pestrun/pest/params.csv took: 0:00:00.002185
# 2026-01-15 11:19:54.777894 starting: writing list-style template file '/home/dgketchum/code/swim-rs/examples/2_Fort_Peck/data/pestrun/pest/p_ndvi_0_US-FPe_0_constant.csv.tpl'
# 2026-01-15 11:19:54.785289 finished: writing list-style template file '/home/dgketchum/code/swim-rs/examples/2_Fort_Peck/data/pestrun/pest/p_ndvi_0_US-FPe_0_constant.csv.tpl' took: 0:00:00.007395
# 2026-01-15 11:19:54.788121 finished: adding constant type m style parameters for file(s) ['params.csv'] took: 0:00:00.012568
# 2026-01-15 11:19:54.788230 starting: adding constant type m style parameters for file(s) ['params.csv']
# 2026-01-15 11:19:54.788302 starting: loading list-style /home/dgketchum/code/swim-rs/examples/2_Fort_Peck/data/pestrun/pest/params.csv
# 2026-01-15 11:19:54.788353 starting: reading list-style file: /home/dgketchum/code/swim-rs/examples/2_Fort_Peck/data/pestrun/pest/params.csv
# 2026-01-15 11:19:54.789286 finished: reading list-style file: /home/dgketchum/code/swim-rs/examples/2_Fort_Peck/data/pestrun/pest/params.csv took: 0:00:00.000933
# 2026-01-15 11:19:54.789369 loaded list-style '/home/dgketchum/code/swim-rs/examples/2_Fort_Peck/data/pestrun/pest/params.csv' of shape (9, 3)
# 2026-01-15 11:19:54.790572 finished: loading list-style /home/dgketchum/code/swim-rs/examples/2_Fort_Peck/data/pestrun/pest/params.csv took: 0:00:00.002270
# 2026-01-15 11:19:54.790659 starting: writing list-style template file '/home/dgketchum/code/swim-rs/examples/2_Fort_Peck/data/pestrun/pest/p_mad_US-FPe_0_constant.csv.tpl'
# 2026-01-15 11:19:54.798085 finished: writing list-style template file '/home/dgketchum/code/swim-rs/examples/2_Fort_Peck/data/pestrun/pest/p_mad_US-FPe_0_constant.csv.tpl' took: 0:00:00.007426
# 2026-01-15 11:19:54.800809 finished: adding constant type m style parameters for file(s) ['params.csv'] took: 0:00:00.012579
# 2026-01-15 11:19:54.800911 starting: adding constant type m style parameters for file(s) ['params.csv']
# 2026-01-15 11:19:54.800982 starting: loading list-style /home/dgketchum/code/swim-rs/examples/2_Fort_Peck/data/pestrun/pest/params.csv
# 2026-01-15 11:19:54.801029 starting: reading list-style file: /home/dgketchum/code/swim-rs/examples/2_Fort_Peck/data/pestrun/pest/params.csv
# 2026-01-15 11:19:54.801906 finished: reading list-style file: /home/dgketchum/code/swim-rs/examples/2_Fort_Peck/data/pestrun/pest/params.csv took: 0:00:00.000877
# 2026-01-15 11:19:54.801986 loaded list-style '/home/dgketchum/code/swim-rs/examples/2_Fort_Peck/data/pestrun/pest/params.csv' of shape (9, 3)
# 2026-01-15 11:19:54.803157 finished: loading list-style /home/dgketchum/code/swim-rs/examples/2_Fort_Peck/data/pestrun/pest/params.csv took: 0:00:00.002175
# 2026-01-15 11:19:54.803242 starting: writing list-style template file '/home/dgketchum/code/swim-rs/examples/2_Fort_Peck/data/pestrun/pest/p_swe_alpha_US-FPe_0_constant.csv.tpl'
# 2026-01-15 11:19:54.810629 finished: writing list-style template file '/home/dgketchum/code/swim-rs/examples/2_Fort_Peck/data/pestrun/pest/p_swe_alpha_US-FPe_0_constant.csv.tpl' took: 0:00:00.007387
# 2026-01-15 11:19:54.813363 finished: adding constant type m style parameters for file(s) ['params.csv'] took: 0:00:00.012452
# 2026-01-15 11:19:54.813467 starting: adding constant type m style parameters for file(s) ['params.csv']
# 2026-01-15 11:19:54.813538 starting: loading list-style /home/dgketchum/code/swim-rs/examples/2_Fort_Peck/data/pestrun/pest/params.csv
# 2026-01-15 11:19:54.813587 starting: reading list-style file: /home/dgketchum/code/swim-rs/examples/2_Fort_Peck/data/pestrun/pest/params.csv
# 2026-01-15 11:19:54.814509 finished: reading list-style file: /home/dgketchum/code/swim-rs/examples/2_Fort_Peck/data/pestrun/pest/params.csv took: 0:00:00.000922
# 2026-01-15 11:19:54.814589 loaded list-style '/home/dgketchum/code/swim-rs/examples/2_Fort_Peck/data/pestrun/pest/params.csv' of shape (9, 3)
# 2026-01-15 11:19:54.815716 finished: loading list-style /home/dgketchum/code/swim-rs/examples/2_Fort_Peck/data/pestrun/pest/params.csv took: 0:00:00.002178
# 2026-01-15 11:19:54.815804 starting: writing list-style template file '/home/dgketchum/code/swim-rs/examples/2_Fort_Peck/data/pestrun/pest/p_swe_beta_US-FPe_0_constant.csv.tpl'
# 2026-01-15 11:19:54.823235 finished: writing list-style template file '/home/dgketchum/code/swim-rs/examples/2_Fort_Peck/data/pestrun/pest/p_swe_beta_US-FPe_0_constant.csv.tpl' took: 0:00:00.007431
# 2026-01-15 11:19:54.826106 finished: adding constant type m style parameters for file(s) ['params.csv'] took: 0:00:00.012639
# 2026-01-15 11:19:54.913424 starting: adding observations from output file obs/obs_etf_US-FPe.np
# 2026-01-15 11:19:54.914828 starting: adding observations from array output file 'obs/obs_etf_US-FPe.np'
# 2026-01-15 11:19:54.948632 starting: adding observation from instruction file '/home/dgketchum/code/swim-rs/examples/2_Fort_Peck/data/pestrun/pest/etf_US-FPe.ins'
# 2026-01-15 11:19:55.062649 finished: adding observation from instruction file '/home/dgketchum/code/swim-rs/examples/2_Fort_Peck/data/pestrun/pest/etf_US-FPe.ins' took: 0:00:00.114017
# 2026-01-15 11:19:55.063486 finished: adding observations from array output file 'obs/obs_etf_US-FPe.np' took: 0:00:00.148658
# 2026-01-15 11:19:55.063705 finished: adding observations from output file obs/obs_etf_US-FPe.np took: 0:00:00.150281
# 2026-01-15 11:19:55.750098 starting: adding observations from output file obs/obs_swe_US-FPe.np
# 2026-01-15 11:19:55.750732 starting: adding observations from array output file 'obs/obs_swe_US-FPe.np'
# 2026-01-15 11:19:55.779848 starting: adding observation from instruction file '/home/dgketchum/code/swim-rs/examples/2_Fort_Peck/data/pestrun/pest/swe_US-FPe.ins'
# 2026-01-15 11:19:55.890236 finished: adding observation from instruction file '/home/dgketchum/code/swim-rs/examples/2_Fort_Peck/data/pestrun/pest/swe_US-FPe.ins' took: 0:00:00.110388
# 2026-01-15 11:19:55.891216 finished: adding observations from array output file 'obs/obs_swe_US-FPe.np' took: 0:00:00.140484
# 2026-01-15 11:19:55.891433 finished: adding observations from output file obs/obs_swe_US-FPe.np took: 0:00:00.141335
# noptmax:0, npar_adj:8, nnz_obs:2868
# noptmax:0, npar_adj:8, nnz_obs:2868
# Configured PEST++ for 1 targets,

# %%
# Show the files created in the pest directory
pest_files = [f for f in sorted(os.listdir(builder.pest_dir)) 
              if os.path.isfile(os.path.join(builder.pest_dir, f))]
print("Files in pest directory:")
for f in pest_files:
    print(f"  {f}")
# Out:
# Files in pest directory:
#   2_Fort_Peck.idx.csv
#   2_Fort_Peck.pst
#   2_fort_peck.insfile_data.csv
#   2_fort_peck.obs_data.csv
#   2_fort_peck.par_data.csv
#   2_fort_peck.pargp_data.csv
#   2_fort_peck.tplfile_data.csv
#   custom_forward_run.py
#   etf_US-FPe.ins
#   mult2model_info.csv
#   p_aw_US-FPe_0_constant.csv.tpl
#   p_kr_alpha_US-FPe_0_constant.csv.tpl
#   p_ks_alpha_US-FPe_0_constant.csv.tpl
#   p_mad_US-FPe_0_constant.csv.tpl
#   p_ndvi_0_US-FPe_0_constant.csv.tpl
#   p_ndvi_k_US-FPe_0_constant.csv.tpl
#   p_swe_alpha_US-FPe_0_constant.csv.tpl
#   p_swe_beta_US-FPe_0_constant.csv.tpl
#   params.csv
#   spinup.json
#   swe_US-FPe.ins

# %% [markdown]
# ### Examine the .pst File
#
# The PEST++ version 2 control file is concise, delegating details to external files:

# %%
with open(builder.pst_file, 'r') as f:
    print(f.read())
# Out:
# pcf version=2
# * control data keyword
# pestmode                                 estimation
# noptmax                                 0
# svdmode                                 1
# maxsing                          10000000
# eigthresh                           1e-06
# eigwrite                                1
# * parameter groups external
# 2_fort_peck.pargp_data.csv
# * parameter data external
# 2_fort_peck.par_data.csv
# * observation data external
# 2_fort_peck.obs_data.csv
# * model command line
# python custom_forward_run.py
# * model input external
# 2_fort_peck.tplfile_data.csv
# * model output external
# 2_fort_peck.insfile_data.csv

# %% [markdown]
# ## 4. Configure and Test
#
# Now we:
# 1. Build the localizer matrix (links parameters to relevant observations)
# 2. Run spinup to save initial water balance state
# 3. Do a dry run to verify everything works
# 4. Set control parameters for the full calibration

# %%
# Build localizer matrix
# - SWE observations update only swe_alpha and swe_beta
# - ETf observations update all other parameters
builder.build_localizer()

# Run spinup to save water balance state as initial conditions for calibration runs
# This runs the model once and saves the final state to spinup.json
print("Running spinup...")
builder.spinup(overwrite=True)

# Run a minimal model run to verify the setup
print("\nRunning dry run...")
builder.dry_run()

# Configure for 3 optimization iterations with 20 realizations each
# Increase realizations (e.g., 100-200) for production runs
builder.write_control_settings(noptmax=3, reals=20)
# Out:
# noptmax:0, npar_adj:8, nnz_obs:2868
# Running spinup...
# RUNNING SPINUP
# USING PARAMETER DEFAULTS
#
# Running dry run...
# noptmax:3, npar_adj:8, nnz_obs:2868
# writing /home/dgketchum/code/swim-rs/examples/2_Fort_Peck/data/pestrun/pest/2_Fort_Peck.pst with noptmax=3, 20 realizations

# %%
# Show the updated control file with calibration settings
with open(builder.pst_file, 'r') as f:
    print(f.read())
# Out:
# pcf version=2
# * control data keyword
# pestmode                                 estimation
# noptmax                                 3
# svdmode                                 1
# maxsing                          10000000
# eigthresh                           1e-06
# eigwrite                                1
# ies_localizer                  loc.mat
# ies_num_reals                  20
# ies_drop_conflicts             true
# * parameter groups external
# 2_fort_peck.pargp_data.csv
# * parameter data external
# 2_fort_peck.par_data.csv
# * observation data external
# 2_fort_peck.obs_data.csv
# * model command line
# python custom_forward_run.py
# * model input external
# 2_fort_peck.tplfile_data.csv
# * model output external
# 2_fort_peck.insfile_data.csv

# %% [markdown]
# ## 5. Run PEST++ Calibration
#
# Now we launch PEST++ with parallel workers. Adjust `workers` to match your machine's capabilities.
#
# **Important:** This can take a while. Watch for the progress indicator showing completed runs (C), failed (F), and total (T).

# %%
workers = config.workers or 6
_pst = f"{config.project_name}.pst"

print(f"Starting PEST++ with {workers} workers...")
print(f"Control file: {_pst}")

run_pst(builder.pest_dir,
        'pestpp-ies',
        _pst,
        num_workers=workers,
        worker_root=builder.workers_dir,
        master_dir=builder.master_dir,
        cleanup=True,
        verbose=True)
# Out:
# Starting PEST++ with 20 workers...
# Control file: 2_Fort_Peck.pst
# rmtree: /home/dgketchum/code/swim-rs/examples/2_Fort_Peck/data/pestrun/workers/worker_6
# rmtree: /home/dgketchum/code/swim-rs/examples/2_Fort_Peck/data/pestrun/workers/worker_14
# rmtree: /home/dgketchum/code/swim-rs/examples/2_Fort_Peck/data/pestrun/workers/worker_3
# rmtree: /home/dgketchum/code/swim-rs/examples/2_Fort_Peck/data/pestrun/workers/worker_12
# rmtree: /home/dgketchum/code/swim-rs/examples/2_Fort_Peck/data/pestrun/workers/worker_18
# rmtree: /home/dgketchum/code/swim-rs/examples/2_Fort_Peck/data/pestrun/workers/worker_15
# rmtree: /home/dgketchum/code/swim-rs/examples/2_Fort_Peck/data/pestrun/workers/worker_19
# rmtree: /home/dgketchum/code/swim-rs/examples/2_Fort_Peck/data/pestrun/workers/worker_8
# rmtree: /home/dgketchum/code/swim-rs/examples/2_Fort_Peck/data/pestrun/workers/worker_16
# rmtree: /home/dgketchum/code/swim-rs/examples/2_Fort_Peck/data/pestrun/workers/worker_2
# rmtree: /home/dgketchum/code/swim-rs/examples/2_Fort_Peck/data/pestrun/workers/worker_11
# rmtree: /home/dgketchum/code/swim-rs/examples/2_Fort_Peck/data/pestrun/workers/worker_0
# rmtree: /home/dgketchum/code/swim-rs/examples/2_Fort_Peck/data/pestrun/workers/worker_13
# rmtree: /home/dgketchum/code/swim-rs/examples/2_Fort_Peck/data/pestrun/workers/worker_10
# rmtree: /home/dgketchum/code/swim-rs/examples/2_Fort_Peck/data/pestrun/workers/worker_4
# rmtree: /home/dgketchum/code/swim-rs/examples/2_Fort_Peck/data/pestrun/workers/worker_1
# rmtree: /home/dgketchum/code/swim-rs/examples/2_Fort_Peck/data/pestrun/workers/worker_7
# rmtree: /home/dgketchum/code/swim-rs/examples/2_Fort_Peck/data/pestrun/workers/worker_17
# rmtree: /home/dgketchum/code/swim-rs/examples/2_Fort_Peck/data/pestrun/workers/worker_5
# rmtree: /home/dgketchum/code/swim-rs/examples/2_Fort_Peck/data/pestrun/workers/worker_9
# master:pestpp-ies 2_Fort_Peck.pst /h :5005 in /home/dgketchum/code/swim-rs/examples/2_Fort_Peck/data/pestrun/master
#
#
#              pestpp-ies: a GLM iterative ensemble smoother
#
#                    by the PEST++ development team
#
# ...processing command line: ' pestpp-ies 2_Fort_Peck.pst /h :5005'
# ...using panther run manager in master mode using port 5005
#
#
# version: 5.2.25
# binary compiled on Jan 13 2026 at 20:33:04
# using control file: "2_Fort_Peck.pst"
# in directory: "/home/dgketchum/code/swim-rs/examples/2_Fort_Peck/data/pestrun/master"
# on host: "fcfc-mcozoran"
# on a(n) linux operating system
# with release configuration
# started at 01/15/26 11:20:27
#
# processing control file 2_Fort_Peck.pst
#
#
# :~-._                                                 _.-~:
# : :.~^o._        ________---------________        _.o^~.:.:
#  : ::.`?88booo~~~.::::::::...::::::::::::..~~oood88P'.::.:
#  :  ::: `?88P .:::....         ........:::::. ?88P' :::. :
#   :  :::. `? .::.            . ...........:::. P' .:::. :
#    :  :::   ... ..  ...       .. .::::......::.   :::. :
#    `  :' .... ..  .:::::.     . ..:::::::....:::.  `: .'
#     :..    ____:::::::::.  . . ....:::::::::____  ... :
#    :... `:~    ^~-:::::..  .........:::::-~^    ~::.::::
#    `.::. `\   (8)  \b:::..::.:.:::::::d/  (8)   /'.::::'
#     ::::.  ~-._v    |b.::::::::::::::d|    v_.-~..:::::
#     `.:::::... ~~^?888b..:::::::::::d888P^~...::::::::'
#      `.::::::::::....~~~ .:::::::::~~~:::::::::::::::'
#       `..:::::::::::   .   ....::::    ::::::::::::,'
#         `. .:::::::    .      .::::.    ::::::::'.'
#           `._ .:::    .        :::::.    :::::_.'
#              `-. :    .        :::::      :,-'
#                 :.   :___     .:::___   .::
#       ..--~~~~--:+::. ~~^?b..:::dP^~~.::++:--~~~~--..
#         ___....--`+:::.    `~8~'    .:::+'--....___
#       ~~   __..---`_=:: ___gd8bg___ :==_'---..__   ~~
#        -~~~  _.--~~`-.~~~~~~~~~~~~~~~,-' ~~--._ ~~~-
#
#
#                starting PANTHER master...
#
# IP addresses:
#   0.0.0.0:5005 (IPv4)
#
# PANTHER master listening on socket: 0.0.0.0:5005 (IPv4)
#
#   ---  initializing  ---
# ...using glm algorithm
# ...using REDSVD for truncated svd solve
# ...maxsing: 10000000
# ...eigthresh:  1e-06
# ...initializing localizer
# ...using localized solution with 8 sequential upgrade steps
# ...localizing by parameters
# ...using lambda multipliers: 0.1 , 1 , 10 ,
# ...using lambda scaling factors: 0.75 , 1 , 1.1 ,
# ...acceptable phi factor:  1.05
# ...lambda increase factor:  10
# ...lambda decrease factor:  0.75
# ...max run fail:  1
# ...initializing prior parameter covariance matrix
# ...parcov loaded  from parameter bounds, using par_sigma_range 4
# ...initializing observation noise covariance matrix
# ...obscov loaded  from observation weights
# ...drawing parameter realizations:  20
# ...not using prior parameter covariance matrix scaling
# ...drawing observation noise realizations:  20
# observations not grouped by observations groups, reordering obs ensemble
# ...setting weights ensemble from control file weights
# ...saved weight ensemble to  2_Fort_Peck.weights.csv
# ...adding 'base' parameter values to ensemble
# ...adding 'base' observation values to ensemble
# ...adding 'base' weight values to weight ensemble
# ...saved initial parameter ensemble to  2_Fort_Peck.0.par.csv
# ...saved obs+noise observation ensemble (obsval + noise realizations) to  2_Fort_Peck.obs+noise.csv
# ...using subset in lambda testing, percentage of realizations used in subset testing:  10
# ...subset how:  RANDOM
# ...centering on ensemble mean vector
# ...running initial ensemble of size 20
#     running model 20 times
#     starting at 01/15/26 11:20:30
#
#     waiting for agents to appear...
#
#
# PANTHER progress
#    avg = average model run time in minutes
#    runs(C = completed | F = failed | T = timed out)
#    agents(R = running | W = waiting | U = unavailable)
# --------------------------------------------------------------------------------
# worker:pestpp-ies 2_Fort_Peck.pst /h localhost:5005 in /home/dgketchum/code/swim-rs/examples/2_Fort_Peck/data/pestrun/workers/worker_0
# worker:pestpp-ies 2_Fort_Peck.pst /h localhost:5005 in /home/dgketchum/code/swim-rs/examples/2_Fort_Peck/data/pestrun/workers/worker_1
# worker:pestpp-ies 2_Fort_Peck.pst /h localhost:5005 in /home/dgketchum/code/swim-rs/examples/2_Fort_Peck/data/pestrun/workers/worker_2
# worker:pestpp-ies 2_Fort_Peck.pst /h localhost:5005 in /home/dgketchum/code/swim-rs/examples/2_Fort_Peck/data/pestrun/workers/worker_3
# worker:pestpp-ies 2_Fort_Peck.pst /h localhost:5005 in /home/dgketchum/code/swim-rs/examples/2_Fort_Peck/data/pestrun/workers/worker_4
# worker:pestpp-ies 2_Fort_Peck.pst /h localhost:5005 in /home/dgketchum/code/swim-rs/examples/2_Fort_Peck/data/pestrun/workers/worker_5
# worker:pestpp-ies 2_Fort_Peck.pst /h localhost:5005 in /home/dgketchum/code/swim-rs/examples/2_Fort_Peck/data/pestrun/workers/worker_6
# worker:pestpp-ies 2_Fort_Peck.pst /h localhost:5005 in /home/dgketchum/code/swim-rs/examples/2_Fort_Peck/data/pestrun/workers/worker_7
# worker:pestpp-ies 2_Fort_Peck.pst /h localhost:5005 in /home/dgketchum/code/swim-rs/examples/2_Fort_Peck/data/pestrun/workers/worker_8
# worker:pestpp-ies 2_Fort_Peck.pst /h localhost:5005 in /home/dgketchum/code/swim-rs/examples/2_Fort_Peck/data/pestrun/workers/worker_9
# worker:pestpp-ies 2_Fort_Peck.pst /h localhost:5005 in /home/dgketchum/code/swim-rs/examples/2_Fort_Peck/data/pestrun/workers/worker_10
# worker:pestpp-ies 2_Fort_Peck.pst /h localhost:5005 in /home/dgketchum/code/swim-rs/examples/2_Fort_Peck/data/pestrun/workers/worker_11
# worker:pestpp-ies 2_Fort_Peck.pst /h localhost:5005 in /home/dgketchum/code/swim-rs/examples/2_Fort_Peck/data/pestrun/workers/worker_12
# worker:pestpp-ies 2_Fort_Peck.pst /h localhost:5005 in /home/dgketchum/code/swim-rs/examples/2_Fort_Peck/data/pestrun/workers/worker_13
# 01/15 11:21:23 remaining file transfers: 0|T0    ) agents(R2   |W12  |U0   ) 0
#
#    20 runs complete :  0 runs failed
#    0.247 avg run time (min) : 0.898 run mgr time (min)
#    14 agents connected
#
#
# ...saved initial obs ensemble to 2_Fort_Peck.0.obs.csv
# saved par and rei files for realization BASE for iteration 0
# saved par and rei files for realization BASE
#
#   ---  pre-drop initial phi summary  ---
#        phi type           mean            std            min            max
#        measured        974.387        453.551        591.665        2560.43
#          actual        759.037        434.083        504.274        2295.94
#      note: 'measured' phi reported above includes
#            realizations of measurement noise,
#            'actual' phi does not.
#   ---  observation group phi summary ---
#        (computed using 'actual' phi)
#            (sorted by mean phi)
# group                                   count  nconflict      mean       std       min       max   percent       std
# oname:obs/obs_etf_us-fpe.np_otype:arr     939         57       633       103       503       830      93.4      19.4
# oname:obs/obs_swe_us-fpe.np_otype:arr    1929          7       127       400     0.851  1.59e+03      6.55      19.4
#
# ...checking for prior-data conflict
#
#   ---  WARNING: 64 non-zero weighted observations are in conflict with the prior simulated ensemble.
#   ---
# ...see 2_Fort_Peck.0.pdc.csv for listing of conflicted observations
#
# ...dropping conflicted observations
# ...number of non-zero weighted observations reduced from 2868 to 2804
#
# ...updating localizer
# dropped 64 from localizer rows because forgive_missing is true
# ...saved adjusted weight ensemble to  2_Fort_Peck.adjusted.weights.csv
# worker:pestpp-ies 2_Fort_Peck.pst /h localhost:5005 in /home/dgketchum/code/swim-rs/examples/2_Fort_Peck/data/pestrun/workers/worker_14
# saved par and rei files for realization BASE for iteration 0
# saved par and rei files for realization BASE
#
#   ---  initial phi summary  ---
#        phi type           mean            std            min            max
#        measured        777.021        446.158        433.891        2345.79
#          actual        602.549        429.341        369.231        2123.67
#      note: 'measured' phi reported above includes
#            realizations of measurement noise,
#            'actual' phi does not.
#   ---  observation group phi summary ---
#        (computed using 'actual' phi)
#            (sorted by mean phi)
# group                                   count  nconflict      mean       std       min       max   percent       std
# oname:obs/obs_etf_us-fpe.np_otype:arr     882          0       477      91.7       368       654      92.8        21
# oname:obs/obs_swe_us-fpe.np_otype:arr    1922          0       126       398      0.85  1.58e+03      7.18        21
#
# ...current lambda: 0.1
#
#    ---  parameter group change summary  ---
# group     count  mean chg  std chg  n at ubnd  % at ubnd  n at lbnd  % at lbnd  n std decr
# swe_beta      1         0        0          4         20          0          0           0
# ndvi_0        1         0        0          4         20          0          0           0
# mad           1         0        0          3         15          0          0           0
# swe_alpha     1         0        0          2         10          0          0           0
# ndvi_k        1         0        0          1          5          0          0           0
# aw            1         0        0          1          5          0          0           0
# ks_alpha      1         0        0          0          0          0          0           0
# kr_alpha      1         0        0          0          0          0          0           0
#
#
#   ---  initialization complete  ---
#
#   ---  starting solve for iteration: 1  ---
# ...current lambda:  0.1
# ...preparing fast-lookup containers for threaded localization solve
# ...starting calcs for glm factor 0.01
# ...finished calcs for: 0.01
# ...starting calcs for glm factor 0.1
# ...finished calcs for: 0.1
# ...starting calcs for glm factor 1
# ...finished calcs for: 1
#
#   ---  running upgrade ensembles  ---
# ...subset idx:pe real name:  2:2, 8:8, 16:16, 19:BASE,
# ...subset idx:oe real name:  2:2, 8:8, 16:16, 19:BASE,
#     running model 36 times
#     starting at 01/15/26 11:21:26
#     15 agents ready
#
#
# PANTHER progress
#    avg = average model run time in minutes
#    runs(C = completed | F = failed | T = timed out)
#    agents(R = running | W = waiting | U = unavailable)
# --------------------------------------------------------------------------------
# worker:pestpp-ies 2_Fort_Peck.pst /h localhost:5005 in /home/dgketchum/code/swim-rs/examples/2_Fort_Peck/data/pestrun/workers/worker_15
# worker:pestpp-ies 2_Fort_Peck.pst /h localhost:5005 in /home/dgketchum/code/swim-rs/examples/2_Fort_Peck/data/pestrun/workers/worker_16
# worker:pestpp-ies 2_Fort_Peck.pst /h localhost:5005 in /home/dgketchum/code/swim-rs/examples/2_Fort_Peck/data/pestrun/workers/worker_17
# worker:pestpp-ies 2_Fort_Peck.pst /h localhost:5005 in /home/dgketchum/code/swim-rs/examples/2_Fort_Peck/data/pestrun/workers/worker_18
# worker:pestpp-ies 2_Fort_Peck.pst /h localhost:5005 in /home/dgketchum/code/swim-rs/examples/2_Fort_Peck/data/pestrun/workers/worker_19
# 01/15 11:22:08 remaining file transfers: 0|T0    ) agents(R1   |W19  |U0   ) 0
#
#    36 runs complete :  0 runs failed
#    0.268 avg run time (min) : 0.692 run mgr time (min)
#    20 agents connected
#
#
#
#   ---  evaluating upgrade ensembles  ---
# ...last mean:  777.021
# ...last stdev:  446.158
#
#   ---  phi summary for best lambda, scale fac: 0.01 , 1.1 ,   ---
#        phi type           mean            std            min            max
#        measured        538.184        102.354        384.746        593.778
#          actual        374.257        22.1279        345.846        397.203
#      note: 'measured' phi reported above includes
#            realizations of measurement noise,
#            'actual' phi does not.
#
#   ---  running remaining realizations for best lambda, scale:0.01 , 1.1 ,   ---
#     running model 16 times
#     starting at 01/15/26 11:22:10
#     20 agents ready
#
#
# PANTHER progress
#    avg = average model run time in minutes
#    runs(C = completed | F = failed | T = timed out)
#    agents(R = running | W = waiting | U = unavailable)
# --------------------------------------------------------------------------------
# 01/15 11:22:26 remaining file transfers: 0|T0    ) agents(R2   |W18  |U0   ) 0
#
#    16 runs complete :  0 runs failed
#    0.26 avg run time (min) : 0.268 run mgr time (min)
#    20 agents connected
#
#
# ...phi summary for entire ensemble using lambda,scale_fac 0.01 , 1.1 ,
#        phi type           mean            std            min            max
#        measured        554.094        48.4165        384.746        594.294
#          actual        377.677        16.4446        344.316        397.203
#      note: 'measured' phi reported above includes
#            realizations of measurement noise,
#            'actual' phi does not.
# ...last best mean phi * acceptable phi factor:  815.873
# ...current best mean phi:  554.094
#
#   ---  updating parameter ensemble  ---
#
#   ---  updating lambda to  0.0075  ---
#
#   ---  EnsembleMethod iteration 1 report  ---
#    number of active realizations:   20
#    number of model runs:            72
#       current obs ensemble saved to 2_Fort_Peck.1.obs.csv
#       current par ensemble saved to 2_Fort_Peck.1.par.csv
# saved par and rei files for realization BASE for iteration 1
# saved par and rei files for realization BASE
#        phi type           mean            std            min            max
#        measured        554.094        48.4165        384.746        594.294
#          actual        377.677        16.4446        344.316        397.203
#      note: 'measured' phi reported above includes
#            realizations of measurement noise,
#            'actual' phi does not.
#   ---  observation group phi summary ---
#        (computed using 'actual' phi)
#            (sorted by mean phi)
# group                                   count  nconflict      mean       std       min       max   percent       std
# oname:obs/obs_etf_us-fpe.np_otype:arr     882         97       376        16       343       395      99.6     0.142
# oname:obs/obs_swe_us-fpe.np_otype:arr    1922        696      1.63     0.582     0.855      2.67     0.426     0.142
#
#
#    ---  parameter group change summary  ---
# group     count  mean chg  std chg  n at ubnd  % at ubnd  n at lbnd  % at lbnd  n std decr
# aw            1     10.16    48.65          4         20          0          0           0
# swe_beta      1     2.682    1.034          0          0          0          0           0
# swe_alpha     1     3.735    23.93          0          0          0          0           0
# ndvi_k        1     13.27    36.71          0          0          0          0           0
# ndvi_0        1     45.44    80.73          0          0          0          0           0
# mad           1     151.6    45.99          0          0          0          0           0
# ks_alpha      1     31.94    29.75          0          0          0          0           0
# kr_alpha      1     27.17    78.94          0          0          0          0           0
#
# ...saved parameter change summary to 2_Fort_Peck.1.pcs.csv
#
#   ---  phi-based termination criteria check  ---
# ...phiredstp:  0.01
# ...nphistp:  3
# ...nphinored (also used for consecutive bad lambda cycles):  3
# ...best mean phi sequence: 777.021 , 554.094 ,
# ...best phi yet:  554.094
# ...number of consecutive bad lambda testing cycles:  0
# ...number of iterations satisfying phiredstp criteria:  1
# ...number of iterations since best yet mean phi:  0
#
#   ---  starting solve for iteration: 2  ---
# ...current lambda:  0.0075
# ...preparing fast-lookup containers for threaded localization solve
# ...starting calcs for glm factor 0.00075
# ...finished calcs for: 0.00075
# ...starting calcs for glm factor 0.0075
# ...finished calcs for: 0.0075
# ...starting calcs for glm factor 0.075
# ...finished calcs for: 0.075
#
#   ---  running upgrade ensembles  ---
# ...subset idx:pe real name:  3:BASE, 6:3, 13:11, 19:18,
# ...subset idx:oe real name:  3:BASE, 6:3, 13:11, 19:18,
#     running model 36 times
#     starting at 01/15/26 11:22:28
#     20 agents ready
#
#
# PANTHER progress
#    avg = average model run time in minutes
#    runs(C = completed | F = failed | T = timed out)
#    agents(R = running | W = waiting | U = unavailable)
# --------------------------------------------------------------------------------
# 01/15 11:23:00 remaining file transfers: 0|T0    ) agents(R12  |W8   |U0   ) 0
#
#    36 runs complete :  0 runs failed
#    0.271 avg run time (min) : 0.541 run mgr time (min)
#    20 agents connected
#
#
#
#   ---  evaluating upgrade ensembles  ---
# ...last mean:  554.094
# ...last stdev:  48.4165
#
#   ---  phi summary for best lambda, scale fac: 0.00075 , 1.1 ,   ---
#        phi type           mean            std            min            max
#        measured        511.597        101.334        363.122        577.103
#          actual        375.158        8.58213        363.122        382.053
#      note: 'measured' phi reported above includes
#            realizations of measurement noise,
#            'actual' phi does not.
#
#   ---  running remaining realizations for best lambda, scale:0.00075 , 1.1 ,   ---
#     running model 16 times
#     starting at 01/15/26 11:23:01
#     20 agents ready
#
#
# PANTHER progress
#    avg = average model run time in minutes
#    runs(C = completed | F = failed | T = timed out)
#    agents(R = running | W = waiting | U = unavailable)
# --------------------------------------------------------------------------------
# 01/15 11:23:19 remaining file transfers: 0|T0    ) agents(R1   |W19  |U0   ) 0
#
#    16 runs complete :  0 runs failed
#    0.263 avg run time (min) : 0.297 run mgr time (min)
#    20 agents connected
#
#
# ...phi summary for entire ensemble using lambda,scale_fac 0.00075 , 1.1 ,
#        phi type           mean            std            min            max
#        measured        545.544        53.2242        363.122        615.092
#          actual        368.964        19.5015        336.547         413.44
#      note: 'measured' phi reported above includes
#            realizations of measurement noise,
#            'actual' phi does not.
# ...last best mean phi * acceptable phi factor:  581.799
# ...current best mean phi:  545.544
#
#   ---  updating parameter ensemble  ---
#
#   ---  not updating lambda (standard deviation reduction criteria not met)  ---
#
#   ---  EnsembleMethod iteration 2 report  ---
#    number of active realizations:   20
#    number of model runs:            124
#       current obs ensemble saved to 2_Fort_Peck.2.obs.csv
#       current par ensemble saved to 2_Fort_Peck.2.par.csv
# saved par and rei files for realization BASE for iteration 2
# saved par and rei files for realization BASE
#        phi type           mean            std            min            max
#        measured        545.544        53.2242        363.122        615.092
#          actual        368.964        19.5015        336.547         413.44
#      note: 'measured' phi reported above includes
#            realizations of measurement noise,
#            'actual' phi does not.
#   ---  observation group phi summary ---
#        (computed using 'actual' phi)
#            (sorted by mean phi)
# group                                   count  nconflict      mean       std       min       max   percent       std
# oname:obs/obs_etf_us-fpe.np_otype:arr     882        106       368      19.2       336       413      99.6      0.14
# oname:obs/obs_swe_us-fpe.np_otype:arr    1922        686      1.43     0.563     0.838      2.63     0.383      0.14
#
#
#    ---  parameter group change summary  ---
# group     count  mean chg  std chg  n at ubnd  % at ubnd  n at lbnd  % at lbnd  n std decr
# aw            1     13.61    76.24         12         60          0          0           0
# swe_beta      1     13.04    2.575          0          0          0          0           0
# swe_alpha     1      22.8    31.92          0          0          0          0           0
# ndvi_k        1     16.97    59.15          0          0          0          0           0
# ndvi_0        1     46.57    87.88          0          0          0          0           0
# mad           1     189.3    52.02          0          0          0          0           0
# ks_alpha      1     11.67    44.25          0          0          0          0           0
# kr_alpha      1     50.47     84.5          0          0          0          0           0
#
# ...saved parameter change summary to 2_Fort_Peck.2.pcs.csv
#
#   ---  phi-based termination criteria check  ---
# ...phiredstp:  0.01
# ...nphistp:  3
# ...nphinored (also used for consecutive bad lambda cycles):  3
# ...best mean phi sequence: 777.021 , 554.094 , 545.544 ,
# ...best phi yet:  545.544
# ...number of consecutive bad lambda testing cycles:  0
# ...number of iterations satisfying phiredstp criteria:  1
# ...number of iterations since best yet mean phi:  0
#
#   ---  starting solve for iteration: 3  ---
# ...current lambda:  0.0075
# ...preparing fast-lookup containers for threaded localization solve
# ...starting calcs for glm factor 0.00075
# ...finished calcs for: 0.00075
# ...starting calcs for glm factor 0.0075
# ...finished calcs for: 0.0075
# ...starting calcs for glm factor 0.075
# ...finished calcs for: 0.075
#
#   ---  running upgrade ensembles  ---
# ...subset idx:pe real name:  0:BASE, 4:2, 12:7, 16:13,
# ...subset idx:oe real name:  0:BASE, 4:2, 12:7, 16:13,
#     running model 36 times
#     starting at 01/15/26 11:23:21
#     20 agents ready
#
#
# PANTHER progress
#    avg = average model run time in minutes
#    runs(C = completed | F = failed | T = timed out)
#    agents(R = running | W = waiting | U = unavailable)
# --------------------------------------------------------------------------------
# 01/15 11:23:55 remaining file transfers: 0|T0    ) agents(R1   |W19  |U0   ) 0
#
#    36 runs complete :  0 runs failed
#    0.269 avg run time (min) : 0.559 run mgr time (min)
#    20 agents connected
#
#
#
#   ---  evaluating upgrade ensembles  ---
# ...last mean:  545.544
# ...last stdev:  53.2242
#
#   ---  phi summary for best lambda, scale fac: 0.00075 , 1.1 ,   ---
#        phi type           mean            std            min            max
#        measured        516.314         114.05        345.995        587.524
#          actual        356.503        14.8505        345.995        378.473
#      note: 'measured' phi reported above includes
#            realizations of measurement noise,
#            'actual' phi does not.
#
#   ---  running remaining realizations for best lambda, scale:0.00075 , 1.1 ,   ---
#     running model 16 times
#     starting at 01/15/26 11:23:56
#     20 agents ready
#
#
# PANTHER progress
#    avg = average model run time in minutes
#    runs(C = completed | F = failed | T = timed out)
#    agents(R = running | W = waiting | U = unavailable)
# --------------------------------------------------------------------------------
# 01/15 11:24:13 remaining file transfers: 0|T0    ) agents(R8   |W12  |U0   ) 0
#
#    16 runs complete :  0 runs failed
#    0.267 avg run time (min) : 0.277 run mgr time (min)
#    20 agents connected
#
#
# ...phi summary for entire ensemble using lambda,scale_fac 0.00075 , 1.1 ,
#        phi type           mean            std            min            max
#        measured        542.297        57.9747        345.995         622.71
#          actual        365.443         21.282        333.507        420.731
#      note: 'measured' phi reported above includes
#            realizations of measurement noise,
#            'actual' phi does not.
# ...last best mean phi * acceptable phi factor:  572.822
# ...current best mean phi:  542.297
#
#   ---  updating parameter ensemble  ---
#
#   ---  not updating lambda (standard deviation reduction criteria not met)  ---
#
#   ---  EnsembleMethod iteration 3 report  ---
#    number of active realizations:   20
#    number of model runs:            176
#       current obs ensemble saved to 2_Fort_Peck.3.obs.csv
#       current par ensemble saved to 2_Fort_Peck.3.par.csv
# saved par and rei files for realization BASE for iteration 3
# saved par and rei files for realization BASE
#        phi type           mean            std            min            max
#        measured        542.297        57.9747        345.995         622.71
#          actual        365.443         21.282        333.507        420.731
#      note: 'measured' phi reported above includes
#            realizations of measurement noise,
#            'actual' phi does not.
#   ---  observation group phi summary ---
#        (computed using 'actual' phi)
#            (sorted by mean phi)
# group                                   count  nconflict      mean       std       min       max   percent       std
# oname:obs/obs_etf_us-fpe.np_otype:arr     882        105       364      21.1       333       420      99.7     0.131
# oname:obs/obs_swe_us-fpe.np_otype:arr    1922        675      1.29      0.52      0.84      2.58      0.35     0.131
#
#
#    ---  parameter group change summary  ---
# group     count  mean chg  std chg  n at ubnd  % at ubnd  n at lbnd  % at lbnd  n std decr
# aw            1     14.22    84.07         15         75          0          0           0
# swe_beta      1     23.09    5.174          0          0          0          0           0
# swe_alpha     1     43.74    40.34          0          0          0          0           0
# ndvi_k        1     19.01    64.17          0          0          0          0           0
# ndvi_0        1     45.77    88.87          0          0          0          0           0
# mad           1     193.9     55.9          0          0          0          0           0
# ks_alpha      1     31.05     51.9          0          0          0          0           0
# kr_alpha      1     61.67    86.94          0          0          0          0           0
#
# ...saved parameter change summary to 2_Fort_Peck.3.pcs.csv
#
#   ---  phi-based termination criteria check  ---
# ...phiredstp:  0.01
# ...nphistp:  3
# ...nphinored (also used for consecutive bad lambda cycles):  3
# ...best mean phi sequence: 777.021 , 554.094 , 545.544 , 542.297 ,
# ...best phi yet:  542.297
# ...number of consecutive bad lambda testing cycles:  0
# ...number of iterations satisfying phiredstp criteria:  2
# ...number of iterations since best yet mean phi:  0
# ...solution iterations >= noptmax, all done
#
#
# pestpp-ies analysis complete...
# started at 01/15/26 11:20:27
# finished at 01/15/26 11:24:14
# took 3.78333 minutes

# %% [markdown]
# ## Debugging Tips
#
# If calibration fails, try these steps:
#
# ### Never saw the PEST++ panther logo?
# - Ensure `pestpp-ies` is in your PATH
# - Try running with full path: `/path/to/pestpp-ies`
# - On Windows, use `.exe` extension
#
# ### Python error traceback?
# Debug from the bottom up:
# 1. Verify `swimrs/calibrate/run_mp.py` runs standalone
# 2. Test `custom_forward_run.py` from the pest directory
# 3. Try running `pestpp-ies` directly from pest directory
#
# ### Saw panther but got errors?
# Common error: `output file 'pred/pred_swe_US-FPe.np' not found`
# - This usually means SWIM failed before writing predictions
# - Set `cleanup=False` above to preserve worker directories
# - Check `workers/worker_0/panther_worker.rec` for errors
#
# **Most errors (90%) are due to incorrect paths!**

# %% [markdown]
# ## 6. Check Results
#
# After successful calibration, parameter files are saved for each optimization iteration:

# %%
# Parameter files are in master_dir after calibration
import os
import shutil

results_dir = builder.master_dir if os.path.exists(builder.master_dir) else builder.pest_dir

par_files = [f for f in sorted(os.listdir(results_dir)) if '.par.csv' in f]
print(f"Parameter files (in {results_dir}):")
for f in par_files:
    print(f"  {f}")

if par_files:
    final_par = par_files[-1]
    print(f"\nFinal calibrated parameters: {final_par}")
    
    # Copy final parameters to pest/archive/ for consistency with calibration.py script
    archive_dir = os.path.join(builder.pest_dir, 'archive')
    os.makedirs(archive_dir, exist_ok=True)
    src = os.path.join(results_dir, final_par)
    dst = os.path.join(archive_dir, final_par)
    shutil.copy2(src, dst)
    print(f"Archived to: {dst}")

# Close the container
container.close()
print("\nContainer closed.")
# Out:
# Parameter files (in /home/dgketchum/code/swim-rs/examples/2_Fort_Peck/data/pestrun/master):
#   2_Fort_Peck.0.par.csv
#   2_Fort_Peck.1.par.csv
#   2_Fort_Peck.2.par.csv
#   2_Fort_Peck.3.par.csv
#
# Final calibrated parameters: 2_Fort_Peck.3.par.csv
# Archived to: /home/dgketchum/code/swim-rs/examples/2_Fort_Peck/data/pestrun/pest/archive/2_Fort_Peck.3.par.csv
#
# Container closed.

# %% [markdown]
# ## Summary
#
# You've set up and run a PEST++ calibration using:
# - PT-JPL ETf observations from Landsat (via OpenET)
# - SNODAS SWE observations
# - Iterative Ensemble Smoother (pestpp-ies)
#
# The parameter files (e.g., `2_Fort_Peck.3.par.csv`) contain the calibrated parameter sets. Each row represents a different realization from the ensemble.
#
# **Next step:** In notebook `03_calibrated_model.ipynb`, we'll run the model in forecast mode with calibrated parameters and validate against flux tower observations.
