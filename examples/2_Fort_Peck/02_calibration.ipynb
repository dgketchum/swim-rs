# %% [markdown]
# # Calibration Tutorial - Fort Peck, MT - Unirrigated Flux Plot
#
# ## Step 2: Calibrate with PEST++
#
# Now we see if we can improve the model's performance through calibration.
#
# ### PEST++ Resources
#
# PEST++ has excellent documentation covering both theory and practice:
#
# 1. **The PEST Manual 4th Ed.** (Doherty, 2002): https://www.epa.gov/sites/default/files/documents/PESTMAN.PDF
# 2. **GMDSI tutorial notebooks**: https://github.com/gmdsi/GMDSI_notebooks
# 3. **PEST++ User's Manual**: https://github.com/usgs/pestpp/blob/master/documentation/pestpp_users_manual.md
# 4. **PEST Book** (Doherty, 2015): https://pesthomepage.org/pest-book
#
# **Note:** We use PT-JPL ETf and SNODAS SWE for calibration - not flux observations. The flux data is reserved for validation only.

# %% [markdown]
# ### PEST++ Installation
#
# Install PEST++ via conda-forge (recommended):
#
# ```bash
# conda install conda-forge::pestpp
# ```
#
# This installs `pestpp-ies` and other PEST++ tools directly into your conda environment. Verify the installation:
#
# ```bash
# pestpp-ies --version
# ```
#
# **Alternative:** For manual installation from source, see the [PEST++ GitHub releases](https://github.com/usgs/pestpp/releases).

# %%
import os
import sys

root = os.path.abspath('../..')
sys.path.append(root)

from swimrs.container import SwimContainer
from swimrs.calibrate.pest_builder import PestBuilder
from swimrs.swim.config import ProjectConfig
from swimrs.calibrate.run_pest import run_pst

# %% [markdown]
# ## 1. Load Configuration
#
# Load the project configuration and prepare paths.

# %%
project = '2_Fort_Peck'
project_ws = os.path.abspath('.')

config_path = os.path.join(project_ws, '2_Fort_Peck.toml')

config = ProjectConfig()
config.read_config(config_path, project_ws)

# %% [markdown]
# ## 2. Generate Observation Files
#
# PEST++ needs observation files (ETf and SWE) to compare against model predictions. We export these from the SwimContainer built in the data preparation step.
#
# The export creates per-field numpy files:
# - `obs_etf_{field_id}.np`: ETf observations (PT-JPL) with irrigation mask switching
# - `obs_swe_{field_id}.np`: SWE observations from SNODAS

# %%
# Open container for observations export and PEST++ setup
container_path = os.path.join(project_ws, 'data', f'{project}.swim')
container = SwimContainer.open(container_path, mode='r')

# Export observation files for PEST++ calibration
# Note: obs_folder is set to {pest_run_dir}/obs in the TOML config
obs_dir = os.path.join(project_ws, 'data', 'pestrun', 'obs')
os.makedirs(obs_dir, exist_ok=True)

container.export.observations(
    output_dir=obs_dir,
    etf_model='ptjpl',
    masks=('irr', 'inv_irr'),
    irr_threshold=0.1,
)
print(f"Observation files written to {obs_dir}")
# Out:
# Observation files written to /home/dgketchum/code/swim-rs/examples/2_Fort_Peck/data/pestrun/obs

# %% [markdown]
# ## 3. Build PEST++ Control Files
#
# The `PestBuilder` class sets up everything needed for PEST++ calibration:
#
# ### Calibration Loop
# 1. Initialize model with initial parameter values
# 2. Run model, write results
# 3. Compare results to observations (ETf, SWE)
# 4. Propose new parameters
# 5. Repeat until convergence
#
# ### Tunable Parameters
# SWIM uses 8 tunable parameters:
# - **Soil water:** `aw` (available water), `rew` (readily evaporable water), `tew` (total evaporable water)
# - **NDVI-Kcb relationship:** `ndvi_alpha`, `ndvi_beta`
# - **Stress threshold:** `mad` (management allowable depletion)
# - **Snow melt:** `swe_alpha`, `swe_beta`

# %%
# PestBuilder auto-generates custom_forward_run.py using the process package
# with portable swim_input.h5 file for fully self-contained workers
builder = PestBuilder(config, container=container, use_existing=False)
# Out:
# Using default Python script at: /home/dgketchum/code/swim-rs/src/swimrs/calibrate/custom_forward_run.py

# %% [markdown]
# ### Build the .pst Control File
#
# The `build_pest()` method:
# - Copies project files to a `pest/` directory
# - Creates the `.pst` control file
# - Sets up parameter templates (`.tpl`) and instruction files (`.ins`)
#
# **Note:** ETf observations are sparse (only on satellite capture dates). The PEST builder automatically assigns weight 1.0 to valid observations and weight 0.0 to missing dates, ensuring we only calibrate against actual satellite captures.

# %%
# Build the pest control file
# WARNING: This will erase any existing pest directory!
builder.build_pest(target_etf=config.etf_target_model, members=config.etf_ensemble_members)
# Out:
# 2026-01-27 13:58:33.595109 starting: opening PstFrom.log for logging
# 2026-01-27 13:58:33.595638 starting PstFrom process
# 2026-01-27 13:58:33.595769 starting: setting up dirs
# 2026-01-27 13:58:33.595948 starting: removing existing new_d '/home/dgketchum/code/swim-rs/examples/2_Fort_Peck/data/pestrun/pest'
# 2026-01-27 13:58:33.609845 finished: removing existing new_d '/home/dgketchum/code/swim-rs/examples/2_Fort_Peck/data/pestrun/pest' took: 0:00:00.013897
# 2026-01-27 13:58:33.609954 starting: copying original_d '/home/dgketchum/code/swim-rs/examples/2_Fort_Peck/data/pestrun/_template' to new_d '/home/dgketchum/code/swim-rs/examples/2_Fort_Peck/data/pestrun/pest'
# 2026-01-27 13:58:33.611709 finished: copying original_d '/home/dgketchum/code/swim-rs/examples/2_Fort_Peck/data/pestrun/_template' to new_d '/home/dgketchum/code/swim-rs/examples/2_Fort_Peck/data/pestrun/pest' took: 0:00:00.001755
# 2026-01-27 13:58:33.612041 finished: setting up dirs took: 0:00:00.016272
# 2026-01-27 13:58:33.612266 starting: adding constant type m style parameters for file(s) ['params.csv']
# 2026-01-27 13:58:33.612451 starting: loading list-style /home/dgketchum/code/swim-rs/examples/2_Fort_Peck/data/pestrun/pest/params.csv
# 2026-01-27 13:58:33.612562 starting: reading list-style file: /home/dgketchum/code/swim-rs/examples/2_Fort_Peck/data/pestrun/pest/params.csv
# 2026-01-27 13:58:33.615172 finished: reading list-style file: /home/dgketchum/code/swim-rs/examples/2_Fort_Peck/data/pestrun/pest/params.csv took: 0:00:00.002610
# 2026-01-27 13:58:33.615341 loaded list-style '/home/dgketchum/code/swim-rs/examples/2_Fort_Peck/data/pestrun/pest/params.csv' of shape (9, 3)
# 2026-01-27 13:58:33.617605 finished: loading list-style /home/dgketchum/code/swim-rs/examples/2_Fort_Peck/data/pestrun/pest/params.csv took: 0:00:00.005154
# 2026-01-27 13:58:33.617756 starting: writing list-style template file '/home/dgketchum/code/swim-rs/examples/2_Fort_Peck/data/pestrun/pest/p_aw_US-FPe_0_constant.csv.tpl'
# 2026-01-27 13:58:33.630412 finished: writing list-style template file '/home/dgketchum/code/swim-rs/examples/2_Fort_Peck/data/pestrun/pest/p_aw_US-FPe_0_constant.csv.tpl' took: 0:00:00.012656
# 2026-01-27 13:58:33.633822 finished: adding constant type m style parameters for file(s) ['params.csv'] took: 0:00:00.021556
# 2026-01-27 13:58:33.633945 starting: adding constant type m style parameters for file(s) ['params.csv']
# 2026-01-27 13:58:33.634029 starting: loading list-style /home/dgketchum/code/swim-rs/examples/2_Fort_Peck/data/pestrun/pest/params.csv
# 2026-01-27 13:58:33.634086 starting: reading list-style file: /home/dgketchum/code/swim-rs/examples/2_Fort_Peck/data/pestrun/pest/params.csv
# 2026-01-27 13:58:33.635099 finished: reading list-style file: /home/dgketchum/code/swim-rs/examples/2_Fort_Peck/data/pestrun/pest/params.csv took: 0:00:00.001013
# 2026-01-27 13:58:33.635178 loaded list-style '/home/dgketchum/code/swim-rs/examples/2_Fort_Peck/data/pestrun/pest/params.csv' of shape (9, 3)
# 2026-01-27 13:58:33.636384 finished: loading list-style /home/dgketchum/code/swim-rs/examples/2_Fort_Peck/data/pestrun/pest/params.csv took: 0:00:00.002355
# 2026-01-27 13:58:33.636475 starting: writing list-style template file '/home/dgketchum/code/swim-rs/examples/2_Fort_Peck/data/pestrun/pest/p_ks_alpha_US-FPe_0_constant.csv.tpl'
# 2026-01-27 13:58:33.644394 finished: writing list-style template file '/home/dgketchum/code/swim-rs/examples/2_Fort_Peck/data/pestrun/pest/p_ks_alpha_US-FPe_0_constant.csv.tpl' took: 0:00:00.007919
# 2026-01-27 13:58:33.647289 finished: adding constant type m style parameters for file(s) ['params.csv'] took: 0:00:00.013344
# 2026-01-27 13:58:33.647392 starting: adding constant type m style parameters for file(s) ['params.csv']
# 2026-01-27 13:58:33.647463 starting: loading list-style /home/dgketchum/code/swim-rs/examples/2_Fort_Peck/data/pestrun/pest/params.csv
# 2026-01-27 13:58:33.647513 starting: reading list-style file: /home/dgketchum/code/swim-rs/examples/2_Fort_Peck/data/pestrun/pest/params.csv
# 2026-01-27 13:58:33.648386 finished: reading list-style file: /home/dgketchum/code/swim-rs/examples/2_Fort_Peck/data/pestrun/pest/params.csv took: 0:00:00.000873
# 2026-01-27 13:58:33.648479 loaded list-style '/home/dgketchum/code/swim-rs/examples/2_Fort_Peck/data/pestrun/pest/params.csv' of shape (9, 3)
# 2026-01-27 13:58:33.649684 finished: loading list-style /home/dgketchum/code/swim-rs/examples/2_Fort_Peck/data/pestrun/pest/params.csv took: 0:00:00.002221
# 2026-01-27 13:58:33.649777 starting: writing list-style template file '/home/dgketchum/code/swim-rs/examples/2_Fort_Peck/data/pestrun/pest/p_kr_alpha_US-FPe_0_constant.csv.tpl'
# 2026-01-27 13:58:33.657571 finished: writing list-style template file '/home/dgketchum/code/swim-rs/examples/2_Fort_Peck/data/pestrun/pest/p_kr_alpha_US-FPe_0_constant.csv.tpl' took: 0:00:00.007794
# 2026-01-27 13:58:33.660356 finished: adding constant type m style parameters for file(s) ['params.csv'] took: 0:00:00.012964
# 2026-01-27 13:58:33.660460 starting: adding constant type m style parameters for file(s) ['params.csv']
# 2026-01-27 13:58:33.660530 starting: loading list-style /home/dgketchum/code/swim-rs/examples/2_Fort_Peck/data/pestrun/pest/params.csv
# 2026-01-27 13:58:33.660580 starting: reading list-style file: /home/dgketchum/code/swim-rs/examples/2_Fort_Peck/data/pestrun/pest/params.csv
# 2026-01-27 13:58:33.661424 finished: reading list-style file: /home/dgketchum/code/swim-rs/examples/2_Fort_Peck/data/pestrun/pest/params.csv took: 0:00:00.000844
# 2026-01-27 13:58:33.661503 loaded list-style '/home/dgketchum/code/swim-rs/examples/2_Fort_Peck/data/pestrun/pest/params.csv' of shape (9, 3)
# 2026-01-27 13:58:33.662720 finished: loading list-style /home/dgketchum/code/swim-rs/examples/2_Fort_Peck/data/pestrun/pest/params.csv took: 0:00:00.002190
# 2026-01-27 13:58:33.662804 starting: writing list-style template file '/home/dgketchum/code/swim-rs/examples/2_Fort_Peck/data/pestrun/pest/p_ndvi_k_US-FPe_0_constant.csv.tpl'
# 2026-01-27 13:58:33.670986 finished: writing list-style template file '/home/dgketchum/code/swim-rs/examples/2_Fort_Peck/data/pestrun/pest/p_ndvi_k_US-FPe_0_constant.csv.tpl' took: 0:00:00.008182
# 2026-01-27 13:58:33.674022 finished: adding constant type m style parameters for file(s) ['params.csv'] took: 0:00:00.013562
# 2026-01-27 13:58:33.674216 starting: adding constant type m style parameters for file(s) ['params.csv']
# 2026-01-27 13:58:33.674298 starting: loading list-style /home/dgketchum/code/swim-rs/examples/2_Fort_Peck/data/pestrun/pest/params.csv
# 2026-01-27 13:58:33.674405 starting: reading list-style file: /home/dgketchum/code/swim-rs/examples/2_Fort_Peck/data/pestrun/pest/params.csv
# 2026-01-27 13:58:33.675709 finished: reading list-style file: /home/dgketchum/code/swim-rs/examples/2_Fort_Peck/data/pestrun/pest/params.csv took: 0:00:00.001304
# 2026-01-27 13:58:33.676040 loaded list-style '/home/dgketchum/code/swim-rs/examples/2_Fort_Peck/data/pestrun/pest/params.csv' of shape (9, 3)
# 2026-01-27 13:58:33.677248 finished: loading list-style /home/dgketchum/code/swim-rs/examples/2_Fort_Peck/data/pestrun/pest/params.csv took: 0:00:00.002950
# 2026-01-27 13:58:33.677333 starting: writing list-style template file '/home/dgketchum/code/swim-rs/examples/2_Fort_Peck/data/pestrun/pest/p_ndvi_0_US-FPe_0_constant.csv.tpl'
# 2026-01-27 13:58:33.685133 finished: writing list-style template file '/home/dgketchum/code/swim-rs/examples/2_Fort_Peck/data/pestrun/pest/p_ndvi_0_US-FPe_0_constant.csv.tpl' took: 0:00:00.007800
# 2026-01-27 13:58:33.688074 finished: adding constant type m style parameters for file(s) ['params.csv'] took: 0:00:00.013858
# 2026-01-27 13:58:33.688181 starting: adding constant type m style parameters for file(s) ['params.csv']
# 2026-01-27 13:58:33.688253 starting: loading list-style /home/dgketchum/code/swim-rs/examples/2_Fort_Peck/data/pestrun/pest/params.csv
# 2026-01-27 13:58:33.688304 starting: reading list-style file: /home/dgketchum/code/swim-rs/examples/2_Fort_Peck/data/pestrun/pest/params.csv
# 2026-01-27 13:58:33.689179 finished: reading list-style file: /home/dgketchum/code/swim-rs/examples/2_Fort_Peck/data/pestrun/pest/params.csv took: 0:00:00.000875
# 2026-01-27 13:58:33.689278 loaded list-style '/home/dgketchum/code/swim-rs/examples/2_Fort_Peck/data/pestrun/pest/params.csv' of shape (9, 3)
# 2026-01-27 13:58:33.690463 finished: loading list-style /home/dgketchum/code/swim-rs/examples/2_Fort_Peck/data/pestrun/pest/params.csv took: 0:00:00.002210
# 2026-01-27 13:58:33.690560 starting: writing list-style template file '/home/dgketchum/code/swim-rs/examples/2_Fort_Peck/data/pestrun/pest/p_mad_US-FPe_0_constant.csv.tpl'
# 2026-01-27 13:58:33.698059 finished: writing list-style template file '/home/dgketchum/code/swim-rs/examples/2_Fort_Peck/data/pestrun/pest/p_mad_US-FPe_0_constant.csv.tpl' took: 0:00:00.007499
# 2026-01-27 13:58:33.700813 finished: adding constant type m style parameters for file(s) ['params.csv'] took: 0:00:00.012632
# 2026-01-27 13:58:33.700914 starting: adding constant type m style parameters for file(s) ['params.csv']
# 2026-01-27 13:58:33.700982 starting: loading list-style /home/dgketchum/code/swim-rs/examples/2_Fort_Peck/data/pestrun/pest/params.csv
# 2026-01-27 13:58:33.701030 starting: reading list-style file: /home/dgketchum/code/swim-rs/examples/2_Fort_Peck/data/pestrun/pest/params.csv
# 2026-01-27 13:58:33.701849 finished: reading list-style file: /home/dgketchum/code/swim-rs/examples/2_Fort_Peck/data/pestrun/pest/params.csv took: 0:00:00.000819
# 2026-01-27 13:58:33.701926 loaded list-style '/home/dgketchum/code/swim-rs/examples/2_Fort_Peck/data/pestrun/pest/params.csv' of shape (9, 3)
# 2026-01-27 13:58:33.703022 finished: loading list-style /home/dgketchum/code/swim-rs/examples/2_Fort_Peck/data/pestrun/pest/params.csv took: 0:00:00.002040
# 2026-01-27 13:58:33.703102 starting: writing list-style template file '/home/dgketchum/code/swim-rs/examples/2_Fort_Peck/data/pestrun/pest/p_swe_alpha_US-FPe_0_constant.csv.tpl'
# 2026-01-27 13:58:33.710616 finished: writing list-style template file '/home/dgketchum/code/swim-rs/examples/2_Fort_Peck/data/pestrun/pest/p_swe_alpha_US-FPe_0_constant.csv.tpl' took: 0:00:00.007514
# 2026-01-27 13:58:33.713466 finished: adding constant type m style parameters for file(s) ['params.csv'] took: 0:00:00.012552
# 2026-01-27 13:58:33.713573 starting: adding constant type m style parameters for file(s) ['params.csv']
# 2026-01-27 13:58:33.713647 starting: loading list-style /home/dgketchum/code/swim-rs/examples/2_Fort_Peck/data/pestrun/pest/params.csv
# 2026-01-27 13:58:33.713706 starting: reading list-style file: /home/dgketchum/code/swim-rs/examples/2_Fort_Peck/data/pestrun/pest/params.csv
# 2026-01-27 13:58:33.714589 finished: reading list-style file: /home/dgketchum/code/swim-rs/examples/2_Fort_Peck/data/pestrun/pest/params.csv took: 0:00:00.000883
# 2026-01-27 13:58:33.714672 loaded list-style '/home/dgketchum/code/swim-rs/examples/2_Fort_Peck/data/pestrun/pest/params.csv' of shape (9, 3)
# 2026-01-27 13:58:33.715826 finished: loading list-style /home/dgketchum/code/swim-rs/examples/2_Fort_Peck/data/pestrun/pest/params.csv took: 0:00:00.002179
# 2026-01-27 13:58:33.715908 starting: writing list-style template file '/home/dgketchum/code/swim-rs/examples/2_Fort_Peck/data/pestrun/pest/p_swe_beta_US-FPe_0_constant.csv.tpl'
# 2026-01-27 13:58:33.723410 finished: writing list-style template file '/home/dgketchum/code/swim-rs/examples/2_Fort_Peck/data/pestrun/pest/p_swe_beta_US-FPe_0_constant.csv.tpl' took: 0:00:00.007502
# 2026-01-27 13:58:33.726730 finished: adding constant type m style parameters for file(s) ['params.csv'] took: 0:00:00.013157
# 2026-01-27 13:58:33.813480 starting: adding observations from output file obs/obs_etf_US-FPe.np
# 2026-01-27 13:58:33.814072 starting: adding observations from array output file 'obs/obs_etf_US-FPe.np'
# 2026-01-27 13:58:33.846550 starting: adding observation from instruction file '/home/dgketchum/code/swim-rs/examples/2_Fort_Peck/data/pestrun/pest/etf_US-FPe.ins'
# 2026-01-27 13:58:33.958164 finished: adding observation from instruction file '/home/dgketchum/code/swim-rs/examples/2_Fort_Peck/data/pestrun/pest/etf_US-FPe.ins' took: 0:00:00.111614
# 2026-01-27 13:58:33.959193 finished: adding observations from array output file 'obs/obs_etf_US-FPe.np' took: 0:00:00.145121
# 2026-01-27 13:58:33.959849 finished: adding observations from output file obs/obs_etf_US-FPe.np took: 0:00:00.146369
# 2026-01-27 13:58:34.625458 starting: adding observations from output file obs/obs_swe_US-FPe.np
# 2026-01-27 13:58:34.625614 starting: adding observations from array output file 'obs/obs_swe_US-FPe.np'
# 2026-01-27 13:58:34.648486 starting: adding observation from instruction file '/home/dgketchum/code/swim-rs/examples/2_Fort_Peck/data/pestrun/pest/swe_US-FPe.ins'
# 2026-01-27 13:58:34.760452 finished: adding observation from instruction file '/home/dgketchum/code/swim-rs/examples/2_Fort_Peck/data/pestrun/pest/swe_US-FPe.ins' took: 0:00:00.111966
# 2026-01-27 13:58:34.761638 finished: adding observations from array output file 'obs/obs_swe_US-FPe.np' took: 0:00:00.136024
# 2026-01-27 13:58:34.761911 finished: adding observations from output file obs/obs_swe_US-FPe.np took: 0:00:00.136453
# noptmax:0, npar_adj:8, nnz_obs:2868
# Building portable swim_input.h5 with spinup state...
# Created swim_input.h5 at /home/dgketchum/code/swim-rs/examples/2_Fort_Peck/data/pestrun/pest/swim_input.h5
# noptmax:0, npar_adj:8, nnz_obs:2868
# Configured PEST++ for 1 targets,

# %%
# Show the files created in the pest directory
pest_files = [f for f in sorted(os.listdir(builder.pest_dir)) 
              if os.path.isfile(os.path.join(builder.pest_dir, f))]
print("Files in pest directory:")
for f in pest_files:
    print(f"  {f}")
# Out:
# Files in pest directory:
#   2_Fort_Peck.idx.csv
#   2_Fort_Peck.pst
#   2_fort_peck.insfile_data.csv
#   2_fort_peck.obs_data.csv
#   2_fort_peck.par_data.csv
#   2_fort_peck.pargp_data.csv
#   2_fort_peck.tplfile_data.csv
#   custom_forward_run.py
#   etf_US-FPe.ins
#   mult2model_info.csv
#   p_aw_US-FPe_0_constant.csv.tpl
#   p_kr_alpha_US-FPe_0_constant.csv.tpl
#   p_ks_alpha_US-FPe_0_constant.csv.tpl
#   p_mad_US-FPe_0_constant.csv.tpl
#   p_ndvi_0_US-FPe_0_constant.csv.tpl
#   p_ndvi_k_US-FPe_0_constant.csv.tpl
#   p_swe_alpha_US-FPe_0_constant.csv.tpl
#   p_swe_beta_US-FPe_0_constant.csv.tpl
#   params.csv
#   swe_US-FPe.ins
#   swim_input.h5

# %% [markdown]
# ### Examine the .pst File
#
# The PEST++ version 2 control file is concise, delegating details to external files:

# %%
with open(builder.pst_file, 'r') as f:
    print(f.read())
# Out:
# pcf version=2
# * control data keyword
# pestmode                                 estimation
# noptmax                                 0
# svdmode                                 1
# maxsing                          10000000
# eigthresh                           1e-06
# eigwrite                                1
# * parameter groups external
# 2_fort_peck.pargp_data.csv
# * parameter data external
# 2_fort_peck.par_data.csv
# * observation data external
# 2_fort_peck.obs_data.csv
# * model command line
# python custom_forward_run.py
# * model input external
# 2_fort_peck.tplfile_data.csv
# * model output external
# 2_fort_peck.insfile_data.csv

# %% [markdown]
# ## 4. Configure and Test
#
# Now we:
# 1. Build the localizer matrix (links parameters to relevant observations)
# 2. Run spinup to save initial water balance state
# 3. Do a dry run to verify everything works
# 4. Set control parameters for the full calibration

# %%
# Build localizer matrix
# - SWE observations update only swe_alpha and swe_beta
# - ETf observations update all other parameters
builder.build_localizer()

# Run spinup to save water balance state as initial conditions for calibration runs
# This runs the model once and saves the final state to spinup.json
print("Running spinup...")
builder.spinup(overwrite=True)

# Run a minimal model run to verify the setup
print("\nRunning dry run...")
builder.dry_run()

# Configure for 3 optimization iterations with 20 realizations each
# Increase realizations (e.g., 100-200) for production runs
builder.write_control_settings(noptmax=3, reals=20)
# Out:
# noptmax:0, npar_adj:8, nnz_obs:2868
# Running spinup...
# RUNNING SPINUP
# Spinup saved to /home/dgketchum/code/swim-rs/examples/2_Fort_Peck/data/pestrun/spinup.json
#
# Running dry run...
# noptmax:3, npar_adj:8, nnz_obs:2868
# writing /home/dgketchum/code/swim-rs/examples/2_Fort_Peck/data/pestrun/pest/2_Fort_Peck.pst with noptmax=3, 20 realizations

# %%
# Show the updated control file with calibration settings
with open(builder.pst_file, 'r') as f:
    print(f.read())
# Out:
# pcf version=2
# * control data keyword
# pestmode                                 estimation
# noptmax                                 3
# svdmode                                 1
# maxsing                          10000000
# eigthresh                           1e-06
# eigwrite                                1
# ies_localizer                  loc.mat
# ies_num_reals                  20
# ies_drop_conflicts             true
# * parameter groups external
# 2_fort_peck.pargp_data.csv
# * parameter data external
# 2_fort_peck.par_data.csv
# * observation data external
# 2_fort_peck.obs_data.csv
# * model command line
# python custom_forward_run.py
# * model input external
# 2_fort_peck.tplfile_data.csv
# * model output external
# 2_fort_peck.insfile_data.csv

# %% [markdown]
# ## 5. Run PEST++ Calibration
#
# Now we launch PEST++ with parallel workers. Adjust `workers` to match your machine's capabilities.
#
# **Important:** This can take a while. Watch for the progress indicator showing completed runs (C), failed (F), and total (T).

# %%
workers = config.workers or 6
_pst = f"{config.project_name}.pst"

print(f"Starting PEST++ with {workers} workers...")
print(f"Control file: {_pst}")

run_pst(builder.pest_dir,
        'pestpp-ies',
        _pst,
        num_workers=workers,
        worker_root=builder.workers_dir,
        master_dir=builder.master_dir,
        cleanup=True,
        verbose=True)
# Out:
# Starting PEST++ with 20 workers...
# Control file: 2_Fort_Peck.pst
# master:pestpp-ies 2_Fort_Peck.pst /h :5005 in /home/dgketchum/code/swim-rs/examples/2_Fort_Peck/data/pestrun/master
#
#
#              pestpp-ies: a GLM iterative ensemble smoother
#
#                    by the PEST++ development team
#
# ...processing command line: ' pestpp-ies 2_Fort_Peck.pst /h :5005'
# ...using panther run manager in master mode using port 5005
#
#
# version: 5.2.25
# binary compiled on Jan 13 2026 at 20:33:04
# using control file: "2_Fort_Peck.pst"
# in directory: "/home/dgketchum/code/swim-rs/examples/2_Fort_Peck/data/pestrun/master"
# on host: "fcfc-mcozoran"
# on a(n) linux operating system
# with release configuration
# started at 01/27/26 13:58:42
#
# processing control file 2_Fort_Peck.pst
#
#
# :~-._                                                 _.-~:
# : :.~^o._        ________---------________        _.o^~.:.:
#  : ::.`?88booo~~~.::::::::...::::::::::::..~~oood88P'.::.:
#  :  ::: `?88P .:::....         ........:::::. ?88P' :::. :
#   :  :::. `? .::.            . ...........:::. P' .:::. :
#    :  :::   ... ..  ...       .. .::::......::.   :::. :
#    `  :' .... ..  .:::::.     . ..:::::::....:::.  `: .'
#     :..    ____:::::::::.  . . ....:::::::::____  ... :
#    :... `:~    ^~-:::::..  .........:::::-~^    ~::.::::
#    `.::. `\   (8)  \b:::..::.:.:::::::d/  (8)   /'.::::'
#     ::::.  ~-._v    |b.::::::::::::::d|    v_.-~..:::::
#     `.:::::... ~~^?888b..:::::::::::d888P^~...::::::::'
#      `.::::::::::....~~~ .:::::::::~~~:::::::::::::::'
#       `..:::::::::::   .   ....::::    ::::::::::::,'
#         `. .:::::::    .      .::::.    ::::::::'.'
#           `._ .:::    .        :::::.    :::::_.'
#              `-. :    .        :::::      :,-'
#                 :.   :___     .:::___   .::
#       ..--~~~~--:+::. ~~^?b..:::dP^~~.::++:--~~~~--..
#         ___....--`+:::.    `~8~'    .:::+'--....___
#       ~~   __..---`_=:: ___gd8bg___ :==_'---..__   ~~
#        -~~~  _.--~~`-.~~~~~~~~~~~~~~~,-' ~~--._ ~~~-
#
#
#                starting PANTHER master...
#
# IP addresses:
#   0.0.0.0:5005 (IPv4)
#
# PANTHER master listening on socket: 0.0.0.0:5005 (IPv4)
#
#   ---  initializing  ---
# ...using glm algorithm
# ...using REDSVD for truncated svd solve
# ...maxsing: 10000000
# ...eigthresh:  1e-06
# ...initializing localizer
# ...using localized solution with 8 sequential upgrade steps
# ...localizing by parameters
# ...using lambda multipliers: 0.1 , 1 , 10 ,
# ...using lambda scaling factors: 0.75 , 1 , 1.1 ,
# ...acceptable phi factor:  1.05
# ...lambda increase factor:  10
# ...lambda decrease factor:  0.75
# ...max run fail:  1
# ...initializing prior parameter covariance matrix
# ...parcov loaded  from parameter bounds, using par_sigma_range 4
# ...initializing observation noise covariance matrix
# worker:pestpp-ies 2_Fort_Peck.pst /h localhost:5005 in /home/dgketchum/code/swim-rs/examples/2_Fort_Peck/data/pestrun/workers/worker_0
# worker:pestpp-ies 2_Fort_Peck.pst /h localhost:5005 in /home/dgketchum/code/swim-rs/examples/2_Fort_Peck/data/pestrun/workers/worker_1
# worker:pestpp-ies 2_Fort_Peck.pst /h localhost:5005 in /home/dgketchum/code/swim-rs/examples/2_Fort_Peck/data/pestrun/workers/worker_2
# worker:pestpp-ies 2_Fort_Peck.pst /h localhost:5005 in /home/dgketchum/code/swim-rs/examples/2_Fort_Peck/data/pestrun/workers/worker_3
# worker:pestpp-ies 2_Fort_Peck.pst /h localhost:5005 in /home/dgketchum/code/swim-rs/examples/2_Fort_Peck/data/pestrun/workers/worker_4
# worker:pestpp-ies 2_Fort_Peck.pst /h localhost:5005 in /home/dgketchum/code/swim-rs/examples/2_Fort_Peck/data/pestrun/workers/worker_5
# worker:pestpp-ies 2_Fort_Peck.pst /h localhost:5005 in /home/dgketchum/code/swim-rs/examples/2_Fort_Peck/data/pestrun/workers/worker_6
# worker:pestpp-ies 2_Fort_Peck.pst /h localhost:5005 in /home/dgketchum/code/swim-rs/examples/2_Fort_Peck/data/pestrun/workers/worker_7
# worker:pestpp-ies 2_Fort_Peck.pst /h localhost:5005 in /home/dgketchum/code/swim-rs/examples/2_Fort_Peck/data/pestrun/workers/worker_8
# worker:pestpp-ies 2_Fort_Peck.pst /h localhost:5005 in /home/dgketchum/code/swim-rs/examples/2_Fort_Peck/data/pestrun/workers/worker_9
# worker:pestpp-ies 2_Fort_Peck.pst /h localhost:5005 in /home/dgketchum/code/swim-rs/examples/2_Fort_Peck/data/pestrun/workers/worker_10
# worker:pestpp-ies 2_Fort_Peck.pst /h localhost:5005 in /home/dgketchum/code/swim-rs/examples/2_Fort_Peck/data/pestrun/workers/worker_11
# ...obscov loaded  from observation weights
# worker:pestpp-ies 2_Fort_Peck.pst /h localhost:5005 in /home/dgketchum/code/swim-rs/examples/2_Fort_Peck/data/pestrun/workers/worker_12
# ...drawing parameter realizations:  20
# ...not using prior parameter covariance matrix scaling
# worker:pestpp-ies 2_Fort_Peck.pst /h localhost:5005 in /home/dgketchum/code/swim-rs/examples/2_Fort_Peck/data/pestrun/workers/worker_13
# worker:pestpp-ies 2_Fort_Peck.pst /h localhost:5005 in /home/dgketchum/code/swim-rs/examples/2_Fort_Peck/data/pestrun/workers/worker_14
# worker:pestpp-ies 2_Fort_Peck.pst /h localhost:5005 in /home/dgketchum/code/swim-rs/examples/2_Fort_Peck/data/pestrun/workers/worker_15
# ...drawing observation noise realizations:  20
# worker:pestpp-ies 2_Fort_Peck.pst /h localhost:5005 in /home/dgketchum/code/swim-rs/examples/2_Fort_Peck/data/pestrun/workers/worker_16
# observations not grouped by observations groups, reordering obs ensemble
# worker:pestpp-ies 2_Fort_Peck.pst /h localhost:5005 in /home/dgketchum/code/swim-rs/examples/2_Fort_Peck/data/pestrun/workers/worker_17
# worker:pestpp-ies 2_Fort_Peck.pst /h localhost:5005 in /home/dgketchum/code/swim-rs/examples/2_Fort_Peck/data/pestrun/workers/worker_18
# worker:pestpp-ies 2_Fort_Peck.pst /h localhost:5005 in /home/dgketchum/code/swim-rs/examples/2_Fort_Peck/data/pestrun/workers/worker_19
# ...setting weights ensemble from control file weights
# ...saved weight ensemble to  2_Fort_Peck.weights.csv
# ...adding 'base' parameter values to ensemble
# ...adding 'base' observation values to ensemble
# ...adding 'base' weight values to weight ensemble
# ...saved initial parameter ensemble to  2_Fort_Peck.0.par.csv
# ...saved obs+noise observation ensemble (obsval + noise realizations) to  2_Fort_Peck.obs+noise.csv
# ...using subset in lambda testing, percentage of realizations used in subset testing:  10
# ...subset how:  RANDOM
# ...centering on ensemble mean vector
# ...running initial ensemble of size 20
#     running model 20 times
#     starting at 01/27/26 13:58:44
#
#     waiting for agents to appear...
#
#
# PANTHER progress
#    avg = average model run time in minutes
#    runs(C = completed | F = failed | T = timed out)
#    agents(R = running | W = waiting | U = unavailable)
# --------------------------------------------------------------------------------
# 01/27 13:58:49 remaining file transfers: 0|T0    ) agents(R1   |W13  |U6   ) 0
#
#    20 runs complete :  0 runs failed
#    0.0715 avg run time (min) : 0.0837 run mgr time (min)
#    20 agents connected
#
#
# ...saved initial obs ensemble to 2_Fort_Peck.0.obs.csv
# saved par and rei files for realization BASE for iteration 0
# saved par and rei files for realization BASE
#
#   ---  pre-drop initial phi summary  ---
#        phi type           mean            std            min            max
#        measured        972.471        436.114        558.813        2499.86
#          actual         757.31        415.504         462.11        2232.73
#      note: 'measured' phi reported above includes
#            realizations of measurement noise,
#            'actual' phi does not.
#   ---  observation group phi summary ---
#        (computed using 'actual' phi)
#            (sorted by mean phi)
# group                                   count  nconflict      mean       std       min       max   percent       std
# oname:obs/obs_etf_us-fpe.np_otype:arr     939         72       635       108       461       797      93.4      19.5
# oname:obs/obs_swe_us-fpe.np_otype:arr    1929          7       123       387     0.851  1.54e+03      6.58      19.5
#
# ...checking for prior-data conflict
#
#   ---  WARNING: 79 non-zero weighted observations are in conflict with the prior simulated ensemble.
#   ---
# ...see 2_Fort_Peck.0.pdc.csv for listing of conflicted observations
#
# ...dropping conflicted observations
# ...number of non-zero weighted observations reduced from 2868 to 2789
#
# ...updating localizer
# dropped 79 from localizer rows because forgive_missing is true
# ...saved adjusted weight ensemble to  2_Fort_Peck.adjusted.weights.csv
# saved par and rei files for realization BASE for iteration 0
# saved par and rei files for realization BASE
#
#   ---  initial phi summary  ---
#        phi type           mean            std            min            max
#        measured        771.237         428.75        396.999        2276.45
#          actual        595.552        411.776        328.204        2057.61
#      note: 'measured' phi reported above includes
#            realizations of measurement noise,
#            'actual' phi does not.
#   ---  observation group phi summary ---
#        (computed using 'actual' phi)
#            (sorted by mean phi)
# group                                   count  nconflict      mean       std       min       max   percent       std
# oname:obs/obs_etf_us-fpe.np_otype:arr     867          0       473      98.1       327       618      92.8      21.2
# oname:obs/obs_swe_us-fpe.np_otype:arr    1922          0       122       386      0.85  1.53e+03      7.25      21.2
#
# ...current lambda: 0.1
#
#    ---  parameter group change summary  ---
# group     count  mean chg  std chg  n at ubnd  % at ubnd  n at lbnd  % at lbnd  n std decr
# swe_beta      1         0        0          4         20          0          0           0
# ndvi_0        1         0        0          4         20          0          0           0
# mad           1         0        0          3         15          0          0           0
# swe_alpha     1         0        0          2         10          0          0           0
# ndvi_k        1         0        0          1          5          0          0           0
# aw            1         0        0          1          5          0          0           0
# ks_alpha      1         0        0          0          0          0          0           0
# kr_alpha      1         0        0          0          0          0          0           0
#
#
#   ---  initialization complete  ---
#
#   ---  starting solve for iteration: 1  ---
# ...current lambda:  0.1
# ...preparing fast-lookup containers for threaded localization solve
# ...starting calcs for glm factor 0.01
# ...finished calcs for: 0.01
# ...starting calcs for glm factor 0.1
# ...finished calcs for: 0.1
# ...starting calcs for glm factor 1
# ...finished calcs for: 1
#
#   ---  running upgrade ensembles  ---
# ...subset idx:pe real name:  2:2, 8:8, 16:16, 19:BASE,
# ...subset idx:oe real name:  2:2, 8:8, 16:16, 19:BASE,
#     running model 36 times
#     starting at 01/27/26 13:58:51
#     20 agents ready
#
#
# PANTHER progress
#    avg = average model run time in minutes
#    runs(C = completed | F = failed | T = timed out)
#    agents(R = running | W = waiting | U = unavailable)
# --------------------------------------------------------------------------------
# 01/27 13:59:00 remaining file transfers: 0|T0    ) agents(R9   |W10  |U1   ) 0
#
#    36 runs complete :  0 runs failed
#    0.0664 avg run time (min) : 0.137 run mgr time (min)
#    20 agents connected
#
#
#
#   ---  evaluating upgrade ensembles  ---
# ...last mean:  771.237
# ...last stdev:  428.75
#
#   ---  phi summary for best lambda, scale fac: 0.01 , 1.1 ,   ---
#        phi type           mean            std            min            max
#        measured        489.926        101.999        337.349        549.307
#          actual        329.235        18.4003        309.648        350.789
#      note: 'measured' phi reported above includes
#            realizations of measurement noise,
#            'actual' phi does not.
#
#   ---  running remaining realizations for best lambda, scale:0.01 , 1.1 ,   ---
#     running model 16 times
#     starting at 01/27/26 13:59:01
#     20 agents ready
#
#
# PANTHER progress
#    avg = average model run time in minutes
#    runs(C = completed | F = failed | T = timed out)
#    agents(R = running | W = waiting | U = unavailable)
# --------------------------------------------------------------------------------
# 01/27 13:59:05 remaining file transfers: 0|T0    ) agents(R16  |W4   |U0   ) 0
#
#    16 runs complete :  0 runs failed
#    0.0616 avg run time (min) : 0.0649 run mgr time (min)
#    20 agents connected
#
#
# ...phi summary for entire ensemble using lambda,scale_fac 0.01 , 1.1 ,
#        phi type           mean            std            min            max
#        measured        507.764        47.1186        337.349        549.307
#          actual        333.057        14.6283        299.746        350.789
#      note: 'measured' phi reported above includes
#            realizations of measurement noise,
#            'actual' phi does not.
# ...last best mean phi * acceptable phi factor:  809.798
# ...current best mean phi:  507.764
#
#   ---  updating parameter ensemble  ---
#
#   ---  updating lambda to  0.0075  ---
#
#   ---  EnsembleMethod iteration 1 report  ---
#    number of active realizations:   20
#    number of model runs:            72
#       current obs ensemble saved to 2_Fort_Peck.1.obs.csv
#       current par ensemble saved to 2_Fort_Peck.1.par.csv
# saved par and rei files for realization BASE for iteration 1
# saved par and rei files for realization BASE
#        phi type           mean            std            min            max
#        measured        507.764        47.1186        337.349        549.307
#          actual        333.057        14.6283        299.746        350.789
#      note: 'measured' phi reported above includes
#            realizations of measurement noise,
#            'actual' phi does not.
#   ---  observation group phi summary ---
#        (computed using 'actual' phi)
#            (sorted by mean phi)
# group                                   count  nconflict      mean       std       min       max   percent       std
# oname:obs/obs_etf_us-fpe.np_otype:arr     867         90       331      14.2       299       349      99.5     0.163
# oname:obs/obs_swe_us-fpe.np_otype:arr    1922        696      1.63     0.583     0.855      2.67     0.484     0.163
#
#
#    ---  parameter group change summary  ---
# group     count  mean chg  std chg  n at ubnd  % at ubnd  n at lbnd  % at lbnd  n std decr
# aw            1     8.748    49.55          2         10          0          0           0
# swe_beta      1     2.704    1.032          0          0          0          0           0
# swe_alpha     1     3.606    23.94          0          0          0          0           0
# ndvi_k        1     5.051    46.08          0          0          0          0           0
# ndvi_0        1     59.37    79.07          0          0          0          0           0
# mad           1     153.2    60.06          0          0          0          0           0
# ks_alpha      1     52.31    48.03          0          0          0          0           0
# kr_alpha      1     48.27    81.71          0          0          0          0           0
#
# ...saved parameter change summary to 2_Fort_Peck.1.pcs.csv
#
#   ---  phi-based termination criteria check  ---
# ...phiredstp:  0.01
# ...nphistp:  3
# ...nphinored (also used for consecutive bad lambda cycles):  3
# ...best mean phi sequence: 771.237 , 507.764 ,
# ...best phi yet:  507.764
# ...number of consecutive bad lambda testing cycles:  0
# ...number of iterations satisfying phiredstp criteria:  1
# ...number of iterations since best yet mean phi:  0
#
#   ---  starting solve for iteration: 2  ---
# ...current lambda:  0.0075
# ...preparing fast-lookup containers for threaded localization solve
# ...starting calcs for glm factor 0.00075
# ...finished calcs for: 0.00075
# ...starting calcs for glm factor 0.0075
# ...finished calcs for: 0.0075
# ...starting calcs for glm factor 0.075
# ...finished calcs for: 0.075
#
#   ---  running upgrade ensembles  ---
# ...subset idx:pe real name:  3:BASE, 6:3, 13:11, 19:18,
# ...subset idx:oe real name:  3:BASE, 6:3, 13:11, 19:18,
#     running model 36 times
#     starting at 01/27/26 13:59:07
#     20 agents ready
#
#
# PANTHER progress
#    avg = average model run time in minutes
#    runs(C = completed | F = failed | T = timed out)
#    agents(R = running | W = waiting | U = unavailable)
# --------------------------------------------------------------------------------
# 01/27 13:59:15 remaining file transfers: 0|T0    ) agents(R2   |W18  |U0   ) 0
#
#    36 runs complete :  0 runs failed
#    0.0661 avg run time (min) : 0.136 run mgr time (min)
#    20 agents connected
#
#
#
#   ---  evaluating upgrade ensembles  ---
# ...last mean:  507.764
# ...last stdev:  47.1186
#
#   ---  phi summary for best lambda, scale fac: 0.00075 , 1.1 ,   ---
#        phi type           mean            std            min            max
#        measured        465.912        103.252        315.709        534.977
#          actual        327.469        8.06622        315.709        334.024
#      note: 'measured' phi reported above includes
#            realizations of measurement noise,
#            'actual' phi does not.
#
#   ---  running remaining realizations for best lambda, scale:0.00075 , 1.1 ,   ---
#     running model 16 times
#     starting at 01/27/26 13:59:16
#     20 agents ready
#
#
# PANTHER progress
#    avg = average model run time in minutes
#    runs(C = completed | F = failed | T = timed out)
#    agents(R = running | W = waiting | U = unavailable)
# --------------------------------------------------------------------------------
# 01/27 13:59:20 remaining file transfers: 0|T0    ) agents(R16  |W4   |U0   ) 0
#
#    16 runs complete :  0 runs failed
#    0.0632 avg run time (min) : 0.066 run mgr time (min)
#    20 agents connected
#
#
# ...phi summary for entire ensemble using lambda,scale_fac 0.00075 , 1.1 ,
#        phi type           mean            std            min            max
#        measured        498.314        51.6505        315.709        557.747
#          actual        323.459        17.6359        298.679        368.055
#      note: 'measured' phi reported above includes
#            realizations of measurement noise,
#            'actual' phi does not.
# ...last best mean phi * acceptable phi factor:  533.152
# ...current best mean phi:  498.314
#
#   ---  updating parameter ensemble  ---
#
#   ---  not updating lambda (standard deviation reduction criteria not met)  ---
#
#   ---  EnsembleMethod iteration 2 report  ---
#    number of active realizations:   20
#    number of model runs:            124
#       current obs ensemble saved to 2_Fort_Peck.2.obs.csv
#       current par ensemble saved to 2_Fort_Peck.2.par.csv
# saved par and rei files for realization BASE for iteration 2
# saved par and rei files for realization BASE
#        phi type           mean            std            min            max
#        measured        498.314        51.6505        315.709        557.747
#          actual        323.459        17.6359        298.679        368.055
#      note: 'measured' phi reported above includes
#            realizations of measurement noise,
#            'actual' phi does not.
#   ---  observation group phi summary ---
#        (computed using 'actual' phi)
#            (sorted by mean phi)
# group                                   count  nconflict      mean       std       min       max   percent       std
# oname:obs/obs_etf_us-fpe.np_otype:arr     867         86       322      17.4       298       367      99.6     0.161
# oname:obs/obs_swe_us-fpe.np_otype:arr    1922        686      1.43     0.563     0.838      2.63     0.438     0.161
#
#
#    ---  parameter group change summary  ---
# group     count  mean chg  std chg  n at ubnd  % at ubnd  n at lbnd  % at lbnd  n std decr
# aw            1     13.09    74.84          8         40          0          0           0
# swe_beta      1     13.11    2.582          0          0          0          0           0
# swe_alpha     1     22.97    31.95          0          0          0          0           0
# ndvi_k        1     12.11    67.57          0          0          0          0           0
# ndvi_0        1     63.36    86.56          0          0          0          0           0
# mad           1     188.9    65.44          0          0          0          0           0
# ks_alpha      1     16.96    62.69          0          0          0          0           0
# kr_alpha      1     68.42    86.33          0          0          0          0           0
#
# ...saved parameter change summary to 2_Fort_Peck.2.pcs.csv
#
#   ---  phi-based termination criteria check  ---
# ...phiredstp:  0.01
# ...nphistp:  3
# ...nphinored (also used for consecutive bad lambda cycles):  3
# ...best mean phi sequence: 771.237 , 507.764 , 498.314 ,
# ...best phi yet:  498.314
# ...number of consecutive bad lambda testing cycles:  0
# ...number of iterations satisfying phiredstp criteria:  1
# ...number of iterations since best yet mean phi:  0
#
#   ---  starting solve for iteration: 3  ---
# ...current lambda:  0.0075
# ...preparing fast-lookup containers for threaded localization solve
# ...starting calcs for glm factor 0.00075
# ...finished calcs for: 0.00075
# ...starting calcs for glm factor 0.0075
# ...finished calcs for: 0.0075
# ...starting calcs for glm factor 0.075
# ...finished calcs for: 0.075
#
#   ---  running upgrade ensembles  ---
# ...subset idx:pe real name:  0:BASE, 4:2, 12:7, 16:13,
# ...subset idx:oe real name:  0:BASE, 4:2, 12:7, 16:13,
#     running model 36 times
#     starting at 01/27/26 13:59:22
#     20 agents ready
#
#
# PANTHER progress
#    avg = average model run time in minutes
#    runs(C = completed | F = failed | T = timed out)
#    agents(R = running | W = waiting | U = unavailable)
# --------------------------------------------------------------------------------
# 01/27 13:59:30 remaining file transfers: 0|T0    ) agents(R2   |W17  |U1   ) 0
#
#    36 runs complete :  0 runs failed
#    0.0673 avg run time (min) : 0.14 run mgr time (min)
#    20 agents connected
#
#
#
#   ---  evaluating upgrade ensembles  ---
# ...last mean:  498.314
# ...last stdev:  51.6505
#
#   ---  phi summary for best lambda, scale fac: 0.00075 , 1.1 ,   ---
#        phi type           mean            std            min            max
#        measured        464.802        109.637        300.405        523.755
#          actual         309.68        13.2489        300.405        329.342
#      note: 'measured' phi reported above includes
#            realizations of measurement noise,
#            'actual' phi does not.
#
#   ---  running remaining realizations for best lambda, scale:0.00075 , 1.1 ,   ---
#     running model 16 times
#     starting at 01/27/26 13:59:32
#     20 agents ready
#
#
# PANTHER progress
#    avg = average model run time in minutes
#    runs(C = completed | F = failed | T = timed out)
#    agents(R = running | W = waiting | U = unavailable)
# --------------------------------------------------------------------------------
# 01/27 13:59:36 remaining file transfers: 0|T0    ) agents(R16  |W4   |U0   ) 0
#
#    16 runs complete :  0 runs failed
#    0.0638 avg run time (min) : 0.0662 run mgr time (min)
#    20 agents connected
#
#
# ...phi summary for entire ensemble using lambda,scale_fac 0.00075 , 1.1 ,
#        phi type           mean            std            min            max
#        measured        495.234        56.1963        300.405        573.688
#          actual        320.141        20.0306        295.727        379.554
#      note: 'measured' phi reported above includes
#            realizations of measurement noise,
#            'actual' phi does not.
# ...last best mean phi * acceptable phi factor:  523.229
# ...current best mean phi:  495.234
#
#   ---  updating parameter ensemble  ---
#
#   ---  not updating lambda (standard deviation reduction criteria not met)  ---
#
#   ---  EnsembleMethod iteration 3 report  ---
#    number of active realizations:   20
#    number of model runs:            176
#       current obs ensemble saved to 2_Fort_Peck.3.obs.csv
#       current par ensemble saved to 2_Fort_Peck.3.par.csv
# saved par and rei files for realization BASE for iteration 3
# saved par and rei files for realization BASE
#        phi type           mean            std            min            max
#        measured        495.234        56.1963        300.405        573.688
#          actual        320.141        20.0306        295.727        379.554
#      note: 'measured' phi reported above includes
#            realizations of measurement noise,
#            'actual' phi does not.
#   ---  observation group phi summary ---
#        (computed using 'actual' phi)
#            (sorted by mean phi)
# group                                   count  nconflict      mean       std       min       max   percent       std
# oname:obs/obs_etf_us-fpe.np_otype:arr     867         86       319      19.9       295       379      99.6     0.152
# oname:obs/obs_swe_us-fpe.np_otype:arr    1922        675      1.29     0.521      0.84      2.58       0.4     0.152
#
#
#    ---  parameter group change summary  ---
# group     count  mean chg  std chg  n at ubnd  % at ubnd  n at lbnd  % at lbnd  n std decr
# aw            1     13.75    79.41         11         55          0          0           0
# swe_beta      1     23.17    5.194          0          0          0          0           0
# swe_alpha     1     43.91    40.38          0          0          0          0           0
# ndvi_k        1     15.62     71.5          0          0          0          0           0
# ndvi_0        1     66.92    87.74          0          0          0          0           0
# mad           1     198.5    66.67          0          0          0          0           0
# ks_alpha      1     3.121    67.84          0          0          0          0           0
# kr_alpha      1     76.32    87.68          0          0          0          0           0
#
# ...saved parameter change summary to 2_Fort_Peck.3.pcs.csv
#
#   ---  phi-based termination criteria check  ---
# ...phiredstp:  0.01
# ...nphistp:  3
# ...nphinored (also used for consecutive bad lambda cycles):  3
# ...best mean phi sequence: 771.237 , 507.764 , 498.314 , 495.234 ,
# ...best phi yet:  495.234
# ...number of consecutive bad lambda testing cycles:  0
# ...number of iterations satisfying phiredstp criteria:  2
# ...number of iterations since best yet mean phi:  0
# ...solution iterations >= noptmax, all done
#
#
# pestpp-ies analysis complete...
# started at 01/27/26 13:58:42
# finished at 01/27/26 13:59:38
# took 0.933333 minutes

# %% [markdown]
# ## Debugging Tips
#
# If calibration fails, try these steps:
#
# ### Never saw the PEST++ panther logo?
# - Ensure `pestpp-ies` is in your PATH
# - Try running with full path: `/path/to/pestpp-ies`
# - On Windows, use `.exe` extension
#
# ### Python error traceback?
# Debug from the bottom up:
# 1. Verify `swimrs/calibrate/run_mp.py` runs standalone
# 2. Test `custom_forward_run.py` from the pest directory
# 3. Try running `pestpp-ies` directly from pest directory
#
# ### Saw panther but got errors?
# Common error: `output file 'pred/pred_swe_US-FPe.np' not found`
# - This usually means SWIM failed before writing predictions
# - Set `cleanup=False` above to preserve worker directories
# - Check `workers/worker_0/panther_worker.rec` for errors
#
# **Most errors (90%) are due to incorrect paths!**

# %% [markdown]
# ## 6. Check Results
#
# After successful calibration, parameter files are saved for each optimization iteration:

# %%
# Parameter files are in master_dir after calibration
import os
import shutil

results_dir = builder.master_dir if os.path.exists(builder.master_dir) else builder.pest_dir

par_files = [f for f in sorted(os.listdir(results_dir)) if '.par.csv' in f]
print(f"Parameter files (in {results_dir}):")
for f in par_files:
    print(f"  {f}")

if par_files:
    final_par = par_files[-1]
    print(f"\nFinal calibrated parameters: {final_par}")
    
    # Copy final parameters to pest/archive/ for consistency with calibration.py script
    archive_dir = os.path.join(builder.pest_dir, 'archive')
    os.makedirs(archive_dir, exist_ok=True)
    src = os.path.join(results_dir, final_par)
    dst = os.path.join(archive_dir, final_par)
    shutil.copy2(src, dst)
    print(f"Archived to: {dst}")

# Close the container
container.close()
print("\nContainer closed.")
# Out:
# Parameter files (in /home/dgketchum/code/swim-rs/examples/2_Fort_Peck/data/pestrun/master):
#   2_Fort_Peck.0.par.csv
#   2_Fort_Peck.1.par.csv
#   2_Fort_Peck.2.par.csv
#   2_Fort_Peck.3.par.csv
#
# Final calibrated parameters: 2_Fort_Peck.3.par.csv
# Archived to: /home/dgketchum/code/swim-rs/examples/2_Fort_Peck/data/pestrun/pest/archive/2_Fort_Peck.3.par.csv
#
# Container closed.

# %% [markdown]
# ## Summary
#
# You've set up and run a PEST++ calibration using:
# - PT-JPL ETf observations from Landsat (via OpenET)
# - SNODAS SWE observations
# - Iterative Ensemble Smoother (pestpp-ies)
#
# The parameter files (e.g., `2_Fort_Peck.3.par.csv`) contain the calibrated parameter sets. Each row represents a different realization from the ensemble.
#
# **Next step:** In notebook `03_calibrated_model.ipynb`, we'll run the model in forecast mode with calibrated parameters and validate against flux tower observations.
