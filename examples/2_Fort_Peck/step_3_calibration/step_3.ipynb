# %% [raw]
# # Calibration Tutorial - Fork Peck, MT - Unirrigated Flux Plot
#
# ## Step 3: Calibrate
#
# Now we see if we are able to improve the model's performance through calibration.
#
# The main calibration tool used in SWIM (PEST++) has been developed over many years by many clever and diligent developers. They've done us a huge favor by writing great documentation that covers the highly varied functionality of PEST++. It's worth it to check out the materials, which will serve those looking for a cursory look, all the way to those that want a deep dive. Several stand-out resources to refer to are the following:
#
# 1. The PEST Manual 4th. Ed., Doherty, J., 2002.: https://www.epa.gov/sites/default/files/documents/PESTMAN.PDF. This treats the use of PESTS++ predecessor PEST, but does a great job explaining how we might estimate parameters given observations and a model.
# 2. The GMDSI tutorial notebooks. These are applications of PEST++ using the groundwater modeling software MODFLOW and the modern Python inteface to PEST++, pyemu: https://github.com/gmdsi/GMDSI_notebooks
# 3. The PEST++ User's Manual (https://github.com/usgs/pestpp/blob/master/documentation/pestpp_users_manual.md).
# 4. Calibration and Uncertainty Analysis for Complex Environmental Models. Doherty, J., 2015. See https://pesthomepage.org/pest-book.
#
# Note: We are not using the flux data for calibration, it's only for validation. We'd probably get a pretty good SWIM model using the flux data to tune the model, but we're interested in the broad applicability of the method, and thus only use the widely-available SSEBop and SNODAS data.

# %% [markdown]
# ### 1. PEST++ Installation
#
# The PEST++ developers do a great job describing the installation process, so we won't cover it here.
#
# Get the latest release of PEST++ for your operating system: https://github.com/usgs/pestpp/releases
#
# Follow the installation instructions: https://github.com/usgs/pestpp/blob/master/documentation/cmake.md

# %% [markdown]
# ### 2. Setup the calibration files
#
# In order to use PEST++, we need to run through what is, perhaps, a common loop in model calibration:
#
# 1. Intialize the model with intial conditions.
# 2. Run the model, write the results.
# 3. Compare the results to observations.
# 4. Propose a new, hopefully better, set of parameters.
# 5. Run the model with the new parameters, write the results.
# 6. Repeat 3 - 5.
#
# And so on, until we are satisfied with the performance of the model.
#
# The purpose of the SWIM calibration approach and this tutorial is to set up a system where the model and the calibration software can operate with minimal interaction. All we need SWIM to do is take the proposed parameters and use them in a model run, and write the results in a convenient format in a convenient place. All we need the calibration software to do is to compare the model results to observations, determine how to tweak the parameters we've told it are 'tunable', and write a new parameter proposal in a convenient format in a convenient place. If we succeed in building such a system, and have maintained independence between the calibration software and the model, we should be able to make changes to one and not need to make changes to the other. In theory, this objective makes development easier.
#
# The `calibration` package in SWIM contains software to build what we need to do this with three modules:
#
# 1. `build_pp_files.py` uses several functions to build the files that control PEST++ behavior:
#    - The function `build_pest` builds the main `.pst` control file, which defines the eight tunable SWIM model parameters `'aw', 'rew', 'tew', 'ndvi_alpha', 'ndvi_beta', 'mad', 'swe_alpha'`, and `'swe_beta'`. These are three soil water holding capacity parameters (`'aw', 'rew', 'tew'`), the coefficients that control the relationship between remote-sensing-based NDVI and the model transpiration rate parameter `Kcb` (`'ndvi_alpha', 'ndvi_beta'`), the control on when soil water deficit begins to impact transpiration rate (`'mad'`), and the two coefficients that determine the melting rate of snow (`'swe_alpha'`, `'swe_beta'`). The `.pst` file also contains the observation data, which we have derived from SNODAS (SWE) and SSEBop (ETf). Further, the file contains estimates of the noise we believe is in the data. Finally, the `.pst` points to the main Python file that will be used to call the `pestpp-ies` command, the function that runs the PEST++ implementation of Iterative Ensemble Smoother, the algorithm we'll use.
# 2. `custom_forward_run.py` has a single, simple function (`run`) that uses a system call to execute a SWIM script that runs the model, much like how we've run it ouselves previously. You will need to modify `custom_forward_run.py` to enter your machine's path.
# 3. `run_pest.py` is the module that we launch, and that starts PEST++ running. This will also need to be modified to use your machine's path.
#
# The actual flow of code execution during calibration is a little confusing, because we use a Python script (`run_pest.py`) to run a command line executable (`'pestpp-ies'`), which itself then executes `custom_forward_run.py` to finally run our Python SWIM code! I know!

# %%
import os
import sys

root = os.path.abspath('../../..')
sys.path.append(root)

from swimrs.prep.prep_plots import preproc

from swimrs.calibrate.pest_builder import PestBuilder
from swimrs.swim.config import ProjectConfig

from swimrs.calibrate.run_pest import run_pst

# %% [markdown]
# Let's instantiate our `ProjectConfig` object:

# %%
project = '2_Fort_Peck'
project_ws = os.path.join(root, 'examples', project)
if not os.path.isdir(project_ws):
    root_ = os.path.abspath('')
    project_ws_ = os.path.join(root, 'examples', project)

config_path = os.path.join(project_ws, 'config.toml')

config = ProjectConfig()
config.read_config(config_path, project_ws)
# Out:
# Config: /home/dgketchum/PycharmProjects/swim-rs/tutorials/2_Fort_Peck/config.toml
# CALIBRATION OFF
# FORECAST OFF

# %%
# write the observed data to files within project workspace (tutorial directory)
preproc(config_path, project_ws)
# Out:
# Writing observations to file...
#
#
# Config: /home/dgketchum/PycharmProjects/swim-rs/tutorials/2_Fort_Peck/config.toml
# CALIBRATION OFF
# FORECAST OFF
#
# US-FPe
# preproc ETf mean: 0.14
# preproc SWE mean: 0.01
#
# Prepped 1 fields input

# %% [markdown]
# ### The PestBuilder object
#
# We use the PestBuilder class to do (almost) everything we need to set up for calibration. PestBuilder needs access to our `input_data` and `config` objects, plus we've got a custom python script we need to point it to:

# %%
py_script = os.path.join(project_ws, 'custom_forward_run.py')

builder = PestBuilder(config, use_existing=False, python_script=py_script)
# Out:
# Config: /home/dgketchum/PycharmProjects/swim-rs/tutorials/2_Fort_Peck/config.toml
# CALIBRATION OFF
# FORECAST OFF

# %% [markdown]
# The `PestBuilder` calss initializes by reading in the configuration object with `ProjectConfig`, and the sample plot data with the `SamplePlots` object.
#
# Next, we build the `.pst` file. The method `build_pest` will erase the existing pest directory if there is one! It will also copy everything from `project_ws` into the `pest` directory, which is nice because it will only manipulate copies after that. The function builds the `4_Flux_Network.pst` file, which is the only argument needed at this time to run PEST++ on the problem.
#
# Note that during the processing of the ETf data, we wrote an e.g., `etf_inv_irr_ct.csv` table that simply marked the image capture dates. In build_pest(), the observations are given weight 1.0 on these dates, and weight 0.0 on non-capture dates, sp we don't use interpolated ETf values for calibration. The idea here is to only evaluate the objective function on capture dates to give the model the freedom to behave like a soil water balance model on in-between dates.
#
# The `custom_forward_run.py` script is used by PEST++ to launch our model. This script is important to get right; it will ensure the model is writing the output to the correct location, so PEST++ can find it and use it to improve the parameter set.
#
# Good. Now, let's build the `.pst` control file for our calibration project.

# %%
# Build the pest control file
# It will copy everything from the project_ws into a new 'pest' directory
builder.build_pest(target_etf=config.etf_target_model, members=config.etf_ensemble_members)
# Out:
# 2025-01-27 17:04:32.397568 starting: opening PstFrom.log for logging
# 2025-01-27 17:04:32.397668 starting PstFrom process
# 2025-01-27 17:04:32.397711 starting: setting up dirs
# 2025-01-27 17:04:32.398200 starting: copying original_d '/home/dgketchum/PycharmProjects/swim-rs/tutorials/2_Fort_Peck' to new_d '/home/dgketchum/PycharmProjects/swim-rs/tutorials/2_Fort_Peck/pest'
# 2025-01-27 17:04:32.680439 finished: copying original_d '/home/dgketchum/PycharmProjects/swim-rs/tutorials/2_Fort_Peck' to new_d '/home/dgketchum/PycharmProjects/swim-rs/tutorials/2_Fort_Peck/pest' took: 0:00:00.282239
# 2025-01-27 17:04:32.680860 finished: setting up dirs took: 0:00:00.283149
# 2025-01-27 17:04:32.680966 starting: adding constant type m style parameters for file(s) ['params.csv']
# 2025-01-27 17:04:32.681045 starting: loading list-style /home/dgketchum/PycharmProjects/swim-rs/tutorials/2_Fort_Peck/pest/params.csv
# 2025-01-27 17:04:32.681091 starting: reading list-style file: /home/dgketchum/PycharmProjects/swim-rs/tutorials/2_Fort_Peck/pest/params.csv
# 2025-01-27 17:04:32.682421 finished: reading list-style file: /home/dgketchum/PycharmProjects/swim-rs/tutorials/2_Fort_Peck/pest/params.csv took: 0:00:00.001330
# 2025-01-27 17:04:32.682516 loaded list-style '/home/dgketchum/PycharmProjects/swim-rs/tutorials/2_Fort_Peck/pest/params.csv' of shape (9, 3)
# 2025-01-27 17:04:32.684081 finished: loading list-style /home/dgketchum/PycharmProjects/swim-rs/tutorials/2_Fort_Peck/pest/params.csv took: 0:00:00.003036
# 2025-01-27 17:04:32.684164 starting: writing list-style template file '/home/dgketchum/PycharmProjects/swim-rs/tutorials/2_Fort_Peck/pest/p_aw_US-FPe_0_constant.csv.tpl'
# 2025-01-27 17:04:32.693547 finished: writing list-style template file '/home/dgketchum/PycharmProjects/swim-rs/tutorials/2_Fort_Peck/pest/p_aw_US-FPe_0_constant.csv.tpl' took: 0:00:00.009383
# 2025-01-27 17:04:32.697403 finished: adding constant type m style parameters for file(s) ['params.csv'] took: 0:00:00.016437
# 2025-01-27 17:04:32.697534 starting: adding constant type m style parameters for file(s) ['params.csv']
# 2025-01-27 17:04:32.697626 starting: loading list-style /home/dgketchum/PycharmProjects/swim-rs/tutorials/2_Fort_Peck/pest/params.csv
# 2025-01-27 17:04:32.697694 starting: reading list-style file: /home/dgketchum/PycharmProjects/swim-rs/tutorials/2_Fort_Peck/pest/params.csv
# 2025-01-27 17:04:32.699065 finished: reading list-style file: /home/dgketchum/PycharmProjects/swim-rs/tutorials/2_Fort_Peck/pest/params.csv took: 0:00:00.001371
# 2025-01-27 17:04:32.699161 loaded list-style '/home/dgketchum/PycharmProjects/swim-rs/tutorials/2_Fort_Peck/pest/params.csv' of shape (9, 3)
# 2025-01-27 17:04:32.700732 finished: loading list-style /home/dgketchum/PycharmProjects/swim-rs/tutorials/2_Fort_Peck/pest/params.csv took: 0:00:00.003106
# 2025-01-27 17:04:32.700834 starting: writing list-style template file '/home/dgketchum/PycharmProjects/swim-rs/tutorials/2_Fort_Peck/pest/p_rew_US-FPe_0_constant.csv.tpl'
# 2025-01-27 17:04:32.709327 finished: writing list-style template file '/home/dgketchum/PycharmProjects/swim-rs/tutorials/2_Fort_Peck/pest/p_rew_US-FPe_0_constant.csv.tpl' took: 0:00:00.008493
# 2025-01-27 17:04:32.712925 finished: adding constant type m style parameters for file(s) ['params.csv'] took: 0:00:00.015391
# 2025-01-27 17:04:32.713033 starting: adding constant type m style parameters for file(s) ['params.csv']
# 2025-01-27 17:04:32.713116 starting: loading list-style /home/dgketchum/PycharmProjects/swim-rs/tutorials/2_Fort_Peck/pest/params.csv
# 2025-01-27 17:04:32.713165 starting: reading list-style file: /home/dgketchum/PycharmProjects/swim-rs/tutorials/2_Fort_Peck/pest/params.csv
# 2025-01-27 17:04:32.714448 finished: reading list-style file: /home/dgketchum/PycharmProjects/swim-rs/tutorials/2_Fort_Peck/pest/params.csv took: 0:00:00.001283
# 2025-01-27 17:04:32.714537 loaded list-style '/home/dgketchum/PycharmProjects/swim-rs/tutorials/2_Fort_Peck/pest/params.csv' of shape (9, 3)
# 2025-01-27 17:04:32.716226 finished: loading list-style /home/dgketchum/PycharmProjects/swim-rs/tutorials/2_Fort_Peck/pest/params.csv took: 0:00:00.003110
# 2025-01-27 17:04:32.716346 starting: writing list-style template file '/home/dgketchum/PycharmProjects/swim-rs/tutorials/2_Fort_Peck/pest/p_tew_US-FPe_0_constant.csv.tpl'
# 2025-01-27 17:04:32.724602 finished: writing list-style template file '/home/dgketchum/PycharmProjects/swim-rs/tutorials/2_Fort_Peck/pest/p_tew_US-FPe_0_constant.csv.tpl' took: 0:00:00.008256
# 2025-01-27 17:04:32.728034 finished: adding constant type m style parameters for file(s) ['params.csv'] took: 0:00:00.015001
# 2025-01-27 17:04:32.728135 starting: adding constant type m style parameters for file(s) ['params.csv']
# 2025-01-27 17:04:32.728239 starting: loading list-style /home/dgketchum/PycharmProjects/swim-rs/tutorials/2_Fort_Peck/pest/params.csv
# 2025-01-27 17:04:32.728290 starting: reading list-style file: /home/dgketchum/PycharmProjects/swim-rs/tutorials/2_Fort_Peck/pest/params.csv
# 2025-01-27 17:04:32.729341 finished: reading list-style file: /home/dgketchum/PycharmProjects/swim-rs/tutorials/2_Fort_Peck/pest/params.csv took: 0:00:00.001051
# 2025-01-27 17:04:32.729407 loaded list-style '/home/dgketchum/PycharmProjects/swim-rs/tutorials/2_Fort_Peck/pest/params.csv' of shape (9, 3)
# 2025-01-27 17:04:32.731037 finished: loading list-style /home/dgketchum/PycharmProjects/swim-rs/tutorials/2_Fort_Peck/pest/params.csv took: 0:00:00.002798
# 2025-01-27 17:04:32.731141 starting: writing list-style template file '/home/dgketchum/PycharmProjects/swim-rs/tutorials/2_Fort_Peck/pest/p_ndvi_alpha_US-FPe_0_constant.csv.tpl'
# 2025-01-27 17:04:32.739987 finished: writing list-style template file '/home/dgketchum/PycharmProjects/swim-rs/tutorials/2_Fort_Peck/pest/p_ndvi_alpha_US-FPe_0_constant.csv.tpl' took: 0:00:00.008846
# 2025-01-27 17:04:32.743731 finished: adding constant type m style parameters for file(s) ['params.csv'] took: 0:00:00.015596
# 2025-01-27 17:04:32.743831 starting: adding constant type m style parameters for file(s) ['params.csv']
# 2025-01-27 17:04:32.743908 starting: loading list-style /home/dgketchum/PycharmProjects/swim-rs/tutorials/2_Fort_Peck/pest/params.csv
# 2025-01-27 17:04:32.743967 starting: reading list-style file: /home/dgketchum/PycharmProjects/swim-rs/tutorials/2_Fort_Peck/pest/params.csv
# 2025-01-27 17:04:32.745058 finished: reading list-style file: /home/dgketchum/PycharmProjects/swim-rs/tutorials/2_Fort_Peck/pest/params.csv took: 0:00:00.001091
# 2025-01-27 17:04:32.745124 loaded list-style '/home/dgketchum/PycharmProjects/swim-rs/tutorials/2_Fort_Peck/pest/params.csv' of shape (9, 3)
# 2025-01-27 17:04:32.746504 finished: loading list-style /home/dgketchum/PycharmProjects/swim-rs/tutorials/2_Fort_Peck/pest/params.csv took: 0:00:00.002596
# 2025-01-27 17:04:32.746575 starting: writing list-style template file '/home/dgketchum/PycharmProjects/swim-rs/tutorials/2_Fort_Peck/pest/p_ndvi_beta_US-FPe_0_constant.csv.tpl'
# 2025-01-27 17:04:32.756156 finished: writing list-style template file '/home/dgketchum/PycharmProjects/swim-rs/tutorials/2_Fort_Peck/pest/p_ndvi_beta_US-FPe_0_constant.csv.tpl' took: 0:00:00.009581
# 2025-01-27 17:04:32.760538 finished: adding constant type m style parameters for file(s) ['params.csv'] took: 0:00:00.016707
# 2025-01-27 17:04:32.760670 starting: adding constant type m style parameters for file(s) ['params.csv']
# 2025-01-27 17:04:32.760780 starting: loading list-style /home/dgketchum/PycharmProjects/swim-rs/tutorials/2_Fort_Peck/pest/params.csv
# 2025-01-27 17:04:32.760842 starting: reading list-style file: /home/dgketchum/PycharmProjects/swim-rs/tutorials/2_Fort_Peck/pest/params.csv
# 2025-01-27 17:04:32.762140 finished: reading list-style file: /home/dgketchum/PycharmProjects/swim-rs/tutorials/2_Fort_Peck/pest/params.csv took: 0:00:00.001298
# 2025-01-27 17:04:32.762205 loaded list-style '/home/dgketchum/PycharmProjects/swim-rs/tutorials/2_Fort_Peck/pest/params.csv' of shape (9, 3)
# 2025-01-27 17:04:32.763780 finished: loading list-style /home/dgketchum/PycharmProjects/swim-rs/tutorials/2_Fort_Peck/pest/params.csv took: 0:00:00.003000
# 2025-01-27 17:04:32.763895 starting: writing list-style template file '/home/dgketchum/PycharmProjects/swim-rs/tutorials/2_Fort_Peck/pest/p_mad_US-FPe_0_constant.csv.tpl'
# 2025-01-27 17:04:32.773303 finished: writing list-style template file '/home/dgketchum/PycharmProjects/swim-rs/tutorials/2_Fort_Peck/pest/p_mad_US-FPe_0_constant.csv.tpl' took: 0:00:00.009408
# 2025-01-27 17:04:32.777009 finished: adding constant type m style parameters for file(s) ['params.csv'] took: 0:00:00.016339
# 2025-01-27 17:04:32.777139 starting: adding constant type m style parameters for file(s) ['params.csv']
# 2025-01-27 17:04:32.777246 starting: loading list-style /home/dgketchum/PycharmProjects/swim-rs/tutorials/2_Fort_Peck/pest/params.csv
# 2025-01-27 17:04:32.777314 starting: reading list-style file: /home/dgketchum/PycharmProjects/swim-rs/tutorials/2_Fort_Peck/pest/params.csv
# 2025-01-27 17:04:32.778654 finished: reading list-style file: /home/dgketchum/PycharmProjects/swim-rs/tutorials/2_Fort_Peck/pest/params.csv took: 0:00:00.001340
# 2025-01-27 17:04:32.778727 loaded list-style '/home/dgketchum/PycharmProjects/swim-rs/tutorials/2_Fort_Peck/pest/params.csv' of shape (9, 3)
# 2025-01-27 17:04:32.780221 finished: loading list-style /home/dgketchum/PycharmProjects/swim-rs/tutorials/2_Fort_Peck/pest/params.csv took: 0:00:00.002975
# 2025-01-27 17:04:32.780323 starting: writing list-style template file '/home/dgketchum/PycharmProjects/swim-rs/tutorials/2_Fort_Peck/pest/p_swe_alpha_US-FPe_0_constant.csv.tpl'
# 2025-01-27 17:04:32.787889 finished: writing list-style template file '/home/dgketchum/PycharmProjects/swim-rs/tutorials/2_Fort_Peck/pest/p_swe_alpha_US-FPe_0_constant.csv.tpl' took: 0:00:00.007566
# 2025-01-27 17:04:32.790849 finished: adding constant type m style parameters for file(s) ['params.csv'] took: 0:00:00.013710
# 2025-01-27 17:04:32.790937 starting: adding constant type m style parameters for file(s) ['params.csv']
# 2025-01-27 17:04:32.791012 starting: loading list-style /home/dgketchum/PycharmProjects/swim-rs/tutorials/2_Fort_Peck/pest/params.csv
# 2025-01-27 17:04:32.791057 starting: reading list-style file: /home/dgketchum/PycharmProjects/swim-rs/tutorials/2_Fort_Peck/pest/params.csv
# 2025-01-27 17:04:32.791970 finished: reading list-style file: /home/dgketchum/PycharmProjects/swim-rs/tutorials/2_Fort_Peck/pest/params.csv took: 0:00:00.000913
# 2025-01-27 17:04:32.792031 loaded list-style '/home/dgketchum/PycharmProjects/swim-rs/tutorials/2_Fort_Peck/pest/params.csv' of shape (9, 3)
# 2025-01-27 17:04:32.793236 finished: loading list-style /home/dgketchum/PycharmProjects/swim-rs/tutorials/2_Fort_Peck/pest/params.csv took: 0:00:00.002224
# 2025-01-27 17:04:32.793305 starting: writing list-style template file '/home/dgketchum/PycharmProjects/swim-rs/tutorials/2_Fort_Peck/pest/p_swe_beta_US-FPe_0_constant.csv.tpl'
# 2025-01-27 17:04:32.800423 finished: writing list-style template file '/home/dgketchum/PycharmProjects/swim-rs/tutorials/2_Fort_Peck/pest/p_swe_beta_US-FPe_0_constant.csv.tpl' took: 0:00:00.007118
# 2025-01-27 17:04:32.803407 finished: adding constant type m style parameters for file(s) ['params.csv'] took: 0:00:00.012470
# 2025-01-27 17:04:32.853932 starting: adding observations from output file obs/obs_etf_US-FPe.np
# 2025-01-27 17:04:32.854001 starting: adding observations from array output file 'obs/obs_etf_US-FPe.np'
# 2025-01-27 17:04:32.872568 starting: adding observation from instruction file '/home/dgketchum/PycharmProjects/swim-rs/tutorials/2_Fort_Peck/pest/etf_US-FPe.ins'
# 2025-01-27 17:04:32.981600 finished: adding observation from instruction file '/home/dgketchum/PycharmProjects/swim-rs/tutorials/2_Fort_Peck/pest/etf_US-FPe.ins' took: 0:00:00.109032
# 2025-01-27 17:04:32.982505 finished: adding observations from array output file 'obs/obs_etf_US-FPe.np' took: 0:00:00.128504
# 2025-01-27 17:04:32.982938 finished: adding observations from output file obs/obs_etf_US-FPe.np took: 0:00:00.129006
# 2025-01-27 17:04:33.667294 starting: adding observations from output file obs/obs_swe_US-FPe.np
# 2025-01-27 17:04:33.667567 starting: adding observations from array output file 'obs/obs_swe_US-FPe.np'
# 2025-01-27 17:04:33.691920 starting: adding observation from instruction file '/home/dgketchum/PycharmProjects/swim-rs/tutorials/2_Fort_Peck/pest/swe_US-FPe.ins'
# 2025-01-27 17:04:33.823021 finished: adding observation from instruction file '/home/dgketchum/PycharmProjects/swim-rs/tutorials/2_Fort_Peck/pest/swe_US-FPe.ins' took: 0:00:00.131101
# 2025-01-27 17:04:33.823964 finished: adding observations from array output file 'obs/obs_swe_US-FPe.np' took: 0:00:00.156397
# 2025-01-27 17:04:33.824155 finished: adding observations from output file obs/obs_swe_US-FPe.np took: 0:00:00.156861
# noptmax:0, npar_adj:8, nnz_obs:4100
# noptmax:0, npar_adj:8, nnz_obs:4100
# 13149 rows in swe, 13149 rows in etf
# Configured PEST++ for 1 targets,

# %%
os.getcwd()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 os.cwd()
#
# AttributeError: module 'os' has no attribute 'cwd'

# %% [markdown]
# See that all the data from `project_ws` are now copied to the 'pest' directory at `swim-rs/2_Fort_Peck/pest`, including the data folder, the other steps to this tutorial, etc. We also see the new files that were built:

# %%
original_files = [f for f in sorted(os.listdir(builder.pest_dir)) if os.path.isfile(os.path.join(builder.pest_dir, f))]
original_files
# Out:
# ['2_Fort_Peck.pst',
#  '2_fort_peck.insfile_data.csv',
#  '2_fort_peck.obs_data.csv',
#  '2_fort_peck.par_data.csv',
#  '2_fort_peck.pargp_data.csv',
#  '2_fort_peck.tplfile_data.csv',
#  'config.toml',
#  'custom_forward_run.py',
#  'etf_US-FPe.ins',
#  'mult2model_info.csv',
#  'p_aw_US-FPe_0_constant.csv.tpl',
#  'p_mad_US-FPe_0_constant.csv.tpl',
#  'p_ndvi_alpha_US-FPe_0_constant.csv.tpl',
#  'p_ndvi_beta_US-FPe_0_constant.csv.tpl',
#  'p_rew_US-FPe_0_constant.csv.tpl',
#  'p_swe_alpha_US-FPe_0_constant.csv.tpl',
#  'p_swe_beta_US-FPe_0_constant.csv.tpl',
#  'p_tew_US-FPe_0_constant.csv.tpl',
#  'params.csv',
#  'swe_US-FPe.ins']

# %% [markdown]
# Check out the files. We see the PEST++ control file, several csv files pointing to parameter information, our python run script, and .tpl and .ins files that spell out to PEST++ where to put the parameter data, and how to read the observations. The params.csv holds our default parameter values and intial estimates of soil parameters from the soils database.
#
# The PEST++ version 2 control file is succint; it delegates the work of detailing how to handle model output, observations, and parameter prosal file and format info to other files.

# %%
with open(builder.pst_file, 'r') as f: 
    print(f.read())
# Out:
# pcf version=2
# * control data keyword
# pestmode                                 estimation
# noptmax                                 0
# svdmode                                 1
# maxsing                          10000000
# eigthresh                           1e-06
# eigwrite                                1
# * parameter groups external
# 2_fort_peck.pargp_data.csv
# * parameter data external
# 2_fort_peck.par_data.csv
# * observation data external
# 2_fort_peck.obs_data.csv
# * model command line
# python custom_forward_run.py
# * model input external
# 2_fort_peck.tplfile_data.csv
# * model output external
# 2_fort_peck.insfile_data.csv

# %% [markdown]
# Once we have to control file built, we will want to use the `build_localizer` method that writes a `.loc` file matching the 'observations' from SNODAS and SSEBop to the parameters we want to tune. We only tune the SWE parameters `swe_alpha` and `swe_beta` using the SNODAS data, while we tune the other parameters using the SSEBop ETf data. The localizer matrix specifies that for PEST++.
#
# We will also do a minimal model run to ensure the `pest` folder has all the files it will need when we use it as the base for a parallelized run. We do this with the `dry_run` method.
#
# Finally, we run the `write_control_settings` that will change set the model up for many runs over three iterations.

# %%
builder.build_localizer()
builder.dry_run()
builder.write_control_settings(noptmax=3, reals=20)
# Out:
# noptmax:0, npar_adj:8, nnz_obs:4100
# run():pestpp-ies /home/dgketchum/PycharmProjects/swim-rs/tutorials/2_Fort_Peck/pest/2_Fort_Peck.pst
# pestpp-ies /home/dgketchum/PycharmProjects/swim-rs/tutorials/2_Fort_Peck/pest/2_Fort_Peck.pst
#
#
#              pestpp-ies: a GLM iterative ensemble smoother
#
#                    by the PEST++ development team
#
#
# version: 5.2.7
# binary compiled on Dec 12 2023 at 13:33:23
#
# started at 01/27/25 13:56:21
# ...processing command line: ' pestpp-ies /home/dgketchum/PycharmProjects/swim-rs/tutorials/2_Fort_Peck/pest/2_Fort_Peck.pst'
# ...using serial run manager
#
# using control file: "/home/dgketchum/PycharmProjects/swim-rs/tutorials/2_Fort_Peck/pest/2_Fort_Peck.pst"
# in directory: "/home/dgketchum/PycharmProjects/swim-rs/tutorials/2_Fort_Peck/pest"
# on host: "dgketchum-r"
#
# processing control file /home/dgketchum/PycharmProjects/swim-rs/tutorials/2_Fort_Peck/pest/2_Fort_Peck.pst
#
# Note: 'NOPTMAX' == 0, switching to forgiveness mode when checking inputs
#
# noptmax = 0, resetting max_run_fail = 1
# checking model IO files...done
#               starting serial run manager ...
#
#
#   ---  initializing  ---
#
#   ---  'noptmax'=0, running control file parameter values and quitting  ---
# ...saving control file parameter ensemble to  /home/dgketchum/PycharmProjects/swim-rs/tutorials/2_Fort_Peck/pest/2_Fort_Peck.base.par.csv
# ...initializing prior parameter covariance matrix
# ...parcov loaded  from parameter bounds, using par_sigma_range 4
# ...running control file parameter values
#
#
#
#     ---  starting serial run manager for 1 runs ---
#
#
# 01/27/25 13:56:22 processing template files with 1 threads...
# thread 0 processed 8 template files
# 01/27/25 13:56:22 done, took 0 seconds
# 01/27/25 13:56:22 calling forward run command(s)
# 01/27/25 13:56:22 calling forward run command: 'python custom_forward_run.py'
#
#
# Config: /home/dgketchum/PycharmProjects/swim-rs/tutorials/2_Fort_Peck/config.toml
# CALIBRATION ON
# FORECAST OFF
# Execution time: 11.13 seconds
#
#
# 01/27/25 13:56:33 foward run command(s) finished, took 11.526 seconds
# 01/27/25 13:56:33 processing instruction files with 1 threads...
# thread 0 processed 2 instruction files
# 01/27/25 13:56:34 done, took 0.18 seconds
#
#
# -->01/27/25 13:56:34 run complete, took: 11.73 seconds
# -->1 of 1 complete, 0 failed
#
#
#
#
#
#     ---  serial run manager runs summary:  ---
#     1 of 1 complete, 0 failed
#     process took : 11.731 seconds
#
#
#
#
# ...saving results from control file parameter value run to  /home/dgketchum/PycharmProjects/swim-rs/tutorials/2_Fort_Peck/pest/2_Fort_Peck.base.obs.csv
#
#   ---  control file parameter phi report:  ---
#        phi type           mean            std            min            max
#        measured        847.626              0        847.626        847.626
#          actual        847.626              0        847.626        847.626
#      note: 'measured' phi reported above includes
#            realizations of measurement noise,
#            'actual' phi does not.
#   ---  observation group phi summary ---
#        (computed using 'actual' phi)
#            (sorted by mean phi)
# group                                       mean       std       min       max   percent       std
# oname:obs/obs_swe_us-fpe.np_otype:arr        805         0       805       805        95         0
# oname:obs/obs_etf_us-fpe.np_otype:arr       42.4         0      42.4      42.4         5         0
#     Note: 'percent' is the percentage of the actual phi for each realization.
#
# saved par and rei files for realization BASE
#
#
# pestpp-ies analysis complete...
# started at 01/27/25 13:56:21
# finished at 01/27/25 13:56:34
# took 0.2 minutes
# noptmax:3, npar_adj:8, nnz_obs:4100

# %% [markdown]
# The control file settings have been changed. The `noptmax` (number of optimization iterations) was increased to 3, with 20 model 'realizations' (runs) per cycle. Once we get the calibration running smoothly, increase the `reals` parameter to a larger number, perhaps 100. We can also see the addition of the `loc.mat` localizer file.

# %%
with open(builder.pst_file, 'r') as f:
    print(f.read())
# Out:
# pcf version=2
# * control data keyword
# pestmode                                 estimation
# noptmax                                 3
# svdmode                                 1
# maxsing                          10000000
# eigthresh                           1e-06
# eigwrite                                1
# ies_localizer                  loc.mat
# ies_num_reals                  20
# * parameter groups external
# 2_fort_peck.pargp_data.csv
# * parameter data external
# 2_fort_peck.par_data.csv
# * observation data external
# 2_fort_peck.obs_data.csv
# * model command line
# python custom_forward_run.py
# * model input external
# 2_fort_peck.tplfile_data.csv
# * model output external
# 2_fort_peck.insfile_data.csv

# %% [markdown]
# **Congratulations** if you've made it this far. There is a lot going on in this project, and staying organized while preparing up to harness a powerful tool like PEST++ is a significant achievement!
#
# Let's see if we can improve SWIM through calibration. We're using multiprocessing; feel free to change `workers` to suit your machine.
#
# Run the calibration launcher:

# %%
workers = config.workers or 6
_pst = f"{config.project_name}.pst"

run_pst(builder.pest_dir,
        'pestpp-ies',
        _pst,
        num_workers=workers,
        worker_root=builder.workers_dir,
        master_dir=builder.master_dir,
        cleanup=True,
        verbose=True)
# Out:
# rmtree: /home/dgketchum/PycharmProjects/swim-rs/tutorials/2_Fort_Peck/workers/worker_1
# rmtree: /home/dgketchum/PycharmProjects/swim-rs/tutorials/2_Fort_Peck/workers/worker_0
# master:pestpp-ies /home/dgketchum/PycharmProjects/swim-rs/tutorials/2_Fort_Peck/pest/2_Fort_Peck.pst /h :5005 in /home/dgketchum/PycharmProjects/swim-rs/tutorials/2_Fort_Peck/master
#
#
#              pestpp-ies: a GLM iterative ensemble smoother
#
#                    by the PEST++ development team
#
#
# version: 5.2.7
# binary compiled on Dec 12 2023 at 13:33:23
#
# started at 01/27/25 16:42:56
# ...processing command line: ' pestpp-ies /home/dgketchum/PycharmProjects/swim-rs/tutorials/2_Fort_Peck/pest/2_Fort_Peck.pst /h :5005'
# ...using panther run manager in master mode using port 5005
#
# using control file: "/home/dgketchum/PycharmProjects/swim-rs/tutorials/2_Fort_Peck/pest/2_Fort_Peck.pst"
# in directory: "/home/dgketchum/PycharmProjects/swim-rs/tutorials/2_Fort_Peck/master"
# on host: "dgketchum-r"
#
# processing control file /home/dgketchum/PycharmProjects/swim-rs/tutorials/2_Fort_Peck/pest/2_Fort_Peck.pst
#
#
# :~-._                                                 _.-~:
# : :.~^o._        ________---------________        _.o^~.:.:
#  : ::.`?88booo~~~.::::::::...::::::::::::..~~oood88P'.::.:
#  :  ::: `?88P .:::....         ........:::::. ?88P' :::. :
#   :  :::. `? .::.            . ...........:::. P' .:::. :
#    :  :::   ... ..  ...       .. .::::......::.   :::. :
#    `  :' .... ..  .:::::.     . ..:::::::....:::.  `: .'
#     :..    ____:::::::::.  . . ....:::::::::____  ... :
#    :... `:~    ^~-:::::..  .........:::::-~^    ~::.::::
#    `.::. `\   (8)  \b:::..::.:.:::::::d/  (8)   /'.::::'
#     ::::.  ~-._v    |b.::::::::::::::d|    v_.-~..:::::
#     `.:::::... ~~^?888b..:::::::::::d888P^~...::::::::'
#      `.::::::::::....~~~ .:::::::::~~~:::::::::::::::'
#       `..:::::::::::   .   ....::::    ::::::::::::,'
#         `. .:::::::    .      .::::.    ::::::::'.'
#           `._ .:::    .        :::::.    :::::_.'
#              `-. :    .        :::::      :,-'
#                 :.   :___     .:::___   .::
#       ..--~~~~--:+::. ~~^?b..:::dP^~~.::++:--~~~~--..
#         ___....--`+:::.    `~8~'    .:::+'--....___
#       ~~   __..---`_=:: ___gd8bg___ :==_'---..__   ~~
#        -~~~  _.--~~`-.~~~~~~~~~~~~~~~,-' ~~--._ ~~~-
#
#
#                starting PANTHER master...
#
# IP addresses:
#   0.0.0.0:5005 (IPv4)
#
# PANTHER master listening on socket: 0.0.0.0:5005 (IPv4)
#
#   ---  initializing  ---
# ...using glm algorithm
# ...using REDSVD for truncated svd solve
# ...maxsing: 10000000
# ...eigthresh:  1e-06
# ...initializing localizer
# ...using localized solution with 5 sequential upgrade steps
# ...localizing by parameters
# ...using lambda multipliers: 0.1 , 1 , 10 ,
# ...using lambda scaling factors: 0.75 , 1 , 1.1 ,
# ...acceptable phi factor:  1.05
# ...lambda increase factor:  10
# ...lambda decrease factor:  0.75
# ...max run fail:  1
# ...initializing prior parameter covariance matrix
# ...parcov loaded  from parameter bounds, using par_sigma_range 4
# ...initializing observation noise covariance matrix
# worker:pestpp-ies /home/dgketchum/PycharmProjects/swim-rs/tutorials/2_Fort_Peck/pest/2_Fort_Peck.pst /h localhost:5005 in /home/dgketchum/PycharmProjects/swim-rs/tutorials/2_Fort_Peck/workers/worker_0
# ...obscov loaded  from observation weights
# ...using reg_factor:  0
# ...drawing parameter realizations:  20
# ...not using prior parameter covariance matrix scaling
# ...drawing observation noise realizations:  20
# observations not grouped by observations groups, reordering obs ensemble
# ...setting weights ensemble from control file weights
# ...saved weight ensemble to  /home/dgketchum/PycharmProjects/swim-rs/tutorials/2_Fort_Peck/pest/2_Fort_Peck.weights.csv
# ...adding 'base' parameter values to ensemble
# ...adding 'base' observation values to ensemble
# ...adding 'base' weight values to weight ensemble
# ...saved initial parameter ensemble to  /home/dgketchum/PycharmProjects/swim-rs/tutorials/2_Fort_Peck/pest/2_Fort_Peck.0.par.csv
# ---------------------------------------------------------------------------
# Error                                     Traceback (most recent call last)
# Cell In[12], line 3
#       1 workers = 6
# ----> 3 run_pst(builder.pest_dir,
#       4         'pestpp-ies',
#       5         builder.pst_file,
#       6         num_workers=workers,
#       7         worker_root=builder.workers_dir,
#       8         master_dir=builder.master_dir,
#       9         cleanup=False,
#      10         verbose=True)
#
# File ~/PycharmProjects/swim-rs/calibrate/run_pest.py:24, in run_pst(_dir, _cmd, pst_file, num_workers, worker_root, master_dir, verbose, cleanup)
#      21 if not os.path.isdir(_dir):
#      22     raise ValueError(f'The pest directory {_dir} does not exist, run pest_builder.py')
# ---> 24 os_utils.start_workers(_dir,
#      25                        _cmd,
#      26                        pst_rel_path=pst_file,
#      27                        num_workers=num_workers,
#      28                        worker_root=worker_root,
#      29                        verbose=verbose,
#      30                        master_dir=master_dir,
#      31                        cleanup=cleanup,
#      32                        port=5005)
#
# File ~/miniconda3/envs/swim/lib/python3.9/site-packages/pyemu/utils/os_utils.py:422, in start_workers(worker_dir, exe_rel_path, pst_rel_path, num_workers, worker_root, port, rel_path, local, cleanup, master_dir, verbose, silent_master, reuse_master, restart, ppw_function, ppw_kwargs)
#     420 if os.path.exists(new_worker_dir):
#     421     _try_remove_existing(new_worker_dir)
# --> 422 _try_copy_dir(worker_dir, new_worker_dir)
#     423 try:
#     424     if exe_verf:
#     425         # if rel_path is not None:
#     426         #     exe_path = os.path.join(rel_path,exe_rel_path)
#     427         # else:
#
# File ~/miniconda3/envs/swim/lib/python3.9/site-packages/pyemu/utils/os_utils.py:245, in _try_copy_dir(o_d, n_d)
#     243 def _try_copy_dir(o_d, n_d):
#     244     try:
# --> 245         shutil.copytree(o_d, n_d)
#     246     except PermissionError:
#     247         time.sleep(3) # pause for windows locking issues
#
# File ~/miniconda3/envs/swim/lib/python3.9/shutil.py:568, in copytree(src, dst, symlinks, ignore, copy_function, ignore_dangling_symlinks, dirs_exist_ok)
#     566 with os.scandir(src) as itr:
#     567     entries = list(itr)
# --> 568 return _copytree(entries=entries, src=src, dst=dst, symlinks=symlinks,
#     569                  ignore=ignore, copy_function=copy_function,
#     570                  ignore_dangling_symlinks=ignore_dangling_symlinks,
#     571                  dirs_exist_ok=dirs_exist_ok)
#
# File ~/miniconda3/envs/swim/lib/python3.9/shutil.py:522, in _copytree(entries, src, dst, symlinks, ignore, copy_function, ignore_dangling_symlinks, dirs_exist_ok)
#     520         errors.append((src, dst, str(why)))
#     521 if errors:
# --> 522     raise Error(errors)
#     523 return dst
#
# Error: [('/home/dgketchum/PycharmProjects/swim-rs/tutorials/2_Fort_Peck/pest/2_Fort_Peck.rns', '/home/dgketchum/PycharmProjects/swim-rs/tutorials/2_Fort_Peck/workers/worker_1/2_Fort_Peck.rns', "[Errno 2] No such file or directory: '/home/dgketchum/PycharmProjects/swim-rs/tutorials/2_Fort_Peck/pest/2_Fort_Peck.rns'")]
# ...saved obs+noise observation ensemble (obsval + noise realizations) to  /home/dgketchum/PycharmProjects/swim-rs/tutorials/2_Fort_Peck/pest/2_Fort_Peck.obs+noise.csv
# ...using subset in lambda testing, number of realizations used in subset testing:  4
# ...subset how:  RANDOM
# ...centering on ensemble mean vector
# ...running initial ensemble of size 20
#     running model 20 times
#     starting at 01/27/25 16:42:58
#
#     waiting for agents to appear...
#
#
# PANTHER progress
#    avg = average model run time in minutes
#    runs(C = completed | F = failed | T = timed out)
#    agents(R = running | W = waiting | U = unavailable)
# --------------------------------------------------------------------------------
# 01/27 16:43:40 mn:0.21  runs(C3    |F0    |T0    ) agents(R1   |W0   |U0   ) 0

# %% [markdown]
# If it runs, you see a progress updater that will have something like `01/05 11:35:11 mn:0.16  runs(C5   |F0    |T0    ) agents(R1   |W0   |U0   ) 0`. The `C` stands for 'complete', and if it increases, PEST++ is running. Go get a coffee.
#
# Let's assume it didn't run.
#
# ### Debugging Tips
#
#  - If you never saw the panther, then `pestpp-ies` was probably not executed. Make sure you can run `pestpp-ies` from the command line in any directory on your machine. You may need to point to the executable with a full path, like `/home/skywalker/software/pestpp-ies`, or a path that ends with the '.exe' extension, if on a Windows machine. In this case, you will need to update command above to ensure we are providing `run_pest.py`'s `run_pst` with the correct executable.
#  - If you never saw the panther and got a Python error traceback, read it carefully. It's tricky to get the interface to work, as we need to launch `run_pest.py`, it needs to launch `pestpp-ies`, that launches `custom_forward_run.py`, which finally actually runs the model with `swimrs/calibrate/run_mp.py`.
#
#    A good debugging approach is to start from the bottom up by getting `run_mp.optimize_fields` to run from arguments provided under `if __name__ == '__main__':` in `swimrs/calibrate/run_mp.py`. Then get `swimrs/calibrate/run_mp.py` to run by launching the `custom_forward_run.py` located in your 'pest' directory. Then try running `swimrs/calibrate/run_pest.py` with arguments provided under `if __name__ == '__main__':`. Trust a simpler way code flow that doesn't decrease flexibility is sought.
#
#  - Try running the `pestpp-ies` commmand from the 'pest' folder. This runs the program in a single thread, and can rule out problems with the 'pest' folder's files and structure. If you can run this, the problem is likely with the `run/run_pest.py` function `run_pst`. Double check the paths and arguments. Try launching it from `run/run_pest.py` instead of from this notebook.
#
#  - If you saw the panther, then `pestpp-ies` ran. Great. You are close. The traceback (message in the ouput) that traces your error is very informative, but the last error is likely not what you need to track down. It's common to see something like
#     ```
#     thread processing instruction file raised an exception: InstructionFile error in file 'swe_US-FPe.ins' : output file'pred/pred_swe_US-FPe.np' not found
#     ```
#
# This interrupted the PEST++ execution of the realization, but likely wasn't the true cause. The error of not finding SWIM's prediction in `pred_swe_US-FPe.np` is actually because SWIM never completed it's run, because SWIM itself has an error. When we run `run_pst`, we're launching the program in each of the number `workers`'s directories, which are copies of the `pest` directory. Set `cleanup` to `False` above, run the code, and go into e.g., `workers/worker_0/panther_worker.rec` and look for errors.
#
# Often, the problem is that SWIM isn't writing its output to the `pred` folder in each worker.
#
# These are just a few ideas. As always, the key to debugging is reading the hints in the traceback and moving up the code operation chain until the problem is found. Science says 9/10 errors are due to paths not being set correctly.

# %% [markdown]
# Once we get a successful run, we see we have many more files in the 'pest' directory, but what we want are the calibrated parameters we'll need to use to run SWIM in forecast mode (i.e., a calibrated run of the model). The should be in the 'pest' directory, though in cases theu may end up in 'master', the location where multiprocessing by pyemu of PEST++ was coordinated:

# %%
[f for f in sorted(os.listdir(builder.pest_dir)) if '.par.csv' in f]
# Out:
# ...saved obs+noise observation ensemble (obsval + noise realizations) to  /home/dgketchum/PycharmProjects/swim-rs/tutorials/2_Fort_Peck/pest/2_Fort_Peck.obs+noise.csv
# ...using subset in lambda testing, number of realizations used in subset testing:  4
# ...subset how:  RANDOM
# ...centering on ensemble mean vector
# ...running initial ensemble of size 20
#     running model 20 times
#     starting at 01/27/25 13:56:37
#
#     waiting for agents to appear...
#
#
# PANTHER progress
#    avg = average model run time in minutes
#    runs(C = completed | F = failed | T = timed out)
#    agents(R = running | W = waiting | U = unavailable)
# --------------------------------------------------------------------------------
# 01/27 14:00:49 mn:0.21  runs(C20   |F0    |T0    ) agents(R0   |W1   |U0   ) 0
#
#    20 runs complete :  0 runs failed
#    0.206 avg run time (min) : 4.2 run mgr time (min)
#    1 agents connected
#
#
# ...saved initial obs ensemble to /home/dgketchum/PycharmProjects/swim-rs/tutorials/2_Fort_Peck/pest/2_Fort_Peck.0.obs.csv
# saved par and rei files for realization BASE for iteration 0
# saved par and rei files for realization BASE
#
#   ---  pre-drop initial phi summary  ---
#        phi type           mean            std            min            max
#        measured         370136    1.06751e+06        847.626    3.60298e+06
#          actual         368782    1.06765e+06         162.56    3.60113e+06
#      note: 'measured' phi reported above includes
#            realizations of measurement noise,
#            'actual' phi does not.
#   ---  observation group phi summary ---
#        (computed using 'actual' phi)
#            (sorted by mean phi)
# group                                       mean       std       min       max   percent       std
# oname:obs/obs_swe_us-fpe.np_otype:arr   3.69e+05  1.07e+06      96.7   3.6e+06        90      11.6
# oname:obs/obs_etf_us-fpe.np_otype:arr       61.6      32.2      27.9       155      9.99      11.6
#     Note: 'percent' is the percentage of the actual phi for each realization.
#
# ...checking for prior-data conflict...
#
#   ---  WARNING: 1061 non-zero weighted observations are in conflict with the prior simulated ensemble.
#   ---
# ...see rec file or /home/dgketchum/PycharmProjects/swim-rs/tutorials/2_Fort_Peck/pest/2_Fort_Peck.pdc.csv for listing of conflicted observations
#
# ...  WARNING: Prior-data conflict detected.  Continuing with IES parameter
#            adjustment will likely result in parameter and forecast bias.
#            Consider using 'ies_drop_conflicts' as a quick fix.
# ...saved adjusted weight ensemble to  /home/dgketchum/PycharmProjects/swim-rs/tutorials/2_Fort_Peck/pest/2_Fort_Peck.adjusted.weights.csv
#
#   ---  initial phi summary  ---
#        phi type           mean            std            min            max
#        measured         370136    1.06751e+06        847.626    3.60298e+06
#          actual         368782    1.06765e+06         162.56    3.60113e+06
#      note: 'measured' phi reported above includes
#            realizations of measurement noise,
#            'actual' phi does not.
#   ---  observation group phi summary ---
#        (computed using 'actual' phi)
#            (sorted by mean phi)
# group                                       mean       std       min       max   percent       std
# oname:obs/obs_swe_us-fpe.np_otype:arr   3.69e+05  1.07e+06      96.7   3.6e+06        90      11.6
# oname:obs/obs_etf_us-fpe.np_otype:arr       61.6      32.2      27.9       155      9.99      11.6
#     Note: 'percent' is the percentage of the actual phi for each realization.
#
# ...current lambda: 10
#
#   ---  initialization complete  ---
#
#   ---  starting solve for iteration: 1  ---
# ...current lambda:  10
# ...preparing fast-lookup containers for threaded localization solve
# ...starting calcs for glm factor 1
# ...finished calcs for: 1
# ...starting calcs for glm factor 10
# ...finished calcs for: 10
# ...starting calcs for glm factor 100
# ...finished calcs for: 100
#
#   ---  running upgrade ensembles  ---
# ...subset idx:pe real name:  0:0, 2:2, 5:5, 19:BASE,
# ...subset idx:oe real name:  0:0, 2:2, 5:5, 19:BASE,
#     running model 36 times
#     starting at 01/27/25 14:00:51
#     1 agents ready
#
#
# PANTHER progress
#    avg = average model run time in minutes
#    runs(C = completed | F = failed | T = timed out)
#    agents(R = running | W = waiting | U = unavailable)
# --------------------------------------------------------------------------------
# 01/27 14:08:08 mn:0.2   runs(C36   |F0    |T0    ) agents(R0   |W1   |U0   ) 0
#
#    36 runs complete :  0 runs failed
#    0.201 avg run time (min) : 7.29 run mgr time (min)
#    1 agents connected
#
#
#
#   ---  evaluating upgrade ensembles  ---
# ...last mean:  370136
# ...last stdev:  1.06751e+06
#
#   ---  phi summary for best lambda, scale fac: 1 , 1.1 ,   ---
#        phi type           mean            std            min            max
#        measured        1357.26        814.815         136.78        1825.57
#          actual        146.049        8.30487         136.78        153.193
#      note: 'measured' phi reported above includes
#            realizations of measurement noise,
#            'actual' phi does not.
#
#   ---  running remaining realizations for best lambda, scale:1 , 1.1 ,   ---
#     running model 16 times
#     starting at 01/27/25 14:08:10
#     1 agents ready
#
#
# PANTHER progress
#    avg = average model run time in minutes
#    runs(C = completed | F = failed | T = timed out)
#    agents(R = running | W = waiting | U = unavailable)
# --------------------------------------------------------------------------------
# 01/27 14:11:26 mn:0.2   runs(C16   |F0    |T0    ) agents(R0   |W1   |U0   ) 0
#
#    16 runs complete :  0 runs failed
#    0.201 avg run time (min) : 3.27 run mgr time (min)
#    1 agents connected
#
#
# ...phi summary for entire ensemble using lambda,scale_fac 1 , 1.1 ,
#        phi type           mean            std            min            max
#        measured        1655.81        361.925         136.78        1859.65
#          actual        149.409        14.6067        109.164        172.334
#      note: 'measured' phi reported above includes
#            realizations of measurement noise,
#            'actual' phi does not.
# ...last best mean phi * acceptable phi factor:  388643
# ...current best mean phi:  1655.81
#
#   ---  updating parameter ensemble  ---
#
#   ---  updating lambda to  0.75  ---
#
#   ---  EnsembleMethod iteration 1 report  ---
#    number of active realizations:   20
#    number of model runs:            72
#       current obs ensemble saved to /home/dgketchum/PycharmProjects/swim-rs/tutorials/2_Fort_Peck/pest/2_Fort_Peck.1.obs.csv
#       current par ensemble saved to /home/dgketchum/PycharmProjects/swim-rs/tutorials/2_Fort_Peck/pest/2_Fort_Peck.1.par.csv
# saved par and rei files for realization BASE for iteration 1
# saved par and rei files for realization BASE
#        phi type           mean            std            min            max
#        measured        1655.81        361.925         136.78        1859.65
#          actual        149.409        14.6067        109.164        172.334
#      note: 'measured' phi reported above includes
#            realizations of measurement noise,
#            'actual' phi does not.
#   ---  observation group phi summary ---
#        (computed using 'actual' phi)
#            (sorted by mean phi)
# group                                       mean       std       min       max   percent       std
# oname:obs/obs_swe_us-fpe.np_otype:arr       99.7      12.4      77.7       115        67      7.75
# oname:obs/obs_etf_us-fpe.np_otype:arr       49.7        14      22.7      83.4        33      7.75
#     Note: 'percent' is the percentage of the actual phi for each realization.
#
#
#    ---  parameter group change summmary  ---
# group            mean chg   std chg n at ubnd % at ubnd n at lbnd % at lbnd   init CV   curr CV
# swe_alpha         4.6e+02        87        17        85         0         0       2.2     0.049
# snow_beta              20        34         0         0         0         0      0.96       0.8
# aw                     15        32         4        20         0         0      0.17       0.1
# tew                   4.3        37         0         0         0         0      0.13     0.085
# rew                   2.9        33         0         0         0         0      0.17      0.12
# ndvi_alpha          3e-14         0         0         0         1         5       2.6       2.6
# ndvi_beta               0         0         4        20         0         0       1.4       1.4
# mad                     0         0         1         5         0         0      0.54      0.54
#     Note: parameter change summary sorted according to abs 'mean change'.
#     Note: the parameter change statistics implicitly include the effect of
#           realizations that have failed or have been dropped.
#
# ...saved parameter change summary to /home/dgketchum/PycharmProjects/swim-rs/tutorials/2_Fort_Peck/pest/2_Fort_Peck.1.pcs.csv
#
#   ---  phi-based termination criteria check  ---
# ...phiredstp:  0.01
# ...nphistp:  3
# ...nphinored (also used for consecutive bad lambda cycles):  3
# ...best mean phi sequence: 370136 , 1655.81 ,
# ...best phi yet:  1655.81
# ...number of consecutive bad lambda testing cycles:  0
# ...number of iterations satisfying phiredstp criteria:  1
# ...number of iterations since best yet mean phi:  0
#
#   ---  starting solve for iteration: 2  ---
# ...current lambda:  0.75
# ...preparing fast-lookup containers for threaded localization solve
# ...starting calcs for glm factor 0.075
# ...finished calcs for: 0.075
# ...starting calcs for glm factor 0.75
# ...finished calcs for: 0.75
# ...starting calcs for glm factor 7.5
# ...finished calcs for: 7.5
#
#   ---  running upgrade ensembles  ---
# ...subset idx:pe real name:  2:5, 3:BASE, 10:9, 15:14,
# ...subset idx:oe real name:  2:5, 3:BASE, 10:9, 15:14,
#     running model 36 times
#     starting at 01/27/25 14:11:28
#     1 agents ready
#
#
# PANTHER progress
#    avg = average model run time in minutes
#    runs(C = completed | F = failed | T = timed out)
#    agents(R = running | W = waiting | U = unavailable)
# --------------------------------------------------------------------------------
# 01/27 14:18:46 mn:0.2   runs(C36   |F0    |T0    ) agents(R0   |W1   |U0   ) 0
#
#    36 runs complete :  0 runs failed
#    0.198 avg run time (min) : 7.3 run mgr time (min)
#    1 agents connected
#
#
#
#   ---  evaluating upgrade ensembles  ---
# ...last mean:  1655.81
# ...last stdev:  361.925
#
#   ---  phi summary for best lambda, scale fac: 0.075 , 1.1 ,   ---
#        phi type           mean            std            min            max
#        measured        1320.26        803.576        116.074        1771.67
#          actual         126.75        17.1692        109.451        147.056
#      note: 'measured' phi reported above includes
#            realizations of measurement noise,
#            'actual' phi does not.
#
#   ---  running remaining realizations for best lambda, scale:0.075 , 1.1 ,   ---
#     running model 16 times
#     starting at 01/27/25 14:18:47
#     1 agents ready
#
#
# PANTHER progress
#    avg = average model run time in minutes
#    runs(C = completed | F = failed | T = timed out)
#    agents(R = running | W = waiting | U = unavailable)
# --------------------------------------------------------------------------------
# 01/27 14:22:02 mn:0.2   runs(C16   |F0    |T0    ) agents(R0   |W1   |U0   ) 0
#
#    16 runs complete :  0 runs failed
#    0.198 avg run time (min) : 3.25 run mgr time (min)
#    1 agents connected
#
#
# ...phi summary for entire ensemble using lambda,scale_fac 0.075 , 1.1 ,
#        phi type           mean            std            min            max
#        measured        1629.94         360.03        116.074        1823.65
#          actual        123.557        13.1901        98.9021        147.056
#      note: 'measured' phi reported above includes
#            realizations of measurement noise,
#            'actual' phi does not.
# ...last best mean phi * acceptable phi factor:  1738.6
# ...current best mean phi:  1629.94
#
#   ---  updating parameter ensemble  ---
#
#   ---  updating lambda to  0.05625  ---
#
#   ---  EnsembleMethod iteration 2 report  ---
#    number of active realizations:   20
#    number of model runs:            124
#       current obs ensemble saved to /home/dgketchum/PycharmProjects/swim-rs/tutorials/2_Fort_Peck/pest/2_Fort_Peck.2.obs.csv
#       current par ensemble saved to /home/dgketchum/PycharmProjects/swim-rs/tutorials/2_Fort_Peck/pest/2_Fort_Peck.2.par.csv
# saved par and rei files for realization BASE for iteration 2
# saved par and rei files for realization BASE
#        phi type           mean            std            min            max
#        measured        1629.94         360.03        116.074        1823.65
#          actual        123.557        13.1901        98.9021        147.056
#      note: 'measured' phi reported above includes
#            realizations of measurement noise,
#            'actual' phi does not.
#   ---  observation group phi summary ---
#        (computed using 'actual' phi)
#            (sorted by mean phi)
# group                                       mean       std       min       max   percent       std
# oname:obs/obs_swe_us-fpe.np_otype:arr       75.4      1.26      72.7      78.4      61.7      6.69
# oname:obs/obs_etf_us-fpe.np_otype:arr       48.1      13.2      22.8      68.6      38.3      6.69
#     Note: 'percent' is the percentage of the actual phi for each realization.
#
#
#    ---  parameter group change summmary  ---
# group            mean chg   std chg n at ubnd % at ubnd n at lbnd % at lbnd   init CV   curr CV
# swe_alpha         4.4e+02        88         0         0         0         0       2.2      0.05
# snow_beta         1.8e+02        76         0         0         1         5      0.96       0.3
# aw                     21        44         7        35         0         0      0.17      0.08
# rew                    10        38         0         0         0         0      0.17      0.12
# tew                     9        49         0         0         0         0      0.13     0.071
# ndvi_beta               0   2.4e-14         4        20         0         0       1.4       1.4
# ndvi_alpha              0         0         0         0         1         5       2.6       2.6
# mad                     0         0         1         5         0         0      0.54      0.54
#     Note: parameter change summary sorted according to abs 'mean change'.
#     Note: the parameter change statistics implicitly include the effect of
#           realizations that have failed or have been dropped.
#
# ...saved parameter change summary to /home/dgketchum/PycharmProjects/swim-rs/tutorials/2_Fort_Peck/pest/2_Fort_Peck.2.pcs.csv
#
#   ---  phi-based termination criteria check  ---
# ...phiredstp:  0.01
# ...nphistp:  3
# ...nphinored (also used for consecutive bad lambda cycles):  3
# ...best mean phi sequence: 370136 , 1655.81 , 1629.94 ,
# ...best phi yet:  1629.94
# ...number of consecutive bad lambda testing cycles:  0
# ...number of iterations satisfying phiredstp criteria:  1
# ...number of iterations since best yet mean phi:  0
#
#   ---  starting solve for iteration: 3  ---
# ...current lambda:  0.05625
# ...preparing fast-lookup containers for threaded localization solve
# ...starting calcs for glm factor 0.005625
# ...finished calcs for: 0.005625
# ...starting calcs for glm factor 0.05625
# ...finished calcs for: 0.05625
# ...starting calcs for glm factor 0.5625
# ...finished calcs for: 0.5625
#
#   ---  running upgrade ensembles  ---
# ...subset idx:pe real name:  1:BASE, 5:2, 13:11, 16:15,
# ...subset idx:oe real name:  1:BASE, 5:2, 13:11, 16:15,
#     running model 36 times
#     starting at 01/27/25 14:22:03
#     1 agents ready
#
#
# PANTHER progress
#    avg = average model run time in minutes
#    runs(C = completed | F = failed | T = timed out)
#    agents(R = running | W = waiting | U = unavailable)
# --------------------------------------------------------------------------------
# 01/27 14:29:19 mn:0.2   runs(C36   |F0    |T0    ) agents(R0   |W1   |U0   ) 0
#
#    36 runs complete :  0 runs failed
#    0.202 avg run time (min) : 7.27 run mgr time (min)
#    1 agents connected
#
#
#
#   ---  evaluating upgrade ensembles  ---
# ...last mean:  1629.94
# ...last stdev:  360.03
#
#   ---  phi summary for best lambda, scale fac: 0.005625 , 1.1 ,   ---
#        phi type           mean            std            min            max
#        measured        1299.28        789.443        115.118        1696.69
#          actual        123.923        13.0071        115.118        142.781
#      note: 'measured' phi reported above includes
#            realizations of measurement noise,
#            'actual' phi does not.
#
#   ---  running remaining realizations for best lambda, scale:0.005625 , 1.1 ,   ---
#     running model 16 times
#     starting at 01/27/25 14:29:21
#     1 agents ready
#
#
# PANTHER progress
#    avg = average model run time in minutes
#    runs(C = completed | F = failed | T = timed out)
#    agents(R = running | W = waiting | U = unavailable)
# --------------------------------------------------------------------------------
# 01/27 14:32:36 mn:0.2   runs(C16   |F0    |T0    ) agents(R0   |W1   |U0   ) 0
#
#    16 runs complete :  0 runs failed
#    0.199 avg run time (min) : 3.25 run mgr time (min)
#    1 agents connected
#
#
# ...phi summary for entire ensemble using lambda,scale_fac 0.005625 , 1.1 ,
#        phi type           mean            std            min            max
#        measured        1628.95        360.014        115.118        1822.96
#          actual        122.577        13.6302        98.2255        143.469
#      note: 'measured' phi reported above includes
#            realizations of measurement noise,
#            'actual' phi does not.
# ...last best mean phi * acceptable phi factor:  1711.43
# ...current best mean phi:  1628.95
#
#   ---  updating parameter ensemble  ---
#
#   ---  updating lambda to  0.00421875  ---
#
#   ---  EnsembleMethod iteration 3 report  ---
#    number of active realizations:   20
#    number of model runs:            176
#       current obs ensemble saved to /home/dgketchum/PycharmProjects/swim-rs/tutorials/2_Fort_Peck/pest/2_Fort_Peck.3.obs.csv
#       current par ensemble saved to /home/dgketchum/PycharmProjects/swim-rs/tutorials/2_Fort_Peck/pest/2_Fort_Peck.3.par.csv
# saved par and rei files for realization BASE for iteration 3
# saved par and rei files for realization BASE
#        phi type           mean            std            min            max
#        measured        1628.95        360.014        115.118        1822.96
#          actual        122.577        13.6302        98.2255        143.469
#      note: 'measured' phi reported above includes
#            realizations of measurement noise,
#            'actual' phi does not.
#   ---  observation group phi summary ---
#        (computed using 'actual' phi)
#            (sorted by mean phi)
# group                                       mean       std       min       max   percent       std
# oname:obs/obs_swe_us-fpe.np_otype:arr       74.8      1.01      72.3      76.5      61.7      6.98
# oname:obs/obs_etf_us-fpe.np_otype:arr       47.8      13.7      22.8      69.5      38.3      6.98
#     Note: 'percent' is the percentage of the actual phi for each realization.
#
#
#    ---  parameter group change summmary  ---
# group            mean chg   std chg n at ubnd % at ubnd n at lbnd % at lbnd   init CV   curr CV
# swe_alpha         4.5e+02        88         3        15         0         0       2.2     0.047
# snow_beta         1.8e+02        77         0         0         1         5      0.96      0.29
# aw                     23        53         8        40         0         0      0.17     0.065
# rew                    13        41         0         0         1         5      0.17      0.12
# tew                    11        55         0         0         0         0      0.13     0.065
# mad               1.7e-14   1.6e-14         1         5         0         0      0.54      0.54
# ndvi_beta               0         0         4        20         0         0       1.4       1.4
# ndvi_alpha              0         0         0         0         1         5       2.6       2.6
#     Note: parameter change summary sorted according to abs 'mean change'.
#     Note: the parameter change statistics implicitly include the effect of
#           realizations that have failed or have been dropped.
#
# ...saved parameter change summary to /home/dgketchum/PycharmProjects/swim-rs/tutorials/2_Fort_Peck/pest/2_Fort_Peck.3.pcs.csv
#
#   ---  phi-based termination criteria check  ---
# ...phiredstp:  0.01
# ...nphistp:  3
# ...nphinored (also used for consecutive bad lambda cycles):  3
# ...best mean phi sequence: 370136 , 1655.81 , 1629.94 , 1628.95 ,
# ...best phi yet:  1628.95
# ...number of consecutive bad lambda testing cycles:  0
# ...number of iterations satisfying phiredstp criteria:  2
# ...number of iterations since best yet mean phi:  0
#
#
# pestpp-ies analysis complete...
# started at 01/27/25 13:56:35
# finished at 01/27/25 14:32:40
# took 36.0833 minutes

# %% [markdown]
# Make sure these exist. There is a parameter file for each optimization run, the intial '0' run, and the three optimization runs we specified with `noptmax`. Each file has a row for each realization, with columns having a parameter value for each tunable parameter. This is the valuable data we will examine in the next step.

# %% [markdown]
# This workflow benefits from a powerful machine; the higher number of workers you can employ, the faster the otpimization will run.
