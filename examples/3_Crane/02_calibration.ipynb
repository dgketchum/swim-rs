# %% [markdown]
# # Calibration Tutorial - Crane, OR - Irrigated Flux Plot
#
# ## Step 2: Calibrate with PEST++
#
# Now we see if we can improve the model's performance through calibration.
#
# ### PEST++ Resources
#
# PEST++ has excellent documentation covering both theory and practice:
#
# 1. **The PEST Manual 4th Ed.** (Doherty, 2002): https://www.epa.gov/sites/default/files/documents/PESTMAN.PDF
# 2. **GMDSI tutorial notebooks**: https://github.com/gmdsi/GMDSI_notebooks
# 3. **PEST++ User's Manual**: https://github.com/usgs/pestpp/blob/master/documentation/pestpp_users_manual.md
# 4. **PEST Book** (Doherty, 2015): https://pesthomepage.org/pest-book
#
# **Note:** We use SSEBop ETf and SNODAS SWE for calibration - these are widely available remote sensing products.

# %% [markdown]
# ### PEST++ Installation
#
# Install PEST++ via conda-forge (recommended):
#
# ```bash
# conda install conda-forge::pestpp
# ```
#
# This installs `pestpp-ies` and other PEST++ tools directly into your conda environment. Verify the installation:
#
# ```bash
# pestpp-ies --version
# ```
#
# **Alternative:** For manual installation from source, see the [PEST++ GitHub releases](https://github.com/usgs/pestpp/releases).

# %%
import os
import sys

root = os.path.abspath('../..')
sys.path.append(root)

from swimrs.container import SwimContainer
from swimrs.calibrate.pest_builder import PestBuilder
from swimrs.swim.config import ProjectConfig
from swimrs.calibrate.run_pest import run_pst
# Out:
# /home/dgketchum/miniconda/envs/swim/lib/python3.11/site-packages/pyemu/__init__.py:37: UserWarning: Failed to import legacy module. May impact ability to access older methods.ModuleNotFoundError No module named 'flopy'

# %% [markdown]
# ## 1. Load Configuration
#
# Load the project configuration and prepare paths.

# %%
project = '3_Crane'
project_ws = os.path.abspath('.')

config_path = os.path.join(project_ws, '3_Crane.toml')

config = ProjectConfig()
config.read_config(config_path, project_ws)

# %% [markdown]
# ## 2. Generate Observation Files
#
# PEST++ needs observation files (ETf and SWE) to compare against model predictions. We export these from the SwimContainer built in the data preparation step.
#
# The export creates per-field numpy files:
# - `obs_etf_{field_id}.np`: ETf observations with irrigation mask switching
# - `obs_swe_{field_id}.np`: SWE observations from SNODAS

# %%
# Open container for observations export and PEST++ setup
container_path = os.path.join(project_ws, 'data', f'{project}.swim')
container = SwimContainer.open(container_path, mode='r')

# Export observation files for PEST++ calibration
# Note: obs_folder is set to {pest_run_dir}/obs in the TOML config
obs_dir = os.path.join(project_ws, 'data', 'pestrun', 'obs')
os.makedirs(obs_dir, exist_ok=True)

container.export.observations(
    output_dir=obs_dir,
    etf_model='ssebop',
    masks=('irr', 'inv_irr'),
    irr_threshold=0.1,
)
print(f"Observation files written to {obs_dir}")
# Out:
# Observation files written to /home/dgketchum/code/swim-rs/examples/3_Crane/data/pestrun/obs

# %% [markdown]
# ## 3. Build PEST++ Control Files
#
# The `PestBuilder` class sets up everything needed for PEST++ calibration:
#
# ### Calibration Loop
# 1. Initialize model with initial parameter values
# 2. Run model, write results
# 3. Compare results to observations (ETf, SWE)
# 4. Propose new parameters
# 5. Repeat until convergence
#
# ### Tunable Parameters
# SWIM uses 8 tunable parameters:
# - **Soil water:** `aw` (available water), `rew` (readily evaporable water), `tew` (total evaporable water)
# - **NDVI-Kcb relationship:** `ndvi_alpha`, `ndvi_beta`
# - **Stress threshold:** `mad` (management allowable depletion)
# - **Snow melt:** `swe_alpha`, `swe_beta`

# %%
# PestBuilder auto-generates custom_forward_run.py using the process package
# with portable swim_input.h5 file for fully self-contained workers
builder = PestBuilder(config, container=container, use_existing=False)
# Out:
# Using default Python script at: /home/dgketchum/code/swim-rs/src/swimrs/calibrate/custom_forward_run.py

# %% [markdown]
# ### Build the .pst Control File
#
# The `build_pest()` method:
# - Copies project files to a `pest/` directory
# - Creates the `.pst` control file
# - Sets up parameter templates (`.tpl`) and instruction files (`.ins`)
#
# **Note:** ETf observations are sparse (only on satellite capture dates). The PEST builder automatically assigns weight 1.0 to valid observations and weight 0.0 to missing dates, ensuring we only calibrate against actual satellite captures.

# %%
# Build the pest control file
# WARNING: This will erase any existing pest directory!
builder.build_pest(target_etf=config.etf_target_model, members=config.etf_ensemble_members)
# Out:
# 2026-01-19 00:09:19.243224 starting: opening PstFrom.log for logging
# 2026-01-19 00:09:19.243654 starting PstFrom process
# 2026-01-19 00:09:19.243788 starting: setting up dirs
# 2026-01-19 00:09:19.243957 starting: removing existing new_d '/home/dgketchum/code/swim-rs/examples/3_Crane/data/pestrun/pest'
# 2026-01-19 00:09:19.255835 finished: removing existing new_d '/home/dgketchum/code/swim-rs/examples/3_Crane/data/pestrun/pest' took: 0:00:00.011878
# 2026-01-19 00:09:19.255917 starting: copying original_d '/home/dgketchum/code/swim-rs/examples/3_Crane/data/pestrun/_template' to new_d '/home/dgketchum/code/swim-rs/examples/3_Crane/data/pestrun/pest'
# 2026-01-19 00:09:19.257338 finished: copying original_d '/home/dgketchum/code/swim-rs/examples/3_Crane/data/pestrun/_template' to new_d '/home/dgketchum/code/swim-rs/examples/3_Crane/data/pestrun/pest' took: 0:00:00.001421
# 2026-01-19 00:09:19.257629 finished: setting up dirs took: 0:00:00.013841
# 2026-01-19 00:09:19.257831 starting: adding constant type m style parameters for file(s) ['params.csv']
# 2026-01-19 00:09:19.257987 starting: loading list-style /home/dgketchum/code/swim-rs/examples/3_Crane/data/pestrun/pest/params.csv
# 2026-01-19 00:09:19.258081 starting: reading list-style file: /home/dgketchum/code/swim-rs/examples/3_Crane/data/pestrun/pest/params.csv
# 2026-01-19 00:09:19.260466 finished: reading list-style file: /home/dgketchum/code/swim-rs/examples/3_Crane/data/pestrun/pest/params.csv took: 0:00:00.002385
# 2026-01-19 00:09:19.260750 loaded list-style '/home/dgketchum/code/swim-rs/examples/3_Crane/data/pestrun/pest/params.csv' of shape (9, 3)
# 2026-01-19 00:09:19.263608 finished: loading list-style /home/dgketchum/code/swim-rs/examples/3_Crane/data/pestrun/pest/params.csv took: 0:00:00.005621
# 2026-01-19 00:09:19.263788 starting: writing list-style template file '/home/dgketchum/code/swim-rs/examples/3_Crane/data/pestrun/pest/p_aw_S2_0_constant.csv.tpl'
# 2026-01-19 00:09:19.276588 finished: writing list-style template file '/home/dgketchum/code/swim-rs/examples/3_Crane/data/pestrun/pest/p_aw_S2_0_constant.csv.tpl' took: 0:00:00.012800
# 2026-01-19 00:09:19.280068 finished: adding constant type m style parameters for file(s) ['params.csv'] took: 0:00:00.022237
# 2026-01-19 00:09:19.280584 starting: adding constant type m style parameters for file(s) ['params.csv']
# 2026-01-19 00:09:19.280714 starting: loading list-style /home/dgketchum/code/swim-rs/examples/3_Crane/data/pestrun/pest/params.csv
# 2026-01-19 00:09:19.280778 starting: reading list-style file: /home/dgketchum/code/swim-rs/examples/3_Crane/data/pestrun/pest/params.csv
# 2026-01-19 00:09:19.282179 finished: reading list-style file: /home/dgketchum/code/swim-rs/examples/3_Crane/data/pestrun/pest/params.csv took: 0:00:00.001401
# 2026-01-19 00:09:19.282287 loaded list-style '/home/dgketchum/code/swim-rs/examples/3_Crane/data/pestrun/pest/params.csv' of shape (9, 3)
# 2026-01-19 00:09:19.283873 finished: loading list-style /home/dgketchum/code/swim-rs/examples/3_Crane/data/pestrun/pest/params.csv took: 0:00:00.003159
# 2026-01-19 00:09:19.283970 starting: writing list-style template file '/home/dgketchum/code/swim-rs/examples/3_Crane/data/pestrun/pest/p_ks_alpha_S2_0_constant.csv.tpl'
# 2026-01-19 00:09:19.292906 finished: writing list-style template file '/home/dgketchum/code/swim-rs/examples/3_Crane/data/pestrun/pest/p_ks_alpha_S2_0_constant.csv.tpl' took: 0:00:00.008936
# 2026-01-19 00:09:19.295931 finished: adding constant type m style parameters for file(s) ['params.csv'] took: 0:00:00.015347
# 2026-01-19 00:09:19.296041 starting: adding constant type m style parameters for file(s) ['params.csv']
# 2026-01-19 00:09:19.296117 starting: loading list-style /home/dgketchum/code/swim-rs/examples/3_Crane/data/pestrun/pest/params.csv
# 2026-01-19 00:09:19.296171 starting: reading list-style file: /home/dgketchum/code/swim-rs/examples/3_Crane/data/pestrun/pest/params.csv
# 2026-01-19 00:09:19.297083 finished: reading list-style file: /home/dgketchum/code/swim-rs/examples/3_Crane/data/pestrun/pest/params.csv took: 0:00:00.000912
# 2026-01-19 00:09:19.297177 loaded list-style '/home/dgketchum/code/swim-rs/examples/3_Crane/data/pestrun/pest/params.csv' of shape (9, 3)
# 2026-01-19 00:09:19.298420 finished: loading list-style /home/dgketchum/code/swim-rs/examples/3_Crane/data/pestrun/pest/params.csv took: 0:00:00.002303
# 2026-01-19 00:09:19.298514 starting: writing list-style template file '/home/dgketchum/code/swim-rs/examples/3_Crane/data/pestrun/pest/p_kr_alpha_S2_0_constant.csv.tpl'
# 2026-01-19 00:09:19.305932 finished: writing list-style template file '/home/dgketchum/code/swim-rs/examples/3_Crane/data/pestrun/pest/p_kr_alpha_S2_0_constant.csv.tpl' took: 0:00:00.007418
# 2026-01-19 00:09:19.308809 finished: adding constant type m style parameters for file(s) ['params.csv'] took: 0:00:00.012768
# 2026-01-19 00:09:19.308930 starting: adding constant type m style parameters for file(s) ['params.csv']
# 2026-01-19 00:09:19.309006 starting: loading list-style /home/dgketchum/code/swim-rs/examples/3_Crane/data/pestrun/pest/params.csv
# 2026-01-19 00:09:19.309059 starting: reading list-style file: /home/dgketchum/code/swim-rs/examples/3_Crane/data/pestrun/pest/params.csv
# 2026-01-19 00:09:19.309908 finished: reading list-style file: /home/dgketchum/code/swim-rs/examples/3_Crane/data/pestrun/pest/params.csv took: 0:00:00.000849
# 2026-01-19 00:09:19.309988 loaded list-style '/home/dgketchum/code/swim-rs/examples/3_Crane/data/pestrun/pest/params.csv' of shape (9, 3)
# 2026-01-19 00:09:19.311166 finished: loading list-style /home/dgketchum/code/swim-rs/examples/3_Crane/data/pestrun/pest/params.csv took: 0:00:00.002160
# 2026-01-19 00:09:19.311268 starting: writing list-style template file '/home/dgketchum/code/swim-rs/examples/3_Crane/data/pestrun/pest/p_ndvi_k_S2_0_constant.csv.tpl'
# 2026-01-19 00:09:19.318914 finished: writing list-style template file '/home/dgketchum/code/swim-rs/examples/3_Crane/data/pestrun/pest/p_ndvi_k_S2_0_constant.csv.tpl' took: 0:00:00.007646
# 2026-01-19 00:09:19.321700 finished: adding constant type m style parameters for file(s) ['params.csv'] took: 0:00:00.012770
# 2026-01-19 00:09:19.321808 starting: adding constant type m style parameters for file(s) ['params.csv']
# 2026-01-19 00:09:19.321878 starting: loading list-style /home/dgketchum/code/swim-rs/examples/3_Crane/data/pestrun/pest/params.csv
# 2026-01-19 00:09:19.321926 starting: reading list-style file: /home/dgketchum/code/swim-rs/examples/3_Crane/data/pestrun/pest/params.csv
# 2026-01-19 00:09:19.322782 finished: reading list-style file: /home/dgketchum/code/swim-rs/examples/3_Crane/data/pestrun/pest/params.csv took: 0:00:00.000856
# 2026-01-19 00:09:19.322863 loaded list-style '/home/dgketchum/code/swim-rs/examples/3_Crane/data/pestrun/pest/params.csv' of shape (9, 3)
# 2026-01-19 00:09:19.324063 finished: loading list-style /home/dgketchum/code/swim-rs/examples/3_Crane/data/pestrun/pest/params.csv took: 0:00:00.002185
# 2026-01-19 00:09:19.324145 starting: writing list-style template file '/home/dgketchum/code/swim-rs/examples/3_Crane/data/pestrun/pest/p_ndvi_0_S2_0_constant.csv.tpl'
# 2026-01-19 00:09:19.331497 finished: writing list-style template file '/home/dgketchum/code/swim-rs/examples/3_Crane/data/pestrun/pest/p_ndvi_0_S2_0_constant.csv.tpl' took: 0:00:00.007352
# 2026-01-19 00:09:19.334211 finished: adding constant type m style parameters for file(s) ['params.csv'] took: 0:00:00.012403
# 2026-01-19 00:09:19.334314 starting: adding constant type m style parameters for file(s) ['params.csv']
# 2026-01-19 00:09:19.334382 starting: loading list-style /home/dgketchum/code/swim-rs/examples/3_Crane/data/pestrun/pest/params.csv
# 2026-01-19 00:09:19.334429 starting: reading list-style file: /home/dgketchum/code/swim-rs/examples/3_Crane/data/pestrun/pest/params.csv
# 2026-01-19 00:09:19.335243 finished: reading list-style file: /home/dgketchum/code/swim-rs/examples/3_Crane/data/pestrun/pest/params.csv took: 0:00:00.000814
# 2026-01-19 00:09:19.335320 loaded list-style '/home/dgketchum/code/swim-rs/examples/3_Crane/data/pestrun/pest/params.csv' of shape (9, 3)
# 2026-01-19 00:09:19.336426 finished: loading list-style /home/dgketchum/code/swim-rs/examples/3_Crane/data/pestrun/pest/params.csv took: 0:00:00.002044
# 2026-01-19 00:09:19.336513 starting: writing list-style template file '/home/dgketchum/code/swim-rs/examples/3_Crane/data/pestrun/pest/p_mad_S2_0_constant.csv.tpl'
# 2026-01-19 00:09:19.343680 finished: writing list-style template file '/home/dgketchum/code/swim-rs/examples/3_Crane/data/pestrun/pest/p_mad_S2_0_constant.csv.tpl' took: 0:00:00.007167
# 2026-01-19 00:09:19.346373 finished: adding constant type m style parameters for file(s) ['params.csv'] took: 0:00:00.012059
# 2026-01-19 00:09:19.346474 starting: adding constant type m style parameters for file(s) ['params.csv']
# 2026-01-19 00:09:19.346543 starting: loading list-style /home/dgketchum/code/swim-rs/examples/3_Crane/data/pestrun/pest/params.csv
# 2026-01-19 00:09:19.346591 starting: reading list-style file: /home/dgketchum/code/swim-rs/examples/3_Crane/data/pestrun/pest/params.csv
# 2026-01-19 00:09:19.347401 finished: reading list-style file: /home/dgketchum/code/swim-rs/examples/3_Crane/data/pestrun/pest/params.csv took: 0:00:00.000810
# 2026-01-19 00:09:19.347478 loaded list-style '/home/dgketchum/code/swim-rs/examples/3_Crane/data/pestrun/pest/params.csv' of shape (9, 3)
# 2026-01-19 00:09:19.348587 finished: loading list-style /home/dgketchum/code/swim-rs/examples/3_Crane/data/pestrun/pest/params.csv took: 0:00:00.002044
# 2026-01-19 00:09:19.348674 starting: writing list-style template file '/home/dgketchum/code/swim-rs/examples/3_Crane/data/pestrun/pest/p_swe_alpha_S2_0_constant.csv.tpl'
# 2026-01-19 00:09:19.355792 finished: writing list-style template file '/home/dgketchum/code/swim-rs/examples/3_Crane/data/pestrun/pest/p_swe_alpha_S2_0_constant.csv.tpl' took: 0:00:00.007118
# 2026-01-19 00:09:19.358614 finished: adding constant type m style parameters for file(s) ['params.csv'] took: 0:00:00.012140
# 2026-01-19 00:09:19.358732 starting: adding constant type m style parameters for file(s) ['params.csv']
# 2026-01-19 00:09:19.358822 starting: loading list-style /home/dgketchum/code/swim-rs/examples/3_Crane/data/pestrun/pest/params.csv
# 2026-01-19 00:09:19.358872 starting: reading list-style file: /home/dgketchum/code/swim-rs/examples/3_Crane/data/pestrun/pest/params.csv
# 2026-01-19 00:09:19.359756 finished: reading list-style file: /home/dgketchum/code/swim-rs/examples/3_Crane/data/pestrun/pest/params.csv took: 0:00:00.000884
# 2026-01-19 00:09:19.359834 loaded list-style '/home/dgketchum/code/swim-rs/examples/3_Crane/data/pestrun/pest/params.csv' of shape (9, 3)
# 2026-01-19 00:09:19.360941 finished: loading list-style /home/dgketchum/code/swim-rs/examples/3_Crane/data/pestrun/pest/params.csv took: 0:00:00.002119
# 2026-01-19 00:09:19.361021 starting: writing list-style template file '/home/dgketchum/code/swim-rs/examples/3_Crane/data/pestrun/pest/p_swe_beta_S2_0_constant.csv.tpl'
# 2026-01-19 00:09:19.368277 finished: writing list-style template file '/home/dgketchum/code/swim-rs/examples/3_Crane/data/pestrun/pest/p_swe_beta_S2_0_constant.csv.tpl' took: 0:00:00.007256
# 2026-01-19 00:09:19.371013 finished: adding constant type m style parameters for file(s) ['params.csv'] took: 0:00:00.012281
# 2026-01-19 00:09:19.767953 starting: adding observations from output file obs/obs_etf_S2.np
# 2026-01-19 00:09:19.768571 starting: adding observations from array output file 'obs/obs_etf_S2.np'
# 2026-01-19 00:09:19.794358 starting: adding observation from instruction file '/home/dgketchum/code/swim-rs/examples/3_Crane/data/pestrun/pest/etf_S2.ins'
# 2026-01-19 00:09:19.903952 finished: adding observation from instruction file '/home/dgketchum/code/swim-rs/examples/3_Crane/data/pestrun/pest/etf_S2.ins' took: 0:00:00.109594
# 2026-01-19 00:09:19.904765 finished: adding observations from array output file 'obs/obs_etf_S2.np' took: 0:00:00.136194
# 2026-01-19 00:09:19.904964 finished: adding observations from output file obs/obs_etf_S2.np took: 0:00:00.137011
# 2026-01-19 00:09:20.579702 starting: adding observations from output file obs/obs_swe_S2.np
# 2026-01-19 00:09:20.579835 starting: adding observations from array output file 'obs/obs_swe_S2.np'
# 2026-01-19 00:09:20.600594 starting: adding observation from instruction file '/home/dgketchum/code/swim-rs/examples/3_Crane/data/pestrun/pest/swe_S2.ins'
# 2026-01-19 00:09:20.707443 finished: adding observation from instruction file '/home/dgketchum/code/swim-rs/examples/3_Crane/data/pestrun/pest/swe_S2.ins' took: 0:00:00.106849
# 2026-01-19 00:09:20.708305 finished: adding observations from array output file 'obs/obs_swe_S2.np' took: 0:00:00.128470
# 2026-01-19 00:09:20.708490 finished: adding observations from output file obs/obs_swe_S2.np took: 0:00:00.128788
# noptmax:0, npar_adj:8, nnz_obs:1186
# Building portable swim_input.h5 with spinup state...
# Created swim_input.h5 at /home/dgketchum/code/swim-rs/examples/3_Crane/data/pestrun/pest/swim_input.h5
# noptmax:0, npar_adj:8, nnz_obs:1186
# Configured PEST++ for 1 targets,

# %%
# Show the files created in the pest directory
pest_files = [f for f in sorted(os.listdir(builder.pest_dir)) 
              if os.path.isfile(os.path.join(builder.pest_dir, f))]
print("Files in pest directory:")
for f in pest_files:
    print(f"  {f}")
# Out:
# Files in pest directory:
#   3_Crane.idx.csv
#   3_Crane.pst
#   3_crane.insfile_data.csv
#   3_crane.obs_data.csv
#   3_crane.par_data.csv
#   3_crane.pargp_data.csv
#   3_crane.tplfile_data.csv
#   custom_forward_run.py
#   etf_S2.ins
#   mult2model_info.csv
#   p_aw_S2_0_constant.csv.tpl
#   p_kr_alpha_S2_0_constant.csv.tpl
#   p_ks_alpha_S2_0_constant.csv.tpl
#   p_mad_S2_0_constant.csv.tpl
#   p_ndvi_0_S2_0_constant.csv.tpl
#   p_ndvi_k_S2_0_constant.csv.tpl
#   p_swe_alpha_S2_0_constant.csv.tpl
#   p_swe_beta_S2_0_constant.csv.tpl
#   params.csv
#   swe_S2.ins
#   swim_input.h5

# %% [markdown]
# ### Examine the .pst File
#
# The PEST++ version 2 control file is concise, delegating details to external files:

# %%
with open(builder.pst_file, 'r') as f:
    print(f.read())
# Out:
# pcf version=2
# * control data keyword
# pestmode                                 estimation
# noptmax                                 0
# svdmode                                 1
# maxsing                          10000000
# eigthresh                           1e-06
# eigwrite                                1
# * parameter groups external
# 3_crane.pargp_data.csv
# * parameter data external
# 3_crane.par_data.csv
# * observation data external
# 3_crane.obs_data.csv
# * model command line
# python custom_forward_run.py
# * model input external
# 3_crane.tplfile_data.csv
# * model output external
# 3_crane.insfile_data.csv

# %% [markdown]
# ## 4. Configure and Test
#
# Now we:
# 1. Build the localizer matrix (links parameters to relevant observations)
# 2. Run spinup to save initial water balance state
# 3. Do a dry run to verify everything works
# 4. Set control parameters for the full calibration

# %%
# Build localizer matrix
# - SWE observations update only swe_alpha and swe_beta
# - ETf observations update all other parameters
builder.build_localizer()

# Run spinup to save water balance state as initial conditions for calibration runs
# This runs the model once and saves the final state to spinup.json
print("Running spinup...")
builder.spinup(overwrite=True)

# Run a minimal model run to verify the setup
print("\nRunning dry run...")
builder.dry_run()

# Configure for 3 optimization iterations with 20 realizations each
# Increase realizations (e.g., 100-200) for production runs
builder.write_control_settings(noptmax=3, reals=20)
# Out:
# noptmax:0, npar_adj:8, nnz_obs:1186
# Running spinup...
# RUNNING SPINUP
# Spinup saved to /home/dgketchum/code/swim-rs/examples/3_Crane/data/pestrun/spinup.json
#
# Running dry run...
# noptmax:3, npar_adj:8, nnz_obs:1186
# writing /home/dgketchum/code/swim-rs/examples/3_Crane/data/pestrun/pest/3_Crane.pst with noptmax=3, 20 realizations

# %%
# Show the updated control file with calibration settings
with open(builder.pst_file, 'r') as f:
    print(f.read())
# Out:
# pcf version=2
# * control data keyword
# pestmode                                 estimation
# noptmax                                 3
# svdmode                                 1
# maxsing                          10000000
# eigthresh                           1e-06
# eigwrite                                1
# ies_localizer                  loc.mat
# ies_num_reals                  20
# ies_drop_conflicts             true
# * parameter groups external
# 3_crane.pargp_data.csv
# * parameter data external
# 3_crane.par_data.csv
# * observation data external
# 3_crane.obs_data.csv
# * model command line
# python custom_forward_run.py
# * model input external
# 3_crane.tplfile_data.csv
# * model output external
# 3_crane.insfile_data.csv

# %% [markdown]
# ## 5. Run PEST++ Calibration
#
# Now we launch PEST++ with parallel workers. Adjust `workers` to match your machine's capabilities.
#
# **Important:** This can take a while. Watch for the progress indicator.

# %%
workers = config.workers or 6
_pst = f"{config.project_name}.pst"

print(f"Starting PEST++ with {workers} workers...")
print(f"Control file: {_pst}")

run_pst(builder.pest_dir,
        'pestpp-ies',
        _pst,
        num_workers=workers,
        worker_root=builder.workers_dir,
        master_dir=builder.master_dir,
        cleanup=True,
        verbose=True)
# Out:
# Starting PEST++ with 6 workers...
# Control file: 3_Crane.pst
# master:pestpp-ies 3_Crane.pst /h :5005 in /home/dgketchum/code/swim-rs/examples/3_Crane/data/pestrun/master
#
#
#              pestpp-ies: a GLM iterative ensemble smoother
#
#                    by the PEST++ development team
#
# ...processing command line: ' pestpp-ies 3_Crane.pst /h :5005'
# ...using panther run manager in master mode using port 5005
#
#
# version: 5.2.25
# binary compiled on Jan 13 2026 at 20:33:04
# using control file: "3_Crane.pst"
# in directory: "/home/dgketchum/code/swim-rs/examples/3_Crane/data/pestrun/master"
# on host: "fcfc-mcozoran"
# on a(n) linux operating system
# with release configuration
# started at 01/19/26 00:09:27
#
# processing control file 3_Crane.pst
#
#
# :~-._                                                 _.-~:
# : :.~^o._        ________---------________        _.o^~.:.:
#  : ::.`?88booo~~~.::::::::...::::::::::::..~~oood88P'.::.:
#  :  ::: `?88P .:::....         ........:::::. ?88P' :::. :
#   :  :::. `? .::.            . ...........:::. P' .:::. :
#    :  :::   ... ..  ...       .. .::::......::.   :::. :
#    `  :' .... ..  .:::::.     . ..:::::::....:::.  `: .'
#     :..    ____:::::::::.  . . ....:::::::::____  ... :
#    :... `:~    ^~-:::::..  .........:::::-~^    ~::.::::
#    `.::. `\   (8)  \b:::..::.:.:::::::d/  (8)   /'.::::'
#     ::::.  ~-._v    |b.::::::::::::::d|    v_.-~..:::::
#     `.:::::... ~~^?888b..:::::::::::d888P^~...::::::::'
#      `.::::::::::....~~~ .:::::::::~~~:::::::::::::::'
#       `..:::::::::::   .   ....::::    ::::::::::::,'
#         `. .:::::::    .      .::::.    ::::::::'.'
#           `._ .:::    .        :::::.    :::::_.'
#              `-. :    .        :::::      :,-'
#                 :.   :___     .:::___   .::
#       ..--~~~~--:+::. ~~^?b..:::dP^~~.::++:--~~~~--..
#         ___....--`+:::.    `~8~'    .:::+'--....___
#       ~~   __..---`_=:: ___gd8bg___ :==_'---..__   ~~
#        -~~~  _.--~~`-.~~~~~~~~~~~~~~~,-' ~~--._ ~~~-
#
#
#                starting PANTHER master...
#
# IP addresses:
#   0.0.0.0:5005 (IPv4)
#
# PANTHER master listening on socket: 0.0.0.0:5005 (IPv4)
#
#   ---  initializing  ---
# ...using glm algorithm
# ...using REDSVD for truncated svd solve
# ...maxsing: 10000000
# ...eigthresh:  1e-06
# ...initializing localizer
# ...using localized solution with 2 sequential upgrade steps
# ...localizing by parameters
# ...using lambda multipliers: 0.1 , 1 , 10 ,
# ...using lambda scaling factors: 0.75 , 1 , 1.1 ,
# ...acceptable phi factor:  1.05
# ...lambda increase factor:  10
# ...lambda decrease factor:  0.75
# ...max run fail:  1
# ...initializing prior parameter covariance matrix
# ...parcov loaded  from parameter bounds, using par_sigma_range 4
# ...initializing observation noise covariance matrix
# worker:pestpp-ies 3_Crane.pst /h localhost:5005 in /home/dgketchum/code/swim-rs/examples/3_Crane/data/pestrun/workers/worker_0
# worker:pestpp-ies 3_Crane.pst /h localhost:5005 in /home/dgketchum/code/swim-rs/examples/3_Crane/data/pestrun/workers/worker_1
# worker:pestpp-ies 3_Crane.pst /h localhost:5005 in /home/dgketchum/code/swim-rs/examples/3_Crane/data/pestrun/workers/worker_2
# ...obscov loaded  from observation weights
# worker:pestpp-ies 3_Crane.pst /h localhost:5005 in /home/dgketchum/code/swim-rs/examples/3_Crane/data/pestrun/workers/worker_3
# ...drawing parameter realizations:  20
# ...not using prior parameter covariance matrix scaling
# worker:pestpp-ies 3_Crane.pst /h localhost:5005 in /home/dgketchum/code/swim-rs/examples/3_Crane/data/pestrun/workers/worker_4
# worker:pestpp-ies 3_Crane.pst /h localhost:5005 in /home/dgketchum/code/swim-rs/examples/3_Crane/data/pestrun/workers/worker_5
# ...drawing observation noise realizations:  20
# observations not grouped by observations groups, reordering obs ensemble
# ...setting weights ensemble from control file weights
# ...saved weight ensemble to  3_Crane.weights.csv
# ...adding 'base' parameter values to ensemble
# ...adding 'base' observation values to ensemble
# ...adding 'base' weight values to weight ensemble
# ...saved initial parameter ensemble to  3_Crane.0.par.csv
# ...saved obs+noise observation ensemble (obsval + noise realizations) to  3_Crane.obs+noise.csv
# ...using subset in lambda testing, percentage of realizations used in subset testing:  10
# ...subset how:  RANDOM
# ...centering on ensemble mean vector
# ...running initial ensemble of size 20
#     running model 20 times
#     starting at 01/19/26 00:09:29
#
#     waiting for agents to appear...
#
#
# PANTHER progress
#    avg = average model run time in minutes
#    runs(C = completed | F = failed | T = timed out)
#    agents(R = running | W = waiting | U = unavailable)
# --------------------------------------------------------------------------------
# 01/19 00:09:42 remaining file transfers: 0|T0    ) agents(R2   |W4   |U0   ) 0
#
#    20 runs complete :  0 runs failed
#    0.0524 avg run time (min) : 0.215 run mgr time (min)
#    6 agents connected
#
#
# ...saved initial obs ensemble to 3_Crane.0.obs.csv
# saved par and rei files for realization BASE for iteration 0
# saved par and rei files for realization BASE
#
#   ---  pre-drop initial phi summary  ---
#        phi type           mean            std            min            max
#        measured          218.4        669.272       0.596156        2179.58
#          actual        218.321        669.116       0.563348        2179.51
#      note: 'measured' phi reported above includes
#            realizations of measurement noise,
#            'actual' phi does not.
#   ---  observation group phi summary ---
#        (computed using 'actual' phi)
#            (sorted by mean phi)
# group                               count  nconflict      mean       std       min       max   percent       std
# oname:obs/obs_swe_s2.np_otype:arr    1186         11       218       669     0.563  2.18e+03       100  1.85e-13
#
# ...checking for prior-data conflict
#
#   ---  WARNING: 11 non-zero weighted observations are in conflict with the prior simulated ensemble.
#   ---
# ...see 3_Crane.0.pdc.csv for listing of conflicted observations
#
# ...dropping conflicted observations
# ...number of non-zero weighted observations reduced from 1186 to 1175
#
# ...updating localizer
# dropped 11 from localizer rows because forgive_missing is true
# ...saved adjusted weight ensemble to  3_Crane.adjusted.weights.csv
# saved par and rei files for realization BASE for iteration 0
# saved par and rei files for realization BASE
#
#   ---  initial phi summary  ---
#        phi type           mean            std            min            max
#        measured        216.814         664.42       0.582047        2163.75
#          actual        216.735         664.26       0.548536        2163.67
#      note: 'measured' phi reported above includes
#            realizations of measurement noise,
#            'actual' phi does not.
#   ---  observation group phi summary ---
#        (computed using 'actual' phi)
#            (sorted by mean phi)
# group                               count  nconflict      mean       std       min       max   percent       std
# oname:obs/obs_swe_s2.np_otype:arr    1175          0       217       664     0.549  2.16e+03       100  1.85e-13
#
# ...current lambda: 0.01
#
#    ---  parameter group change summary  ---
# group     count  mean chg  std chg  n at ubnd  % at ubnd  n at lbnd  % at lbnd  n std decr
# aw            1         0        0          0          0         12         60           0
# mad           1         0        0          0          0          9         45           0
# swe_beta      1         0        0          4         20          0          0           0
# ndvi_0        1         0        0          4         20          0          0           0
# swe_alpha     1         0        0          2         10          0          0           0
# ndvi_k        1         0        0          1          5          0          0           0
# ks_alpha      1         0        0          0          0          0          0           0
# kr_alpha      1         0        0          0          0          0          0           0
#
#
#   ---  initialization complete  ---
#
#   ---  starting solve for iteration: 1  ---
# ...current lambda:  0.01
# ...preparing fast-lookup containers for threaded localization solve
# ...starting calcs for glm factor 0.001
# ...finished calcs for: 0.001
# ...starting calcs for glm factor 0.01
# ...finished calcs for: 0.01
# ...starting calcs for glm factor 0.1
# ...finished calcs for: 0.1
#
#   ---  running upgrade ensembles  ---
# ...subset idx:pe real name:  4:4, 11:11, 12:12, 19:BASE,
# ...subset idx:oe real name:  4:4, 11:11, 12:12, 19:BASE,
#     running model 36 times
#     starting at 01/19/26 00:09:44
#     6 agents ready
#
#
# PANTHER progress
#    avg = average model run time in minutes
#    runs(C = completed | F = failed | T = timed out)
#    agents(R = running | W = waiting | U = unavailable)
# --------------------------------------------------------------------------------
# 01/19 00:10:03 remaining file transfers: 0|T0    ) agents(R6   |W0   |U0   ) 0
#
#    36 runs complete :  0 runs failed
#    0.053 avg run time (min) : 0.323 run mgr time (min)
#    6 agents connected
#
#
#
#   ---  evaluating upgrade ensembles  ---
# ...last mean:  216.814
# ...last stdev:  664.42
#
#   ---  phi summary for best lambda, scale fac: 0.001 , 0.75 ,   ---
#        phi type           mean            std            min            max
#        measured        1.05986       0.302767       0.805036        1.49295
#          actual        1.03601       0.292116       0.805036        1.45966
#      note: 'measured' phi reported above includes
#            realizations of measurement noise,
#            'actual' phi does not.
#
#   ---  running remaining realizations for best lambda, scale:0.001 , 0.75 ,   ---
#     running model 16 times
#     starting at 01/19/26 00:10:05
#     6 agents ready
#
#
# PANTHER progress
#    avg = average model run time in minutes
#    runs(C = completed | F = failed | T = timed out)
#    agents(R = running | W = waiting | U = unavailable)
# --------------------------------------------------------------------------------
# 01/19 00:10:14 remaining file transfers: 0|T0    ) agents(R4   |W2   |U0   ) 0
#
#    16 runs complete :  0 runs failed
#    0.0521 avg run time (min) : 0.157 run mgr time (min)
#    6 agents connected
#
#
# ...phi summary for entire ensemble using lambda,scale_fac 0.001 , 0.75 ,
#        phi type           mean            std            min            max
#        measured       0.907856       0.263749       0.582395        1.49295
#          actual       0.880798       0.262886         0.5487        1.45966
#      note: 'measured' phi reported above includes
#            realizations of measurement noise,
#            'actual' phi does not.
# ...last best mean phi * acceptable phi factor:  227.655
# ...current best mean phi:  0.907856
#
#   ---  updating parameter ensemble  ---
#
#   ---  updating lambda to  0.00075  ---
#
#   ---  EnsembleMethod iteration 1 report  ---
#    number of active realizations:   20
#    number of model runs:            72
#       current obs ensemble saved to 3_Crane.1.obs.csv
#       current par ensemble saved to 3_Crane.1.par.csv
# saved par and rei files for realization BASE for iteration 1
# saved par and rei files for realization BASE
#        phi type           mean            std            min            max
#        measured       0.907856       0.263749       0.582395        1.49295
#          actual       0.880798       0.262886         0.5487        1.45966
#      note: 'measured' phi reported above includes
#            realizations of measurement noise,
#            'actual' phi does not.
#   ---  observation group phi summary ---
#        (computed using 'actual' phi)
#            (sorted by mean phi)
# group                               count  nconflict      mean       std       min       max   percent       std
# oname:obs/obs_swe_s2.np_otype:arr    1175        226     0.881     0.263     0.549      1.46       100  2.01e-13
#
#
#    ---  parameter group change summary  ---
# group     count  mean chg  std chg  n at ubnd  % at ubnd  n at lbnd  % at lbnd  n std decr
# aw            1 2.153e-14        0          0          0         12         60           0
# mad           1         0        0          0          0          9         45           0
# ndvi_0        1         0        0          4         20          0          0           0
# ndvi_k        1         0        0          1          5          0          0           0
# swe_beta      1   0.01439    1.407          0          0          0          0           0
# swe_alpha     1     10.64    20.88          0          0          0          0           0
# ks_alpha      1 1.362e-14        0          0          0          0          0           0
# kr_alpha      1         0        0          0          0          0          0           0
#
# ...saved parameter change summary to 3_Crane.1.pcs.csv
#
#   ---  phi-based termination criteria check  ---
# ...phiredstp:  0.01
# ...nphistp:  3
# ...nphinored (also used for consecutive bad lambda cycles):  3
# ...best mean phi sequence: 216.814 , 0.907856 ,
# ...best phi yet:  0.907856
# ...number of consecutive bad lambda testing cycles:  0
# ...number of iterations satisfying phiredstp criteria:  1
# ...number of iterations since best yet mean phi:  0
#
#   ---  starting solve for iteration: 2  ---
# ...current lambda:  0.00075
# ...preparing fast-lookup containers for threaded localization solve
# ...starting calcs for glm factor 7.5e-05
# ...finished calcs for: 7.5e-05
# ...starting calcs for glm factor 0.00075
# ...finished calcs for: 0.00075
# ...starting calcs for glm factor 0.0075
# ...finished calcs for: 0.0075
#
#   ---  running upgrade ensembles  ---
# ...subset idx:pe real name:  3:BASE, 16:15, 17:16, 19:18,
# ...subset idx:oe real name:  3:BASE, 16:15, 17:16, 19:18,
#     running model 36 times
#     starting at 01/19/26 00:10:16
#     6 agents ready
#
#
# PANTHER progress
#    avg = average model run time in minutes
#    runs(C = completed | F = failed | T = timed out)
#    agents(R = running | W = waiting | U = unavailable)
# --------------------------------------------------------------------------------
# 01/19 00:10:35 remaining file transfers: 0|T0    ) agents(R6   |W0   |U0   ) 0
#
#    36 runs complete :  0 runs failed
#    0.0529 avg run time (min) : 0.327 run mgr time (min)
#    6 agents connected
#
#
#
#   ---  evaluating upgrade ensembles  ---
# ...last mean:  0.907856
# ...last stdev:  0.263749
#
#   ---  phi summary for best lambda, scale fac: 7.5e-05 , 1.1 ,   ---
#        phi type           mean            std            min            max
#        measured       0.805054       0.280049       0.610432        1.21732
#          actual        0.78315       0.270942       0.591492         1.1782
#      note: 'measured' phi reported above includes
#            realizations of measurement noise,
#            'actual' phi does not.
#
#   ---  running remaining realizations for best lambda, scale:7.5e-05 , 1.1 ,   ---
#     running model 16 times
#     starting at 01/19/26 00:10:37
#     6 agents ready
#
#
# PANTHER progress
#    avg = average model run time in minutes
#    runs(C = completed | F = failed | T = timed out)
#    agents(R = running | W = waiting | U = unavailable)
# --------------------------------------------------------------------------------
# 01/19 00:10:47 remaining file transfers: 0|T0    ) agents(R4   |W2   |U0   ) 0
#
#    16 runs complete :  0 runs failed
#    0.0524 avg run time (min) : 0.161 run mgr time (min)
#    6 agents connected
#
#
# ...phi summary for entire ensemble using lambda,scale_fac 7.5e-05 , 1.1 ,
#        phi type           mean            std            min            max
#        measured       0.852674       0.260352        0.58786         1.4437
#          actual        0.82572       0.258984       0.553985        1.41012
#      note: 'measured' phi reported above includes
#            realizations of measurement noise,
#            'actual' phi does not.
# ...last best mean phi * acceptable phi factor:  0.953249
# ...current best mean phi:  0.852674
#
#   ---  updating parameter ensemble  ---
#
#   ---  updating lambda to  5.625e-05  ---
#
#   ---  EnsembleMethod iteration 2 report  ---
#    number of active realizations:   20
#    number of model runs:            124
#       current obs ensemble saved to 3_Crane.2.obs.csv
#       current par ensemble saved to 3_Crane.2.par.csv
# saved par and rei files for realization BASE for iteration 2
# saved par and rei files for realization BASE
#        phi type           mean            std            min            max
#        measured       0.852674       0.260352        0.58786         1.4437
#          actual        0.82572       0.258984       0.553985        1.41012
#      note: 'measured' phi reported above includes
#            realizations of measurement noise,
#            'actual' phi does not.
#   ---  observation group phi summary ---
#        (computed using 'actual' phi)
#            (sorted by mean phi)
# group                               count  nconflict      mean       std       min       max   percent       std
# oname:obs/obs_swe_s2.np_otype:arr    1175        262     0.826     0.259     0.554      1.41       100  2.19e-13
#
#
#    ---  parameter group change summary  ---
# group     count  mean chg  std chg  n at ubnd  % at ubnd  n at lbnd  % at lbnd  n std decr
# aw            1         0        0          0          0         12         60           0
# mad           1         0        0          0          0          9         45           0
# ndvi_0        1         0        0          4         20          0          0           0
# ndvi_k        1         0        0          1          5          0          0           0
# swe_beta      1     5.736    2.968          0          0          0          0           0
# swe_alpha     1     2.614    28.98          0          0          0          0           0
# ks_alpha      1         0        0          0          0          0          0           0
# kr_alpha      1         0        0          0          0          0          0           0
#
# ...saved parameter change summary to 3_Crane.2.pcs.csv
#
#   ---  phi-based termination criteria check  ---
# ...phiredstp:  0.01
# ...nphistp:  3
# ...nphinored (also used for consecutive bad lambda cycles):  3
# ...best mean phi sequence: 216.814 , 0.907856 , 0.852674 ,
# ...best phi yet:  0.852674
# ...number of consecutive bad lambda testing cycles:  0
# ...number of iterations satisfying phiredstp criteria:  1
# ...number of iterations since best yet mean phi:  0
#
#   ---  starting solve for iteration: 3  ---
# ...current lambda:  5.625e-05
# ...preparing fast-lookup containers for threaded localization solve
# ...starting calcs for glm factor 5.625e-06
# ...finished calcs for: 5.625e-06
# ...starting calcs for glm factor 5.625e-05
# ...finished calcs for: 5.625e-05
# ...starting calcs for glm factor 0.0005625
# ...finished calcs for: 0.0005625
#
#   ---  running upgrade ensembles  ---
# ...subset idx:pe real name:  0:BASE, 2:16, 9:2, 16:10,
# ...subset idx:oe real name:  0:BASE, 2:16, 9:2, 16:10,
#     running model 36 times
#     starting at 01/19/26 00:10:48
#     6 agents ready
#
#
# PANTHER progress
#    avg = average model run time in minutes
#    runs(C = completed | F = failed | T = timed out)
#    agents(R = running | W = waiting | U = unavailable)
# --------------------------------------------------------------------------------
# 01/19 00:11:08 remaining file transfers: 0|T0    ) agents(R6   |W0   |U0   ) 0
#
#    36 runs complete :  0 runs failed
#    0.0536 avg run time (min) : 0.322 run mgr time (min)
#    6 agents connected
#
#
#
#   ---  evaluating upgrade ensembles  ---
# ...last mean:  0.852674
# ...last stdev:  0.260352
#
#   ---  phi summary for best lambda, scale fac: 5.625e-06 , 1.1 ,   ---
#        phi type           mean            std            min            max
#        measured       0.809323       0.256197       0.593453        1.17954
#          actual        0.78272       0.248968       0.562326        1.14028
#      note: 'measured' phi reported above includes
#            realizations of measurement noise,
#            'actual' phi does not.
#
#   ---  running remaining realizations for best lambda, scale:5.625e-06 , 1.1 ,   ---
#     running model 16 times
#     starting at 01/19/26 00:11:09
#     6 agents ready
#
#
# PANTHER progress
#    avg = average model run time in minutes
#    runs(C = completed | F = failed | T = timed out)
#    agents(R = running | W = waiting | U = unavailable)
# --------------------------------------------------------------------------------
# 01/19 00:11:18 remaining file transfers: 0|T0    ) agents(R4   |W2   |U0   ) 0
#
#    16 runs complete :  0 runs failed
#    0.052 avg run time (min) : 0.159 run mgr time (min)
#    6 agents connected
#
#
# ...phi summary for entire ensemble using lambda,scale_fac 5.625e-06 , 1.1 ,
#        phi type           mean            std            min            max
#        measured       0.819637        0.25036       0.575534        1.40617
#          actual       0.792561       0.248839       0.553573        1.37229
#      note: 'measured' phi reported above includes
#            realizations of measurement noise,
#            'actual' phi does not.
# ...last best mean phi * acceptable phi factor:  0.895308
# ...current best mean phi:  0.819637
#
#   ---  updating parameter ensemble  ---
#
#   ---  updating lambda to  4.21875e-06  ---
#
#   ---  EnsembleMethod iteration 3 report  ---
#    number of active realizations:   20
#    number of model runs:            176
#       current obs ensemble saved to 3_Crane.3.obs.csv
#       current par ensemble saved to 3_Crane.3.par.csv
# saved par and rei files for realization BASE for iteration 3
# saved par and rei files for realization BASE
#        phi type           mean            std            min            max
#        measured       0.819637        0.25036       0.575534        1.40617
#          actual       0.792561       0.248839       0.553573        1.37229
#      note: 'measured' phi reported above includes
#            realizations of measurement noise,
#            'actual' phi does not.
#   ---  observation group phi summary ---
#        (computed using 'actual' phi)
#            (sorted by mean phi)
# group                               count  nconflict      mean       std       min       max   percent       std
# oname:obs/obs_swe_s2.np_otype:arr    1175        281     0.793     0.249     0.554      1.37       100  1.88e-13
#
#
#    ---  parameter group change summary  ---
# group     count  mean chg  std chg  n at ubnd  % at ubnd  n at lbnd  % at lbnd  n std decr
# aw            1 2.153e-14        0          0          0         12         60           0
# mad           1         0        0          0          0          9         45           0
# ndvi_0        1         0        0          4         20          0          0           0
# ndvi_k        1         0        0          1          5          0          0           0
# swe_beta      1     10.76    4.544          0          0          0          0           0
# swe_alpha     1      12.7    35.98          0          0          0          0           0
# ks_alpha      1         0        0          0          0          0          0           0
# kr_alpha      1         01.343e-14          0          0          0          0           0
#
# ...saved parameter change summary to 3_Crane.3.pcs.csv
#
#   ---  phi-based termination criteria check  ---
# ...phiredstp:  0.01
# ...nphistp:  3
# ...nphinored (also used for consecutive bad lambda cycles):  3
# ...best mean phi sequence: 216.814 , 0.907856 , 0.852674 , 0.819637 ,
# ...best phi yet:  0.819637
# ...number of consecutive bad lambda testing cycles:  0
# ...number of iterations satisfying phiredstp criteria:  1
# ...number of iterations since best yet mean phi:  0
# ...solution iterations >= noptmax, all done
#
#
# pestpp-ies analysis complete...
# started at 01/19/26 00:09:27
# finished at 01/19/26 00:11:20
# took 1.86667 minutes

# %% [markdown]
# ## Debugging Tips
#
# If calibration fails, try these steps:
#
# ### Never saw the PEST++ panther logo?
# - Verify installation: `which pestpp-ies` (Linux/Mac) or `where pestpp-ies` (Windows)
# - If not found, reinstall: `conda install conda-forge::pestpp`
# - Ensure your conda environment is activated
#
# ### Python error traceback?
# Debug from the bottom up:
# 1. Verify `swimrs/calibrate/run_mp.py` runs standalone
# 2. Test `custom_forward_run.py` from the pest directory
# 3. Try running `pestpp-ies` directly from pest directory
#
# ### Saw panther but got errors?
# Common error: `output file 'pred/pred_swe_S2.np' not found`
# - This usually means SWIM failed before writing predictions
# - Set `cleanup=False` above to preserve worker directories
# - Check `workers/worker_0/panther_worker.rec` for errors
#
# **Most errors (90%) are due to incorrect paths!**

# %% [markdown]
# ## 6. Check Results
#
# After successful calibration, parameter files are saved for each optimization iteration:

# %%
# Parameter files are in master_dir after calibration
import os
import shutil

results_dir = builder.master_dir if os.path.exists(builder.master_dir) else builder.pest_dir

par_files = [f for f in sorted(os.listdir(results_dir)) if '.par.csv' in f]
print(f"Parameter files (in {results_dir}):")
for f in par_files:
    print(f"  {f}")

if par_files:
    final_par = par_files[-1]
    print(f"\nFinal calibrated parameters: {final_par}")
    
    # Copy final parameters to pest/archive/ for consistency with calibration.py script
    archive_dir = os.path.join(builder.pest_dir, 'archive')
    os.makedirs(archive_dir, exist_ok=True)
    src = os.path.join(results_dir, final_par)
    dst = os.path.join(archive_dir, final_par)
    shutil.copy2(src, dst)
    print(f"Archived to: {dst}")

# Close the container
container.close()
print("\nContainer closed.")
# Out:
# Parameter files (in /home/dgketchum/code/swim-rs/examples/3_Crane/data/pestrun/master):
#   3_Crane.0.par.csv
#   3_Crane.1.par.csv
#   3_Crane.2.par.csv
#   3_Crane.3.par.csv
#
# Final calibrated parameters: 3_Crane.3.par.csv
# Archived to: /home/dgketchum/code/swim-rs/examples/3_Crane/data/pestrun/pest/archive/3_Crane.3.par.csv
#
# Container closed.

# %% [markdown]
# ## Summary
#
# You've set up and run a PEST++ calibration using:
# - SSEBop ETf observations from Landsat
# - SNODAS SWE observations
# - Iterative Ensemble Smoother (pestpp-ies)
#
# The parameter files (e.g., `3_Crane.3.par.csv`) contain the calibrated parameter sets.
#
# **Next step:** In notebook `03_calibrated_model.ipynb`, we'll run the model in forecast mode with calibrated parameters and evaluate the improvement.
