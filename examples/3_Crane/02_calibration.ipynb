# %% [markdown]
# # Calibration Tutorial - Crane, OR - Irrigated Flux Plot
#
# ## Step 2: Calibrate with PEST++
#
# Now we see if we can improve the model's performance through calibration.
#
# ### PEST++ Resources
#
# PEST++ has excellent documentation covering both theory and practice:
#
# 1. **The PEST Manual 4th Ed.** (Doherty, 2002): https://www.epa.gov/sites/default/files/documents/PESTMAN.PDF
# 2. **GMDSI tutorial notebooks**: https://github.com/gmdsi/GMDSI_notebooks
# 3. **PEST++ User's Manual**: https://github.com/usgs/pestpp/blob/master/documentation/pestpp_users_manual.md
# 4. **PEST Book** (Doherty, 2015): https://pesthomepage.org/pest-book
#
# **Note:** We use SSEBop ETf and SNODAS SWE for calibration - these are widely available remote sensing products.

# %% [markdown]
# ### PEST++ Installation
#
# Install PEST++ via conda-forge (recommended):
#
# ```bash
# conda install conda-forge::pestpp
# ```
#
# This installs `pestpp-ies` and other PEST++ tools directly into your conda environment. Verify the installation:
#
# ```bash
# pestpp-ies --version
# ```
#
# **Alternative:** For manual installation from source, see the [PEST++ GitHub releases](https://github.com/usgs/pestpp/releases).

# %%
import os
import sys

root = os.path.abspath('../..')
sys.path.append(root)

from swimrs.container import SwimContainer
from swimrs.calibrate.pest_builder import PestBuilder
from swimrs.swim.config import ProjectConfig
from swimrs.calibrate.run_pest import run_pst

# %% [markdown]
# ## 1. Load Configuration
#
# Load the project configuration and prepare paths.

# %%
project = '3_Crane'
project_ws = os.path.abspath('.')

config_path = os.path.join(project_ws, '3_Crane.toml')

config = ProjectConfig()
config.read_config(config_path, project_ws)

# %% [markdown]
# ## 2. Generate Observation Files
#
# PEST++ needs observation files (ETf and SWE) to compare against model predictions. We export these from the SwimContainer built in the data preparation step.
#
# The export creates per-field numpy files:
# - `obs_etf_{field_id}.np`: ETf observations with irrigation mask switching
# - `obs_swe_{field_id}.np`: SWE observations from SNODAS

# %%
# Open container for observations export and PEST++ setup
container_path = os.path.join(project_ws, 'data', f'{project}.swim')
container = SwimContainer.open(container_path, mode='r')

# Export observation files for PEST++ calibration
# Note: obs_folder is set to {pest_run_dir}/obs in the TOML config
obs_dir = os.path.join(project_ws, 'data', 'pestrun', 'obs')
os.makedirs(obs_dir, exist_ok=True)

container.export.observations(
    output_dir=obs_dir,
    etf_model='ssebop',
    masks=('irr', 'inv_irr'),
    irr_threshold=0.1,
)
print(f"Observation files written to {obs_dir}")
# Out:
# Observation files written to /home/dgketchum/code/swim-rs/examples/3_Crane/data/pestrun/obs

# %% [markdown]
# ## 3. Build PEST++ Control Files
#
# The `PestBuilder` class sets up everything needed for PEST++ calibration:
#
# ### Calibration Loop
# 1. Initialize model with initial parameter values
# 2. Run model, write results
# 3. Compare results to observations (ETf, SWE)
# 4. Propose new parameters
# 5. Repeat until convergence
#
# ### Tunable Parameters
# SWIM uses 8 tunable parameters:
# - **Soil water:** `aw` (available water), `rew` (readily evaporable water), `tew` (total evaporable water)
# - **NDVI-Kcb relationship:** `ndvi_alpha`, `ndvi_beta`
# - **Stress threshold:** `mad` (management allowable depletion)
# - **Snow melt:** `swe_alpha`, `swe_beta`

# %%
# PestBuilder auto-generates custom_forward_run.py using the process package
# with portable swim_input.h5 file for fully self-contained workers
builder = PestBuilder(config, container=container, use_existing=False)
# Out:
# Using default Python script at: /home/dgketchum/code/swim-rs/src/swimrs/calibrate/custom_forward_run.py

# %% [markdown]
# ### Build the .pst Control File
#
# The `build_pest()` method:
# - Copies project files to a `pest/` directory
# - Creates the `.pst` control file
# - Sets up parameter templates (`.tpl`) and instruction files (`.ins`)
#
# **Note:** ETf observations are sparse (only on satellite capture dates). The PEST builder automatically assigns weight 1.0 to valid observations and weight 0.0 to missing dates, ensuring we only calibrate against actual satellite captures.

# %%
# Build the pest control file
# WARNING: This will erase any existing pest directory!
builder.build_pest(target_etf=config.etf_target_model, members=config.etf_ensemble_members)
# Out:
# 2026-01-27 15:30:32.738730 starting: opening PstFrom.log for logging
# 2026-01-27 15:30:32.739286 starting PstFrom process
# 2026-01-27 15:30:32.739405 starting: setting up dirs
# 2026-01-27 15:30:32.739582 starting: removing existing new_d '/home/dgketchum/code/swim-rs/examples/3_Crane/data/pestrun/pest'
# 2026-01-27 15:30:32.752523 finished: removing existing new_d '/home/dgketchum/code/swim-rs/examples/3_Crane/data/pestrun/pest' took: 0:00:00.012941
# 2026-01-27 15:30:32.752633 starting: copying original_d '/home/dgketchum/code/swim-rs/examples/3_Crane/data/pestrun/_template' to new_d '/home/dgketchum/code/swim-rs/examples/3_Crane/data/pestrun/pest'
# 2026-01-27 15:30:32.754312 finished: copying original_d '/home/dgketchum/code/swim-rs/examples/3_Crane/data/pestrun/_template' to new_d '/home/dgketchum/code/swim-rs/examples/3_Crane/data/pestrun/pest' took: 0:00:00.001679
# 2026-01-27 15:30:32.754648 finished: setting up dirs took: 0:00:00.015243
# 2026-01-27 15:30:32.754889 starting: adding constant type m style parameters for file(s) ['params.csv']
# 2026-01-27 15:30:32.755069 starting: loading list-style /home/dgketchum/code/swim-rs/examples/3_Crane/data/pestrun/pest/params.csv
# 2026-01-27 15:30:32.755176 starting: reading list-style file: /home/dgketchum/code/swim-rs/examples/3_Crane/data/pestrun/pest/params.csv
# 2026-01-27 15:30:32.757523 finished: reading list-style file: /home/dgketchum/code/swim-rs/examples/3_Crane/data/pestrun/pest/params.csv took: 0:00:00.002347
# 2026-01-27 15:30:32.757693 loaded list-style '/home/dgketchum/code/swim-rs/examples/3_Crane/data/pestrun/pest/params.csv' of shape (9, 3)
# 2026-01-27 15:30:32.759876 finished: loading list-style /home/dgketchum/code/swim-rs/examples/3_Crane/data/pestrun/pest/params.csv took: 0:00:00.004807
# 2026-01-27 15:30:32.760014 starting: writing list-style template file '/home/dgketchum/code/swim-rs/examples/3_Crane/data/pestrun/pest/p_aw_S2_0_constant.csv.tpl'
# 2026-01-27 15:30:32.773966 finished: writing list-style template file '/home/dgketchum/code/swim-rs/examples/3_Crane/data/pestrun/pest/p_aw_S2_0_constant.csv.tpl' took: 0:00:00.013952
# 2026-01-27 15:30:32.777925 finished: adding constant type m style parameters for file(s) ['params.csv'] took: 0:00:00.023036
# 2026-01-27 15:30:32.778082 starting: adding constant type m style parameters for file(s) ['params.csv']
# 2026-01-27 15:30:32.778217 starting: loading list-style /home/dgketchum/code/swim-rs/examples/3_Crane/data/pestrun/pest/params.csv
# 2026-01-27 15:30:32.778285 starting: reading list-style file: /home/dgketchum/code/swim-rs/examples/3_Crane/data/pestrun/pest/params.csv
# 2026-01-27 15:30:32.779610 finished: reading list-style file: /home/dgketchum/code/swim-rs/examples/3_Crane/data/pestrun/pest/params.csv took: 0:00:00.001325
# 2026-01-27 15:30:32.779717 loaded list-style '/home/dgketchum/code/swim-rs/examples/3_Crane/data/pestrun/pest/params.csv' of shape (9, 3)
# 2026-01-27 15:30:32.781556 finished: loading list-style /home/dgketchum/code/swim-rs/examples/3_Crane/data/pestrun/pest/params.csv took: 0:00:00.003339
# 2026-01-27 15:30:32.781723 starting: writing list-style template file '/home/dgketchum/code/swim-rs/examples/3_Crane/data/pestrun/pest/p_ks_alpha_S2_0_constant.csv.tpl'
# 2026-01-27 15:30:32.791373 finished: writing list-style template file '/home/dgketchum/code/swim-rs/examples/3_Crane/data/pestrun/pest/p_ks_alpha_S2_0_constant.csv.tpl' took: 0:00:00.009650
# 2026-01-27 15:30:32.794346 finished: adding constant type m style parameters for file(s) ['params.csv'] took: 0:00:00.016264
# 2026-01-27 15:30:32.794959 starting: adding constant type m style parameters for file(s) ['params.csv']
# 2026-01-27 15:30:32.795078 starting: loading list-style /home/dgketchum/code/swim-rs/examples/3_Crane/data/pestrun/pest/params.csv
# 2026-01-27 15:30:32.795154 starting: reading list-style file: /home/dgketchum/code/swim-rs/examples/3_Crane/data/pestrun/pest/params.csv
# 2026-01-27 15:30:32.797082 finished: reading list-style file: /home/dgketchum/code/swim-rs/examples/3_Crane/data/pestrun/pest/params.csv took: 0:00:00.001928
# 2026-01-27 15:30:32.797460 loaded list-style '/home/dgketchum/code/swim-rs/examples/3_Crane/data/pestrun/pest/params.csv' of shape (9, 3)
# 2026-01-27 15:30:32.799356 finished: loading list-style /home/dgketchum/code/swim-rs/examples/3_Crane/data/pestrun/pest/params.csv took: 0:00:00.004278
# 2026-01-27 15:30:32.799477 starting: writing list-style template file '/home/dgketchum/code/swim-rs/examples/3_Crane/data/pestrun/pest/p_kr_alpha_S2_0_constant.csv.tpl'
# 2026-01-27 15:30:32.809022 finished: writing list-style template file '/home/dgketchum/code/swim-rs/examples/3_Crane/data/pestrun/pest/p_kr_alpha_S2_0_constant.csv.tpl' took: 0:00:00.009545
# 2026-01-27 15:30:32.811811 finished: adding constant type m style parameters for file(s) ['params.csv'] took: 0:00:00.016852
# 2026-01-27 15:30:32.811915 starting: adding constant type m style parameters for file(s) ['params.csv']
# 2026-01-27 15:30:32.812045 starting: loading list-style /home/dgketchum/code/swim-rs/examples/3_Crane/data/pestrun/pest/params.csv
# 2026-01-27 15:30:32.812131 starting: reading list-style file: /home/dgketchum/code/swim-rs/examples/3_Crane/data/pestrun/pest/params.csv
# 2026-01-27 15:30:32.813517 finished: reading list-style file: /home/dgketchum/code/swim-rs/examples/3_Crane/data/pestrun/pest/params.csv took: 0:00:00.001386
# 2026-01-27 15:30:32.813615 loaded list-style '/home/dgketchum/code/swim-rs/examples/3_Crane/data/pestrun/pest/params.csv' of shape (9, 3)
# 2026-01-27 15:30:32.815395 finished: loading list-style /home/dgketchum/code/swim-rs/examples/3_Crane/data/pestrun/pest/params.csv took: 0:00:00.003350
# 2026-01-27 15:30:32.815502 starting: writing list-style template file '/home/dgketchum/code/swim-rs/examples/3_Crane/data/pestrun/pest/p_ndvi_k_S2_0_constant.csv.tpl'
# 2026-01-27 15:30:32.824502 finished: writing list-style template file '/home/dgketchum/code/swim-rs/examples/3_Crane/data/pestrun/pest/p_ndvi_k_S2_0_constant.csv.tpl' took: 0:00:00.009000
# 2026-01-27 15:30:32.827308 finished: adding constant type m style parameters for file(s) ['params.csv'] took: 0:00:00.015393
# 2026-01-27 15:30:32.827413 starting: adding constant type m style parameters for file(s) ['params.csv']
# 2026-01-27 15:30:32.827482 starting: loading list-style /home/dgketchum/code/swim-rs/examples/3_Crane/data/pestrun/pest/params.csv
# 2026-01-27 15:30:32.827530 starting: reading list-style file: /home/dgketchum/code/swim-rs/examples/3_Crane/data/pestrun/pest/params.csv
# 2026-01-27 15:30:32.828507 finished: reading list-style file: /home/dgketchum/code/swim-rs/examples/3_Crane/data/pestrun/pest/params.csv took: 0:00:00.000977
# 2026-01-27 15:30:32.828609 loaded list-style '/home/dgketchum/code/swim-rs/examples/3_Crane/data/pestrun/pest/params.csv' of shape (9, 3)
# 2026-01-27 15:30:32.830499 finished: loading list-style /home/dgketchum/code/swim-rs/examples/3_Crane/data/pestrun/pest/params.csv took: 0:00:00.003017
# 2026-01-27 15:30:32.830620 starting: writing list-style template file '/home/dgketchum/code/swim-rs/examples/3_Crane/data/pestrun/pest/p_ndvi_0_S2_0_constant.csv.tpl'
# 2026-01-27 15:30:32.840113 finished: writing list-style template file '/home/dgketchum/code/swim-rs/examples/3_Crane/data/pestrun/pest/p_ndvi_0_S2_0_constant.csv.tpl' took: 0:00:00.009493
# 2026-01-27 15:30:32.842924 finished: adding constant type m style parameters for file(s) ['params.csv'] took: 0:00:00.015511
# 2026-01-27 15:30:32.843032 starting: adding constant type m style parameters for file(s) ['params.csv']
# 2026-01-27 15:30:32.843105 starting: loading list-style /home/dgketchum/code/swim-rs/examples/3_Crane/data/pestrun/pest/params.csv
# 2026-01-27 15:30:32.843155 starting: reading list-style file: /home/dgketchum/code/swim-rs/examples/3_Crane/data/pestrun/pest/params.csv
# 2026-01-27 15:30:32.844027 finished: reading list-style file: /home/dgketchum/code/swim-rs/examples/3_Crane/data/pestrun/pest/params.csv took: 0:00:00.000872
# 2026-01-27 15:30:32.844105 loaded list-style '/home/dgketchum/code/swim-rs/examples/3_Crane/data/pestrun/pest/params.csv' of shape (9, 3)
# 2026-01-27 15:30:32.845303 finished: loading list-style /home/dgketchum/code/swim-rs/examples/3_Crane/data/pestrun/pest/params.csv took: 0:00:00.002198
# 2026-01-27 15:30:32.845399 starting: writing list-style template file '/home/dgketchum/code/swim-rs/examples/3_Crane/data/pestrun/pest/p_mad_S2_0_constant.csv.tpl'
# 2026-01-27 15:30:32.855822 finished: writing list-style template file '/home/dgketchum/code/swim-rs/examples/3_Crane/data/pestrun/pest/p_mad_S2_0_constant.csv.tpl' took: 0:00:00.010423
# 2026-01-27 15:30:32.858793 finished: adding constant type m style parameters for file(s) ['params.csv'] took: 0:00:00.015761
# 2026-01-27 15:30:32.858902 starting: adding constant type m style parameters for file(s) ['params.csv']
# 2026-01-27 15:30:32.858975 starting: loading list-style /home/dgketchum/code/swim-rs/examples/3_Crane/data/pestrun/pest/params.csv
# 2026-01-27 15:30:32.859025 starting: reading list-style file: /home/dgketchum/code/swim-rs/examples/3_Crane/data/pestrun/pest/params.csv
# 2026-01-27 15:30:32.859899 finished: reading list-style file: /home/dgketchum/code/swim-rs/examples/3_Crane/data/pestrun/pest/params.csv took: 0:00:00.000874
# 2026-01-27 15:30:32.859977 loaded list-style '/home/dgketchum/code/swim-rs/examples/3_Crane/data/pestrun/pest/params.csv' of shape (9, 3)
# 2026-01-27 15:30:32.861158 finished: loading list-style /home/dgketchum/code/swim-rs/examples/3_Crane/data/pestrun/pest/params.csv took: 0:00:00.002183
# 2026-01-27 15:30:32.861244 starting: writing list-style template file '/home/dgketchum/code/swim-rs/examples/3_Crane/data/pestrun/pest/p_swe_alpha_S2_0_constant.csv.tpl'
# 2026-01-27 15:30:32.871303 finished: writing list-style template file '/home/dgketchum/code/swim-rs/examples/3_Crane/data/pestrun/pest/p_swe_alpha_S2_0_constant.csv.tpl' took: 0:00:00.010059
# 2026-01-27 15:30:32.874386 finished: adding constant type m style parameters for file(s) ['params.csv'] took: 0:00:00.015484
# 2026-01-27 15:30:32.874497 starting: adding constant type m style parameters for file(s) ['params.csv']
# 2026-01-27 15:30:32.874575 starting: loading list-style /home/dgketchum/code/swim-rs/examples/3_Crane/data/pestrun/pest/params.csv
# 2026-01-27 15:30:32.874627 starting: reading list-style file: /home/dgketchum/code/swim-rs/examples/3_Crane/data/pestrun/pest/params.csv
# 2026-01-27 15:30:32.875554 finished: reading list-style file: /home/dgketchum/code/swim-rs/examples/3_Crane/data/pestrun/pest/params.csv took: 0:00:00.000927
# 2026-01-27 15:30:32.875636 loaded list-style '/home/dgketchum/code/swim-rs/examples/3_Crane/data/pestrun/pest/params.csv' of shape (9, 3)
# 2026-01-27 15:30:32.876864 finished: loading list-style /home/dgketchum/code/swim-rs/examples/3_Crane/data/pestrun/pest/params.csv took: 0:00:00.002289
# 2026-01-27 15:30:32.876953 starting: writing list-style template file '/home/dgketchum/code/swim-rs/examples/3_Crane/data/pestrun/pest/p_swe_beta_S2_0_constant.csv.tpl'
# 2026-01-27 15:30:32.884750 finished: writing list-style template file '/home/dgketchum/code/swim-rs/examples/3_Crane/data/pestrun/pest/p_swe_beta_S2_0_constant.csv.tpl' took: 0:00:00.007797
# 2026-01-27 15:30:32.887564 finished: adding constant type m style parameters for file(s) ['params.csv'] took: 0:00:00.013067
# 2026-01-27 15:30:33.245618 starting: adding observations from output file obs/obs_etf_S2.np
# 2026-01-27 15:30:33.246202 starting: adding observations from array output file 'obs/obs_etf_S2.np'
# 2026-01-27 15:30:33.276768 starting: adding observation from instruction file '/home/dgketchum/code/swim-rs/examples/3_Crane/data/pestrun/pest/etf_S2.ins'
# 2026-01-27 15:30:33.418941 finished: adding observation from instruction file '/home/dgketchum/code/swim-rs/examples/3_Crane/data/pestrun/pest/etf_S2.ins' took: 0:00:00.142173
# 2026-01-27 15:30:33.420401 finished: adding observations from array output file 'obs/obs_etf_S2.np' took: 0:00:00.174199
# 2026-01-27 15:30:33.421952 finished: adding observations from output file obs/obs_etf_S2.np took: 0:00:00.176334
# 2026-01-27 15:30:35.102614 starting: adding observations from output file obs/obs_swe_S2.np
# 2026-01-27 15:30:35.102814 starting: adding observations from array output file 'obs/obs_swe_S2.np'
# 2026-01-27 15:30:35.128989 starting: adding observation from instruction file '/home/dgketchum/code/swim-rs/examples/3_Crane/data/pestrun/pest/swe_S2.ins'
# 2026-01-27 15:30:35.242798 finished: adding observation from instruction file '/home/dgketchum/code/swim-rs/examples/3_Crane/data/pestrun/pest/swe_S2.ins' took: 0:00:00.113809
# 2026-01-27 15:30:35.243920 finished: adding observations from array output file 'obs/obs_swe_S2.np' took: 0:00:00.141106
# 2026-01-27 15:30:35.244194 finished: adding observations from output file obs/obs_swe_S2.np took: 0:00:00.141580
# noptmax:0, npar_adj:8, nnz_obs:1800
# Building portable swim_input.h5 with spinup state...
# Created swim_input.h5 at /home/dgketchum/code/swim-rs/examples/3_Crane/data/pestrun/pest/swim_input.h5
# noptmax:0, npar_adj:8, nnz_obs:1800
# === PEST++ Build Diagnostics ===
# pst: /home/dgketchum/code/swim-rs/examples/3_Crane/data/pestrun/pest/3_Crane.pst
# observations: total=26298, valid=7490, nonzero_weight=1800
# ETf: valid=568, nonzero_weight=614
# SWE: valid=6922, nonzero_weight=1186
#
# Observation groups: 2
#                             group     n  valid  w>0       w_sum  w_max  obs_min    obs_max   sd_nan%
# oname:obs/obs_etf_s2.np_otype:arr 13149    568  614 2629.046151 10.000 0.050562   1.330665 95.330443
# oname:obs/obs_swe_s2.np_otype:arr 13149   6922 1186    1.186000  0.001 0.000000 176.669708  0.000000
#
# parameters: n=8, at_lower=0, at_upper=0, groups=8
# Configured PEST++ for 1 targets,

# %%
# Show the files created in the pest directory
pest_files = [f for f in sorted(os.listdir(builder.pest_dir)) 
              if os.path.isfile(os.path.join(builder.pest_dir, f))]
print("Files in pest directory:")
for f in pest_files:
    print(f"  {f}")
# Out:
# Files in pest directory:
#   3_Crane.idx.csv
#   3_Crane.pst
#   3_crane.insfile_data.csv
#   3_crane.obs_data.csv
#   3_crane.par_data.csv
#   3_crane.pargp_data.csv
#   3_crane.tplfile_data.csv
#   custom_forward_run.py
#   etf_S2.ins
#   mult2model_info.csv
#   p_aw_S2_0_constant.csv.tpl
#   p_kr_alpha_S2_0_constant.csv.tpl
#   p_ks_alpha_S2_0_constant.csv.tpl
#   p_mad_S2_0_constant.csv.tpl
#   p_ndvi_0_S2_0_constant.csv.tpl
#   p_ndvi_k_S2_0_constant.csv.tpl
#   p_swe_alpha_S2_0_constant.csv.tpl
#   p_swe_beta_S2_0_constant.csv.tpl
#   params.csv
#   swe_S2.ins
#   swim_input.h5

# %% [markdown]
# ### Examine the .pst File
#
# The PEST++ version 2 control file is concise, delegating details to external files:

# %%
with open(builder.pst_file, 'r') as f:
    print(f.read())
# Out:
# pcf version=2
# * control data keyword
# pestmode                                 estimation
# noptmax                                 0
# svdmode                                 1
# maxsing                          10000000
# eigthresh                           1e-06
# eigwrite                                1
# * parameter groups external
# 3_crane.pargp_data.csv
# * parameter data external
# 3_crane.par_data.csv
# * observation data external
# 3_crane.obs_data.csv
# * model command line
# python custom_forward_run.py
# * model input external
# 3_crane.tplfile_data.csv
# * model output external
# 3_crane.insfile_data.csv

# %% [markdown]
# ## 4. Configure and Test
#
# Now we:
# 1. Build the localizer matrix (links parameters to relevant observations)
# 2. Run spinup to save initial water balance state
# 3. Do a dry run to verify everything works
# 4. Set control parameters for the full calibration

# %%
# Build localizer matrix
# - SWE observations update only swe_alpha and swe_beta
# - ETf observations update all other parameters
builder.build_localizer()

# Run spinup to save water balance state as initial conditions for calibration runs
# This runs the model once and saves the final state to spinup.json
print("Running spinup...")
builder.spinup(overwrite=True)

# Run a minimal model run to verify the setup
print("\nRunning dry run...")
builder.dry_run()

# Configure for 3 optimization iterations with 20 realizations each
# Increase realizations (e.g., 100-200) for production runs
builder.write_control_settings(noptmax=3, reals=20)
# Out:
# noptmax:0, npar_adj:8, nnz_obs:1800
# Running spinup...
# RUNNING SPINUP
# Spinup saved to /home/dgketchum/code/swim-rs/examples/3_Crane/data/pestrun/spinup.json
#
# Running dry run...
# noptmax:3, npar_adj:8, nnz_obs:1800
# writing /home/dgketchum/code/swim-rs/examples/3_Crane/data/pestrun/pest/3_Crane.pst with noptmax=3, 20 realizations

# %%
# Show the updated control file with calibration settings
with open(builder.pst_file, 'r') as f:
    print(f.read())
# Out:
# pcf version=2
# * control data keyword
# pestmode                                 estimation
# noptmax                                 3
# svdmode                                 1
# maxsing                          10000000
# eigthresh                           1e-06
# eigwrite                                1
# ies_localizer                  loc.mat
# ies_num_reals                  20
# ies_drop_conflicts             true
# * parameter groups external
# 3_crane.pargp_data.csv
# * parameter data external
# 3_crane.par_data.csv
# * observation data external
# 3_crane.obs_data.csv
# * model command line
# python custom_forward_run.py
# * model input external
# 3_crane.tplfile_data.csv
# * model output external
# 3_crane.insfile_data.csv

# %% [markdown]
# ## 5. Run PEST++ Calibration
#
# Now we launch PEST++ with parallel workers. Adjust `workers` to match your machine's capabilities.
#
# **Important:** This can take a while. Watch for the progress indicator.

# %%
workers = config.workers or 6
_pst = f"{config.project_name}.pst"

print(f"Starting PEST++ with {workers} workers...")
print(f"Control file: {_pst}")

run_pst(builder.pest_dir,
        'pestpp-ies',
        _pst,
        num_workers=workers,
        worker_root=builder.workers_dir,
        master_dir=builder.master_dir,
        cleanup=True,
        verbose=True)
# Out:
# Starting PEST++ with 6 workers...
# Control file: 3_Crane.pst
# master:pestpp-ies 3_Crane.pst /h :5005 in /home/dgketchum/code/swim-rs/examples/3_Crane/data/pestrun/master
#
#
#              pestpp-ies: a GLM iterative ensemble smoother
#
#                    by the PEST++ development team
#
# ...processing command line: ' pestpp-ies 3_Crane.pst /h :5005'
# ...using panther run manager in master mode using port 5005
#
#
# version: 5.2.25
# binary compiled on Jan 13 2026 at 20:33:04
# using control file: "3_Crane.pst"
# in directory: "/home/dgketchum/code/swim-rs/examples/3_Crane/data/pestrun/master"
# on host: "fcfc-mcozoran"
# on a(n) linux operating system
# with release configuration
# started at 01/27/26 15:30:42
#
# processing control file 3_Crane.pst
# :~-._                                                 _.-~:
# : :.~^o._        ________---------________        _.o^~.:.:
#  : ::.`?88booo~~~.::::::::...::::::::::::..~~oood88P'.::.:
#  :  ::: `?88P .:::....         ........:::::. ?88P' :::. :
#   :  :::. `? .::.            . ...........:::. P' .:::. :
#    :  :::   ... ..  ...       .. .::::......::.   :::. :
#    `  :' .... ..  .:::::.     . ..:::::::....:::.  `: .'
#     :..    ____:::::::::.  . . ....:::::::::____  ... :
#    :... `:~    ^~-:::::..  .........:::::-~^    ~::.::::
#    `.::. `\   (8)  \b:::..::.:.:::::::d/  (8)   /'.::::'
#     ::::.  ~-._v    |b.::::::::::::::d|    v_.-~..:::::
#     `.:::::... ~~^?888b..:::::::::::d888P^~...::::::::'
#      `.::::::::::....~~~ .:::::::::~~~:::::::::::::::'
#       `..:::::::::::   .   ....::::    ::::::::::::,'
#         `. .:::::::    .      .::::.    ::::::::'.'
#           `._ .:::    .        :::::.    :::::_.'
#              `-. :    .        :::::      :,-'
#                 :.   :___     .:::___   .::
#       ..--~~~~--:+::. ~~^?b..:::dP^~~.::++:--~~~~--..
#         ___....--`+:::.    `~8~'    .:::+'--....___
#       ~~   __..---`_=:: ___gd8bg___ :==_'---..__   ~~
#        -~~~  _.--~~`-.~~~~~~~~~~~~~~~,-' ~~--._ ~~~-
#
#
#                starting PANTHER master...
#
# IP addresses:
#   0.0.0.0:5005 (IPv4)
#
# PANTHER master listening on socket: 0.0.0.0:5005 (IPv4)
#
#   ---  initializing  ---
# ...using glm algorithm
# ...using REDSVD for truncated svd solve
# ...maxsing: 10000000
# ...eigthresh:  1e-06
# ...initializing localizer
# ...using localized solution with 8 sequential upgrade steps
# ...localizing by parameters
# ...using lambda multipliers: 0.1 , 1 , 10 ,
# ...using lambda scaling factors: 0.75 , 1 , 1.1 ,
# ...acceptable phi factor:  1.05
# ...lambda increase factor:  10
# ...lambda decrease factor:  0.75
# ...max run fail:  1
# ...initializing prior parameter covariance matrix
# ...parcov loaded  from parameter bounds, using par_sigma_range 4
# ...initializing observation noise covariance matrix
# worker:pestpp-ies 3_Crane.pst /h localhost:5005 in /home/dgketchum/code/swim-rs/examples/3_Crane/data/pestrun/workers/worker_0
# worker:pestpp-ies 3_Crane.pst /h localhost:5005 in /home/dgketchum/code/swim-rs/examples/3_Crane/data/pestrun/workers/worker_1
# worker:pestpp-ies 3_Crane.pst /h localhost:5005 in /home/dgketchum/code/swim-rs/examples/3_Crane/data/pestrun/workers/worker_2
# worker:pestpp-ies 3_Crane.pst /h localhost:5005 in /home/dgketchum/code/swim-rs/examples/3_Crane/data/pestrun/workers/worker_3
# worker:pestpp-ies 3_Crane.pst /h localhost:5005 in /home/dgketchum/code/swim-rs/examples/3_Crane/data/pestrun/workers/worker_4
# worker:pestpp-ies 3_Crane.pst /h localhost:5005 in /home/dgketchum/code/swim-rs/examples/3_Crane/data/pestrun/workers/worker_5
# ...obscov loaded  from observation weights
# ...drawing parameter realizations:  20
# ...not using prior parameter covariance matrix scaling
# ...drawing observation noise realizations:  20
# observations not grouped by observations groups, reordering obs ensemble
# ...setting weights ensemble from control file weights
# ...saved weight ensemble to  3_Crane.weights.csv
# ...adding 'base' parameter values to ensemble
# ...adding 'base' observation values to ensemble
# ...adding 'base' weight values to weight ensemble
# ...saved initial parameter ensemble to  3_Crane.0.par.csv
# ...saved obs+noise observation ensemble (obsval + noise realizations) to  3_Crane.obs+noise.csv
# ...using subset in lambda testing, percentage of realizations used in subset testing:  10
# ...subset how:  RANDOM
# ...centering on ensemble mean vector
# ...running initial ensemble of size 20
#     running model 20 times
#     starting at 01/27/26 15:30:44
#
#     waiting for agents to appear...
#
#
# PANTHER progress
#    avg = average model run time in minutes
#    runs(C = completed | F = failed | T = timed out)
#    agents(R = running | W = waiting | U = unavailable)
# --------------------------------------------------------------------------------
# 01/27 15:30:45 mn:0     runs(C0    |F0    |T0    ) agents(R6   |W0   |U0   ) 0
# 01/27 15:30:46 mn:0     runs(C0    |F0    |T0    ) agents(R6   |W0   |U0   ) 0
# 01/27 15:30:47 mn:0     runs(C0    |F0    |T0    ) agents(R6   |W0   |U0   ) 0
# 01/27 15:30:48 mn:0.058 runs(C4    |F0    |T0    ) agents(R5   |W0   |U1   ) 0
# 01/27 15:30:49 mn:0.059 runs(C6    |F0    |T0    ) agents(R6   |W0   |U0   ) 0
# 01/27 15:30:50 mn:0.059 runs(C6    |F0    |T0    ) agents(R6   |W0   |U0   ) 0
# 01/27 15:30:51 mn:0.059 runs(C6    |F0    |T0    ) agents(R6   |W0   |U0   ) 0
# 01/27 15:30:52 mn:0.056 runs(C12   |F0    |T0    ) agents(R6   |W0   |U0   ) 0
# 01/27 15:30:53 mn:0.056 runs(C12   |F0    |T0    ) agents(R6   |W0   |U0   ) 0
# 01/27 15:30:54 mn:0.056 runs(C12   |F0    |T0    ) agents(R6   |W0   |U0   ) 0
# 01/27 15:30:55 mn:0.055 runs(C18   |F0    |T0    ) agents(R2   |W4   |U0   ) 0
# 01/27 15:30:56 mn:0.055 runs(C18   |F0    |T0    ) agents(R2   |W4   |U0   ) 0
# 01/27 15:30:57 mn:0.055 runs(C18   |F0    |T0    ) agents(R2   |W4   |U0   ) 0
# 01/27 15:30:57 remaining file transfers: 0
#
#    20 runs complete :  0 runs failed
#    0.0539 avg run time (min) : 0.226 run mgr time (min)
#    6 agents connected
# ...saved initial obs ensemble to 3_Crane.0.obs.csv
# saved par and rei files for realization BASE for iteration 0
# saved par and rei files for realization BASE
#
#   ---  pre-drop initial phi summary  ---
#        phi type           mean            std            min            max
#        measured    1.40856e+07        30577.1    1.40458e+07    1.41351e+07
#          actual    1.40852e+07        30869.5    1.40464e+07    1.41353e+07
#      note: 'measured' phi reported above includes
#            realizations of measurement noise,
#            'actual' phi does not.
#   ---  observation group phi summary ---
#        (computed using 'actual' phi)
#            (sorted by mean phi)
# group                               count  nconflict      mean       std       min       max   percent       std
# oname:obs/obs_etf_s2.np_otype:arr     614        106  1.41e+07  3.08e+04   1.4e+07  1.41e+07       100   0.00475
# oname:obs/obs_swe_s2.np_otype:arr    1186          8       218       669     0.564  2.18e+03   0.00155   0.00475
#
# ...checking for prior-data conflict
#
#   ---  WARNING: 114 non-zero weighted observations are in conflict with the prior simulated ensemble.
#   ---
# ...see 3_Crane.0.pdc.csv for listing of conflicted observations
#
# ...dropping conflicted observations
# ...number of non-zero weighted observations reduced from 1800 to 1686
#
# ...updating localizer
# dropped 114 from localizer rows because forgive_missing is true
# ...saved adjusted weight ensemble to  3_Crane.adjusted.weights.csv
# saved par and rei files for realization BASE for iteration 0
# saved par and rei files for realization BASE
#
#   ---  initial phi summary  ---
#        phi type           mean            std            min            max
#        measured        1767.75        1054.75        509.736        4248.24
#          actual        1599.69        1057.72        317.693        4054.19
#      note: 'measured' phi reported above includes
#            realizations of measurement noise,
#            'actual' phi does not.
#   ---  observation group phi summary ---
#        (computed using 'actual' phi)
#            (sorted by mean phi)
# group                               count  nconflict      mean       std       min       max   percent       std
# oname:obs/obs_etf_s2.np_otype:arr     508          0  1.38e+03       703       317  2.13e+03      94.4      16.9
# oname:obs/obs_swe_s2.np_otype:arr    1178          0       217       665     0.555  2.17e+03      5.59      16.9
#
# ...current lambda: 0.1
#
#    ---  parameter group change summary  ---
# group     count  mean chg  std chg  n at ubnd  % at ubnd  n at lbnd  % at lbnd  n std decr
# aw            1         0        0          0          0         12         60           0
# mad           1         0        0          0          0          9         45           0
# swe_beta      1         0        0          4         20          0          0           0
# swe_alpha     1         0        0          2         10          0          0           0
# ndvi_k        1         0        0          0          0          1          5           0
# ndvi_0        1         0        0          1          5          0          0           0
# ks_alpha      1         0        0          0          0          0          0           0
# kr_alpha      1         0        0          0          0          0          0           0
#
#
#   ---  initialization complete  ---
#
#   ---  starting solve for iteration: 1  ---
# ...current lambda:  0.1
# ...preparing fast-lookup containers for threaded localization solve
# ...starting calcs for glm factor 0.01
# ...finished calcs for: 0.01
# ...starting calcs for glm factor 0.1
# ...finished calcs for: 0.1
# ...starting calcs for glm factor 1
# ...finished calcs for: 1
#
#   ---  running upgrade ensembles  ---
# ...subset idx:pe real name:  9:9, 12:12, 17:17, 19:BASE,
# ...subset idx:oe real name:  9:9, 12:12, 17:17, 19:BASE,
#     running model 36 times
#     starting at 01/27/26 15:31:00
#     6 agents ready
#
#
# PANTHER progress
#    avg = average model run time in minutes
#    runs(C = completed | F = failed | T = timed out)
#    agents(R = running | W = waiting | U = unavailable)
# --------------------------------------------------------------------------------
# 01/27 15:31:01 mn:0     runs(C0    |F0    |T0    ) agents(R6   |W0   |U0   ) 0
# 01/27 15:31:02 mn:0     runs(C0    |F0    |T0    ) agents(R6   |W0   |U0   ) 0
# 01/27 15:31:03 mn:0     runs(C0    |F0    |T0    ) agents(R6   |W0   |U0   ) 0
# 01/27 15:31:04 mn:0.054 runs(C6    |F0    |T0    ) agents(R6   |W0   |U0   ) 0
# 01/27 15:31:05 mn:0.054 runs(C6    |F0    |T0    ) agents(R6   |W0   |U0   ) 0
# 01/27 15:31:06 mn:0.054 runs(C6    |F0    |T0    ) agents(R6   |W0   |U0   ) 0
# 01/27 15:31:07 mn:0.054 runs(C12   |F0    |T0    ) agents(R6   |W0   |U0   ) 0
# 01/27 15:31:08 mn:0.054 runs(C12   |F0    |T0    ) agents(R6   |W0   |U0   ) 0
# 01/27 15:31:09 mn:0.054 runs(C12   |F0    |T0    ) agents(R6   |W0   |U0   ) 0
# 01/27 15:31:10 mn:0.054 runs(C18   |F0    |T0    ) agents(R6   |W0   |U0   ) 0
# 01/27 15:31:11 mn:0.054 runs(C18   |F0    |T0    ) agents(R6   |W0   |U0   ) 0
# 01/27 15:31:12 mn:0.054 runs(C18   |F0    |T0    ) agents(R6   |W0   |U0   ) 0
# 01/27 15:31:13 mn:0.054 runs(C20   |F0    |T0    ) agents(R6   |W0   |U0   ) 0
# 01/27 15:31:14 mn:0.054 runs(C24   |F0    |T0    ) agents(R6   |W0   |U0   ) 0
# 01/27 15:31:15 mn:0.054 runs(C24   |F0    |T0    ) agents(R6   |W0   |U0   ) 0
# 01/27 15:31:16 mn:0.054 runs(C24   |F0    |T0    ) agents(R6   |W0   |U0   ) 0
# 01/27 15:31:17 mn:0.054 runs(C30   |F0    |T0    ) agents(R6   |W0   |U0   ) 0
# 01/27 15:31:18 mn:0.054 runs(C30   |F0    |T0    ) agents(R6   |W0   |U0   ) 0
# 01/27 15:31:19 mn:0.054 runs(C30   |F0    |T0    ) agents(R6   |W0   |U0   ) 0
# 01/27 15:31:20 remaining file transfers: 0
#
#    36 runs complete :  0 runs failed
#    0.0543 avg run time (min) : 0.329 run mgr time (min)
#    6 agents connected
#   ---  evaluating upgrade ensembles  ---
# ...last mean:  1767.75
# ...last stdev:  1054.75
#   ---  phi summary for best lambda, scale fac: 1 , 0.75 ,   ---
#        phi type           mean            std            min            max
#        measured        509.919        111.126        344.457         578.52
#          actual        372.744        26.6289        344.457        408.509
#      note: 'measured' phi reported above includes
#            realizations of measurement noise,
#            'actual' phi does not.
#
#   ---  running remaining realizations for best lambda, scale:1 , 0.75 ,   ---
#     running model 16 times
#     starting at 01/27/26 15:31:21
#     6 agents ready
#
#
# PANTHER progress
#    avg = average model run time in minutes
#    runs(C = completed | F = failed | T = timed out)
#    agents(R = running | W = waiting | U = unavailable)
# --------------------------------------------------------------------------------
# 01/27 15:31:22 mn:0     runs(C0    |F0    |T0    ) agents(R6   |W0   |U0   ) 0
# 01/27 15:31:23 mn:0     runs(C0    |F0    |T0    ) agents(R6   |W0   |U0   ) 0
# 01/27 15:31:24 mn:0.049 runs(C1    |F0    |T0    ) agents(R6   |W0   |U0   ) 0
# 01/27 15:31:25 mn:0.052 runs(C6    |F0    |T0    ) agents(R6   |W0   |U0   ) 0
# 01/27 15:31:26 mn:0.052 runs(C6    |F0    |T0    ) agents(R6   |W0   |U0   ) 0
# 01/27 15:31:27 mn:0.052 runs(C6    |F0    |T0    ) agents(R6   |W0   |U0   ) 0
# 01/27 15:31:28 mn:0.053 runs(C12   |F0    |T0    ) agents(R4   |W2   |U0   ) 0
# 01/27 15:31:29 mn:0.053 runs(C12   |F0    |T0    ) agents(R4   |W2   |U0   ) 0
# 01/27 15:31:30 mn:0.053 runs(C12   |F0    |T0    ) agents(R4   |W2   |U0   ) 0
# 01/27 15:31:31 remaining file transfers: 0
#
#    16 runs complete :  0 runs failed
#    0.0527 avg run time (min) : 0.161 run mgr time (min)
#    6 agents connected
# ...phi summary for entire ensemble using lambda,scale_fac 1 , 0.75 ,
#        phi type           mean            std            min            max
#        measured        626.475        219.431        344.457        1427.34
#          actual        455.079        198.977        332.902         1200.6
#      note: 'measured' phi reported above includes
#            realizations of measurement noise,
#            'actual' phi does not.
# ...last best mean phi * acceptable phi factor:  1856.13
# ...current best mean phi:  626.475
#
#   ---  updating parameter ensemble  ---
#
#   ---  updating lambda to  0.75  ---
#
#   ---  EnsembleMethod iteration 1 report  ---
#    number of active realizations:   20
#    number of model runs:            72
#       current obs ensemble saved to 3_Crane.1.obs.csv
#       current par ensemble saved to 3_Crane.1.par.csv
# saved par and rei files for realization BASE for iteration 1
# saved par and rei files for realization BASE
#        phi type           mean            std            min            max
#        measured        626.475        219.431        344.457        1427.34
#          actual        455.079        198.977        332.902         1200.6
#      note: 'measured' phi reported above includes
#            realizations of measurement noise,
#            'actual' phi does not.
#   ---  observation group phi summary ---
#        (computed using 'actual' phi)
#            (sorted by mean phi)
# group                               count  nconflict      mean       std       min       max   percent       std
# oname:obs/obs_etf_s2.np_otype:arr     508         18       454       199       332   1.2e+03      99.8    0.0698
# oname:obs/obs_swe_s2.np_otype:arr    1178        231     0.904     0.264     0.554      1.48     0.214    0.0698
#
#
#    ---  parameter group change summary  ---
# group     count  mean chg  std chg  n at ubnd  % at ubnd  n at lbnd  % at lbnd  n std decr
# mad           1     4.031    31.12          0          0          9         45           0
# ndvi_0        1     66.56    68.46          2         10          0          0           0
# swe_beta      1     1.104   0.9884          0          0          0          0           0
# swe_alpha     1     12.93    19.25          0          0          0          0           0
# ndvi_k        1     16.46    24.64          0          0          0          0           0
# ks_alpha      1     39.19    29.07          0          0          0          0           0
# kr_alpha      1     1.933    33.99          0          0          0          0           0
# aw            1     7.694    30.11          0          0          0          0           0
#
# ...saved parameter change summary to 3_Crane.1.pcs.csv
#
#   ---  phi-based termination criteria check  ---
# ...phiredstp:  0.01
# ...nphistp:  3
# ...nphinored (also used for consecutive bad lambda cycles):  3
# ...best mean phi sequence: 1767.75 , 626.475 ,
# ...best phi yet:  626.475
# ...number of consecutive bad lambda testing cycles:  0
# ...number of iterations satisfying phiredstp criteria:  1
# ...number of iterations since best yet mean phi:  0
#
#   ---  starting solve for iteration: 2  ---
# ...current lambda:  0.75
# ...preparing fast-lookup containers for threaded localization solve
# ...starting calcs for glm factor 0.075
# ...finished calcs for: 0.075
# ...starting calcs for glm factor 0.75
# ...finished calcs for: 0.75
# ...starting calcs for glm factor 7.5
# ...finished calcs for: 7.5
#
#   ---  running upgrade ensembles  ---
# ...subset idx:pe real name:  3:BASE, 6:2, 11:7, 19:18,
# ...subset idx:oe real name:  3:BASE, 6:2, 11:7, 19:18,
#     running model 36 times
#     starting at 01/27/26 15:31:32
#     6 agents ready
#
#
# PANTHER progress
#    avg = average model run time in minutes
#    runs(C = completed | F = failed | T = timed out)
#    agents(R = running | W = waiting | U = unavailable)
# --------------------------------------------------------------------------------
# 01/27 15:31:33 mn:0     runs(C0    |F0    |T0    ) agents(R6   |W0   |U0   ) 0
# 01/27 15:31:34 mn:0     runs(C0    |F0    |T0    ) agents(R6   |W0   |U0   ) 0
# 01/27 15:31:35 mn:0     runs(C0    |F0    |T0    ) agents(R6   |W0   |U0   ) 0
# 01/27 15:31:36 mn:0.052 runs(C6    |F0    |T0    ) agents(R6   |W0   |U0   ) 0
# 01/27 15:31:37 mn:0.052 runs(C6    |F0    |T0    ) agents(R6   |W0   |U0   ) 0
# 01/27 15:31:38 mn:0.052 runs(C6    |F0    |T0    ) agents(R6   |W0   |U0   ) 0
# 01/27 15:31:39 mn:0.054 runs(C12   |F0    |T0    ) agents(R6   |W0   |U0   ) 0
# 01/27 15:31:40 mn:0.054 runs(C12   |F0    |T0    ) agents(R6   |W0   |U0   ) 0
# 01/27 15:31:41 mn:0.054 runs(C12   |F0    |T0    ) agents(R6   |W0   |U0   ) 0
# 01/27 15:31:42 mn:0.054 runs(C17   |F0    |T0    ) agents(R5   |W0   |U1   ) 0
# 01/27 15:31:43 mn:0.054 runs(C18   |F0    |T0    ) agents(R6   |W0   |U0   ) 0
# 01/27 15:31:44 mn:0.054 runs(C18   |F0    |T0    ) agents(R6   |W0   |U0   ) 0
# 01/27 15:31:45 mn:0.054 runs(C19   |F0    |T0    ) agents(R6   |W0   |U0   ) 0
# 01/27 15:31:46 mn:0.054 runs(C24   |F0    |T0    ) agents(R6   |W0   |U0   ) 0
# 01/27 15:31:47 mn:0.054 runs(C24   |F0    |T0    ) agents(R6   |W0   |U0   ) 0
# 01/27 15:31:48 mn:0.054 runs(C24   |F0    |T0    ) agents(R6   |W0   |U0   ) 0
# 01/27 15:31:49 mn:0.054 runs(C30   |F0    |T0    ) agents(R6   |W0   |U0   ) 0
# 01/27 15:31:50 mn:0.054 runs(C30   |F0    |T0    ) agents(R6   |W0   |U0   ) 0
# 01/27 15:31:51 mn:0.054 runs(C30   |F0    |T0    ) agents(R6   |W0   |U0   ) 0
# 01/27 15:31:52 remaining file transfers: 0
#
#    36 runs complete :  0 runs failed
#    0.0543 avg run time (min) : 0.33 run mgr time (min)
#    6 agents connected
#   ---  evaluating upgrade ensembles  ---
# ...last mean:  626.475
# ...last stdev:  219.431
#   ---  phi summary for best lambda, scale fac: 7.5 , 1 ,   ---
#        phi type           mean            std            min            max
#        measured        464.848        85.2024        337.313        513.257
#          actual        324.585        8.51336        319.399        337.313
#      note: 'measured' phi reported above includes
#            realizations of measurement noise,
#            'actual' phi does not.
#
#   ---  running remaining realizations for best lambda, scale:7.5 , 1 ,   ---
#     running model 16 times
#     starting at 01/27/26 15:31:53
#     6 agents ready
#
#
# PANTHER progress
#    avg = average model run time in minutes
#    runs(C = completed | F = failed | T = timed out)
#    agents(R = running | W = waiting | U = unavailable)
# --------------------------------------------------------------------------------
# 01/27 15:31:54 mn:0     runs(C0    |F0    |T0    ) agents(R6   |W0   |U0   ) 0
# 01/27 15:31:55 mn:0     runs(C0    |F0    |T0    ) agents(R6   |W0   |U0   ) 0
# 01/27 15:31:56 mn:0     runs(C0    |F0    |T0    ) agents(R6   |W0   |U0   ) 0
# 01/27 15:31:57 mn:0.052 runs(C6    |F0    |T0    ) agents(R6   |W0   |U0   ) 0
# 01/27 15:31:58 mn:0.052 runs(C6    |F0    |T0    ) agents(R6   |W0   |U0   ) 0
# 01/27 15:31:59 mn:0.052 runs(C6    |F0    |T0    ) agents(R6   |W0   |U0   ) 0
# 01/27 15:32:00 mn:0.053 runs(C12   |F0    |T0    ) agents(R4   |W2   |U0   ) 0
# 01/27 15:32:01 mn:0.053 runs(C12   |F0    |T0    ) agents(R4   |W2   |U0   ) 0
# 01/27 15:32:02 mn:0.053 runs(C12   |F0    |T0    ) agents(R4   |W2   |U0   ) 0
# 01/27 15:32:03 remaining file transfers: 0
#
#    16 runs complete :  0 runs failed
#    0.0529 avg run time (min) : 0.16 run mgr time (min)
#    6 agents connected
# ...phi summary for entire ensemble using lambda,scale_fac 7.5 , 1 ,
#        phi type           mean            std            min            max
#        measured        510.432        49.2463        337.313        567.583
#          actual         338.03        15.8162        306.625        361.722
#      note: 'measured' phi reported above includes
#            realizations of measurement noise,
#            'actual' phi does not.
# ...last best mean phi * acceptable phi factor:  657.799
# ...current best mean phi:  510.432
#
#   ---  updating parameter ensemble  ---
#
#   ---  updating lambda to  5.625  ---
#
#   ---  EnsembleMethod iteration 2 report  ---
#    number of active realizations:   20
#    number of model runs:            124
#       current obs ensemble saved to 3_Crane.2.obs.csv
#       current par ensemble saved to 3_Crane.2.par.csv
# saved par and rei files for realization BASE for iteration 2
# saved par and rei files for realization BASE
#        phi type           mean            std            min            max
#        measured        510.432        49.2463        337.313        567.583
#          actual         338.03        15.8162        306.625        361.722
#      note: 'measured' phi reported above includes
#            realizations of measurement noise,
#            'actual' phi does not.
#   ---  observation group phi summary ---
#        (computed using 'actual' phi)
#            (sorted by mean phi)
# group                               count  nconflict      mean       std       min       max   percent       std
# oname:obs/obs_etf_s2.np_otype:arr     508         46       337      15.7       306       360      99.7    0.0753
# oname:obs/obs_swe_s2.np_otype:arr    1178        232     0.897     0.265     0.554      1.48     0.265    0.0753
#
#
#    ---  parameter group change summary  ---
# group     count  mean chg  std chg  n at ubnd  % at ubnd  n at lbnd  % at lbnd  n std decr
# mad           1     4.711     42.2          0          0          7         35           0
# swe_beta      1    0.3942    1.196          0          0          0          0           0
# swe_alpha     1     11.23     20.3          0          0          0          0           0
# ndvi_k        1     16.39    32.81          0          0          0          0           0
# ndvi_0        1     71.62    92.92          0          0          0          0           0
# ks_alpha      1     38.67    35.74          0          0          0          0           0
# kr_alpha      1     6.685    46.93          0          0          0          0           0
# aw            1     9.088     39.9          0          0          0          0           0
#
# ...saved parameter change summary to 3_Crane.2.pcs.csv
#
#   ---  phi-based termination criteria check  ---
# ...phiredstp:  0.01
# ...nphistp:  3
# ...nphinored (also used for consecutive bad lambda cycles):  3
# ...best mean phi sequence: 1767.75 , 626.475 , 510.432 ,
# ...best phi yet:  510.432
# ...number of consecutive bad lambda testing cycles:  0
# ...number of iterations satisfying phiredstp criteria:  1
# ...number of iterations since best yet mean phi:  0
#
#   ---  starting solve for iteration: 3  ---
# ...current lambda:  5.625
# ...preparing fast-lookup containers for threaded localization solve
# ...starting calcs for glm factor 0.5625
# ...finished calcs for: 0.5625
# ...starting calcs for glm factor 5.625
# ...finished calcs for: 5.625
# ...starting calcs for glm factor 56.25
# ...finished calcs for: 56.25
#
#   ---  running upgrade ensembles  ---
# ...subset idx:pe real name:  0:BASE, 4:9, 9:3, 17:14,
# ...subset idx:oe real name:  0:BASE, 4:9, 9:3, 17:14,
#     running model 36 times
#     starting at 01/27/26 15:32:05
#     6 agents ready
#
#
# PANTHER progress
#    avg = average model run time in minutes
#    runs(C = completed | F = failed | T = timed out)
#    agents(R = running | W = waiting | U = unavailable)
# --------------------------------------------------------------------------------
# 01/27 15:32:06 mn:0     runs(C0    |F0    |T0    ) agents(R6   |W0   |U0   ) 0
# 01/27 15:32:07 mn:0     runs(C0    |F0    |T0    ) agents(R6   |W0   |U0   ) 0
# 01/27 15:32:08 mn:0     runs(C0    |F0    |T0    ) agents(R6   |W0   |U0   ) 0
# 01/27 15:32:09 mn:0.053 runs(C6    |F0    |T0    ) agents(R6   |W0   |U0   ) 0
# 01/27 15:32:10 mn:0.053 runs(C6    |F0    |T0    ) agents(R6   |W0   |U0   ) 0
# 01/27 15:32:11 mn:0.053 runs(C6    |F0    |T0    ) agents(R6   |W0   |U0   ) 0
# 01/27 15:32:12 mn:0.054 runs(C12   |F0    |T0    ) agents(R6   |W0   |U0   ) 0
# 01/27 15:32:13 mn:0.054 runs(C12   |F0    |T0    ) agents(R6   |W0   |U0   ) 0
# 01/27 15:32:14 mn:0.054 runs(C12   |F0    |T0    ) agents(R6   |W0   |U0   ) 0
# 01/27 15:32:15 mn:0.054 runs(C18   |F0    |T0    ) agents(R6   |W0   |U0   ) 0
# 01/27 15:32:16 mn:0.054 runs(C18   |F0    |T0    ) agents(R6   |W0   |U0   ) 0
# 01/27 15:32:17 mn:0.054 runs(C18   |F0    |T0    ) agents(R6   |W0   |U0   ) 0
# 01/27 15:32:18 mn:0.054 runs(C18   |F0    |T0    ) agents(R6   |W0   |U0   ) 0
# 01/27 15:32:19 mn:0.056 runs(C24   |F0    |T0    ) agents(R6   |W0   |U0   ) 0
# 01/27 15:32:20 mn:0.056 runs(C24   |F0    |T0    ) agents(R6   |W0   |U0   ) 0
# 01/27 15:32:21 mn:0.056 runs(C24   |F0    |T0    ) agents(R6   |W0   |U0   ) 0
# 01/27 15:32:22 mn:0.055 runs(C30   |F0    |T0    ) agents(R6   |W0   |U0   ) 0
# 01/27 15:32:23 mn:0.055 runs(C30   |F0    |T0    ) agents(R6   |W0   |U0   ) 0
# 01/27 15:32:24 mn:0.055 runs(C30   |F0    |T0    ) agents(R6   |W0   |U0   ) 0
# 01/27 15:32:25 remaining file transfers: 0
#
#    36 runs complete :  0 runs failed
#    0.0542 avg run time (min) : 0.332 run mgr time (min)
#    6 agents connected
#   ---  evaluating upgrade ensembles  ---
# ...last mean:  510.432
# ...last stdev:  49.2463
#   ---  phi summary for best lambda, scale fac: 0.5625 , 1.1 ,   ---
#        phi type           mean            std            min            max
#        measured        457.098        100.612        306.694        518.931
#          actual        308.301        4.01037        305.625        314.272
#      note: 'measured' phi reported above includes
#            realizations of measurement noise,
#            'actual' phi does not.
#
#   ---  running remaining realizations for best lambda, scale:0.5625 , 1.1 ,   ---
#     running model 16 times
#     starting at 01/27/26 15:32:26
#     6 agents ready
#
#
# PANTHER progress
#    avg = average model run time in minutes
#    runs(C = completed | F = failed | T = timed out)
#    agents(R = running | W = waiting | U = unavailable)
# --------------------------------------------------------------------------------
# 01/27 15:32:27 mn:0     runs(C0    |F0    |T0    ) agents(R6   |W0   |U0   ) 0
# 01/27 15:32:28 mn:0     runs(C0    |F0    |T0    ) agents(R6   |W0   |U0   ) 0
# 01/27 15:32:29 mn:0.049 runs(C1    |F0    |T0    ) agents(R6   |W0   |U0   ) 0
# 01/27 15:32:30 mn:0.051 runs(C6    |F0    |T0    ) agents(R6   |W0   |U0   ) 0
# 01/27 15:32:31 mn:0.051 runs(C6    |F0    |T0    ) agents(R6   |W0   |U0   ) 0
# 01/27 15:32:32 mn:0.051 runs(C6    |F0    |T0    ) agents(R6   |W0   |U0   ) 0
# 01/27 15:32:33 mn:0.053 runs(C12   |F0    |T0    ) agents(R4   |W2   |U0   ) 0
# 01/27 15:32:34 mn:0.053 runs(C12   |F0    |T0    ) agents(R4   |W2   |U0   ) 0
# 01/27 15:32:35 mn:0.053 runs(C12   |F0    |T0    ) agents(R4   |W2   |U0   ) 0
# 01/27 15:32:35 remaining file transfers: 0
#
#    16 runs complete :  0 runs failed
#    0.0533 avg run time (min) : 0.16 run mgr time (min)
#    6 agents connected
# ...phi summary for entire ensemble using lambda,scale_fac 0.5625 , 1.1 ,
#        phi type           mean            std            min            max
#        measured        480.843        44.4524        306.694        518.931
#          actual        308.318        4.21049        296.991        314.987
#      note: 'measured' phi reported above includes
#            realizations of measurement noise,
#            'actual' phi does not.
# ...last best mean phi * acceptable phi factor:  535.954
# ...current best mean phi:  480.843
#
#   ---  updating parameter ensemble  ---
#
#   ---  updating lambda to  0.421875  ---
#
#   ---  EnsembleMethod iteration 3 report  ---
#    number of active realizations:   20
#    number of model runs:            176
#       current obs ensemble saved to 3_Crane.3.obs.csv
#       current par ensemble saved to 3_Crane.3.par.csv
# saved par and rei files for realization BASE for iteration 3
# saved par and rei files for realization BASE
#        phi type           mean            std            min            max
#        measured        480.843        44.4524        306.694        518.931
#          actual        308.318        4.21049        296.991        314.987
#      note: 'measured' phi reported above includes
#            realizations of measurement noise,
#            'actual' phi does not.
#   ---  observation group phi summary ---
#        (computed using 'actual' phi)
#            (sorted by mean phi)
# group                               count  nconflict      mean       std       min       max   percent       std
# oname:obs/obs_etf_s2.np_otype:arr     508         59       307       4.1       296       314      99.7    0.0837
# oname:obs/obs_swe_s2.np_otype:arr    1178        252     0.858     0.264     0.557      1.45     0.278    0.0837
#
#
#    ---  parameter group change summary  ---
# group     count  mean chg  std chg  n at ubnd  % at ubnd  n at lbnd  % at lbnd  n std decr
# mad           1     7.987    54.51          0          0         12         60           0
# swe_beta      1     3.504     2.31          0          0          0          0           0
# swe_alpha     1     2.134    25.94          0          0          0          0           0
# ndvi_k        1    0.6576    79.48          0          0          0          0           0
# ndvi_0        1     78.22    98.21          0          0          0          0           1
# ks_alpha      1     10.64    44.67          0          0          0          0           0
# kr_alpha      1     32.19    70.44          0          0          0          0           0
# aw            1     15.38    53.42          0          0          0          0           0
#
# ...saved parameter change summary to 3_Crane.3.pcs.csv
#
#   ---  phi-based termination criteria check  ---
# ...phiredstp:  0.01
# ...nphistp:  3
# ...nphinored (also used for consecutive bad lambda cycles):  3
# ...best mean phi sequence: 1767.75 , 626.475 , 510.432 , 480.843 ,
# ...best phi yet:  480.843
# ...number of consecutive bad lambda testing cycles:  0
# ...number of iterations satisfying phiredstp criteria:  1
# ...number of iterations since best yet mean phi:  0
# ...solution iterations >= noptmax, all done
#
#
# pestpp-ies analysis complete...
# started at 01/27/26 15:30:42
# finished at 01/27/26 15:32:37
# took 1.9 minutes

# %% [markdown]
# ## Debugging Tips
#
# If calibration fails, try these steps:
#
# ### Never saw the PEST++ panther logo?
# - Verify installation: `which pestpp-ies` (Linux/Mac) or `where pestpp-ies` (Windows)
# - If not found, reinstall: `conda install conda-forge::pestpp`
# - Ensure your conda environment is activated
#
# ### Python error traceback?
# Debug from the bottom up:
# 1. Verify `swimrs/calibrate/run_mp.py` runs standalone
# 2. Test `custom_forward_run.py` from the pest directory
# 3. Try running `pestpp-ies` directly from pest directory
#
# ### Saw panther but got errors?
# Common error: `output file 'pred/pred_swe_S2.np' not found`
# - This usually means SWIM failed before writing predictions
# - Set `cleanup=False` above to preserve worker directories
# - Check `workers/worker_0/panther_worker.rec` for errors
#
# **Most errors (90%) are due to incorrect paths!**

# %% [markdown]
# ## 6. Check Results
#
# After successful calibration, parameter files are saved for each optimization iteration:

# %%
# Parameter files are in master_dir after calibration
import os
import shutil

results_dir = builder.master_dir if os.path.exists(builder.master_dir) else builder.pest_dir

par_files = [f for f in sorted(os.listdir(results_dir)) if '.par.csv' in f]
print(f"Parameter files (in {results_dir}):")
for f in par_files:
    print(f"  {f}")

if par_files:
    final_par = par_files[-1]
    print(f"\nFinal calibrated parameters: {final_par}")
    
    # Copy final parameters to pest/archive/ for consistency with calibration.py script
    archive_dir = os.path.join(builder.pest_dir, 'archive')
    os.makedirs(archive_dir, exist_ok=True)
    src = os.path.join(results_dir, final_par)
    dst = os.path.join(archive_dir, final_par)
    shutil.copy2(src, dst)
    print(f"Archived to: {dst}")

# Close the container
container.close()
print("\nContainer closed.")
# Out:
# Parameter files (in /home/dgketchum/code/swim-rs/examples/3_Crane/data/pestrun/master):
#   3_Crane.0.par.csv
#   3_Crane.1.par.csv
#   3_Crane.2.par.csv
#   3_Crane.3.par.csv
#
# Final calibrated parameters: 3_Crane.3.par.csv
# Archived to: /home/dgketchum/code/swim-rs/examples/3_Crane/data/pestrun/pest/archive/3_Crane.3.par.csv
#
# Container closed.

# %% [markdown]
# ## Summary
#
# You've set up and run a PEST++ calibration using:
# - SSEBop ETf observations from Landsat
# - SNODAS SWE observations
# - Iterative Ensemble Smoother (pestpp-ies)
#
# The parameter files (e.g., `3_Crane.3.par.csv`) contain the calibrated parameter sets.
#
# **Next step:** In notebook `03_calibrated_model.ipynb`, we'll run the model in forecast mode with calibrated parameters and evaluate the improvement.
