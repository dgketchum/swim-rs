# %% [markdown]
# # More Earth Engine: Irrigation, Snow, and Soils Data Extraction
#
# In this notebook, we will:
# 1. Use the `sample_snodas_swe` function to perform snodas snow water equivalent (SWE) extraction.
# 2. Use the `get_irrigation` function to perform irrigation mask extraction.
# 3. Use the `get_ssurgo` function to perform soils extraction.
#
# Ensure that the Earth Engine Python API is authenticated and configured, and that the Earth Engine CLI is available in your environment.

# %% [markdown]
# ## 1. Import Libraries and Authorize Earth Engine

# %%
import os
import sys
import ee


root = os.path.abspath('../../..')
sys.path.append(root)

from data_extraction.ee.snodas_export import sample_snodas_swe
from data_extraction.snodas.snodas import create_timeseries_json
from data_extraction.ee.ee_props import get_irrigation, get_ssurgo
from data_extraction.ee.ee_utils import is_authorized
from utils.google_bucket import list_and_copy_gcs_bucket

sys.path.insert(0, os.path.abspath('../../..'))
sys.setrecursionlimit(5000)

if not is_authorized():
    ee.Authenticate()
ee.Initialize()

# %% [markdown]
# ## 1: Extract Raster Data
#
# Here, we're going to use functions with a similar workflow to those we used to get ETf and NDVI data from Earth Engine.
#
# For the raster data extraction, there are three functions we need to run:
#
# *   **`sample_snodas_swe`**:
#     *   This function iterates over the daily SNODAS images in Earth Engine, extracting mean SWE for each sample plot for each day, September through May.
#     *   https://nsidc.org/data/g02158/versions/1
#     *   We will follow up and write the SNODAS data to per-field files with `snodas_processing`.
# *   **`get_irrigation`**:
#     *   This function uses IrrMapper to get statistics about the irrigation status of each plot for each year, including the fraction of the plot that was irrigated.
#     *   https://www.mdpi.com/2072-4292/12/14/2328
# *   **`get_ssurgo`**:
#     *   This function uses data summarized and put in a public Earth Engine asset by Charles Morton at Desert Research Institute from SSURGO (https://www.nrcs.usda.gov/resources/data-and-reports/soil-survey-geographic-database-ssurgo) to summarize plot-scale soil texture and hydraulic properties used by SWIM-RS.
#
# Note: The module carrying `get_irrigation` and `get_ssurgo` also has functions for extracting vegetation height (useful for modeling natural/perennial vegetated sample plots; `get_landfire`), and for crop type (useful for sampling management scenarios; `get_cdl`). These have the same function call argruments and the same output format as with `get_irrigation` or `get_ssurgo`.

# %%
ee_account = 'ee-dgketchum'

# Define Constants and Remote Sensing Data Paths
# TODO: remove hard-coded collecitons and use variables defined here
SWE = 'projects/earthengine-legacy/assets/projects/climate-engine/snodas/daily'

bucket = 'wudr'
fields = 'projects/ee-dgketchum/assets/swim/mt_sid_boulder'

command = '/home/dgketchum/google-cloud-sdk/bin/gsutil'

# We must specify which column in the shapefile represents the field's unique ID, in this case it is 'FID_1'
FEATURE_ID = 'FID_1'

# %% [markdown]
# ### SWE Data
#
# Notes
# - Ensure that your Cloud Storage bucket has the correct permissions for Earth Engine to write to it.
# - This will produce a monthly dataset for Sep - May, regardless of SWE status at the sample plots.

# %%
# let's send all the data we get to our tutorial directories
snow_dst = os.path.join(root, 'tutorials', '1_Boulder', 'data', 'snodas', 'extracts')
if not os.path.isdir(snow_dst):
    os.makedirs(snow_dst, exist_ok=True)

# %%
# Here, we run the sample_snodas_swe function on the uploaded asset.
# Note we use 'check_dir' to check if it's already written to the directory, and 'overwrite=False' so we don't write it again if it is.
sample_snodas_swe(fields, bucket, debug=False, check_dir=snow_dst, overwrite=False, feature_id=FEATURE_ID)

# %% [markdown]
# Copy the data to the local machine once the processing is complete, as with the remote sensing data.

# %%
glob_ = 'swe'
list_and_copy_gcs_bucket(command, bucket, snow_dst, glob=glob_, dry_run=False, overwrite=False)
# Out:
# Copying gs://wudr/swe_2004_01.csv: Copying gs://wudr/swe_2004_01.csv...
# / [1 files][ 49.9 KiB/ 49.9 KiB]
# Operation completed over 1 objects/49.9 KiB.
#
# Copied gs://wudr/swe_2004_01.csv to /home/dgketchum/PycharmProjects/swim-rs/tutorial/step_2_earth_engine_extract/snodas/extracts
# Copying gs://wudr/swe_2004_02.csv: Copying gs://wudr/swe_2004_02.csv...
# / [1 files][ 41.5 KiB/ 41.5 KiB]
# Operation completed over 1 objects/41.5 KiB.
#
# Copied gs://wudr/swe_2004_02.csv to /home/dgketchum/PycharmProjects/swim-rs/tutorial/step_2_earth_engine_extract/snodas/extracts
# Copying gs://wudr/swe_2004_03.csv: Copying gs://wudr/swe_2004_03.csv...
# / [1 files][ 14.9 KiB/ 14.9 KiB]
# Operation completed over 1 objects/14.9 KiB.
#
# Copied gs://wudr/swe_2004_03.csv to /home/dgketchum/PycharmProjects/swim-rs/tutorial/step_2_earth_engine_extract/snodas/extracts
# Copying gs://wudr/swe_2004_04.csv: Copying gs://wudr/swe_2004_04.csv...
# / [1 files][ 10.2 KiB/ 10.2 KiB]
# Operation completed over 1 objects/10.2 KiB.
#
# Copied gs://wudr/swe_2004_04.csv to /home/dgketchum/PycharmProjects/swim-rs/tutorial/step_2_earth_engine_extract/snodas/extracts
# Copying gs://wudr/swe_2004_05.csv: Copying gs://wudr/swe_2004_05.csv...
# / [1 files][ 10.6 KiB/ 10.6 KiB]
# Operation completed over 1 objects/10.6 KiB.
#
# Copied gs://wudr/swe_2004_05.csv to /home/dgketchum/PycharmProjects/swim-rs/tutorial/step_2_earth_engine_extract/snodas/extracts
# Copying gs://wudr/swe_2004_06.csv: Copying gs://wudr/swe_2004_06.csv...
# / [1 files][ 10.2 KiB/ 10.2 KiB]
# Operation completed over 1 objects/10.2 KiB.
#
# Copied gs://wudr/swe_2004_06.csv to /home/dgketchum/PycharmProjects/swim-rs/tutorial/step_2_earth_engine_extract/snodas/extracts
# Copying gs://wudr/swe_2004_07.csv: Copying gs://wudr/swe_2004_07.csv...
# / [1 files][ 10.6 KiB/ 10.6 KiB]
# Operation completed over 1 objects/10.6 KiB.
#
# Copied gs://wudr/swe_2004_07.csv to /home/dgketchum/PycharmProjects/swim-rs/tutorial/step_2_earth_engine_extract/snodas/extracts
# Copying gs://wudr/swe_2004_08.csv: Copying gs://wudr/swe_2004_08.csv...
# / [1 files][ 10.2 KiB/ 10.2 KiB]
# Operation completed over 1 objects/10.2 KiB.
#
# Copied gs://wudr/swe_2004_08.csv to /home/dgketchum/PycharmProjects/swim-rs/tutorial/step_2_earth_engine_extract/snodas/extracts
# Copying gs://wudr/swe_2004_09.csv: Copying gs://wudr/swe_2004_09.csv...
# / [1 files][  9.9 KiB/  9.9 KiB]
# Operation completed over 1 objects/9.9 KiB.
#
# Copied gs://wudr/swe_2004_09.csv to /home/dgketchum/PycharmProjects/swim-rs/tutorial/step_2_earth_engine_extract/snodas/extracts
# Copying gs://wudr/swe_2004_10.csv: Copying gs://wudr/swe_2004_10.csv...
# / [1 files][ 10.6 KiB/ 10.6 KiB]
# Operation completed over 1 objects/10.6 KiB.
#
# Copied gs://wudr/swe_2004_10.csv to /home/dgketchum/PycharmProjects/swim-rs/tutorial/step_2_earth_engine_extract/snodas/extracts
# Copying gs://wudr/swe_2004_11.csv: Copying gs://wudr/swe_2004_11.csv...
# / [1 files][ 12.3 KiB/ 12.3 KiB]
# Operation completed over 1 objects/12.3 KiB.
#
# Copied gs://wudr/swe_2004_11.csv to /home/dgketchum/PycharmProjects/swim-rs/tutorial/step_2_earth_engine_extract/snodas/extracts
# Copying gs://wudr/swe_2004_12.csv: Copying gs://wudr/swe_2004_12.csv...
# / [1 files][ 14.9 KiB/ 14.9 KiB]
# Operation completed over 1 objects/14.9 KiB.
#
# Copied gs://wudr/swe_2004_12.csv to /home/dgketchum/PycharmProjects/swim-rs/tutorial/step_2_earth_engine_extract/snodas/extracts
# Copying gs://wudr/swe_2005_01.csv: Copying gs://wudr/swe_2005_01.csv...
# / [1 files][ 34.8 KiB/ 34.8 KiB]
# Operation completed over 1 objects/34.8 KiB.
#
# Copied gs://wudr/swe_2005_01.csv to /home/dgketchum/PycharmProjects/swim-rs/tutorial/step_2_earth_engine_extract/snodas/extracts
# Copying gs://wudr/swe_2005_02.csv: Copying gs://wudr/swe_2005_02.csv...
# / [1 files][  9.6 KiB/  9.6 KiB]
# Operation completed over 1 objects/9.6 KiB.
#
# Copied gs://wudr/swe_2005_02.csv to /home/dgketchum/PycharmProjects/swim-rs/tutorial/step_2_earth_engine_extract/snodas/extracts
# Copying gs://wudr/swe_2005_03.csv: Copying gs://wudr/swe_2005_03.csv...
# / [1 files][ 19.0 KiB/ 19.0 KiB]
# Operation completed over 1 objects/19.0 KiB.
#
# Copied gs://wudr/swe_2005_03.csv to /home/dgketchum/PycharmProjects/swim-rs/tutorial/step_2_earth_engine_extract/snodas/extracts
# Copying gs://wudr/swe_2005_04.csv: Copying gs://wudr/swe_2005_04.csv...
# / [1 files][ 12.7 KiB/ 12.7 KiB]
# Operation completed over 1 objects/12.7 KiB.
#
# Copied gs://wudr/swe_2005_04.csv to /home/dgketchum/PycharmProjects/swim-rs/tutorial/step_2_earth_engine_extract/snodas/extracts
# Copying gs://wudr/swe_2005_05.csv: Copying gs://wudr/swe_2005_05.csv...
# / [1 files][ 10.6 KiB/ 10.6 KiB]
# Operation completed over 1 objects/10.6 KiB.
#
# Copied gs://wudr/swe_2005_05.csv to /home/dgketchum/PycharmProjects/swim-rs/tutorial/step_2_earth_engine_extract/snodas/extracts
# Copying gs://wudr/swe_2005_06.csv: Copying gs://wudr/swe_2005_06.csv...
# / [1 files][  9.9 KiB/  9.9 KiB]
# Operation completed over 1 objects/9.9 KiB.
#
# Copied gs://wudr/swe_2005_06.csv to /home/dgketchum/PycharmProjects/swim-rs/tutorial/step_2_earth_engine_extract/snodas/extracts
# Copying gs://wudr/swe_2005_07.csv: Copying gs://wudr/swe_2005_07.csv...
# / [1 files][ 10.6 KiB/ 10.6 KiB]
# Operation completed over 1 objects/10.6 KiB.
#
# Copied gs://wudr/swe_2005_07.csv to /home/dgketchum/PycharmProjects/swim-rs/tutorial/step_2_earth_engine_extract/snodas/extracts
# Copying gs://wudr/swe_2005_08.csv: Copying gs://wudr/swe_2005_08.csv...
# / [1 files][  9.9 KiB/  9.9 KiB]
# Operation completed over 1 objects/9.9 KiB.
#
# Copied gs://wudr/swe_2005_08.csv to /home/dgketchum/PycharmProjects/swim-rs/tutorial/step_2_earth_engine_extract/snodas/extracts
# Copying gs://wudr/swe_2005_09.csv: Copying gs://wudr/swe_2005_09.csv...
# / [1 files][ 10.2 KiB/ 10.2 KiB]
# Operation completed over 1 objects/10.2 KiB.
#
# Copied gs://wudr/swe_2005_09.csv to /home/dgketchum/PycharmProjects/swim-rs/tutorial/step_2_earth_engine_extract/snodas/extracts
# Copying gs://wudr/swe_2005_10.csv: Copying gs://wudr/swe_2005_10.csv...
# / [1 files][ 10.6 KiB/ 10.6 KiB]
# Operation completed over 1 objects/10.6 KiB.
#
# Copied gs://wudr/swe_2005_10.csv to /home/dgketchum/PycharmProjects/swim-rs/tutorial/step_2_earth_engine_extract/snodas/extracts
# Copying gs://wudr/swe_2005_11.csv: Copying gs://wudr/swe_2005_11.csv...
# / [1 files][ 30.1 KiB/ 30.1 KiB]
# Operation completed over 1 objects/30.1 KiB.
#
# Copied gs://wudr/swe_2005_11.csv to /home/dgketchum/PycharmProjects/swim-rs/tutorial/step_2_earth_engine_extract/snodas/extracts
# Copying gs://wudr/swe_2005_12.csv: Copying gs://wudr/swe_2005_12.csv...
# / [1 files][ 31.1 KiB/ 31.1 KiB]
# Operation completed over 1 objects/31.1 KiB.
#
# Copied gs://wudr/swe_2005_12.csv to /home/dgketchum/PycharmProjects/swim-rs/tutorial/step_2_earth_engine_extract/snodas/extracts
# Copying gs://wudr/swe_2006_01.csv: Copying gs://wudr/swe_2006_01.csv...
# / [1 files][ 22.0 KiB/ 22.0 KiB]
# Operation completed over 1 objects/22.0 KiB.
#
# Copied gs://wudr/swe_2006_01.csv to /home/dgketchum/PycharmProjects/swim-rs/tutorial/step_2_earth_engine_extract/snodas/extracts
# Copying gs://wudr/swe_2006_02.csv: Copying gs://wudr/swe_2006_02.csv...
# / [1 files][ 15.7 KiB/ 15.7 KiB]
# Operation completed over 1 objects/15.7 KiB.
#
# Copied gs://wudr/swe_2006_02.csv to /home/dgketchum/PycharmProjects/swim-rs/tutorial/step_2_earth_engine_extract/snodas/extracts
# Copying gs://wudr/swe_2006_03.csv: Copying gs://wudr/swe_2006_03.csv...
# / [1 files][ 28.3 KiB/ 28.3 KiB]
# Operation completed over 1 objects/28.3 KiB.
#
# Copied gs://wudr/swe_2006_03.csv to /home/dgketchum/PycharmProjects/swim-rs/tutorial/step_2_earth_engine_extract/snodas/extracts
# Copying gs://wudr/swe_2006_04.csv: Copying gs://wudr/swe_2006_04.csv...
# / [1 files][ 15.5 KiB/ 15.5 KiB]
# Operation completed over 1 objects/15.5 KiB.
#
# Copied gs://wudr/swe_2006_04.csv to /home/dgketchum/PycharmProjects/swim-rs/tutorial/step_2_earth_engine_extract/snodas/extracts
# Copying gs://wudr/swe_2006_05.csv: Copying gs://wudr/swe_2006_05.csv...
# / [1 files][ 10.6 KiB/ 10.6 KiB]
# Operation completed over 1 objects/10.6 KiB.
#
# Copied gs://wudr/swe_2006_05.csv to /home/dgketchum/PycharmProjects/swim-rs/tutorial/step_2_earth_engine_extract/snodas/extracts
# Copying gs://wudr/swe_2006_06.csv: Copying gs://wudr/swe_2006_06.csv...
# / [1 files][ 10.2 KiB/ 10.2 KiB]
# Operation completed over 1 objects/10.2 KiB.
#
# Copied gs://wudr/swe_2006_06.csv to /home/dgketchum/PycharmProjects/swim-rs/tutorial/step_2_earth_engine_extract/snodas/extracts
# Copying gs://wudr/swe_2006_07.csv: Copying gs://wudr/swe_2006_07.csv...
# / [1 files][ 10.6 KiB/ 10.6 KiB]
# Operation completed over 1 objects/10.6 KiB.
#
# Copied gs://wudr/swe_2006_07.csv to /home/dgketchum/PycharmProjects/swim-rs/tutorial/step_2_earth_engine_extract/snodas/extracts
# Copying gs://wudr/swe_2006_08.csv: Copying gs://wudr/swe_2006_08.csv...
# / [1 files][  9.9 KiB/  9.9 KiB]
# Operation completed over 1 objects/9.9 KiB.
#
# Copied gs://wudr/swe_2006_08.csv to /home/dgketchum/PycharmProjects/swim-rs/tutorial/step_2_earth_engine_extract/snodas/extracts
# Copying gs://wudr/swe_2006_09.csv: Copying gs://wudr/swe_2006_09.csv...
# / [1 files][  9.6 KiB/  9.6 KiB]
# Operation completed over 1 objects/9.6 KiB.
#
# Copied gs://wudr/swe_2006_09.csv to /home/dgketchum/PycharmProjects/swim-rs/tutorial/step_2_earth_engine_extract/snodas/extracts
# Copying gs://wudr/swe_2006_10.csv: Copying gs://wudr/swe_2006_10.csv...
# / [1 files][ 18.2 KiB/ 18.2 KiB]
# Operation completed over 1 objects/18.2 KiB.
#
# Copied gs://wudr/swe_2006_10.csv to /home/dgketchum/PycharmProjects/swim-rs/tutorial/step_2_earth_engine_extract/snodas/extracts
# Copying gs://wudr/swe_2006_11.csv: Copying gs://wudr/swe_2006_11.csv...
# / [1 files][ 23.1 KiB/ 23.1 KiB]
# Operation completed over 1 objects/23.1 KiB.
#
# Copied gs://wudr/swe_2006_11.csv to /home/dgketchum/PycharmProjects/swim-rs/tutorial/step_2_earth_engine_extract/snodas/extracts
# Copying gs://wudr/swe_2006_12.csv: Copying gs://wudr/swe_2006_12.csv...
# / [1 files][ 38.6 KiB/ 38.6 KiB]
# Operation completed over 1 objects/38.6 KiB.
#
# Copied gs://wudr/swe_2006_12.csv to /home/dgketchum/PycharmProjects/swim-rs/tutorial/step_2_earth_engine_extract/snodas/extracts
# Copying gs://wudr/swe_2007_01.csv: Copying gs://wudr/swe_2007_01.csv...
# / [1 files][ 20.8 KiB/ 20.8 KiB]
# Operation completed over 1 objects/20.8 KiB.
#
# Copied gs://wudr/swe_2007_01.csv to /home/dgketchum/PycharmProjects/swim-rs/tutorial/step_2_earth_engine_extract/snodas/extracts
# Copying gs://wudr/swe_2007_02.csv: Copying gs://wudr/swe_2007_02.csv...
# / [1 files][ 28.7 KiB/ 28.7 KiB]
# Operation completed over 1 objects/28.7 KiB.
#
# Copied gs://wudr/swe_2007_02.csv to /home/dgketchum/PycharmProjects/swim-rs/tutorial/step_2_earth_engine_extract/snodas/extracts
# Copying gs://wudr/swe_2007_03.csv: Copying gs://wudr/swe_2007_03.csv...
# / [1 files][ 14.1 KiB/ 14.1 KiB]
# Operation completed over 1 objects/14.1 KiB.
#
# Copied gs://wudr/swe_2007_03.csv to /home/dgketchum/PycharmProjects/swim-rs/tutorial/step_2_earth_engine_extract/snodas/extracts
# Copying gs://wudr/swe_2007_04.csv: Copying gs://wudr/swe_2007_04.csv...
# / [1 files][ 12.0 KiB/ 12.0 KiB]
# Operation completed over 1 objects/12.0 KiB.
#
# Copied gs://wudr/swe_2007_04.csv to /home/dgketchum/PycharmProjects/swim-rs/tutorial/step_2_earth_engine_extract/snodas/extracts
# Copying gs://wudr/swe_2007_05.csv: Copying gs://wudr/swe_2007_05.csv...
# / [1 files][ 10.6 KiB/ 10.6 KiB]
# Operation completed over 1 objects/10.6 KiB.
#
# Copied gs://wudr/swe_2007_05.csv to /home/dgketchum/PycharmProjects/swim-rs/tutorial/step_2_earth_engine_extract/snodas/extracts
# Copying gs://wudr/swe_2007_06.csv: Copying gs://wudr/swe_2007_06.csv...
# / [1 files][ 10.2 KiB/ 10.2 KiB]
# Operation completed over 1 objects/10.2 KiB.
#
# Copied gs://wudr/swe_2007_06.csv to /home/dgketchum/PycharmProjects/swim-rs/tutorial/step_2_earth_engine_extract/snodas/extracts
# Copying gs://wudr/swe_2007_07.csv: Copying gs://wudr/swe_2007_07.csv...
# / [1 files][ 10.6 KiB/ 10.6 KiB]
# Operation completed over 1 objects/10.6 KiB.
#
# Copied gs://wudr/swe_2007_07.csv to /home/dgketchum/PycharmProjects/swim-rs/tutorial/step_2_earth_engine_extract/snodas/extracts
# Copying gs://wudr/swe_2007_08.csv: Copying gs://wudr/swe_2007_08.csv...
# / [1 files][ 10.6 KiB/ 10.6 KiB]
# Operation completed over 1 objects/10.6 KiB.
#
# Copied gs://wudr/swe_2007_08.csv to /home/dgketchum/PycharmProjects/swim-rs/tutorial/step_2_earth_engine_extract/snodas/extracts
# Copying gs://wudr/swe_2007_09.csv: Copying gs://wudr/swe_2007_09.csv...
# / [1 files][ 10.2 KiB/ 10.2 KiB]
# Operation completed over 1 objects/10.2 KiB.
#
# Copied gs://wudr/swe_2007_09.csv to /home/dgketchum/PycharmProjects/swim-rs/tutorial/step_2_earth_engine_extract/snodas/extracts
# Copying gs://wudr/swe_2007_10.csv: Copying gs://wudr/swe_2007_10.csv...
# / [1 files][ 11.7 KiB/ 11.7 KiB]
# Operation completed over 1 objects/11.7 KiB.
#
# Copied gs://wudr/swe_2007_10.csv to /home/dgketchum/PycharmProjects/swim-rs/tutorial/step_2_earth_engine_extract/snodas/extracts
# Copying gs://wudr/swe_2007_11.csv: Copying gs://wudr/swe_2007_11.csv...
# / [1 files][ 12.8 KiB/ 12.8 KiB]
# Operation completed over 1 objects/12.8 KiB.
#
# Copied gs://wudr/swe_2007_11.csv to /home/dgketchum/PycharmProjects/swim-rs/tutorial/step_2_earth_engine_extract/snodas/extracts
# Copying gs://wudr/swe_2007_12.csv: Copying gs://wudr/swe_2007_12.csv...
# / [1 files][ 15.1 KiB/ 15.1 KiB]
# Operation completed over 1 objects/15.1 KiB.
#
# Copied gs://wudr/swe_2007_12.csv to /home/dgketchum/PycharmProjects/swim-rs/tutorial/step_2_earth_engine_extract/snodas/extracts
# Copying gs://wudr/swe_2008_01.csv: Copying gs://wudr/swe_2008_01.csv...
# / [1 files][ 38.4 KiB/ 38.4 KiB]
# Operation completed over 1 objects/38.4 KiB.
#
# Copied gs://wudr/swe_2008_01.csv to /home/dgketchum/PycharmProjects/swim-rs/tutorial/step_2_earth_engine_extract/snodas/extracts
# Copying gs://wudr/swe_2008_02.csv: Copying gs://wudr/swe_2008_02.csv...
# / [1 files][ 25.4 KiB/ 25.4 KiB]
# Operation completed over 1 objects/25.4 KiB.
#
# Copied gs://wudr/swe_2008_02.csv to /home/dgketchum/PycharmProjects/swim-rs/tutorial/step_2_earth_engine_extract/snodas/extracts
# Copying gs://wudr/swe_2008_03.csv: Copying gs://wudr/swe_2008_03.csv...
# / [1 files][ 15.6 KiB/ 15.6 KiB]
# Operation completed over 1 objects/15.6 KiB.
#
# Copied gs://wudr/swe_2008_03.csv to /home/dgketchum/PycharmProjects/swim-rs/tutorial/step_2_earth_engine_extract/snodas/extracts
# Copying gs://wudr/swe_2008_04.csv: Copying gs://wudr/swe_2008_04.csv...
# / [1 files][ 18.9 KiB/ 18.9 KiB]
# Operation completed over 1 objects/18.9 KiB.
#
# Copied gs://wudr/swe_2008_04.csv to /home/dgketchum/PycharmProjects/swim-rs/tutorial/step_2_earth_engine_extract/snodas/extracts
# Copying gs://wudr/swe_2008_05.csv: Copying gs://wudr/swe_2008_05.csv...
# / [1 files][ 10.6 KiB/ 10.6 KiB]
# Operation completed over 1 objects/10.6 KiB.
#
# Copied gs://wudr/swe_2008_05.csv to /home/dgketchum/PycharmProjects/swim-rs/tutorial/step_2_earth_engine_extract/snodas/extracts
# Copying gs://wudr/swe_2008_06.csv: Copying gs://wudr/swe_2008_06.csv...
# / [1 files][  9.6 KiB/  9.6 KiB]
# Operation completed over 1 objects/9.6 KiB.
#
# Copied gs://wudr/swe_2008_06.csv to /home/dgketchum/PycharmProjects/swim-rs/tutorial/step_2_earth_engine_extract/snodas/extracts
# Copying gs://wudr/swe_2008_07.csv: Copying gs://wudr/swe_2008_07.csv...
# / [1 files][ 10.6 KiB/ 10.6 KiB]
# Operation completed over 1 objects/10.6 KiB.
#
# Copied gs://wudr/swe_2008_07.csv to /home/dgketchum/PycharmProjects/swim-rs/tutorial/step_2_earth_engine_extract/snodas/extracts
# Copying gs://wudr/swe_2008_08.csv: Copying gs://wudr/swe_2008_08.csv...
# / [1 files][ 10.6 KiB/ 10.6 KiB]
# Operation completed over 1 objects/10.6 KiB.
#
# Copied gs://wudr/swe_2008_08.csv to /home/dgketchum/PycharmProjects/swim-rs/tutorial/step_2_earth_engine_extract/snodas/extracts
# Copying gs://wudr/swe_2008_09.csv: Copying gs://wudr/swe_2008_09.csv...
# / [1 files][ 10.2 KiB/ 10.2 KiB]
# Operation completed over 1 objects/10.2 KiB.
#
# Copied gs://wudr/swe_2008_09.csv to /home/dgketchum/PycharmProjects/swim-rs/tutorial/step_2_earth_engine_extract/snodas/extracts
# Copying gs://wudr/swe_2008_10.csv: Copying gs://wudr/swe_2008_10.csv...
# / [1 files][ 19.0 KiB/ 19.0 KiB]
# Operation completed over 1 objects/19.0 KiB.
#
# Copied gs://wudr/swe_2008_10.csv to /home/dgketchum/PycharmProjects/swim-rs/tutorial/step_2_earth_engine_extract/snodas/extracts
# Copying gs://wudr/swe_2008_11.csv: Copying gs://wudr/swe_2008_11.csv...
# / [1 files][ 10.2 KiB/ 10.2 KiB]
# Operation completed over 1 objects/10.2 KiB.
#
# Copied gs://wudr/swe_2008_11.csv to /home/dgketchum/PycharmProjects/swim-rs/tutorial/step_2_earth_engine_extract/snodas/extracts
# Copying gs://wudr/swe_2008_12.csv: Copying gs://wudr/swe_2008_12.csv...
# / [1 files][ 36.8 KiB/ 36.8 KiB]
# Operation completed over 1 objects/36.8 KiB.
#
# Copied gs://wudr/swe_2008_12.csv to /home/dgketchum/PycharmProjects/swim-rs/tutorial/step_2_earth_engine_extract/snodas/extracts
# Copying gs://wudr/swe_2009_01.csv: Copying gs://wudr/swe_2009_01.csv...
# / [1 files][ 35.0 KiB/ 35.0 KiB]
# Operation completed over 1 objects/35.0 KiB.
#
# Copied gs://wudr/swe_2009_01.csv to /home/dgketchum/PycharmProjects/swim-rs/tutorial/step_2_earth_engine_extract/snodas/extracts
# Copying gs://wudr/swe_2009_02.csv: Copying gs://wudr/swe_2009_02.csv...
# / [1 files][ 12.2 KiB/ 12.2 KiB]
# Operation completed over 1 objects/12.2 KiB.
#
# Copied gs://wudr/swe_2009_02.csv to /home/dgketchum/PycharmProjects/swim-rs/tutorial/step_2_earth_engine_extract/snodas/extracts
# Copying gs://wudr/swe_2009_03.csv: Copying gs://wudr/swe_2009_03.csv...
# / [1 files][ 30.1 KiB/ 30.1 KiB]
# Operation completed over 1 objects/30.1 KiB.
#
# Copied gs://wudr/swe_2009_03.csv to /home/dgketchum/PycharmProjects/swim-rs/tutorial/step_2_earth_engine_extract/snodas/extracts
# Copying gs://wudr/swe_2009_04.csv: Copying gs://wudr/swe_2009_04.csv...
# / [1 files][ 28.1 KiB/ 28.1 KiB]
# Operation completed over 1 objects/28.1 KiB.
#
# Copied gs://wudr/swe_2009_04.csv to /home/dgketchum/PycharmProjects/swim-rs/tutorial/step_2_earth_engine_extract/snodas/extracts
# Copying gs://wudr/swe_2009_05.csv: Copying gs://wudr/swe_2009_05.csv...
# / [1 files][ 12.4 KiB/ 12.4 KiB]
# Operation completed over 1 objects/12.4 KiB.
#
# Copied gs://wudr/swe_2009_05.csv to /home/dgketchum/PycharmProjects/swim-rs/tutorial/step_2_earth_engine_extract/snodas/extracts
# Copying gs://wudr/swe_2009_06.csv: Copying gs://wudr/swe_2009_06.csv...
# / [1 files][ 10.2 KiB/ 10.2 KiB]
# Operation completed over 1 objects/10.2 KiB.
#
# Copied gs://wudr/swe_2009_06.csv to /home/dgketchum/PycharmProjects/swim-rs/tutorial/step_2_earth_engine_extract/snodas/extracts
# Copying gs://wudr/swe_2009_07.csv: Copying gs://wudr/swe_2009_07.csv...
# / [1 files][ 10.6 KiB/ 10.6 KiB]
# Operation completed over 1 objects/10.6 KiB.
#
# Copied gs://wudr/swe_2009_07.csv to /home/dgketchum/PycharmProjects/swim-rs/tutorial/step_2_earth_engine_extract/snodas/extracts
# Copying gs://wudr/swe_2009_08.csv: Copying gs://wudr/swe_2009_08.csv...
# / [1 files][ 10.2 KiB/ 10.2 KiB]
# Operation completed over 1 objects/10.2 KiB.
#
# Copied gs://wudr/swe_2009_08.csv to /home/dgketchum/PycharmProjects/swim-rs/tutorial/step_2_earth_engine_extract/snodas/extracts
# Copying gs://wudr/swe_2009_09.csv: Copying gs://wudr/swe_2009_09.csv...
# / [1 files][ 10.2 KiB/ 10.2 KiB]
# Operation completed over 1 objects/10.2 KiB.
#
# Copied gs://wudr/swe_2009_09.csv to /home/dgketchum/PycharmProjects/swim-rs/tutorial/step_2_earth_engine_extract/snodas/extracts
# Copying gs://wudr/swe_2009_10.csv: Copying gs://wudr/swe_2009_10.csv...
# / [1 files][ 23.5 KiB/ 23.5 KiB]
# Operation completed over 1 objects/23.5 KiB.
#
# Copied gs://wudr/swe_2009_10.csv to /home/dgketchum/PycharmProjects/swim-rs/tutorial/step_2_earth_engine_extract/snodas/extracts
# Copying gs://wudr/swe_2009_11.csv: Copying gs://wudr/swe_2009_11.csv...
# / [1 files][ 24.2 KiB/ 24.2 KiB]
# Operation completed over 1 objects/24.2 KiB.
#
# Copied gs://wudr/swe_2009_11.csv to /home/dgketchum/PycharmProjects/swim-rs/tutorial/step_2_earth_engine_extract/snodas/extracts
# Copying gs://wudr/swe_2009_12.csv: Copying gs://wudr/swe_2009_12.csv...
# / [1 files][ 49.0 KiB/ 49.0 KiB]
# Operation completed over 1 objects/49.0 KiB.
#
# Copied gs://wudr/swe_2009_12.csv to /home/dgketchum/PycharmProjects/swim-rs/tutorial/step_2_earth_engine_extract/snodas/extracts
# Copying gs://wudr/swe_2010_01.csv: Copying gs://wudr/swe_2010_01.csv...
# / [1 files][ 48.8 KiB/ 48.8 KiB]
# Operation completed over 1 objects/48.8 KiB.
#
# Copied gs://wudr/swe_2010_01.csv to /home/dgketchum/PycharmProjects/swim-rs/tutorial/step_2_earth_engine_extract/snodas/extracts
# Copying gs://wudr/swe_2010_02.csv: Copying gs://wudr/swe_2010_02.csv...
# / [1 files][ 42.6 KiB/ 42.6 KiB]
# Operation completed over 1 objects/42.6 KiB.
#
# Copied gs://wudr/swe_2010_02.csv to /home/dgketchum/PycharmProjects/swim-rs/tutorial/step_2_earth_engine_extract/snodas/extracts
# Copying gs://wudr/swe_2010_03.csv: Copying gs://wudr/swe_2010_03.csv...
# / [1 files][ 18.1 KiB/ 18.1 KiB]
# Operation completed over 1 objects/18.1 KiB.
#
# Copied gs://wudr/swe_2010_03.csv to /home/dgketchum/PycharmProjects/swim-rs/tutorial/step_2_earth_engine_extract/snodas/extracts
# Copying gs://wudr/swe_2010_04.csv: Copying gs://wudr/swe_2010_04.csv...
# / [1 files][ 13.7 KiB/ 13.7 KiB]
# Operation completed over 1 objects/13.7 KiB.
#
# Copied gs://wudr/swe_2010_04.csv to /home/dgketchum/PycharmProjects/swim-rs/tutorial/step_2_earth_engine_extract/snodas/extracts
# Copying gs://wudr/swe_2010_05.csv: Copying gs://wudr/swe_2010_05.csv...
# / [1 files][ 14.6 KiB/ 14.6 KiB]
# Operation completed over 1 objects/14.6 KiB.
#
# Copied gs://wudr/swe_2010_05.csv to /home/dgketchum/PycharmProjects/swim-rs/tutorial/step_2_earth_engine_extract/snodas/extracts
# Copying gs://wudr/swe_2010_06.csv: Copying gs://wudr/swe_2010_06.csv...
# / [1 files][ 10.2 KiB/ 10.2 KiB]
# Operation completed over 1 objects/10.2 KiB.
#
# Copied gs://wudr/swe_2010_06.csv to /home/dgketchum/PycharmProjects/swim-rs/tutorial/step_2_earth_engine_extract/snodas/extracts
# Copying gs://wudr/swe_2010_07.csv: Copying gs://wudr/swe_2010_07.csv...
# / [1 files][ 10.6 KiB/ 10.6 KiB]
# Operation completed over 1 objects/10.6 KiB.
#
# Copied gs://wudr/swe_2010_07.csv to /home/dgketchum/PycharmProjects/swim-rs/tutorial/step_2_earth_engine_extract/snodas/extracts
# Copying gs://wudr/swe_2010_08.csv: Copying gs://wudr/swe_2010_08.csv...
# / [1 files][ 10.6 KiB/ 10.6 KiB]
# Operation completed over 1 objects/10.6 KiB.
#
# Copied gs://wudr/swe_2010_08.csv to /home/dgketchum/PycharmProjects/swim-rs/tutorial/step_2_earth_engine_extract/snodas/extracts
# Copying gs://wudr/swe_2010_09.csv: Copying gs://wudr/swe_2010_09.csv...
# / [1 files][ 10.2 KiB/ 10.2 KiB]
# Operation completed over 1 objects/10.2 KiB.
#
# Copied gs://wudr/swe_2010_09.csv to /home/dgketchum/PycharmProjects/swim-rs/tutorial/step_2_earth_engine_extract/snodas/extracts
# Copying gs://wudr/swe_2010_10.csv: Copying gs://wudr/swe_2010_10.csv...
# / [1 files][ 10.6 KiB/ 10.6 KiB]
# Operation completed over 1 objects/10.6 KiB.
#
# Copied gs://wudr/swe_2010_10.csv to /home/dgketchum/PycharmProjects/swim-rs/tutorial/step_2_earth_engine_extract/snodas/extracts
# Copying gs://wudr/swe_2010_11.csv: Copying gs://wudr/swe_2010_11.csv...
# / [1 files][ 27.4 KiB/ 27.4 KiB]
# Operation completed over 1 objects/27.4 KiB.
#
# Copied gs://wudr/swe_2010_11.csv to /home/dgketchum/PycharmProjects/swim-rs/tutorial/step_2_earth_engine_extract/snodas/extracts
# Copying gs://wudr/swe_2010_12.csv: Copying gs://wudr/swe_2010_12.csv...
# / [1 files][ 50.1 KiB/ 50.1 KiB]
# Operation completed over 1 objects/50.1 KiB.
#
# Copied gs://wudr/swe_2010_12.csv to /home/dgketchum/PycharmProjects/swim-rs/tutorial/step_2_earth_engine_extract/snodas/extracts
# Copying gs://wudr/swe_2011_01.csv: Copying gs://wudr/swe_2011_01.csv...
# / [1 files][ 35.1 KiB/ 35.1 KiB]
# Operation completed over 1 objects/35.1 KiB.
#
# Copied gs://wudr/swe_2011_01.csv to /home/dgketchum/PycharmProjects/swim-rs/tutorial/step_2_earth_engine_extract/snodas/extracts
# Copying gs://wudr/swe_2011_02.csv: Copying gs://wudr/swe_2011_02.csv...
# / [1 files][ 35.3 KiB/ 35.3 KiB]
# Operation completed over 1 objects/35.3 KiB.
#
# Copied gs://wudr/swe_2011_02.csv to /home/dgketchum/PycharmProjects/swim-rs/tutorial/step_2_earth_engine_extract/snodas/extracts
# Copying gs://wudr/swe_2011_03.csv: Copying gs://wudr/swe_2011_03.csv...
# / [1 files][ 17.6 KiB/ 17.6 KiB]
# Operation completed over 1 objects/17.6 KiB.
#
# Copied gs://wudr/swe_2011_03.csv to /home/dgketchum/PycharmProjects/swim-rs/tutorial/step_2_earth_engine_extract/snodas/extracts
# Copying gs://wudr/swe_2011_04.csv: Copying gs://wudr/swe_2011_04.csv...
# / [1 files][ 22.1 KiB/ 22.1 KiB]
# Operation completed over 1 objects/22.1 KiB.
#
# Copied gs://wudr/swe_2011_04.csv to /home/dgketchum/PycharmProjects/swim-rs/tutorial/step_2_earth_engine_extract/snodas/extracts
# Copying gs://wudr/swe_2011_05.csv: Copying gs://wudr/swe_2011_05.csv...
# / [1 files][ 10.6 KiB/ 10.6 KiB]
# Operation completed over 1 objects/10.6 KiB.
#
# Copied gs://wudr/swe_2011_05.csv to /home/dgketchum/PycharmProjects/swim-rs/tutorial/step_2_earth_engine_extract/snodas/extracts
# Copying gs://wudr/swe_2011_06.csv: Copying gs://wudr/swe_2011_06.csv...
# / [1 files][ 10.2 KiB/ 10.2 KiB]
# Operation completed over 1 objects/10.2 KiB.
#
# Copied gs://wudr/swe_2011_06.csv to /home/dgketchum/PycharmProjects/swim-rs/tutorial/step_2_earth_engine_extract/snodas/extracts
# Copying gs://wudr/swe_2011_07.csv: Copying gs://wudr/swe_2011_07.csv...
# / [1 files][ 10.6 KiB/ 10.6 KiB]
# Operation completed over 1 objects/10.6 KiB.
#
# Copied gs://wudr/swe_2011_07.csv to /home/dgketchum/PycharmProjects/swim-rs/tutorial/step_2_earth_engine_extract/snodas/extracts
# Copying gs://wudr/swe_2011_08.csv: Copying gs://wudr/swe_2011_08.csv...
# / [1 files][ 10.6 KiB/ 10.6 KiB]
# Operation completed over 1 objects/10.6 KiB.
#
# Copied gs://wudr/swe_2011_08.csv to /home/dgketchum/PycharmProjects/swim-rs/tutorial/step_2_earth_engine_extract/snodas/extracts
# Copying gs://wudr/swe_2011_09.csv: Copying gs://wudr/swe_2011_09.csv...
# / [1 files][ 10.2 KiB/ 10.2 KiB]
# Operation completed over 1 objects/10.2 KiB.
#
# Copied gs://wudr/swe_2011_09.csv to /home/dgketchum/PycharmProjects/swim-rs/tutorial/step_2_earth_engine_extract/snodas/extracts
# Copying gs://wudr/swe_2011_10.csv: Copying gs://wudr/swe_2011_10.csv...
# / [1 files][ 10.6 KiB/ 10.6 KiB]
# Operation completed over 1 objects/10.6 KiB.
#
# Copied gs://wudr/swe_2011_10.csv to /home/dgketchum/PycharmProjects/swim-rs/tutorial/step_2_earth_engine_extract/snodas/extracts
# Copying gs://wudr/swe_2011_11.csv: Copying gs://wudr/swe_2011_11.csv...
# / [1 files][ 25.1 KiB/ 25.1 KiB]
# Operation completed over 1 objects/25.1 KiB.
#
# Copied gs://wudr/swe_2011_11.csv to /home/dgketchum/PycharmProjects/swim-rs/tutorial/step_2_earth_engine_extract/snodas/extracts
# Copying gs://wudr/swe_2011_12.csv: Copying gs://wudr/swe_2011_12.csv...
# / [1 files][ 28.3 KiB/ 28.3 KiB]
# Operation completed over 1 objects/28.3 KiB.
#
# Copied gs://wudr/swe_2011_12.csv to /home/dgketchum/PycharmProjects/swim-rs/tutorial/step_2_earth_engine_extract/snodas/extracts
# Copying gs://wudr/swe_2012_01.csv: Copying gs://wudr/swe_2012_01.csv...
# / [1 files][ 25.2 KiB/ 25.2 KiB]
# Operation completed over 1 objects/25.2 KiB.
#
# Copied gs://wudr/swe_2012_01.csv to /home/dgketchum/PycharmProjects/swim-rs/tutorial/step_2_earth_engine_extract/snodas/extracts
# Copying gs://wudr/swe_2012_02.csv: Copying gs://wudr/swe_2012_02.csv...
# / [1 files][ 37.8 KiB/ 37.8 KiB]
# Operation completed over 1 objects/37.8 KiB.
#
# Copied gs://wudr/swe_2012_02.csv to /home/dgketchum/PycharmProjects/swim-rs/tutorial/step_2_earth_engine_extract/snodas/extracts
# Copying gs://wudr/swe_2012_03.csv: Copying gs://wudr/swe_2012_03.csv...
# / [1 files][ 13.2 KiB/ 13.2 KiB]
# Operation completed over 1 objects/13.2 KiB.
#
# Copied gs://wudr/swe_2012_03.csv to /home/dgketchum/PycharmProjects/swim-rs/tutorial/step_2_earth_engine_extract/snodas/extracts
# Copying gs://wudr/swe_2012_04.csv: Copying gs://wudr/swe_2012_04.csv...
# / [1 files][ 13.8 KiB/ 13.8 KiB]
# Operation completed over 1 objects/13.8 KiB.
#
# Copied gs://wudr/swe_2012_04.csv to /home/dgketchum/PycharmProjects/swim-rs/tutorial/step_2_earth_engine_extract/snodas/extracts
# Copying gs://wudr/swe_2012_05.csv: Copying gs://wudr/swe_2012_05.csv...
# / [1 files][ 10.6 KiB/ 10.6 KiB]
# Operation completed over 1 objects/10.6 KiB.
#
# Copied gs://wudr/swe_2012_05.csv to /home/dgketchum/PycharmProjects/swim-rs/tutorial/step_2_earth_engine_extract/snodas/extracts
# Copying gs://wudr/swe_2012_06.csv: Copying gs://wudr/swe_2012_06.csv...
# / [1 files][ 10.2 KiB/ 10.2 KiB]
# Operation completed over 1 objects/10.2 KiB.
#
# Copied gs://wudr/swe_2012_06.csv to /home/dgketchum/PycharmProjects/swim-rs/tutorial/step_2_earth_engine_extract/snodas/extracts
# Copying gs://wudr/swe_2012_07.csv: Copying gs://wudr/swe_2012_07.csv...
# / [1 files][ 10.6 KiB/ 10.6 KiB]
# Operation completed over 1 objects/10.6 KiB.
#
# Copied gs://wudr/swe_2012_07.csv to /home/dgketchum/PycharmProjects/swim-rs/tutorial/step_2_earth_engine_extract/snodas/extracts
# Copying gs://wudr/swe_2012_08.csv: Copying gs://wudr/swe_2012_08.csv...
# / [1 files][ 10.6 KiB/ 10.6 KiB]
# Operation completed over 1 objects/10.6 KiB.
#
# Copied gs://wudr/swe_2012_08.csv to /home/dgketchum/PycharmProjects/swim-rs/tutorial/step_2_earth_engine_extract/snodas/extracts
# Copying gs://wudr/swe_2012_09.csv: Copying gs://wudr/swe_2012_09.csv...
# / [1 files][ 10.2 KiB/ 10.2 KiB]
# Operation completed over 1 objects/10.2 KiB.
#
# Copied gs://wudr/swe_2012_09.csv to /home/dgketchum/PycharmProjects/swim-rs/tutorial/step_2_earth_engine_extract/snodas/extracts
# Copying gs://wudr/swe_2012_10.csv: Copying gs://wudr/swe_2012_10.csv...
# / [1 files][ 18.4 KiB/ 18.4 KiB]
# Operation completed over 1 objects/18.4 KiB.
#
# Copied gs://wudr/swe_2012_10.csv to /home/dgketchum/PycharmProjects/swim-rs/tutorial/step_2_earth_engine_extract/snodas/extracts
# Copying gs://wudr/swe_2012_11.csv: Copying gs://wudr/swe_2012_11.csv...
# / [1 files][ 25.7 KiB/ 25.7 KiB]
# Operation completed over 1 objects/25.7 KiB.
#
# Copied gs://wudr/swe_2012_11.csv to /home/dgketchum/PycharmProjects/swim-rs/tutorial/step_2_earth_engine_extract/snodas/extracts
# Copying gs://wudr/swe_2012_12.csv: Copying gs://wudr/swe_2012_12.csv...
# / [1 files][ 36.3 KiB/ 36.3 KiB]
# Operation completed over 1 objects/36.3 KiB.
#
# Copied gs://wudr/swe_2012_12.csv to /home/dgketchum/PycharmProjects/swim-rs/tutorial/step_2_earth_engine_extract/snodas/extracts
# Copying gs://wudr/swe_2013_01.csv: Copying gs://wudr/swe_2013_01.csv...
# / [1 files][ 36.1 KiB/ 36.1 KiB]
# Operation completed over 1 objects/36.1 KiB.
#
# Copied gs://wudr/swe_2013_01.csv to /home/dgketchum/PycharmProjects/swim-rs/tutorial/step_2_earth_engine_extract/snodas/extracts
# Copying gs://wudr/swe_2013_02.csv: Copying gs://wudr/swe_2013_02.csv...
# / [1 files][ 19.0 KiB/ 19.0 KiB]
# Operation completed over 1 objects/19.0 KiB.
#
# Copied gs://wudr/swe_2013_02.csv to /home/dgketchum/PycharmProjects/swim-rs/tutorial/step_2_earth_engine_extract/snodas/extracts
# Copying gs://wudr/swe_2013_03.csv: Copying gs://wudr/swe_2013_03.csv...
# / [1 files][ 19.2 KiB/ 19.2 KiB]
# Operation completed over 1 objects/19.2 KiB.
#
# Copied gs://wudr/swe_2013_03.csv to /home/dgketchum/PycharmProjects/swim-rs/tutorial/step_2_earth_engine_extract/snodas/extracts
# Copying gs://wudr/swe_2013_04.csv: Copying gs://wudr/swe_2013_04.csv...
# / [1 files][ 19.4 KiB/ 19.4 KiB]
# Operation completed over 1 objects/19.4 KiB.
#
# Copied gs://wudr/swe_2013_04.csv to /home/dgketchum/PycharmProjects/swim-rs/tutorial/step_2_earth_engine_extract/snodas/extracts
# Copying gs://wudr/swe_2013_05.csv: Copying gs://wudr/swe_2013_05.csv...
# / [1 files][ 11.9 KiB/ 11.9 KiB]
# Operation completed over 1 objects/11.9 KiB.
#
# Copied gs://wudr/swe_2013_05.csv to /home/dgketchum/PycharmProjects/swim-rs/tutorial/step_2_earth_engine_extract/snodas/extracts
# Copying gs://wudr/swe_2013_06.csv: Copying gs://wudr/swe_2013_06.csv...
# / [1 files][ 10.2 KiB/ 10.2 KiB]
# Operation completed over 1 objects/10.2 KiB.
#
# Copied gs://wudr/swe_2013_06.csv to /home/dgketchum/PycharmProjects/swim-rs/tutorial/step_2_earth_engine_extract/snodas/extracts
# Copying gs://wudr/swe_2013_07.csv: Copying gs://wudr/swe_2013_07.csv...
# / [1 files][ 10.6 KiB/ 10.6 KiB]
# Operation completed over 1 objects/10.6 KiB.
#
# Copied gs://wudr/swe_2013_07.csv to /home/dgketchum/PycharmProjects/swim-rs/tutorial/step_2_earth_engine_extract/snodas/extracts
# Copying gs://wudr/swe_2013_08.csv: Copying gs://wudr/swe_2013_08.csv...
# / [1 files][ 10.6 KiB/ 10.6 KiB]
# Operation completed over 1 objects/10.6 KiB.
#
# Copied gs://wudr/swe_2013_08.csv to /home/dgketchum/PycharmProjects/swim-rs/tutorial/step_2_earth_engine_extract/snodas/extracts
# Copying gs://wudr/swe_2013_09.csv: Copying gs://wudr/swe_2013_09.csv...
# / [1 files][ 10.2 KiB/ 10.2 KiB]
# Operation completed over 1 objects/10.2 KiB.
#
# Copied gs://wudr/swe_2013_09.csv to /home/dgketchum/PycharmProjects/swim-rs/tutorial/step_2_earth_engine_extract/snodas/extracts
# Copying gs://wudr/swe_2013_10.csv: Copying gs://wudr/swe_2013_10.csv...
# / [1 files][ 17.3 KiB/ 17.3 KiB]
# Operation completed over 1 objects/17.3 KiB.
#
# Copied gs://wudr/swe_2013_10.csv to /home/dgketchum/PycharmProjects/swim-rs/tutorial/step_2_earth_engine_extract/snodas/extracts
# Copying gs://wudr/swe_2013_11.csv: Copying gs://wudr/swe_2013_11.csv...
# / [1 files][ 23.0 KiB/ 23.0 KiB]
# Operation completed over 1 objects/23.0 KiB.
#
# Copied gs://wudr/swe_2013_11.csv to /home/dgketchum/PycharmProjects/swim-rs/tutorial/step_2_earth_engine_extract/snodas/extracts
# Copying gs://wudr/swe_2013_12.csv: Copying gs://wudr/swe_2013_12.csv...
# / [1 files][ 39.1 KiB/ 39.1 KiB]
# Operation completed over 1 objects/39.1 KiB.
#
# Copied gs://wudr/swe_2013_12.csv to /home/dgketchum/PycharmProjects/swim-rs/tutorial/step_2_earth_engine_extract/snodas/extracts
# Copying gs://wudr/swe_2014_01.csv: Copying gs://wudr/swe_2014_01.csv...
# / [1 files][ 25.1 KiB/ 25.1 KiB]
# Operation completed over 1 objects/25.1 KiB.
#
# Copied gs://wudr/swe_2014_01.csv to /home/dgketchum/PycharmProjects/swim-rs/tutorial/step_2_earth_engine_extract/snodas/extracts
# Copying gs://wudr/swe_2014_02.csv: Copying gs://wudr/swe_2014_02.csv...
# / [1 files][ 38.9 KiB/ 38.9 KiB]
# Operation completed over 1 objects/38.9 KiB.
#
# Copied gs://wudr/swe_2014_02.csv to /home/dgketchum/PycharmProjects/swim-rs/tutorial/step_2_earth_engine_extract/snodas/extracts
# Copying gs://wudr/swe_2014_03.csv: Copying gs://wudr/swe_2014_03.csv...
# / [1 files][ 25.1 KiB/ 25.1 KiB]
# Operation completed over 1 objects/25.1 KiB.
#
# Copied gs://wudr/swe_2014_03.csv to /home/dgketchum/PycharmProjects/swim-rs/tutorial/step_2_earth_engine_extract/snodas/extracts
# Copying gs://wudr/swe_2014_04.csv: Copying gs://wudr/swe_2014_04.csv...
# / [1 files][ 11.6 KiB/ 11.6 KiB]
# Operation completed over 1 objects/11.6 KiB.
#
# Copied gs://wudr/swe_2014_04.csv to /home/dgketchum/PycharmProjects/swim-rs/tutorial/step_2_earth_engine_extract/snodas/extracts
# Copying gs://wudr/swe_2014_05.csv: Copying gs://wudr/swe_2014_05.csv...
# / [1 files][ 10.6 KiB/ 10.6 KiB]
# Operation completed over 1 objects/10.6 KiB.
#
# Copied gs://wudr/swe_2014_05.csv to /home/dgketchum/PycharmProjects/swim-rs/tutorial/step_2_earth_engine_extract/snodas/extracts
# Copying gs://wudr/swe_2014_06.csv: Copying gs://wudr/swe_2014_06.csv...
# / [1 files][ 10.2 KiB/ 10.2 KiB]
# Operation completed over 1 objects/10.2 KiB.
#
# Copied gs://wudr/swe_2014_06.csv to /home/dgketchum/PycharmProjects/swim-rs/tutorial/step_2_earth_engine_extract/snodas/extracts
# Copying gs://wudr/swe_2014_07.csv: Copying gs://wudr/swe_2014_07.csv...
# / [1 files][ 10.6 KiB/ 10.6 KiB]
# Operation completed over 1 objects/10.6 KiB.
#
# Copied gs://wudr/swe_2014_07.csv to /home/dgketchum/PycharmProjects/swim-rs/tutorial/step_2_earth_engine_extract/snodas/extracts
# Copying gs://wudr/swe_2014_08.csv: Copying gs://wudr/swe_2014_08.csv...
# / [1 files][ 10.6 KiB/ 10.6 KiB]
# Operation completed over 1 objects/10.6 KiB.
#
# Copied gs://wudr/swe_2014_08.csv to /home/dgketchum/PycharmProjects/swim-rs/tutorial/step_2_earth_engine_extract/snodas/extracts
# Copying gs://wudr/swe_2014_09.csv: Copying gs://wudr/swe_2014_09.csv...
# / [1 files][ 10.2 KiB/ 10.2 KiB]
# Operation completed over 1 objects/10.2 KiB.
#
# Copied gs://wudr/swe_2014_09.csv to /home/dgketchum/PycharmProjects/swim-rs/tutorial/step_2_earth_engine_extract/snodas/extracts
# Copying gs://wudr/swe_2014_10.csv: Copying gs://wudr/swe_2014_10.csv...
# / [1 files][ 10.6 KiB/ 10.6 KiB]
# Operation completed over 1 objects/10.6 KiB.
#
# Copied gs://wudr/swe_2014_10.csv to /home/dgketchum/PycharmProjects/swim-rs/tutorial/step_2_earth_engine_extract/snodas/extracts
# Copying gs://wudr/swe_2014_11.csv: Copying gs://wudr/swe_2014_11.csv...
# / [1 files][ 29.7 KiB/ 29.7 KiB]
# Operation completed over 1 objects/29.7 KiB.
#
# Copied gs://wudr/swe_2014_11.csv to /home/dgketchum/PycharmProjects/swim-rs/tutorial/step_2_earth_engine_extract/snodas/extracts
# Copying gs://wudr/swe_2014_12.csv: Copying gs://wudr/swe_2014_12.csv...
# / [1 files][ 46.3 KiB/ 46.3 KiB]
# ...
# / [1 files][ 10.6 KiB/ 10.6 KiB]
# Operation completed over 1 objects/10.6 KiB.
#
# Copied gs://wudr/swe_2020_05.csv to /home/dgketchum/PycharmProjects/swim-rs/tutorial/step_2_earth_engine_extract/snodas/extracts
# Copying gs://wudr/swe_2020_06.csv: Copying gs://wudr/swe_2020_06.csv...
# / [1 files][ 10.2 KiB/ 10.2 KiB]
# Operation completed over 1 objects/10.2 KiB.
#
# Copied gs://wudr/swe_2020_06.csv to /home/dgketchum/PycharmProjects/swim-rs/tutorial/step_2_earth_engine_extract/snodas/extracts
# Copying gs://wudr/swe_2020_07.csv: Copying gs://wudr/swe_2020_07.csv...
# / [1 files][ 10.6 KiB/ 10.6 KiB]
# Operation completed over 1 objects/10.6 KiB.
#
# Copied gs://wudr/swe_2020_07.csv to /home/dgketchum/PycharmProjects/swim-rs/tutorial/step_2_earth_engine_extract/snodas/extracts
# Copying gs://wudr/swe_2020_08.csv: Copying gs://wudr/swe_2020_08.csv...
# / [1 files][ 10.6 KiB/ 10.6 KiB]
# Operation completed over 1 objects/10.6 KiB.
#
# Copied gs://wudr/swe_2020_08.csv to /home/dgketchum/PycharmProjects/swim-rs/tutorial/step_2_earth_engine_extract/snodas/extracts
# Copying gs://wudr/swe_2020_09.csv: Copying gs://wudr/swe_2020_09.csv...
# / [1 files][ 10.2 KiB/ 10.2 KiB]
# Operation completed over 1 objects/10.2 KiB.
#
# Copied gs://wudr/swe_2020_09.csv to /home/dgketchum/PycharmProjects/swim-rs/tutorial/step_2_earth_engine_extract/snodas/extracts
# Copying gs://wudr/swe_2020_10.csv: Copying gs://wudr/swe_2020_10.csv...
# / [1 files][ 22.1 KiB/ 22.1 KiB]
# Operation completed over 1 objects/22.1 KiB.
#
# Copied gs://wudr/swe_2020_10.csv to /home/dgketchum/PycharmProjects/swim-rs/tutorial/step_2_earth_engine_extract/snodas/extracts
# Copying gs://wudr/swe_2020_11.csv: Copying gs://wudr/swe_2020_11.csv...
# / [1 files][ 19.6 KiB/ 19.6 KiB]
# Operation completed over 1 objects/19.6 KiB.
#
# Copied gs://wudr/swe_2020_11.csv to /home/dgketchum/PycharmProjects/swim-rs/tutorial/step_2_earth_engine_extract/snodas/extracts
# Copying gs://wudr/swe_2020_12.csv: Copying gs://wudr/swe_2020_12.csv...
# / [1 files][ 27.2 KiB/ 27.2 KiB]
# Operation completed over 1 objects/27.2 KiB.
#
# Copied gs://wudr/swe_2020_12.csv to /home/dgketchum/PycharmProjects/swim-rs/tutorial/step_2_earth_engine_extract/snodas/extracts
# Copying gs://wudr/swe_2021_01.csv: Copying gs://wudr/swe_2021_01.csv...
# / [1 files][ 17.6 KiB/ 17.6 KiB]
# Operation completed over 1 objects/17.6 KiB.
#
# Copied gs://wudr/swe_2021_01.csv to /home/dgketchum/PycharmProjects/swim-rs/tutorial/step_2_earth_engine_extract/snodas/extracts
# Copying gs://wudr/swe_2021_02.csv: Copying gs://wudr/swe_2021_02.csv...
# / [1 files][ 32.9 KiB/ 32.9 KiB]
# Operation completed over 1 objects/32.9 KiB.
#
# Copied gs://wudr/swe_2021_02.csv to /home/dgketchum/PycharmProjects/swim-rs/tutorial/step_2_earth_engine_extract/snodas/extracts
# Copying gs://wudr/swe_2021_03.csv: Copying gs://wudr/swe_2021_03.csv...
# / [1 files][ 14.6 KiB/ 14.6 KiB]
# Operation completed over 1 objects/14.6 KiB.
#
# Copied gs://wudr/swe_2021_03.csv to /home/dgketchum/PycharmProjects/swim-rs/tutorial/step_2_earth_engine_extract/snodas/extracts
# Copying gs://wudr/swe_2021_04.csv: Copying gs://wudr/swe_2021_04.csv...
# / [1 files][ 15.5 KiB/ 15.5 KiB]
# Operation completed over 1 objects/15.5 KiB.
#
# Copied gs://wudr/swe_2021_04.csv to /home/dgketchum/PycharmProjects/swim-rs/tutorial/step_2_earth_engine_extract/snodas/extracts
# Copying gs://wudr/swe_2021_05.csv: Copying gs://wudr/swe_2021_05.csv...
# / [1 files][ 15.8 KiB/ 15.8 KiB]
# Operation completed over 1 objects/15.8 KiB.
#
# Copied gs://wudr/swe_2021_05.csv to /home/dgketchum/PycharmProjects/swim-rs/tutorial/step_2_earth_engine_extract/snodas/extracts
# Copying gs://wudr/swe_2021_06.csv: Copying gs://wudr/swe_2021_06.csv...
# / [1 files][ 10.2 KiB/ 10.2 KiB]
# Operation completed over 1 objects/10.2 KiB.
#
# Copied gs://wudr/swe_2021_06.csv to /home/dgketchum/PycharmProjects/swim-rs/tutorial/step_2_earth_engine_extract/snodas/extracts
# Copying gs://wudr/swe_2021_07.csv: Copying gs://wudr/swe_2021_07.csv...
# / [1 files][ 10.6 KiB/ 10.6 KiB]
# Operation completed over 1 objects/10.6 KiB.
#
# Copied gs://wudr/swe_2021_07.csv to /home/dgketchum/PycharmProjects/swim-rs/tutorial/step_2_earth_engine_extract/snodas/extracts
# Copying gs://wudr/swe_2021_08.csv: Copying gs://wudr/swe_2021_08.csv...
# / [1 files][ 10.6 KiB/ 10.6 KiB]
# Operation completed over 1 objects/10.6 KiB.
#
# Copied gs://wudr/swe_2021_08.csv to /home/dgketchum/PycharmProjects/swim-rs/tutorial/step_2_earth_engine_extract/snodas/extracts
# Copying gs://wudr/swe_2021_09.csv: Copying gs://wudr/swe_2021_09.csv...
# / [1 files][ 10.2 KiB/ 10.2 KiB]
# Operation completed over 1 objects/10.2 KiB.
#
# Copied gs://wudr/swe_2021_09.csv to /home/dgketchum/PycharmProjects/swim-rs/tutorial/step_2_earth_engine_extract/snodas/extracts
# Copying gs://wudr/swe_2021_10.csv: Copying gs://wudr/swe_2021_10.csv...
# / [1 files][ 15.8 KiB/ 15.8 KiB]
# Operation completed over 1 objects/15.8 KiB.
#
# Copied gs://wudr/swe_2021_10.csv to /home/dgketchum/PycharmProjects/swim-rs/tutorial/step_2_earth_engine_extract/snodas/extracts
# Copying gs://wudr/swe_2021_11.csv: Copying gs://wudr/swe_2021_11.csv...
# / [1 files][ 11.8 KiB/ 11.8 KiB]
# Operation completed over 1 objects/11.8 KiB.
#
# Copied gs://wudr/swe_2021_11.csv to /home/dgketchum/PycharmProjects/swim-rs/tutorial/step_2_earth_engine_extract/snodas/extracts
# Copying gs://wudr/swe_2021_12.csv: Copying gs://wudr/swe_2021_12.csv...
# / [1 files][ 24.0 KiB/ 24.0 KiB]
# Operation completed over 1 objects/24.0 KiB.
#
# Copied gs://wudr/swe_2021_12.csv to /home/dgketchum/PycharmProjects/swim-rs/tutorial/step_2_earth_engine_extract/snodas/extracts
# Copying gs://wudr/swe_2022_01.csv: Copying gs://wudr/swe_2022_01.csv...
# / [1 files][ 49.8 KiB/ 49.8 KiB]
# Operation completed over 1 objects/49.8 KiB.
#
# Copied gs://wudr/swe_2022_01.csv to /home/dgketchum/PycharmProjects/swim-rs/tutorial/step_2_earth_engine_extract/snodas/extracts
# Copying gs://wudr/swe_2022_02.csv: Copying gs://wudr/swe_2022_02.csv...
# / [1 files][ 37.2 KiB/ 37.2 KiB]
# Operation completed over 1 objects/37.2 KiB.
#
# Copied gs://wudr/swe_2022_02.csv to /home/dgketchum/PycharmProjects/swim-rs/tutorial/step_2_earth_engine_extract/snodas/extracts
# Copying gs://wudr/swe_2022_03.csv: Copying gs://wudr/swe_2022_03.csv...
# / [1 files][ 11.5 KiB/ 11.5 KiB]
# Operation completed over 1 objects/11.5 KiB.
#
# Copied gs://wudr/swe_2022_03.csv to /home/dgketchum/PycharmProjects/swim-rs/tutorial/step_2_earth_engine_extract/snodas/extracts
# Copying gs://wudr/swe_2022_04.csv: Copying gs://wudr/swe_2022_04.csv...
# / [1 files][ 20.4 KiB/ 20.4 KiB]
# Operation completed over 1 objects/20.4 KiB.
#
# Copied gs://wudr/swe_2022_04.csv to /home/dgketchum/PycharmProjects/swim-rs/tutorial/step_2_earth_engine_extract/snodas/extracts
# Copying gs://wudr/swe_2022_05.csv: Copying gs://wudr/swe_2022_05.csv...
# / [1 files][ 10.6 KiB/ 10.6 KiB]
# Operation completed over 1 objects/10.6 KiB.
#
# Copied gs://wudr/swe_2022_05.csv to /home/dgketchum/PycharmProjects/swim-rs/tutorial/step_2_earth_engine_extract/snodas/extracts
# Copying gs://wudr/swe_2022_06.csv: Copying gs://wudr/swe_2022_06.csv...
# / [1 files][ 10.2 KiB/ 10.2 KiB]
# Operation completed over 1 objects/10.2 KiB.
#
# Copied gs://wudr/swe_2022_06.csv to /home/dgketchum/PycharmProjects/swim-rs/tutorial/step_2_earth_engine_extract/snodas/extracts
# Copying gs://wudr/swe_2022_07.csv: Copying gs://wudr/swe_2022_07.csv...
# / [1 files][ 10.6 KiB/ 10.6 KiB]
# Operation completed over 1 objects/10.6 KiB.
#
# Copied gs://wudr/swe_2022_07.csv to /home/dgketchum/PycharmProjects/swim-rs/tutorial/step_2_earth_engine_extract/snodas/extracts
# Copying gs://wudr/swe_2022_08.csv: Copying gs://wudr/swe_2022_08.csv...
# / [1 files][ 10.6 KiB/ 10.6 KiB]
# Operation completed over 1 objects/10.6 KiB.
#
# Copied gs://wudr/swe_2022_08.csv to /home/dgketchum/PycharmProjects/swim-rs/tutorial/step_2_earth_engine_extract/snodas/extracts
# Copying gs://wudr/swe_2022_09.csv: Copying gs://wudr/swe_2022_09.csv...
# / [1 files][ 10.2 KiB/ 10.2 KiB]
# Operation completed over 1 objects/10.2 KiB.
#
# Copied gs://wudr/swe_2022_09.csv to /home/dgketchum/PycharmProjects/swim-rs/tutorial/step_2_earth_engine_extract/snodas/extracts
# Copying gs://wudr/swe_2022_10.csv: Copying gs://wudr/swe_2022_10.csv...
# / [1 files][ 12.5 KiB/ 12.5 KiB]
# Operation completed over 1 objects/12.5 KiB.
#
# Copied gs://wudr/swe_2022_10.csv to /home/dgketchum/PycharmProjects/swim-rs/tutorial/step_2_earth_engine_extract/snodas/extracts
# Copying gs://wudr/swe_2022_11.csv: Copying gs://wudr/swe_2022_11.csv...
# / [1 files][ 39.9 KiB/ 39.9 KiB]
# Operation completed over 1 objects/39.9 KiB.
#
# Copied gs://wudr/swe_2022_11.csv to /home/dgketchum/PycharmProjects/swim-rs/tutorial/step_2_earth_engine_extract/snodas/extracts
# Copying gs://wudr/swe_2022_12.csv: Copying gs://wudr/swe_2022_12.csv...
# / [1 files][ 46.2 KiB/ 46.2 KiB]
# Operation completed over 1 objects/46.2 KiB.
#
# Copied gs://wudr/swe_2022_12.csv to /home/dgketchum/PycharmProjects/swim-rs/tutorial/step_2_earth_engine_extract/snodas/extracts
# Copying gs://wudr/swe_2023_01.csv: Copying gs://wudr/swe_2023_01.csv...
# / [1 files][ 17.0 KiB/ 17.0 KiB]
# Operation completed over 1 objects/17.0 KiB.
#
# Copied gs://wudr/swe_2023_01.csv to /home/dgketchum/PycharmProjects/swim-rs/tutorial/step_2_earth_engine_extract/snodas/extracts
# Copying gs://wudr/swe_2023_02.csv: Copying gs://wudr/swe_2023_02.csv...
# / [1 files][ 12.0 KiB/ 12.0 KiB]
# Operation completed over 1 objects/12.0 KiB.
#
# Copied gs://wudr/swe_2023_02.csv to /home/dgketchum/PycharmProjects/swim-rs/tutorial/step_2_earth_engine_extract/snodas/extracts
# Copying gs://wudr/swe_2023_03.csv: Copying gs://wudr/swe_2023_03.csv...
# / [1 files][ 33.2 KiB/ 33.2 KiB]
# Operation completed over 1 objects/33.2 KiB.
#
# Copied gs://wudr/swe_2023_03.csv to /home/dgketchum/PycharmProjects/swim-rs/tutorial/step_2_earth_engine_extract/snodas/extracts
# Copying gs://wudr/swe_2023_04.csv: Copying gs://wudr/swe_2023_04.csv...
# / [1 files][ 20.2 KiB/ 20.2 KiB]
# Operation completed over 1 objects/20.2 KiB.
#
# Copied gs://wudr/swe_2023_04.csv to /home/dgketchum/PycharmProjects/swim-rs/tutorial/step_2_earth_engine_extract/snodas/extracts
# Copying gs://wudr/swe_2023_05.csv: Copying gs://wudr/swe_2023_05.csv...
# / [1 files][ 10.6 KiB/ 10.6 KiB]
# Operation completed over 1 objects/10.6 KiB.
#
# Copied gs://wudr/swe_2023_05.csv to /home/dgketchum/PycharmProjects/swim-rs/tutorial/step_2_earth_engine_extract/snodas/extracts
# Copying gs://wudr/swe_2023_06.csv: Copying gs://wudr/swe_2023_06.csv...
# / [1 files][ 10.2 KiB/ 10.2 KiB]
# Operation completed over 1 objects/10.2 KiB.
#
# Copied gs://wudr/swe_2023_06.csv to /home/dgketchum/PycharmProjects/swim-rs/tutorial/step_2_earth_engine_extract/snodas/extracts
# Copying gs://wudr/swe_2023_07.csv: Copying gs://wudr/swe_2023_07.csv...
# / [1 files][ 10.6 KiB/ 10.6 KiB]
# Operation completed over 1 objects/10.6 KiB.
#
# Copied gs://wudr/swe_2023_07.csv to /home/dgketchum/PycharmProjects/swim-rs/tutorial/step_2_earth_engine_extract/snodas/extracts
# Copying gs://wudr/swe_2023_08.csv: Copying gs://wudr/swe_2023_08.csv...
# / [1 files][ 10.6 KiB/ 10.6 KiB]
# Operation completed over 1 objects/10.6 KiB.
#
# Copied gs://wudr/swe_2023_08.csv to /home/dgketchum/PycharmProjects/swim-rs/tutorial/step_2_earth_engine_extract/snodas/extracts
# Copying gs://wudr/swe_2023_09.csv: Copying gs://wudr/swe_2023_09.csv...
# / [1 files][ 10.2 KiB/ 10.2 KiB]
# Operation completed over 1 objects/10.2 KiB.
#
# Copied gs://wudr/swe_2023_09.csv to /home/dgketchum/PycharmProjects/swim-rs/tutorial/step_2_earth_engine_extract/snodas/extracts
# Copying gs://wudr/swe_2023_10.csv: Copying gs://wudr/swe_2023_10.csv...
# / [1 files][ 18.0 KiB/ 18.0 KiB]
# Operation completed over 1 objects/18.0 KiB.
#
# Copied gs://wudr/swe_2023_10.csv to /home/dgketchum/PycharmProjects/swim-rs/tutorial/step_2_earth_engine_extract/snodas/extracts
# Copying gs://wudr/swe_2023_11.csv: Copying gs://wudr/swe_2023_11.csv...
# / [1 files][ 25.8 KiB/ 25.8 KiB]
# Operation completed over 1 objects/25.8 KiB.
#
# Copied gs://wudr/swe_2023_11.csv to /home/dgketchum/PycharmProjects/swim-rs/tutorial/step_2_earth_engine_extract/snodas/extracts
# Copying gs://wudr/swe_2023_12.csv: Copying gs://wudr/swe_2023_12.csv...
# / [1 files][ 16.2 KiB/ 16.2 KiB]
# Operation completed over 1 objects/16.2 KiB.
#
# Copied gs://wudr/swe_2023_12.csv to /home/dgketchum/PycharmProjects/swim-rs/tutorial/step_2_earth_engine_extract/snodas/extracts

# %% [markdown]
# We will go ahead and convert the month-by-month files to a per-field daily time series of SWE that we will need in Step 4.

# %%
snow_out = os.path.join(root, 'tutorials/1_Boulder/data/snodas/snodas.json')
create_timeseries_json(snow_dst, snow_out, feature_id='FID_1')

# %% [markdown]
# ### Irrigation Data
#
# Notes
# - This will produce an annual dataset of the IrrMapper-estimated irrigated fraction for each sample plot.

# %%
description = 'tutorial_irr'
get_irrigation(fields, description, debug=False, selector=FEATURE_ID)

# %%
dst = os.path.join(root, 'tutorials', '1_Boulder', 'data', 'properties')
list_and_copy_gcs_bucket(command, bucket, dst, glob=description, dry_run=False, overwrite=True)

# %% [markdown]
# ### Soils Data
#
# Notes
# - This will produce an single dataset of the SSURGO-estimated soil properties fraction for each sample plot.

# %%
description = 'tutorial_ssurgo'
get_ssurgo(fields, description, debug=False, selector=FEATURE_ID)
# Out:
# tutorial_ssurgo

# %%
dst = os.path.join(root, 'tutorials', '1_Boulder', 'data', 'properties')
list_and_copy_gcs_bucket(command, bucket, dst, glob=description, dry_run=False, overwrite=False)
